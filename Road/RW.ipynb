# %%
import pandas as pd 

data = pd.read_csv('/Users/mac2/Visual Studio Code/ROADWATCH/Road/message.csv')

data
# Out:
#             id                       date     sender_id  \
# 0      1705274  2024-11-01 12:53:19+00:00  6.415259e+09
# 1      1705273  2024-11-01 12:52:29+00:00  6.415259e+09
# 2      1705272  2024-11-01 12:48:24+00:00  6.415259e+09
# 3      1705271  2024-11-01 12:44:55+00:00  6.415259e+09
# 4      1705270  2024-11-01 12:39:22+00:00  6.415259e+09
# ...        ...                        ...           ...
# 24606  1153328  2023-09-26 12:40:50+00:00  6.207386e+09
# 24607  1125498  2023-09-15 20:52:33+00:00  6.117278e+09
# 24608  1096774  2023-09-07 14:29:37+00:00  6.207386e+09
# 24609   568836  2023-04-13 19:37:30+00:00  5.970923e+09
# 24610   568834  2023-04-13 19:36:50+00:00  5.970923e+09
#
#                                                  message
# 0                                     شرطه نازله من عيلي
# 1                   حادث سير بعد اشارات شيلو باتجاه عيلي
# 2                     المنشية تواجد جيش مع شرطة ومخالفات
# 3      الرجاء من كل شخص بقرا التقرير يكبس ❤️ أو 👍\n\n...
# 4                  تم فتح حاجز عناب الان بالاتجاهين ✅✅✅✅
# ...                                                  ...
# 24606                                                NaN
# 24607                                                NaN
# 24608                                                NaN
# 24609  🚌ارقام مجمعات تكاسي بين المدن::::\n📞رقم كراجات...
# 24610  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
#
# [24611 rows x 4 columns]

# %%
import re
def remove_emojis(text):
    if isinstance(text, str):
        return re.sub(r'[^\w\s,.!?؛:\n]', '', text)
    return text

data['message'] = data['message'].apply(remove_emojis)

data
# Out:
#             id                       date     sender_id  \
# 0      1705274  2024-11-01 12:53:19+00:00  6.415259e+09
# 1      1705273  2024-11-01 12:52:29+00:00  6.415259e+09
# 2      1705272  2024-11-01 12:48:24+00:00  6.415259e+09
# 3      1705271  2024-11-01 12:44:55+00:00  6.415259e+09
# 4      1705270  2024-11-01 12:39:22+00:00  6.415259e+09
# ...        ...                        ...           ...
# 24606  1153328  2023-09-26 12:40:50+00:00  6.207386e+09
# 24607  1125498  2023-09-15 20:52:33+00:00  6.117278e+09
# 24608  1096774  2023-09-07 14:29:37+00:00  6.207386e+09
# 24609   568836  2023-04-13 19:37:30+00:00  5.970923e+09
# 24610   568834  2023-04-13 19:36:50+00:00  5.970923e+09
#
#                                                  message
# 0                                     شرطه نازله من عيلي
# 1                   حادث سير بعد اشارات شيلو باتجاه عيلي
# 2                     المنشية تواجد جيش مع شرطة ومخالفات
# 3      الرجاء من كل شخص بقرا التقرير يكبس  أو \n\nتفا...
# 4                      تم فتح حاجز عناب الان بالاتجاهين
# ...                                                  ...
# 24606                                                NaN
# 24607                                                NaN
# 24608                                                NaN
# 24609  ارقام مجمعات تكاسي بين المدن::::\nرقم كراجات ن...
# 24610  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
#
# [24611 rows x 4 columns]

# %%
def remove_jargon(data, jargon_terms):
      def clean_message(message):
        pattern = re.compile(r'\b(' + '|'.join(re.escape(term) for term in jargon_terms) + r')\b', re.IGNORECASE)
        return pattern.sub('', message)

        data['message'] = data['message'].apply(clean_message)

        data['message'] = data['message'].str.strip().replace(r'\s+', ' ', regex=True)
      return data

data
# Out:
#             id                       date     sender_id  \
# 0      1705274  2024-11-01 12:53:19+00:00  6.415259e+09
# 1      1705273  2024-11-01 12:52:29+00:00  6.415259e+09
# 2      1705272  2024-11-01 12:48:24+00:00  6.415259e+09
# 3      1705271  2024-11-01 12:44:55+00:00  6.415259e+09
# 4      1705270  2024-11-01 12:39:22+00:00  6.415259e+09
# ...        ...                        ...           ...
# 24606  1153328  2023-09-26 12:40:50+00:00  6.207386e+09
# 24607  1125498  2023-09-15 20:52:33+00:00  6.117278e+09
# 24608  1096774  2023-09-07 14:29:37+00:00  6.207386e+09
# 24609   568836  2023-04-13 19:37:30+00:00  5.970923e+09
# 24610   568834  2023-04-13 19:36:50+00:00  5.970923e+09
#
#                                                  message
# 0                                     شرطه نازله من عيلي
# 1                   حادث سير بعد اشارات شيلو باتجاه عيلي
# 2                     المنشية تواجد جيش مع شرطة ومخالفات
# 3      الرجاء من كل شخص بقرا التقرير يكبس  أو \n\nتفا...
# 4                      تم فتح حاجز عناب الان بالاتجاهين
# ...                                                  ...
# 24606                                                NaN
# 24607                                                NaN
# 24608                                                NaN
# 24609  ارقام مجمعات تكاسي بين المدن::::\nرقم كراجات ن...
# 24610  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
#
# [24611 rows x 4 columns]

# %%
print(data['message'].isnull().sum())
# Out:
# 977

# %%
data.dropna(subset=['message'], inplace=True)

# %%
print(data['message'].isnull().sum())
# Out:
# 0

# %%
for index, message in enumerate(data['message']):
    if not isinstance(message, str):
        print(f"Row {index}: {message} (Type: {type(message)})")

# %%
data = data[data['message'].apply(lambda x: isinstance(x, str))]

# %%
def regex_tokenize(data):
    sentence_splitter = re.compile(r'(?<=[.!?]) +')
    word_splitter = re.compile(r'[\u0600-\u06FF]+|\d+|\w+')

    sentences_list = []
    words_list = []
    original_messages = []
    word_indices = []
    sentence_count = 1

    for index, message in data['message'].items():
        if isinstance(message, str):
            sentences = sentence_splitter.split(message.strip())
            for sentence in sentences:
                words = word_splitter.findall(sentence)
                for word_index, word in enumerate(words):
                    sentences_list.append(f"Sentence: {sentence_count} (Message {index})")
                    words_list.append(word)
                    original_messages.append(message)
                    word_indices.append(word_index + 1)
                sentence_count += 1
        else:
            print(f"Warning: Message at index {index} is not a string. Skipping...")

    tokenized_df = pd.DataFrame({
        'Sentence #': sentences_list,
        'Word': words_list,
        'Original Message': original_messages,
        'Word Index': word_indices
    })

    return tokenized_df

tokenized_df = regex_tokenize(data)

tokenized_df[['Sentence', 'Message']] = tokenized_df['Sentence #'].str.extract(r'Sentence: (\d+) \(Message (\d+)\)')

tokenized_df = tokenized_df.drop(columns=['Sentence #'])

tokenized_df
# Out:
#               Word                                   Original Message  \
# 0             شرطه                                 شرطه نازله من عيلي
# 1            نازله                                 شرطه نازله من عيلي
# 2               من                                 شرطه نازله من عيلي
# 3             عيلي                                 شرطه نازله من عيلي
# 4             حادث               حادث سير بعد اشارات شيلو باتجاه عيلي
# ...            ...                                                ...
# 222418       العسل  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
# 222419  0569317865  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
# 222420       ونشات  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
# 222421      الجبعي  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
# 222422        جنين  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
#
#         Word Index Sentence Message
# 0                1        1       0
# 1                2        1       0
# 2                3        1       0
# 3                4        1       0
# 4                1        2       1
# ...            ...      ...     ...
# 222418          35    23936   24610
# 222419          36    23936   24610
# 222420          37    23936   24610
# 222421          38    23936   24610
# 222422           1    23937   24610
#
# [222423 rows x 5 columns]

# %%
tokenized_df.drop(columns='Message', inplace=True)
tokenized_df
# Out:
#               Word                                   Original Message  \
# 0             شرطه                                 شرطه نازله من عيلي
# 1            نازله                                 شرطه نازله من عيلي
# 2               من                                 شرطه نازله من عيلي
# 3             عيلي                                 شرطه نازله من عيلي
# 4             حادث               حادث سير بعد اشارات شيلو باتجاه عيلي
# ...            ...                                                ...
# 222418       العسل  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
# 222419  0569317865  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
# 222420       ونشات  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
# 222421      الجبعي  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
# 222422        جنين  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
#
#         Word Index Sentence
# 0                1        1
# 1                2        1
# 2                3        1
# 3                4        1
# 4                1        2
# ...            ...      ...
# 222418          35    23936
# 222419          36    23936
# 222420          37    23936
# 222421          38    23936
# 222422           1    23937
#
# [222423 rows x 4 columns]

# %%
from collections import Counter
import re

all_text = ' '.join(data['message'].dropna())


words = re.findall(r'\b\w+\b', all_text)
word_counts = Counter(words)

word_count = pd.DataFrame(word_counts.items(), columns=['word', 'count'])

word_count
# Out:
#            word  count
# 0          شرطه    232
# 1         نازله      1
# 2            من   2643
# 3          عيلي    339
# 4          حادث    186
# ...         ...    ...
# 10975       ونش      1
# 10976     وشغال      1
# 10977      مدار      1
# 10978   يراسلني      1
# 10979  وبنضيفوا      1
#
# [10980 rows x 2 columns]

# %%
from rapidfuzz import fuzz

location_names = [
    "المنشية", "يتسهار", "صرة", "زعترة", "عصيرة", "المساكن", "المربعة", 
    "بوابة بورين", "دير شرف", "عورتا", "بيت فوريك", "بزاريا", "شافي شمرون",
    "حومش", "عناب", "الكفريات", "حجة", "وادي قانا", "بيت ليد", "كفر لاقف", 
    "الحمرا", "عوفرا", "ارئيل", "سلفيت", "رام الله", "نابلس", "عين سينيا", 
    "عطارة", "روابي", "عيون الحرامية", "ترمسعيا", "سنجل", "كركر", "بيت ايل", 
    "عزون", "جماعين", "كفل حارس", "مردا", "اللبن الشرقية", "بديا", "برقين", 
    "الزعيم", "العيزرية", "قلنديا", "جبع", "الكونتينر", "عش الغراب", 
    "مخماس", "جيت", "بيتا", "دير بلوط", "ياسوف", "النبي الياس", "سعير", 
    "حلحول", "حوارة", "راس الجورة", "عناتا", "حزما", "اماتين", "بيرزيت", 
    "النبي صالح", "افرات", "تقوع", "دورا", "عتصيون", "العروب", "فرش الهوى", 
    "حاجز النفق", "شارع بيجن", "الخليل", "واد النار", "DCO", "بيت جالا", 
    "اريحا", "برقة", "الغرس", "يتما", "الساوية", "يبرود", "سلواد", 
    "الطيبة", "النشاش", "طولكرم", "المسعودية", "بيت ايل", "جنين", 
    "قلقيلية", "عيلي", "كدوميم", "مخيم الجلزون", "روجيب", "شعفاط", 
    "الرام", "بيت لحم", "حوارة", "قبلان", "عينبوس", "بيت عور", "القرع", 
    "اودلا", "معالي ادوميم", "حزما", "السيلة", "نور شمس", "بلعا", 
    "الجفتلك", "الباذان", "البيرة", "بركان", "حبلة", "حرميش", "طوباس", 
    "السيلة", "افرايم", "ضواحي القدس", "القدس", "العبيدية", "بيت ساحور", 
    "تل الربيع", "يطا", "الظاهرية", "ترقوميا", "دير شرف", "شقبا", 
    "النفق", "شيلو", "عطروت", "حلميش", "المشتل", "عقربا", "قلنديا", 
    "سبسطية", "الفوار", "ادوميم", "العبيدية", "جين صافوت", "زواتا", 
    "حومش", "دير استيا", "العوجا", "بيت امر", "قباطية", "الجلزون", 
    "عطارة", "الخروبة", "عارورة", "الاحراش", "عصيرة الشمالية", "جيوس", "عين يبرود", 
    "عنبتا", "الناقورة", "الدهيشة", "بيت امرين", "قوصين", "عناتا", 
    "باب الزاوية", "الصيرفي", "صوريف", "ضاحية الريحان", "ابو ديس", "سالم", 
    "العيسوية", "بيت حنينا", "البيرة", "الاسكانات", "الزاوية", "النصارية",
    "واد قانا", "المصانع", "كفر عقب", "بير زيت", "عصيرة القبلية", "الفندق"
]

close_words = [
    'مغلق', 'مغلقة', 'وقوف', 'واقفه', 'سكروه', 'مسكره', 'سكر', 
    'مسكرين', 'متوقفه', 'اغلاق', 'اغلاقه'
]
open_words = [
    'فتح', 'فاضي', 'سالك', 'سالكه', 'فاتحة', 'فاتح', 'سلك', 'فتحت',
    'فاتحين', 'بمشو', 'مفتوحة', 'بسلك', 'بمشي', 'مشوا', 'فتحوها', 'سالكات', 'وسلك'
]

def regex_tokenize_with_similarity(data, location_names, similarity_threshold=80, close_threshold=80, open_threshold=80):
    sentence_splitter = re.compile(r'(?<=[.!?]) +')
    word_splitter = re.compile(r'[\u0600-\u06FF]+|\d+|\w+')

    sentences_list = []
    words_list = []
    original_messages = []
    word_indices = []
    labels = []
    similarities = []
    sentence_count = 1

    for index, message in data['message'].items():
        if isinstance(message, str):
            sentences = sentence_splitter.split(message.strip())
            for sentence in sentences:
                words = word_splitter.findall(sentence)
                
                i = 0
                while i < len(words):
                    if i + 1 < len(words) and f"{words[i]} {words[i+1]}" in location_names:
                        labels.extend(["B-LOC", "I-LOC"])
                        similarities.extend([100, 100])  
                        
                        sentences_list.extend([f"Sentence: {sentence_count} (Message {index})"] * 2)
                        words_list.extend([words[i], words[i + 1]])
                        original_messages.extend([message] * 2)
                        word_indices.extend([i + 1, i + 2])
                        
                        i += 2
                        continue
                    elif words[i] in location_names:
                        labels.append("B-LOC")
                        similarities.append(100)
                    else:
                        max_close_similarity = max(fuzz.ratio(words[i], word) for word in close_words)
                        if max_close_similarity >= close_threshold:
                            labels.append("B-close")
                            similarities.append(max_close_similarity)
                        else:
                            max_open_similarity = max(fuzz.ratio(words[i], word) for word in open_words)
                            if max_open_similarity >= open_threshold:
                                labels.append("B-open")
                                similarities.append(max_open_similarity)
                            else:
                                max_loc_similarity = max(fuzz.ratio(words[i], loc) for loc in location_names)
                                labels.append("B-LOC" if max_loc_similarity >= similarity_threshold else "O")
                                similarities.append(max_loc_similarity if max_loc_similarity >= similarity_threshold else 0)

                    sentences_list.append(f"Sentence: {sentence_count} (Message {index})")
                    words_list.append(words[i])
                    original_messages.append(message)
                    word_indices.append(i + 1)
                    i += 1
                    
                sentence_count += 1
        else:
            print(f"Warning: Message at index {index} is not a string. Skipping...")

    tokenized_df = pd.DataFrame({
        'Sentence #': sentences_list,
        'Word': words_list,
        'Original Message': original_messages,
        'Word Index': word_indices,
        'label': labels,
        'Similarity Score': similarities
    })

    return tokenized_df



tokenized_df = regex_tokenize_with_similarity(pd.DataFrame(data), location_names)

tokenized_df[['Sentence', 'Message']] = tokenized_df['Sentence #'].str.extract(r'Sentence: (\d+) \(Message (\d+)\)')


tokenized_df = tokenized_df.drop(columns=['Sentence #'])

# %%
tokenized_df
# Out:
#               Word                                   Original Message  \
# 0             شرطه                                 شرطه نازله من عيلي
# 1            نازله                                 شرطه نازله من عيلي
# 2               من                                 شرطه نازله من عيلي
# 3             عيلي                                 شرطه نازله من عيلي
# 4             حادث               حادث سير بعد اشارات شيلو باتجاه عيلي
# ...            ...                                                ...
# 222418       العسل  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
# 222419  0569317865  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
# 222420       ونشات  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
# 222421      الجبعي  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
# 222422        جنين  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...
#
#         Word Index  label  Similarity Score Sentence Message
# 0                1      O               0.0        1       0
# 1                2      O               0.0        1       0
# 2                3      O               0.0        1       0
# 3                4  B-LOC             100.0        1       0
# 4                1      O               0.0        2       1
# ...            ...    ...               ...      ...     ...
# 222418          35      O               0.0    23936   24610
# 222419          36      O               0.0    23936   24610
# 222420          37      O               0.0    23936   24610
# 222421          38      O               0.0    23936   24610
# 222422           1  B-LOC             100.0    23937   24610
#
# [222423 rows x 7 columns]

# %%
tokenized_df.drop(columns='Message', inplace=True)
tokenized_df = tokenized_df[['Similarity Score', 'Word Index', 'label', 'Word', 'Original Message', 'Sentence']]

# %%
tokenized_df
# Out:
#         Similarity Score  Word Index  label        Word  \
# 0                    0.0           1      O        شرطه
# 1                    0.0           2      O       نازله
# 2                    0.0           3      O          من
# 3                  100.0           4  B-LOC        عيلي
# 4                    0.0           1      O        حادث
# ...                  ...         ...    ...         ...
# 222418               0.0          35      O       العسل
# 222419               0.0          36      O  0569317865
# 222420               0.0          37      O       ونشات
# 222421               0.0          38      O      الجبعي
# 222422             100.0           1  B-LOC        جنين
#
#                                          Original Message Sentence
# 0                                      شرطه نازله من عيلي        1
# 1                                      شرطه نازله من عيلي        1
# 2                                      شرطه نازله من عيلي        1
# 3                                      شرطه نازله من عيلي        1
# 4                    حادث سير بعد اشارات شيلو باتجاه عيلي        2
# ...                                                   ...      ...
# 222418  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...    23936
# 222419  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...    23936
# 222420  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...    23936
# 222421  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...    23936
# 222422  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...    23937
#
# [222423 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count occurrences of each label
label_counts = tokenized_df['label'].value_counts()

# Plot the label distribution
plt.figure(figsize=(10, 6))
sns.barplot(x=label_counts.index, y=label_counts.values, palette="viridis")
plt.title("Distribution of Labels in Tokenized Data")
plt.xlabel("Label")
plt.ylabel("Frequency")
plt.show()
# Out:
# /var/folders/60/jh6gqjyn3vg6kq4wh79wmvkc0000gp/T/ipykernel_19405/1390820595.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=label_counts.index, y=label_counts.values, palette="viridis")

# %%
tokenized_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222423 entries, 0 to 222422
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Similarity Score  222423 non-null  float64
#  1   Word Index        222423 non-null  int64
#  2   label             222423 non-null  object
#  3   Word              222423 non-null  object
#  4   Original Message  222423 non-null  object
#  5   Sentence          222423 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 10.2+ MB

# %%
#tokenized_df = tokenized_df[['Similarity Score', 'Word Index', 'label', 'label_id', 'Word_id', 'Word', 'Original Message', 'Sentence']]

#tokenized_df

# %%
tokenized_df
# Out:
#         Similarity Score  Word Index  label        Word  \
# 0                    0.0           1      O        شرطه
# 1                    0.0           2      O       نازله
# 2                    0.0           3      O          من
# 3                  100.0           4  B-LOC        عيلي
# 4                    0.0           1      O        حادث
# ...                  ...         ...    ...         ...
# 222418               0.0          35      O       العسل
# 222419               0.0          36      O  0569317865
# 222420               0.0          37      O       ونشات
# 222421               0.0          38      O      الجبعي
# 222422             100.0           1  B-LOC        جنين
#
#                                          Original Message Sentence
# 0                                      شرطه نازله من عيلي        1
# 1                                      شرطه نازله من عيلي        1
# 2                                      شرطه نازله من عيلي        1
# 3                                      شرطه نازله من عيلي        1
# 4                    حادث سير بعد اشارات شيلو باتجاه عيلي        2
# ...                                                   ...      ...
# 222418  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...    23936
# 222419  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...    23936
# 222420  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...    23936
# 222421  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...    23936
# 222422  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...    23937
#
# [222423 rows x 6 columns]

# %%
from category_encoders import TargetEncoder
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
tokenized_df['label_encoded'] = label_encoder.fit_transform(tokenized_df['label'])
# Out:
# /var/folders/60/jh6gqjyn3vg6kq4wh79wmvkc0000gp/T/ipykernel_19405/146951505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tokenized_df['label_encoded'] = label_encoder.fit_transform(tokenized_df['label'])

# %%
tokenized_df = tokenized_df[['Similarity Score', 'Word Index', 'label_encoded' ,'label', 'Word', 'Original Message', 'Sentence']]

tokenized_df
# Out:
#         Similarity Score  Word Index  label_encoded  label        Word  \
# 0                    0.0           1              4      O        شرطه
# 1                    0.0           2              4      O       نازله
# 2                    0.0           3              4      O          من
# 3                  100.0           4              0  B-LOC        عيلي
# 4                    0.0           1              4      O        حادث
# ...                  ...         ...            ...    ...         ...
# 222418               0.0          35              4      O       العسل
# 222419               0.0          36              4      O  0569317865
# 222420               0.0          37              4      O       ونشات
# 222421               0.0          38              4      O      الجبعي
# 222422             100.0           1              0  B-LOC        جنين
#
#                                          Original Message Sentence
# 0                                      شرطه نازله من عيلي        1
# 1                                      شرطه نازله من عيلي        1
# 2                                      شرطه نازله من عيلي        1
# 3                                      شرطه نازله من عيلي        1
# 4                    حادث سير بعد اشارات شيلو باتجاه عيلي        2
# ...                                                   ...      ...
# 222418  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...    23936
# 222419  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...    23936
# 222420  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...    23936
# 222421  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...    23936
# 222422  في حال انقطاعك بجميع طرق الضفه::::\nارقام الون...    23937
#
# [222423 rows x 7 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(tokenized_df[['Word']], tokenized_df['label_encoded'], test_size=0.2, random_state=42)

# %%
target_encoder = TargetEncoder(cols=['Word'])
X_train_encoded = target_encoder.fit_transform(X_train, y_train)
X_test_encoded = target_encoder.transform(X_test)

# %%
X_train_encoded
# Out:
#             Word
# 29321   4.000000
# 162146  1.327297
# 216659  4.000000
# 220664  2.000000
# 61851   4.000000
# ...          ...
# 119879  3.194290
# 103694  2.996741
# 131932  2.980443
# 146867  4.000000
# 121958  0.000057
#
# [177938 rows x 1 columns]

# %%
X_test_encoded
# Out:
#                 Word
# 43268   2.000000e+00
# 75094   2.794187e+00
# 208317  3.670588e+00
# 147910  4.000000e+00
# 92361   2.000000e+00
# ...              ...
# 148668  4.000000e+00
# 180650  4.000000e+00
# 162344  4.000000e+00
# 166755  3.516092e+00
# 134293  1.561484e-07
#
# [44485 rows x 1 columns]

# %%
model = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter= 1000, random_state=42)
model.fit(X_train_encoded, y_train)
# Out:
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='multinomial', random_state=42)

# %%
y_pred = model.predict(X_test_encoded)
accuracy = model.score(X_test_encoded, y_test)
print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# Model Accuracy: 0.89

# %%
decoded_predictions = label_encoder.inverse_transform(y_pred)
decoded_actuals = label_encoder.inverse_transform(y_test)

print("\nClassification Report (Sample):")
print(classification_report(decoded_actuals, decoded_predictions, target_names=label_encoder.classes_, zero_division=0))
# Out:
# Classification Report (Sample):
#               precision    recall  f1-score   support
#
#        B-LOC       0.85      0.91      0.88      9202
#      B-close       0.00      0.00      0.00      1355
#       B-open       0.83      0.98      0.90      5254
#        I-LOC       0.00      0.00      0.00      2038
#            O       0.92      0.98      0.95     26636
#
#     accuracy                           0.89     44485
#    macro avg       0.52      0.58      0.55     44485
# weighted avg       0.83      0.89      0.86     44485

# %%
results = X_test.copy()
results['Actual_Label'] = decoded_actuals
results['Predicted_Label'] = decoded_predictions

print("\nSample Prediction Results:")
print(results.sample(100))
# Out:
# Sample Prediction Results:
#           Word Actual_Label Predicted_Label
# 12991    عورتا        B-LOC           B-LOC
# 159378  الشارع            O               O
# 12518      كفل        B-LOC           B-LOC
# 132468   ارئيل        B-LOC           B-LOC
# 45799    دقايق            O               O
# ...        ...          ...             ...
# 93596     الهم            O               O
# 27294    نابلس        B-LOC           B-LOC
# 87509   تياسير            O               O
# 51451     سالك       B-open          B-open
# 209860    حالة            O               O
#
# [100 rows x 3 columns]

# %%
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt

train_sizes, train_scores, test_scores = learning_curve(
    model, X_train_encoded, y_train, cv=5, scoring='accuracy', n_jobs=-1, train_sizes=np.linspace(0.1, 1.0, 10)
)

train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, 'o-', label='Training Accuracy', color='blue')
plt.plot(train_sizes, test_mean, 'o-', label='Validation Accuracy', color='orange')
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.1, color='blue')
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha=0.1, color='orange')

plt.title('Learning Curve')
plt.xlabel('Training Examples')
plt.ylabel('Accuracy')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/mac2/Visual Studio Code/ROADWATCH/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
