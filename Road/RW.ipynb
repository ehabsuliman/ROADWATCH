# %%
import pandas as pd 

data = pd.read_csv('/teamspace/studios/this_studio/messages_cleanedNEW.csv')

data
# Out:
#             id                       date     sender_id  \
# 0      1705274  2024-11-01T12:53:19+00:00  6.415259e+09
# 1      1705273  2024-11-01T12:52:29+00:00  6.415259e+09
# 2      1705272  2024-11-01T12:48:24+00:00  6.415259e+09
# 3      1705271  2024-11-01T12:44:55+00:00  6.415259e+09
# 4      1705270  2024-11-01T12:39:22+00:00  6.415259e+09
# ...        ...                        ...           ...
# 33986  1705279  2024-11-01T13:34:50+00:00  6.415259e+09
# 33987  1705278  2024-11-01T13:34:43+00:00  6.415259e+09
# 33988  1705277  2024-11-01T13:18:29+00:00  6.415259e+09
# 33989  1705276  2024-11-01T13:18:29+00:00  6.415259e+09
# 33990  1705275  2024-11-01T13:17:13+00:00  6.415259e+09
#
#                                                  message
# 0                                     شرطه نازله من عيلي
# 1                   حادث سير بعد اشارات شيلو باتجاه عيلي
# 2                     المنشية تواجد جيش مع شرطة ومخالفات
# 3      الرجاء من كل شخص بقرا التقرير يكبس ❤️ أو 👍\n\n...
# 4                  تم فتح حاجز عناب الان بالاتجاهين ✅✅✅✅
# ...                                                  ...
# 33986                               عناب على الطالع ازمه
# 33987                      راس الجورة سالك لداخل والخارج
# 33988  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 33989                                                NaN
# 33990                                        عورتا لداخل
#
# [33991 rows x 4 columns]

# %%
import re
def remove_emojis(text):
    if isinstance(text, str):
        return re.sub(r'[^\w\s,.!?؛:\n]', '', text)
    return text

data['message'] = data['message'].apply(remove_emojis)

data
# Out:
#             id                       date     sender_id  \
# 0      1705274  2024-11-01T12:53:19+00:00  6.415259e+09
# 1      1705273  2024-11-01T12:52:29+00:00  6.415259e+09
# 2      1705272  2024-11-01T12:48:24+00:00  6.415259e+09
# 3      1705271  2024-11-01T12:44:55+00:00  6.415259e+09
# 4      1705270  2024-11-01T12:39:22+00:00  6.415259e+09
# ...        ...                        ...           ...
# 33986  1705279  2024-11-01T13:34:50+00:00  6.415259e+09
# 33987  1705278  2024-11-01T13:34:43+00:00  6.415259e+09
# 33988  1705277  2024-11-01T13:18:29+00:00  6.415259e+09
# 33989  1705276  2024-11-01T13:18:29+00:00  6.415259e+09
# 33990  1705275  2024-11-01T13:17:13+00:00  6.415259e+09
#
#                                                  message
# 0                                     شرطه نازله من عيلي
# 1                   حادث سير بعد اشارات شيلو باتجاه عيلي
# 2                     المنشية تواجد جيش مع شرطة ومخالفات
# 3      الرجاء من كل شخص بقرا التقرير يكبس  أو \n\nتفا...
# 4                      تم فتح حاجز عناب الان بالاتجاهين
# ...                                                  ...
# 33986                               عناب على الطالع ازمه
# 33987                      راس الجورة سالك لداخل والخارج
# 33988  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 33989                                                NaN
# 33990                                        عورتا لداخل
#
# [33991 rows x 4 columns]

# %%
def remove_jargon(data, jargon_terms):
      def clean_message(message):
        pattern = re.compile(r'\b(' + '|'.join(re.escape(term) for term in jargon_terms) + r')\b', re.IGNORECASE)
        return pattern.sub('', message)

        data['message'] = data['message'].apply(clean_message)

        data['message'] = data['message'].str.strip().replace(r'\s+', ' ', regex=True)
      return data

data
# Out:
#             id                       date     sender_id  \
# 0      1705274  2024-11-01T12:53:19+00:00  6.415259e+09
# 1      1705273  2024-11-01T12:52:29+00:00  6.415259e+09
# 2      1705272  2024-11-01T12:48:24+00:00  6.415259e+09
# 3      1705271  2024-11-01T12:44:55+00:00  6.415259e+09
# 4      1705270  2024-11-01T12:39:22+00:00  6.415259e+09
# ...        ...                        ...           ...
# 33986  1705279  2024-11-01T13:34:50+00:00  6.415259e+09
# 33987  1705278  2024-11-01T13:34:43+00:00  6.415259e+09
# 33988  1705277  2024-11-01T13:18:29+00:00  6.415259e+09
# 33989  1705276  2024-11-01T13:18:29+00:00  6.415259e+09
# 33990  1705275  2024-11-01T13:17:13+00:00  6.415259e+09
#
#                                                  message
# 0                                     شرطه نازله من عيلي
# 1                   حادث سير بعد اشارات شيلو باتجاه عيلي
# 2                     المنشية تواجد جيش مع شرطة ومخالفات
# 3      الرجاء من كل شخص بقرا التقرير يكبس  أو \n\nتفا...
# 4                      تم فتح حاجز عناب الان بالاتجاهين
# ...                                                  ...
# 33986                               عناب على الطالع ازمه
# 33987                      راس الجورة سالك لداخل والخارج
# 33988  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 33989                                                NaN
# 33990                                        عورتا لداخل
#
# [33991 rows x 4 columns]

# %%
print(data['message'].isnull().sum())
# Out:
# 1472

# %%
data.dropna(subset=['message'], inplace=True)

# %%
print(data['message'].isnull().sum())
# Out:
# 0

# %%
for index, message in enumerate(data['message']):
    if not isinstance(message, str):
        print(f"Row {index}: {message} (Type: {type(message)})")

# %%
data = data[data['message'].apply(lambda x: isinstance(x, str))]

# %%
def regex_tokenize(data):
    sentence_splitter = re.compile(r'(?<=[.!?]) +')
    word_splitter = re.compile(r'[\u0600-\u06FF]+|\d+|\w+')

    sentences_list = []
    words_list = []
    original_messages = []
    word_indices = []
    sentence_count = 1

    for index, message in data['message'].items():
        if isinstance(message, str):
            sentences = sentence_splitter.split(message.strip())
            for sentence in sentences:
                words = word_splitter.findall(sentence)
                for word_index, word in enumerate(words):
                    sentences_list.append(f"Sentence: {sentence_count} (Message {index})")
                    words_list.append(word)
                    original_messages.append(message)
                    word_indices.append(word_index + 1)
                sentence_count += 1
        else:
            print(f"Warning: Message at index {index} is not a string. Skipping...")

    tokenized_df = pd.DataFrame({
        'Sentence #': sentences_list,
        'Word': words_list,
        'Original Message': original_messages,
        'Word Index': word_indices
    })

    return tokenized_df

tokenized_df = regex_tokenize(data)

tokenized_df[['Sentence', 'Message']] = tokenized_df['Sentence #'].str.extract(r'Sentence: (\d+) \(Message (\d+)\)')

tokenized_df = tokenized_df.drop(columns=['Sentence #'])

tokenized_df
# Out:
#           Word                                   Original Message  Word Index  \
# 0         شرطه                                 شرطه نازله من عيلي           1
# 1        نازله                                 شرطه نازله من عيلي           2
# 2           من                                 شرطه نازله من عيلي           3
# 3         عيلي                                 شرطه نازله من عيلي           4
# 4         حادث               حادث سير بعد اشارات شيلو باتجاه عيلي           1
# ...        ...                                                ...         ...
# 303763  وتفتيش  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           6
# 303764   سياره  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           7
# 303765   سياره  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           8
# 303766   عورتا                                        عورتا لداخل           1
# 303767   لداخل                                        عورتا لداخل           2
#
#        Sentence Message
# 0             1       0
# 1             1       0
# 2             1       0
# 3             1       0
# 4             2       1
# ...         ...     ...
# 303763    32976   33988
# 303764    32976   33988
# 303765    32976   33988
# 303766    32977   33990
# 303767    32977   33990
#
# [303768 rows x 5 columns]

# %%
tokenized_df.drop(columns='Message', inplace=True)
tokenized_df
# Out:
#           Word                                   Original Message  Word Index  \
# 0         شرطه                                 شرطه نازله من عيلي           1
# 1        نازله                                 شرطه نازله من عيلي           2
# 2           من                                 شرطه نازله من عيلي           3
# 3         عيلي                                 شرطه نازله من عيلي           4
# 4         حادث               حادث سير بعد اشارات شيلو باتجاه عيلي           1
# ...        ...                                                ...         ...
# 303763  وتفتيش  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           6
# 303764   سياره  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           7
# 303765   سياره  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           8
# 303766   عورتا                                        عورتا لداخل           1
# 303767   لداخل                                        عورتا لداخل           2
#
#        Sentence
# 0             1
# 1             1
# 2             1
# 3             1
# 4             2
# ...         ...
# 303763    32976
# 303764    32976
# 303765    32976
# 303766    32977
# 303767    32977
#
# [303768 rows x 4 columns]

# %%
from collections import Counter
import re

all_text = ' '.join(data['message'].dropna())


words = re.findall(r'\b\w+\b', all_text)
word_counts = Counter(words)

word_count = pd.DataFrame(word_counts.items(), columns=['word', 'count'])

word_count
# Out:
#          word  count
# 0        شرطه    293
# 1       نازله      2
# 2          من   3877
# 3        عيلي    459
# 4        حادث    265
# ...       ...    ...
# 13282  مابمرق      1
# 13283   حالين      1
# 13284   بتفرج      1
# 13285   وقامو      1
# 13286  بأغلاق      1
#
# [13287 rows x 2 columns]

# %%
from rapidfuzz import fuzz

location_names = [
    "المنشية", "يتسهار", "صرة", "زعترة", "عصيرة", "المساكن", "المربعة", 
    "بوابة بورين", "دير شرف", "عورتا", "بيت فوريك", "بزاريا", "شافي شمرون",
    "حومش", "عناب", "الكفريات", "حجة", "وادي قانا", "بيت ليد", "كفر لاقف", 
    "الحمرا", "عوفرا", "ارئيل", "سلفيت", "رام الله", "نابلس", "عين سينيا", 
    "عطارة", "روابي", "عيون الحرامية", "ترمسعيا", "سنجل", "كركر", "بيت ايل", 
    "عزون", "جماعين", "كفل حارس", "مردا", "اللبن الشرقية", "بديا", "برقين", 
    "الزعيم", "العيزرية", "قلنديا", "جبع", "الكونتينر", "عش الغراب", 
    "مخماس", "جيت", "بيتا", "دير بلوط", "ياسوف", "النبي الياس", "سعير", 
    "حلحول", "حوارة", "راس الجورة", "عناتا", "حزما", "اماتين", "بيرزيت", 
    "النبي صالح", "افرات", "تقوع", "دورا", "عتصيون", "العروب", "فرش الهوى", 
    "حاجز النفق", "شارع بيجن", "الخليل", "واد النار", "DCO", "بيت جالا", 
    "اريحا", "برقة", "الغرس", "يتما", "الساوية", "يبرود", "سلواد", 
    "الطيبة", "النشاش", "طولكرم", "المسعودية", "بيت ايل", "جنين", 
    "قلقيلية", "عيلي", "كدوميم", "مخيم الجلزون", "روجيب", "شعفاط", 
    "الرام", "بيت لحم", "حوارة", "قبلان", "عينبوس", "بيت عور", "القرع", 
    "اودلا", "معالي ادوميم", "حزما", "السيلة", "نور شمس", "بلعا", 
    "الجفتلك", "الباذان", "البيرة", "بركان", "حبلة", "حرميش", "طوباس", 
    "السيلة", "افرايم", "ضواحي القدس", "القدس", "العبيدية", "بيت ساحور", 
    "تل الربيع", "يطا", "الظاهرية", "ترقوميا", "دير شرف", "شقبا", 
    "النفق", "شيلو", "عطروت", "حلميش", "المشتل", "عقربا", "قلنديا", 
    "سبسطية", "الفوار", "ادوميم", "العبيدية", "جين صافوت", "زواتا", 
    "حومش", "دير استيا", "العوجا", "بيت امر", "قباطية", "الجلزون", 
    "عطارة", "الخروبة", "عارورة", "الاحراش", "عصيرة الشمالية", "جيوس", "عين يبرود", 
    "عنبتا", "الناقورة", "الدهيشة", "بيت امرين", "قوصين", "عناتا", 
    "باب الزاوية", "الصيرفي", "صوريف", "ضاحية الريحان", "ابو ديس", "سالم", 
    "العيسوية", "بيت حنينا", "البيرة", "الاسكانات", "الزاوية", "النصارية",
    "واد قانا", "المصانع", "كفر عقب", "بير زيت", "عصيرة القبلية", "الفندق"
]

close_words = [
    'مغلق', 'مغلقة', 'وقوف', 'واقفه', 'سكروه', 'مسكره', 'سكر', 
    'مسكرين', 'متوقفه', 'اغلاق', 'اغلاقه'
]
open_words = [
    'فتح', 'فاضي', 'سالك', 'سالكه', 'فاتحة', 'فاتح', 'سلك', 'فتحت',
    'فاتحين', 'بمشو', 'مفتوحة', 'بسلك', 'بمشي', 'مشوا', 'فتحوها', 'سالكات', 'وسلك'
]

def regex_tokenize_with_similarity(data, location_names, similarity_threshold=80, close_threshold=80, open_threshold=80):
    sentence_splitter = re.compile(r'(?<=[.!?]) +')
    word_splitter = re.compile(r'[\u0600-\u06FF]+|\d+|\w+')

    sentences_list = []
    words_list = []
    original_messages = []
    word_indices = []
    labels = []
    similarities = []
    sentence_count = 1

    for index, message in data['message'].items():
        if isinstance(message, str):
            sentences = sentence_splitter.split(message.strip())
            for sentence in sentences:
                words = word_splitter.findall(sentence)
                
                i = 0
                while i < len(words):
                    if i + 1 < len(words) and f"{words[i]} {words[i+1]}" in location_names:
                        labels.extend(["B-LOC", "I-LOC"])
                        similarities.extend([100, 100])  
                        
                        sentences_list.extend([f"Sentence: {sentence_count} (Message {index})"] * 2)
                        words_list.extend([words[i], words[i + 1]])
                        original_messages.extend([message] * 2)
                        word_indices.extend([i + 1, i + 2])
                        
                        i += 2
                        continue
                    elif words[i] in location_names:
                        labels.append("B-LOC")
                        similarities.append(100)
                    else:
                        max_close_similarity = max(fuzz.ratio(words[i], word) for word in close_words)
                        if max_close_similarity >= close_threshold:
                            labels.append("B-close")
                            similarities.append(max_close_similarity)
                        else:
                            max_open_similarity = max(fuzz.ratio(words[i], word) for word in open_words)
                            if max_open_similarity >= open_threshold:
                                labels.append("B-open")
                                similarities.append(max_open_similarity)
                            else:
                                max_loc_similarity = max(fuzz.ratio(words[i], loc) for loc in location_names)
                                labels.append("B-LOC" if max_loc_similarity >= similarity_threshold else "O")
                                similarities.append(max_loc_similarity if max_loc_similarity >= similarity_threshold else 0)

                    sentences_list.append(f"Sentence: {sentence_count} (Message {index})")
                    words_list.append(words[i])
                    original_messages.append(message)
                    word_indices.append(i + 1)
                    i += 1
                    
                sentence_count += 1
        else:
            print(f"Warning: Message at index {index} is not a string. Skipping...")

    tokenized_df = pd.DataFrame({
        'Sentence #': sentences_list,
        'Word': words_list,
        'Original Message': original_messages,
        'Word Index': word_indices,
        'label': labels,
        'Similarity Score': similarities
    })

    return tokenized_df



tokenized_df = regex_tokenize_with_similarity(pd.DataFrame(data), location_names)

tokenized_df[['Sentence', 'Message']] = tokenized_df['Sentence #'].str.extract(r'Sentence: (\d+) \(Message (\d+)\)')


tokenized_df = tokenized_df.drop(columns=['Sentence #'])

# %%
tokenized_df
# Out:
#           Word                                   Original Message  Word Index  \
# 0         شرطه                                 شرطه نازله من عيلي           1
# 1        نازله                                 شرطه نازله من عيلي           2
# 2           من                                 شرطه نازله من عيلي           3
# 3         عيلي                                 شرطه نازله من عيلي           4
# 4         حادث               حادث سير بعد اشارات شيلو باتجاه عيلي           1
# ...        ...                                                ...         ...
# 303763  وتفتيش  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           6
# 303764   سياره  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           7
# 303765   سياره  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           8
# 303766   عورتا                                        عورتا لداخل           1
# 303767   لداخل                                        عورتا لداخل           2
#
#         label  Similarity Score Sentence Message
# 0           O               0.0        1       0
# 1           O               0.0        1       0
# 2           O               0.0        1       0
# 3       B-LOC             100.0        1       0
# 4           O               0.0        2       1
# ...       ...               ...      ...     ...
# 303763      O               0.0    32976   33988
# 303764      O               0.0    32976   33988
# 303765      O               0.0    32976   33988
# 303766  B-LOC             100.0    32977   33990
# 303767      O               0.0    32977   33990
#
# [303768 rows x 7 columns]

# %%
tokenized_df.drop(columns='Message', inplace=True)
tokenized_df = tokenized_df[['Similarity Score', 'Word Index', 'label', 'Word', 'Original Message', 'Sentence']]

# %%
tokenized_df
# Out:
#         Similarity Score  Word Index  label    Word  \
# 0                    0.0           1      O    شرطه
# 1                    0.0           2      O   نازله
# 2                    0.0           3      O      من
# 3                  100.0           4  B-LOC    عيلي
# 4                    0.0           1      O    حادث
# ...                  ...         ...    ...     ...
# 303763               0.0           6      O  وتفتيش
# 303764               0.0           7      O   سياره
# 303765               0.0           8      O   سياره
# 303766             100.0           1  B-LOC   عورتا
# 303767               0.0           2      O   لداخل
#
#                                          Original Message Sentence
# 0                                      شرطه نازله من عيلي        1
# 1                                      شرطه نازله من عيلي        1
# 2                                      شرطه نازله من عيلي        1
# 3                                      شرطه نازله من عيلي        1
# 4                    حادث سير بعد اشارات شيلو باتجاه عيلي        2
# ...                                                   ...      ...
# 303763  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...    32976
# 303764  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...    32976
# 303765  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...    32976
# 303766                                        عورتا لداخل    32977
# 303767                                        عورتا لداخل    32977
#
# [303768 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count occurrences of each label
label_counts = tokenized_df['label'].value_counts()

# Plot the label distribution
plt.figure(figsize=(10, 6))
sns.barplot(x=label_counts.index, y=label_counts.values, palette="viridis")
plt.title("Distribution of Labels in Tokenized Data")
plt.xlabel("Label")
plt.ylabel("Frequency")
plt.show()
# Out:
# /tmp/ipykernel_6921/1390820595.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=label_counts.index, y=label_counts.values, palette="viridis")

# %%
tokenized_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303768 entries, 0 to 303767
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Similarity Score  303768 non-null  float64
#  1   Word Index        303768 non-null  int64
#  2   label             303768 non-null  object
#  3   Word              303768 non-null  object
#  4   Original Message  303768 non-null  object
#  5   Sentence          303768 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 13.9+ MB

# %%
tokenized_df['Length Word'] = tokenized_df['Word'].apply(len)
# Out:
# /tmp/ipykernel_6921/1357070171.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tokenized_df['Length Word'] = tokenized_df['Word'].apply(len)

# %%
tokenized_df
# Out:
#         Similarity Score  Word Index  label    Word  \
# 0                    0.0           1      O    شرطه
# 1                    0.0           2      O   نازله
# 2                    0.0           3      O      من
# 3                  100.0           4  B-LOC    عيلي
# 4                    0.0           1      O    حادث
# ...                  ...         ...    ...     ...
# 303763               0.0           6      O  وتفتيش
# 303764               0.0           7      O   سياره
# 303765               0.0           8      O   سياره
# 303766             100.0           1  B-LOC   عورتا
# 303767               0.0           2      O   لداخل
#
#                                          Original Message Sentence  \
# 0                                      شرطه نازله من عيلي        1
# 1                                      شرطه نازله من عيلي        1
# 2                                      شرطه نازله من عيلي        1
# 3                                      شرطه نازله من عيلي        1
# 4                    حادث سير بعد اشارات شيلو باتجاه عيلي        2
# ...                                                   ...      ...
# 303763  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...    32976
# 303764  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...    32976
# 303765  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...    32976
# 303766                                        عورتا لداخل    32977
# 303767                                        عورتا لداخل    32977
#
#         Length Word
# 0                 4
# 1                 5
# 2                 2
# 3                 4
# 4                 4
# ...             ...
# 303763            6
# 303764            5
# 303765            5
# 303766            5
# 303767            5
#
# [303768 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import numpy as np

# %%
label_encoder = LabelEncoder()
tokenized_df['label_encoded'] = label_encoder.fit_transform(tokenized_df['label'])
# Out:
# /tmp/ipykernel_6921/146951505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tokenized_df['label_encoded'] = label_encoder.fit_transform(tokenized_df['label'])

# %%
tokenized_df = tokenized_df[['Similarity Score', 'Word Index', 'label_encoded' ,'label', 'Word', 'Length Word', 'Original Message', 'Sentence']]

tokenized_df
# Out:
#         Similarity Score  Word Index  label_encoded  label    Word  \
# 0                    0.0           1              4      O    شرطه
# 1                    0.0           2              4      O   نازله
# 2                    0.0           3              4      O      من
# 3                  100.0           4              0  B-LOC    عيلي
# 4                    0.0           1              4      O    حادث
# ...                  ...         ...            ...    ...     ...
# 303763               0.0           6              4      O  وتفتيش
# 303764               0.0           7              4      O   سياره
# 303765               0.0           8              4      O   سياره
# 303766             100.0           1              0  B-LOC   عورتا
# 303767               0.0           2              4      O   لداخل
#
#         Length Word                                   Original Message  \
# 0                 4                                 شرطه نازله من عيلي
# 1                 5                                 شرطه نازله من عيلي
# 2                 2                                 شرطه نازله من عيلي
# 3                 4                                 شرطه نازله من عيلي
# 4                 4               حادث سير بعد اشارات شيلو باتجاه عيلي
# ...             ...                                                ...
# 303763            6  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303764            5  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303765            5  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303766            5                                        عورتا لداخل
# 303767            5                                        عورتا لداخل
#
#        Sentence
# 0             1
# 1             1
# 2             1
# 3             1
# 4             2
# ...         ...
# 303763    32976
# 303764    32976
# 303765    32976
# 303766    32977
# 303767    32977
#
# [303768 rows x 8 columns]

# %%
tokenized_df
# Out:
#         Similarity Score  Word Index  label_encoded  label    Word  \
# 0                    0.0           1              4      O    شرطه
# 1                    0.0           2              4      O   نازله
# 2                    0.0           3              4      O      من
# 3                  100.0           4              0  B-LOC    عيلي
# 4                    0.0           1              4      O    حادث
# ...                  ...         ...            ...    ...     ...
# 303763               0.0           6              4      O  وتفتيش
# 303764               0.0           7              4      O   سياره
# 303765               0.0           8              4      O   سياره
# 303766             100.0           1              0  B-LOC   عورتا
# 303767               0.0           2              4      O   لداخل
#
#         Length Word                                   Original Message  \
# 0                 4                                 شرطه نازله من عيلي
# 1                 5                                 شرطه نازله من عيلي
# 2                 2                                 شرطه نازله من عيلي
# 3                 4                                 شرطه نازله من عيلي
# 4                 4               حادث سير بعد اشارات شيلو باتجاه عيلي
# ...             ...                                                ...
# 303763            6  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303764            5  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303765            5  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303766            5                                        عورتا لداخل
# 303767            5                                        عورتا لداخل
#
#        Sentence
# 0             1
# 1             1
# 2             1
# 3             1
# 4             2
# ...         ...
# 303763    32976
# 303764    32976
# 303765    32976
# 303766    32977
# 303767    32977
#
# [303768 rows x 8 columns]

# %%
tokenized_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303768 entries, 0 to 303767
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Similarity Score  303768 non-null  float64
#  1   Word Index        303768 non-null  int64
#  2   label_encoded     303768 non-null  int64
#  3   label             303768 non-null  object
#  4   Word              303768 non-null  object
#  5   Length Word       303768 non-null  int64
#  6   Original Message  303768 non-null  object
#  7   Sentence          303768 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 18.5+ MB

# %%
print(tokenized_df.columns)
# Out:
# Index(['Similarity Score', 'Word Index', 'label_encoded', 'label', 'Word',
#        'Length Word', 'Original Message', 'Sentence'],
#       dtype='object')

# %%
tokenized_words = tokenized_df['Word'].tolist()

len(tokenized_words)
# Out:
# 303768

# %%
tokenized_df['label'] = tokenized_df['label'].replace('I-LOC', 'B-LOC')

# %%
tokenized_df['label'] = tokenized_df['label'].replace({'B-open': 'B-STATE', 'B-close': 'B-STATE'})

# %%
tokenized_df['label'].value_counts()
# Out:
# O          181184
# B-LOC       77127
# B-STATE     45457
# Name: label, dtype: int64

# %%
sentences = [
    list(group['Word'])
    for _, group in tokenized_df.groupby('Sentence')
]
sentences
# Out:
# [['شرطه', 'نازله', 'من', 'عيلي'],
#  ['قلنديا', 'لا', 'الداخل', 'سالك', 'الخارج', 'ازمه'],
#  ['من', 'كف', '٣٥', 'لراس', 'الجورة', 'سالك'],
#  ['مشوا', 'السيارات', 'ع', 'اشارات', 'بيت', 'ايل'],
#  ['ديرشرف', 'سالك', 'بالاتجاهين', 'حاليا'],
#  ['المربعه', 'خبط', 'قنابل', 'صوت', 'وغاز', 'خنقوا', 'الناس'],
#  ['بوابة', 'عزون', 'تحت', 'الجسر'],
#  ['عورتا', 'ازمه', 'للداخل', 'على', 'نابلس'],
#  ['انتبهوا', 'حاجز', 'عورتا', 'حجز', 'سيارات', 'اثناء', 'التجاوز'],
#  ['اللي', 'بتجاوز', 'ع', 'عورتا', 'بوخدو', 'سيارته'],
#  ['الكونتينر', 'سالك', 'حاليا', 'بالاتجاهين'],
#  ['فتح', 'البوابة', 'تحت', 'جسر', 'عزون', 'حاليا'],
#  ['جبارة', 'سالك', 'حاليا'],
#  ['سلفيت', 'حاجز', 'شرطة', 'وتفتيش', 'سيارة', 'سيارة', 'بالاتجاهين'],
#  ['زيف', 'مغلقة', 'خلة', 'المي', 'سالكة'],
#  ['اريحا',
#   'حاجز',
#   'الهيئة',
#   'سالك',
#   'حاجز',
#   'البنانا',
#   'فتح',
#   'مع',
#   'تواجد',
#   'الجيش',
#   'المدخل',
#   'الجنوبي',
#   'لمدينة',
#   'أريحا',
#   'سالك',
#   'البوابة',
#   'الصفراء',
#   'سالك'],
#  ['الي',
#   'جاي',
#   'من',
#   'جهة',
#   'جنين',
#   'او',
#   'نابلس',
#   'الى',
#   'مدخل',
#   'بزاريا',
#   'الطريق',
#   'كمان',
#   'بتكون',
#   'عايدكم',
#   'اليمين',
#   'عند',
#   'كوم',
#   'التراب',
#   'القديم',
#   'بتطلعوها',
#   'وبتنزلو',
#   'بعد',
#   'كوم',
#   'الرمل'],
#  ['وفيه',
#   'اقاويل',
#   'مش',
#   'ب',
#   '300',
#   'متر',
#   'في',
#   '50',
#   'متر',
#   'شوفو',
#   'المناسب'],
#  ['مدخل', 'حجة', 'حاجز', 'وتفتيش', 'مدخل', 'النبي', 'الياس', 'حاجز', 'وازمة'],
#  ['بالنسبة',
#   'للطريق',
#   'الترابي',
#   'الغرس',
#   'بديل',
#   'بزاريا',
#   'في',
#   'قبلو',
#   'ب٣٠٠',
#   'متر',
#   'طلعة',
#   'طبعا',
#   'طريق',
#   'مزفتة',
#   'وممتازة',
#   'بتجيبكم',
#   'بعد',
#   'كوم',
#   'التراب',
#   'واسهل',
#   'واحسن',
#   'من',
#   'طريق',
#   'الغرس',
#   'الكل',
#   'مفكر',
#   'انو',
#   'مسكرة',
#   'بس',
#   'الطريق',
#   'مفتوحة',
#   'بالسلامة',
#   'للجميع'],
#  ['ملاحظة', 'بخصوص', 'المربعة', 'مزعج', 'خاصة', 'للصبايا', 'حاليا', 'للخارج'],
#  ['تفتيش', 'دقيق', 'ونبش', 'مرمطه', 'الله', 'يهونها'],
#  ['دير', 'شرف', 'الان'],
#  ['وضع', 'المربعة'],
#  ['شافي', 'شمرون', 'سالك', 'بدون', 'تواجد', 'الجيش'],
#  ['الفحص', 'فتحت', 'هلا'],
#  ['صرة', 'حاليا', 'حوالي', '١٠', 'سيارات', 'عليه'],
#  ['أزمة', 'دير', 'شرف'],
#  ['عورتا', 'أزمة', 'بالاتجاهين'],
#  ['طريق', 'الغرس', 'بزاريا'],
#  ['سدة', 'قراوة', 'سالكة', 'بس', 'عليها', 'جب', 'جيش', 'حاليا'],
#  ['حاجز', 'الهيئة', 'اريحا', 'سالك', 'حاليا', 'بالاتجاهين'],
#  ['طريق', 'المساكن', 'عصيرة', 'لا', 'ينصح', 'بالمرور', 'منها'],
#  ['ال', '17', 'سالك', 'حاليا'],
#  ['المربعة', 'حاليا', 'الجيش', 'اتهجم', 'على', 'الناس', 'والسيارات'],
#  ['عورتاا', 'ازمة', 'للخارج', 'لشارع', 'روجيب'],
#  ['عطارة', 'البلد', 'سالك'],
#  ['فرش', 'الهوى', 'سالكة'],
#  ['الكونتينر',
#   'سالك',
#   'اتجاهين',
#   'عش',
#   'غراب',
#   'سالك',
#   'اتجاهين',
#   'العيزرية',
#   'ازمة',
#   'اتجاه',
#   'الجنوب',
#   'باتجاه',
#   'الشمال',
#   'سالك'],
#  ['جميع', 'مخارج', 'نابلس', 'ازمة', 'خانقة'],
#  ['دوار', 'كدميمم', 'جيش', 'وشرطه'],
#  ['قلنديا', 'داخل', 'وخارج', 'ازمة'],
#  ['عش', 'غراب', 'لازال', 'فاتح', 'وسالك'],
#  ['صرة',
#   'عليها',
#   'اربع',
#   'سيارات',
#   'طبعا',
#   'للشاحنات',
#   'ونمرا',
#   'صفراء',
#   'فقط'],
#  ['الفندق', 'للخارج', 'ازمه', 'وحاجز', 'تفتيش'],
#  ['طريق', 'زعيم', 'ازمه', 'ماشيه'],
#  ['الجيب',
#   'هلأ',
#   'وقف',
#   'قدام',
#   'السيارات',
#   'الي',
#   'طالعه',
#   'من',
#   'نابلس',
#   'ع',
#   'دير',
#   'شرف'],
#  ['راس',
#   'الجورة',
#   'سالك',
#   'بوابة',
#   'بني',
#   'نعيم',
#   'سالكة',
#   'مع',
#   'تواجد',
#   'للجيش',
#   'دورا',
#   'مغلقة'],
#  ['زيف', 'يطا'],
#  ['واد', 'الحرامية', 'ازمة', 'ماشية'],
#  ['سلفيت', 'ارئيل', 'حاجز', 'شرطه', 'وجيش'],
#  ['وهي', 'دي', 'شرف', 'لا', 'الداخل'],
#  ['دير', 'شرف'],
#  ['العيزاريه', 'سالكه', 'عشمال', 'ازمه', 'خفيفه', 'عجنوب'],
#  ['الغرس', 'بزاريا', 'سالكة', 'واغلبها', 'مزفتة', 'ومرتبة'],
#  ['اكم',
#   'قلب',
#   'يستاهل',
#   'منكم',
#   'ما',
#   'تبخلوا',
#   'علينا',
#   'بقلب',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'يتسهار',
#   'سالك',
#   'صرة',
#   'سالك',
#   'للخارج',
#   'شاحنات',
#   'ونمر',
#   'صفراء',
#   'وحاليا',
#   'ازمه',
#   'للخارجين',
#   'زعترا',
#   'سالك',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'مغلق',
#   'التفافي',
#   'زواتا',
#   'سالك',
#   'المربعه',
#   'ازمه',
#   'بالاتجاهين',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'دير',
#   'شرف',
#   'ازمه',
#   'مع',
#   'كثافة',
#   'سير',
#   'عورتا',
#   'ازمه',
#   'للخارج',
#   'بيت',
#   'فوريك',
#   'ازمه',
#   'لداخل',
#   'بزاريا',
#   'الرئيسي',
#   'مغلق',
#   'البديل',
#   'الغرس',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'حومش',
#   'سالك',
#   'عناب',
#   'مغلق',
#   'بالاتجاهين',
#   'اليوم',
#   'التاسع',
#   'ع',
#   'التوالي',
#   'الكفريات',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'تواجد',
#   'الجيش',
#   'إشارات',
#   'حارس',
#   'سالك',
#   'طريق',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'سالك',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'حاجز',
#   'الحمرا',
#   'ازمه',
#   'عوفرا',
#   'سالك',
#   'اارئيل',
#   'سلفيت',
#   'سالك',
#   'خط',
#   'رام',
#   'الله',
#   'نابلس',
#   'سالك',
#   'عين',
#   'سينا',
#   'سالك',
#   'عطارة',
#   'سالك',
#   'عطاره',
#   'فوق',
#   'الجسر',
#   'سالك',
#   'روابي',
#   'سالك',
#   'اشارات',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'سنجل',
#   'مغلق',
#   'سنجل',
#   'المدخل',
#   'الشمالي',
#   'سالك',
#   'شيلو',
#   'سالك',
#   'عيلي',
#   'سالك',
#   'عيون',
#   'الحراميه',
#   'سالك',
#   'بيت',
#   'ايل',
#   'مغلق',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'تحت',
#   'جسر',
#   'جباره',
#   'سالك',
#   'جماعين',
#   'ساالك',
#   'بوابة',
#   'كفل',
#   'حارس'],
#  ['مغلق',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'مردا',
#   'الشرقيه',
#   'سالك',
#   'بديا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'مدخل',
#   'مردا',
#   'الغربي',
#   'سالك',
#   'متواجد',
#   'معكم',
#   'عالخاص',
#   'لا',
#   'اب',
#   'تحديث',
#   'إستفسار'],
#  ['سبسطية', 'سالكة'],
#  ['اخوي',
#   'طلعنا',
#   'ع',
#   'اشارة',
#   'بيت',
#   'ايل',
#   'رجعوا',
#   'نمر',
#   'الضفة',
#   'بس',
#   'النمر',
#   'الصفرا',
#   'بمرقوا',
#   'من',
#   'الإشارات',
#   'تحت'],
#  ['وازمة', 'من', 'ساعه', 'ولا', 'سيارة', 'خرجت'],
#  ['المربعه', 'تفتيش', 'سياره', 'سيارة'],
#  ['زعترا', 'سالك'],
#  ['خط', 'يتسهار', 'سالك', 'ونظيف'],
#  ['من', 'ازمه', 'عورتا', 'الان'],
#  ['مع', 'تواجد', 'الجيش', 'الان', 'والطريق', 'سالك'],
#  ['كدميمم', 'سالك', 'تماما'],
#  ['الفندق', 'سالكة', 'بس', 'في', 'جيش', 'تفتيش', 'عشوائي'],
#  ['جميع', 'حواجز', 'نابلس', 'ازمة'],
#  ['قلنديا', 'ازمة', 'داخل'],
#  ['قلنديا', 'كفر', 'عقب', 'سالك', 'للداخل', 'الخارج', 'العجل', 'ماشي'],
#  ['الكونتينر', 'سالك', 'بالاتجاهين'],
#  ['عورتا', 'ازمة', 'للخارج', 'الداخل', 'سالك'],
#  ['ازمه', 'مفرق', 'جيت', 'ماشيه'],
#  ['الكونتينر', 'سالك', 'تماما', 'اتجاهين'],
#  ['لا', 'رجعتهم', 'حكيتلهم', 'حلو', 'عن', 'صدورنا', 'الغرس', 'سالكة'],
#  ['يعني', 'ممكن', 'يوصل', 'الموضوع', 'للغرس'],
#  ['طريق',
#   'شافي',
#   'شمرون',
#   'كل',
#   'ما',
#   'يشوفو',
#   'فتحة',
#   'بوقفو',
#   'السير',
#   'وبسكروها'],
#  ['من', 'ازمه', 'الداخل', 'ع', 'دير', 'شرف'],
#  ['الكونتينر',
#   'سالك',
#   'شمالا',
#   'العجل',
#   'ماشي',
#   'مع',
#   'تفتيش',
#   'عشوائي',
#   'باتجاه',
#   'الجنوب'],
#  ['لتاكيد', 'بوابة', 'زيف', 'سالكه', 'وفاتحه'],
#  ['الكونتينر', 'سالكه', 'عبده', 'مغلقه', 'كرمة', 'فاتحه', 'السموع', 'سالكه'],
#  ['طريق',
#   'العمور',
#   'ازمة',
#   'وتفتيش',
#   'سياره',
#   'سياره',
#   'العبيدية',
#   'ازمة',
#   'باتجاه',
#   'الجنوب'],
#  ['بزاريا', 'مبينة', 'فاتحة', 'بس', 'التسكير', 'لقدام', 'تنغروش', 'وتقدمو'],
#  ['عش',
#   'غراب',
#   'فاتح',
#   'وسالك',
#   'جبع',
#   'فاتح',
#   'وسالك',
#   'قلنديا',
#   'ازمة',
#   'بالاتجاهين'],
#  ['بوابة', 'زيف', 'يطا', 'فاتحه', 'وسالكه'],
#  ['تواجد', 'لقوات', 'الاحتلال', 'على', 'شارع', 'المزرعة', 'الشرقية'],
#  ['ازمة', 'العيزرية', 'والزعيم'],
#  ['حومش', 'سالك'],
#  ['راس', 'الجورة', 'سالك', 'اتجاهين', 'فرش', 'الهوى', 'مغلق'],
#  ['راس',
#   'الجوره',
#   'سالك',
#   'مع',
#   'تواجد',
#   'جيش',
#   'طريق',
#   'لعمور',
#   'يطا',
#   'ازمة',
#   'بوابة',
#   'زيف',
#   'تم',
#   'فتحها',
#   'ويمكن',
#   'عشان',
#   'الجيش',
#   'دخل',
#   'في',
#   'اي',
#   'لحظة',
#   'بتسكر',
#   'حاجز',
#   'على',
#   'طريق',
#   'يبرود'],
#  ['https',
#   'vt',
#   'tiktok',
#   'comZS2WEgAWE',
#   'الطريق',
#   'البديلة',
#   'الغرس',
#   'بزاريا',
#   'واعملولي',
#   'متابعة',
#   'ع',
#   'التيكتوك'],
#  ['بوابة', 'دورا', 'مغلقة', 'القصر', 'سالكه'],
#  ['النشاش', 'سالك', 'ازمه', 'الاشاره'],
#  ['الان', 'العيزرية', 'ازمة', 'اتجاهين', 'حتى', 'الزعيم'],
#  ['الغرس', 'بزاريا', 'الآن'],
#  ['راس', 'الجورة', 'سالك'],
#  ['حاجز', 'الهيئة', 'اريحا', 'سالكة'],
#  ['الزعيم',
#   'ازمه',
#   'بالاتجاهين',
#   'العيزرية',
#   'ازمة',
#   'باتجاه',
#   'الجنوب',
#   'الكونتينر',
#   'سالك',
#   'شمالا',
#   'ازمه',
#   'وفتح',
#   'باتجاه',
#   'الجنوب',
#   'وما',
#   'بوقفوا',
#   'حد',
#   'واد',
#   'النار',
#   'سالك',
#   'النشاش',
#   'سالك'],
#  ['دير', 'شر', 'من', 'جهة', 'شافي', 'شمرون'],
#  ['باتجاه', 'الخان', 'الاحمر', 'بعد', 'العيزرية', 'كثافة', 'سير'],
#  ['مش', 'معدلها', 'خليها', 'صمن'],
#  ['الحمرا', 'الان', 'سالكة'],
#  ['النشاش', 'سالك', 'بالاتجاهين'],
#  ['عناب', 'مغلق', 'من', 'سبع', 'صمن', 'ايام', 'حتى', 'اللحظة'],
#  ['بيت', 'ايل', 'الان', 'مغلق'],
#  ['بديل', 'الزعيم', 'طريق', 'كسارات', 'ابو', 'جورج'],
#  ['الغرس', 'بزاريا', 'الان', 'بس', 'بدها', 'شوية', 'أولويات', 'مش', 'اكتر'],
#  ['مدخل',
#   'رنتيس',
#   'سالك',
#   'ونظيف',
#   'خط',
#   'رنتيس',
#   'اللبن',
#   'سالك',
#   'ونظيف',
#   'خط',
#   'اللبن',
#   'دير',
#   'بلوط',
#   'سالك',
#   'ونظيف',
#   'مفرق',
#   'دير',
#   'بلوط',
#   'سالك',
#   'ونظيف',
#   'بوابة',
#   'كفر',
#   'الديك',
#   'مغلقة',
#   'بوابة',
#   'بروقين',
#   'سالكة',
#   'ونظيفة'],
#  ['الغرس', 'بزاريا', 'العالم', 'فوق', 'بعض', 'ازمة', 'خانقة'],
#  ['الزعيم', 'ازمة', 'اتجاهين'],
#  ['سيارة', 'شرطة', 'على', 'اشارات', 'كرمي', 'سور'],
#  ['الحمرا', 'ازمة', 'للخارج', 'مع', 'تفتيش', 'الشحن', 'بحكيش', 'معه'],
#  ['ما', 'زال', 'الكونتينر', 'فل', 'ازمة', 'باتجاه', 'الجنوب'],
#  ['كف', '٣٥', 'سالك', 'ونظيف', 'بكل', 'الاتجاهات'],
#  ['دير', 'شرف', 'فتح', 'الخط', 'للخارج'],
#  ['دير', 'شرف', 'الان', 'ازمة', 'اتجاهين'],
#  ['قلنديا', 'داخل', 'وخارج', 'ازمة', 'ماشية'],
#  ['حومش', 'سلك', 'بحري', 'الان'],
#  ['الي',
#   'جاي',
#   'من',
#   'نابلس',
#   'ل',
#   'طولكرم',
#   'من',
#   'دير',
#   'شرف',
#   'ع',
#   'مدخل',
#   'برقه',
#   'الرئيسي',
#   'عقبالو',
#   'في',
#   'مدخل',
#   'صغير',
#   'بدايتو',
#   'باطون',
#   'بوصلك',
#   'ل',
#   'ب',
#   'زاريا',
#   'اسمو',
#   'طريق',
#   'الغرس',
#   'الطريق',
#   'ممتاز',
#   'ومزفت',
#   'بنسبة',
#   '90',
#   'ومن',
#   'بزاريا',
#   'ل',
#   'عنبتا',
#   'ل',
#   'طولكرم'],
#  ['الزعيم', 'ازمة', 'باتجاه', 'الجنوب'],
#  ['حاجز', 'جبع', 'سالك'],
#  ['ال', '17', 'سالك', 'عصيره', 'الشماليه'],
#  ['عين', 'سينيا', 'سالك', 'حاجز', 'تحت', 'جسر', 'يبرود'],
#  ['الكونتينر',
#   'ازمة',
#   'باتجاه',
#   'الجنوب',
#   'عش',
#   'الغراب',
#   'سالك',
#   'كثافة',
#   'سير',
#   'تحت',
#   'جسر',
#   'بيت',
#   'ساحور',
#   'وماشي',
#   'السير'],
#  ['ما', 'تخجل', 'يا', 'انس', 'كمل', 'عورتا', 'ازمه', 'خانقة', 'كمان'],
#  ['الخارج',
#   'من',
#   'النصاريه',
#   'ازمة',
#   'خانقة',
#   'الحمرا',
#   'تياسير',
#   'اكم',
#   'سياره',
#   'وسالك'],
#  ['دير', 'شرف', 'شخصيا'],
#  ['المربعة', 'ازمة'],
#  ['حومش', 'حاجز', 'دير', 'شرف', 'ازمة'],
#  ['أزمة', 'جسر', 'بيت', 'ساحور'],
#  ['اخوي', 'البوابه', 'الصفرا', 'والهيئة', 'سالكات', 'مع', 'تواجد', 'للجيش'],
#  ['بديل',
#   'بزاريا',
#   'طريق',
#   'الغرس',
#   'او',
#   'من',
#   'جبارة',
#   'للدخول',
#   'الى',
#   'طولكرم',
#   'او',
#   'العكس'],
#  ['بزاريا'],
#  ['الان', 'تم', 'تسكير', 'مدخل', 'بزاريا'],
#  ['تواجد',
#   'جرافه',
#   'مع',
#   'جيش',
#   'ع',
#   'مدخل',
#   'بزاريا',
#   'الرئيسي',
#   'الله',
#   'يستر'],
#  ['دير', 'شرف', 'الازمه', 'لاعند', 'الجامع', 'لا', 'الخارج'],
#  ['عش',
#   'غراب',
#   'سالكه',
#   'بالاتجاهين',
#   'راس',
#   'الجوره',
#   'سالك',
#   'كف',
#   '٣٥',
#   'سالك',
#   'عصيون',
#   'سالك',
#   'مدخل',
#   'سعير',
#   'سالك',
#   'النبي',
#   'يونس',
#   'مغلق',
#   'كفر',
#   'عقب',
#   'سالك',
#   'وازمة',
#   'خفيفة'],
#  ['اريحا', 'الجنوبي', 'سالك', 'تماما', 'مع', 'عدم', 'تواجد', 'جيش'],
#  ['راس', 'الجوره', 'سالك'],
#  ['جسر', 'حلحول', 'مغلق'],
#  ['اكم',
#   'قلب',
#   'يستاهل',
#   'منكم',
#   'ما',
#   'تبخلوا',
#   'علينا',
#   'بقلب',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'يتسهار',
#   'سالك',
#   'صرة',
#   'سالك',
#   'للخارج',
#   'شاحنات',
#   'ونمر',
#   'صفراء',
#   'وحاليا',
#   'ازمه',
#   'للخارجين',
#   'زعترا',
#   'سالك',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'مغلق',
#   'التفافي',
#   'زواتا',
#   'سالك',
#   'المربعه',
#   'ازمه',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'دير',
#   'شرف',
#   'كثافة',
#   'سير',
#   'عورتا',
#   'ازمه',
#   'للهارج',
#   'بيت',
#   'فوريك',
#   'سالك',
#   'بزاريا',
#   'الرئيسي',
#   'سالك',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'حومش',
#   'حاجز',
#   'عناب',
#   'مغلق',
#   'بالاتجاهين',
#   'اليوم',
#   'التاسع',
#   'ع',
#   'التوالي',
#   'الكفريات',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'تواجد',
#   'الجيش',
#   'إشارات',
#   'حارس',
#   'سالك',
#   'طريق',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'سالك',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'حاجز',
#   'الحمرا',
#   'ازمه',
#   'عوفرا',
#   'سالك',
#   'اارئيل',
#   'سلفيت',
#   'سالك',
#   'خط',
#   'رام',
#   'الله',
#   'نابلس',
#   'سالك',
#   'عين',
#   'سينا',
#   'سالك',
#   'عطارة',
#   'سالك',
#   'عطاره',
#   'فوق',
#   'الجسر',
#   'سالك',
#   'روابي',
#   'سالك',
#   'اشارات',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'سنجل',
#   'مغلق',
#   'سنجل',
#   'المدخل',
#   'الشمالي',
#   'سالك',
#   'شيلو',
#   'سالك',
#   'عيلي',
#   'سالك',
#   'عيون',
#   'الحراميه',
#   'سالك',
#   'بيت',
#   'ايل',
#   'ازمه',
#   'للخارج',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'تحت',
#   'جسر',
#   'جباره',
#   'سالك',
#   'جماعين',
#   'ساالك',
#   'بوابة',
#   'كفل',
#   'حارس'],
#  ['مغلق',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'مردا',
#   'الشرقيه',
#   'سالك',
#   'بديا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'مدخل',
#   'مردا',
#   'الغربي',
#   'سالك',
#   'متواجد',
#   'معكم',
#   'عالخاص',
#   'لا',
#   'اب',
#   'تحديث',
#   'إستفسار'],
#  ['حاجز', 'البنانا', 'مغلق', 'بالبوابات', 'حتى', 'الان'],
#  ['الكونتينر', 'ازمة', 'وتفتيش', 'بتجاه', 'الجنوب'],
#  ['دير', 'شرف', 'سالك', 'بالاتجاهين', 'بحري', 'حالبا'],
#  ['حومش', 'ما', 'تزال', 'حومش', 'حتى', 'اللحظه'],
#  ['حاجز', 'للطالع', 'من', 'اريحا', 'من', 'جهة', 'الجسر'],
#  ['جبع', 'سالك', 'تماما'],
#  ['الحمرا',
#   'للي',
#   'نازل',
#   'على',
#   'اريحا',
#   'ازمة',
#   'شديدة',
#   'للي',
#   'داخل',
#   'على',
#   'نابلس',
#   'ولا',
#   'سياره',
#   'حرفيا'],
#  ['قلنديا', 'داخل', 'وخارج', 'في', 'ازمة', 'عادية'],
#  ['كفر', 'عقب', 'فيها', 'شويت', 'ازمة'],
#  ['جبع', 'حزما', 'سالكه', 'داخل', 'وخارج'],
#  ['دير', 'شرف', 'ازمه', 'ماشيه', 'الان'],
#  ['مدخل',
#   'رنتيس',
#   'سالك',
#   'ونظيف',
#   'خط',
#   'رنتيس',
#   'اللبن',
#   'سالك',
#   'ونظيف',
#   'خط',
#   'اللبن',
#   'دير',
#   'بلوط',
#   'سالك',
#   'ونظيف',
#   'مفرق',
#   'دير',
#   'بلوط',
#   'سالك',
#   'ونظيف',
#   'بوابة',
#   'كفر',
#   'الديك',
#   'مغلقة',
#   'بوابة',
#   'بروقين',
#   'سالكة',
#   'ونظيفة'],
#  ['النشاش', 'سالك', 'بالاتجاهين'],
#  ['الخليل', 'المنشية', 'مغلقة'],
#  ['اكم',
#   'قلب',
#   'يستاهل',
#   'منكم',
#   'ما',
#   'تبخلوا',
#   'علينا',
#   'بقلب',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'يتسهار',
#   'سالك',
#   'صرة',
#   'سالك',
#   'للخارج',
#   'شاحنات',
#   'ونمر',
#   'صفراء',
#   'وحاليا',
#   'ازمه',
#   'للخارجين',
#   'زعترا',
#   'سالك',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'مغلق',
#   'التفافي',
#   'زواتا',
#   'سالك',
#   'المربعه',
#   'ازمه',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'دير',
#   'شرف',
#   'سالك',
#   'حاليا',
#   'عورتا',
#   'ازمه',
#   'للهارج',
#   'بيت',
#   'فوريك',
#   'سالك',
#   'بزاريا',
#   'الرئيسي',
#   'سالك',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'حومش',
#   'حاجز',
#   'عناب',
#   'مغلق',
#   'بالاتجاهين',
#   'اليوم',
#   'التاسع',
#   'ع',
#   'التوالي',
#   'الكفريات',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'تواجد',
#   'الجيش',
#   'إشارات',
#   'حارس',
#   'سالك',
#   'طريق',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'سالك',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'حاجز',
#   'الحمرا',
#   'شبه',
#   'يالك',
#   'عوفرا',
#   'سالك',
#   'اارئيل',
#   'سلفيت',
#   'سالك',
#   'خط',
#   'رام',
#   'الله',
#   'نابلس',
#   'سالك',
#   'عين',
#   'سينا',
#   'سالك',
#   'عطارة',
#   'سالك',
#   'عطاره',
#   'فوق',
#   'الجسر',
#   'سالك',
#   'روابي',
#   'سالك',
#   'اشارات',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'سنجل',
#   'مغلق',
#   'سنجل',
#   'المدخل',
#   'الشمالي',
#   'سالك',
#   'شيلو',
#   'سالك',
#   'عيلي',
#   'سالك',
#   'عيون',
#   'الحراميه',
#   'سالك',
#   'بيت',
#   'ايل',
#   'ازمه',
#   'للخارج',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'تحت',
#   'جسر',
#   'جباره',
#   'سالك',
#   'جماعين',
#   'ساالك',
#   'بوابة',
#   'كفل',
#   'حارس'],
#  ['مغلق',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'مردا',
#   'الشرقيه',
#   'سالك',
#   'بديا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'مدخل',
#   'مردا',
#   'الغربي',
#   'سالك',
#   'جبع',
#   'سالك',
#   'قلنديا',
#   'كفر',
#   'عقب',
#   'سالك',
#   'حزما',
#   'سالك'],
#  ['طبعا',
#   'صاحب',
#   'التريلا',
#   'هاد',
#   'كلو',
#   'ذوق',
#   'ع',
#   'دير',
#   'شرف',
#   'اجا',
#   'بعكس',
#   'وطلع',
#   'ع',
#   'الدوار',
#   'وكسر',
#   'مراية',
#   'سياره',
#   'لا',
#   'اهتم',
#   'معلوم',
#   'مركن',
#   'نمرا',
#   'صفرا',
#   'بس',
#   'لا',
#   'حولا',
#   'ولا',
#   'قوه',
#   'الا',
#   'بالله'],
#  ['دير', 'شرف', 'الان'],
#  ['حاجز', 'الحمرا', 'للخارح', 'ابو', '20', 'سيارة', 'وبمشو'],
#  ['عصيرة', 'ال', '17', 'سالك'],
#  ['حاليا', 'مشو', 'السير'],
#  ['حاليا', 'اصلح', 'مخارج', 'ومداخل', 'دير', 'شرف'],
#  ['حاجز', 'الحمرا', 'ازمة', 'للداخل', 'عالنصارية'],
#  ['من', 'دير', 'شرف', 'لا', 'شافي', 'شمرون', 'بحري'],
#  ['عيلي', 'سالك', 'مع', 'تواجد', 'الجيش', 'والشرطه', 'والطريق', 'سالك'],
#  ['دير', 'شرف', 'الان', 'وضعو', 'ممتاز', 'لا', 'الخارج', '٢٠', 'سياره'],
#  ['المربعه', 'من', 'ساعهع', 'ها', 'الوقفه'],
#  ['واد', 'كانا', 'سالك'],
#  ['للتاكيد', 'ولا', 'سيارة', 'عالحمرا', 'للخارج'],
#  ['دير', 'شرف', 'سالك', 'لداخل', 'الخارج', 'بمشي', 'بس', 'ازمه'],
#  ['جبع', 'سالك', 'حزما', 'سالكه'],
#  ['سنجل',
#   'المدخل',
#   'الغربي',
#   'طبعا',
#   'مغلق',
#   'من',
#   'فتره',
#   'المدخل',
#   'الشمالي',
#   'سالك'],
#  ['عورتا', 'سالك', 'لداخل', 'تماما', 'الخارج', 'الله', 'يكون', 'بلعون'],
#  ['بالنسبة',
#   'الحمرا',
#   'عالداخل',
#   'ما',
#   'زال',
#   'ازمة',
#   'اللي',
#   'خارج',
#   'باتجاه',
#   'اريحا',
#   'ولا',
#   'سيارة'],
#  ['خط', 'ستين', 'عند', 'ترمسعيا', 'سالك', 'حاليا', 'راحو', 'الجيش'],
#  ['إشارات', 'بيت', 'ايل', 'سالك'],
#  ['ما', 'بكلمو', 'حدا'],
#  ['عيلي', 'سالك', 'مع', 'تواجد', 'الجيش', 'والشرطه', 'والمستوطنين'],
#  ['أبو', 'إسكندر', 'دير', 'شرف', 'أزمة', 'خانقة'],
#  ['خط',
#   '٩٠',
#   'سالك',
#   'تماما',
#   'مفرق',
#   'آدم',
#   'سالك',
#   'البوابة',
#   'الصفرا',
#   'اريحا',
#   'مشى',
#   'الوضع',
#   'وفكو',
#   'الحاجز',
#   'الحمرا',
#   'حاليا',
#   'للداخل',
#   'باتجاه',
#   'النصارية',
#   'ازمة',
#   'الخارج',
#   'باتجاه',
#   'اريحا',
#   'ولا',
#   'سيارة',
#   'عليه'],
#  ['حزما', 'للمخماس', 'سالك'],
#  ['حزما', 'سالك'],
#  ['Dso', 'اريحا', 'سالك', 'بحري'],
#  ['الكونتينر', 'سالك', 'بالانجاهين'],
#  ['فرش', 'الهوى', 'مغلق'],
#  ['دير', 'شرف', 'سيء', 'جدا', 'وبكسروا', 'السيارات', 'عالدوار'],
#  ['عيلي', 'لحد', 'اللحظة'],
#  ['المدخل',
#   'الشمالي',
#   'اريحا',
#   'ازمة',
#   'خانقة',
#   'وطويلة',
#   'على',
#   'ما',
#   'يبو',
#   'مغلق'],
#  ['واد', 'كانا', 'ارئيل', 'سالك'],
#  ['عناب', 'مغلق', 'بالاتجاهين'],
#  ['بروقين', 'سالك'],
#  ['مدخل', 'سلفيت', 'الشمالي', 'سالك'],
#  ['من',
#   'دوار',
#   'معالي',
#   'ادوميم',
#   'ل',
#   'إشارات',
#   'البحر',
#   'الميت',
#   'سالك',
#   'تماما',
#   'جسر',
#   'اللنبي',
#   'فاتح',
#   'امام',
#   'حركة',
#   'المسافرين',
#   'والبضائع',
#   'البوابة',
#   'الصفرا',
#   'حاليا',
#   'ازمة',
#   'خانقة',
#   'للخارج',
#   'من',
#   'اريحا'],
#  ['حومش', 'بتجاه', 'نابلس', 'مغلق'],
#  ['خط', 'يتسهار', 'سالك', 'ونظيف', 'تمام'],
#  ['حاجز', 'صره', 'للخارج'],
#  ['تياسير', 'سالك', 'بكل', 'الاتجاهات'],
#  ['هاي', 'لمربعة', 'للداخل'],
#  ['بزاريا', 'سالك', 'تماما'],
#  ['انتبهو'],
#  ['حاجز', 'الحمرا', 'أزمة', 'خانقة'],
#  ['راس', 'الجوره', 'سالك', 'تماما'],
#  ['عطاره', 'روابي'],
#  ['عين', 'سينا', 'سالك', 'تماما'],
#  ['من',
#   'ازمة',
#   'العيزرية',
#   'حاليا',
#   'باتجاه',
#   'الشمال',
#   'رحلة',
#   'العادة',
#   'وزيادة',
#   'بس',
#   'اطلع',
#   'منها',
#   'ان',
#   'شاء',
#   'الله',
#   'راح',
#   'انسى',
#   'وين',
#   'رايح'],
#  ['ازمة', 'المربعة', 'واصلة', 'العين', 'اللي', 'تحت'],
#  ['طريق',
#   'معالي',
#   'ادوميم',
#   'سالكه',
#   'بعد',
#   'ما',
#   'تطلع',
#   'من',
#   'ازمة',
#   'العيزرية',
#   'الزعيم',
#   'عناتا',
#   'حزما',
#   'سالكين'],
#  ['عورتا',
#   'لداخل',
#   'ع',
#   'نابلس',
#   'سالك',
#   'تماما',
#   'الخارج',
#   'الله',
#   'يكون',
#   'بلعون'],
#  ['طازه', 'الان', 'لداخل', 'هاي', 'الازم', 'ع', 'دير', 'شرف', 'الان'],
#  ['تم', 'اغلاق', 'فرش', 'الهوى'],
#  ['شرطة', 'على', 'دوار', 'يتما', 'زعترة'],
#  ['النبي', 'يونس', 'باتجاه', 'سعير', 'فاتحه', 'باتجاه', 'حلحول', 'مغلق'],
#  ['من', 'ازمة', 'المربعة'],
#  ['السير', 'واقف', 'بجميع', 'الاتجاهات', 'ع', 'دير', 'شرف'],
#  ['الكونتينر', 'حاليا'],
#  ['طريق',
#   'رام',
#   'لله',
#   'تحويل',
#   'السيارات',
#   'الى',
#   'معرجات',
#   'اللبن',
#   'بسبب',
#   'الجنازة',
#   'في',
#   'مقبرة',
#   'عيلي'],
#  ['جبع', 'سالك'],
#  ['جسر',
#   'حلحول',
#   'فاتح',
#   'للخارج',
#   'من',
#   'حلحول',
#   'فقط',
#   'والناس',
#   'بتدخل',
#   'بعكس',
#   'السير',
#   'المسلك',
#   'مستخدم',
#   'للاتجاهين'],
#  ['دير', 'شرف', 'حدث', 'بلا', 'حرج'],
#  ['ازمة', 'دير', 'شرف', 'للداخل'],
#  ['اعتذر',
#   'عن',
#   'الخاص',
#   'اخواني',
#   'بسبب',
#   'ظروف',
#   'العمل',
#   'ساقوم',
#   'بنشر',
#   'التحديثات',
#   'كالعاده',
#   'من',
#   'القناة'],
#  ['العيزرية',
#   'العجل',
#   'ماشي',
#   'وان',
#   'شاء',
#   'الله',
#   'شوية',
#   'صبر',
#   'بتكون',
#   'سالكه'],
#  ['من', 'رمزونات', 'النبي', 'يونس', 'لكف', '٣٥', 'سالك', 'بالاتجاهين'],
#  ['تياسير', 'سالك', 'ازمة', 'خفيقة', 'للخارج', 'باتجاه', 'اريحا'],
#  ['حاجز',
#   'بيت',
#   'ايل',
#   'سالك',
#   'للداخل',
#   'الخارج',
#   'حوالي',
#   '١٠',
#   'سيارات',
#   'وسالك'],
#  ['الحمرا', 'حاليا', 'الداخل', 'سالك', 'الخارج', 'لكوربة', 'المي'],
#  ['دير',
#   'شرف',
#   'ازمة',
#   'واقف',
#   'للخارج',
#   'وواقفة',
#   'للخارج',
#   'عكس',
#   'السير',
#   'كمان'],
#  ['المربعة', 'وحسب', 'اللي', 'وصلني', 'احنا', 'سبب', 'الأزمة'],
#  ['اخوي',
#   'حاجز',
#   'البنانا',
#   'مغلق',
#   'العوجا',
#   'والهيئه',
#   'والبوابه',
#   'الصفرا',
#   'سالكات'],
#  ['الحمرا', 'سلك', 'حاليا', 'حوالي', '٣٠', 'سيارة'],
#  ['بوابة', 'كرمه', 'الان'],
#  ['دير',
#   'شرف',
#   'الان',
#   'نزول',
#   'شافي',
#   'شمرون',
#   'لا',
#   'حولا',
#   'ولا',
#   'قوه',
#   'الا',
#   'بالله',
#   'العلي',
#   'العظيم'],
#  ['دير', 'شرف', 'للخارج'],
#  ['دير', 'شرف', 'لداخل'],
#  ['شافي', 'شمرون', 'سالك', 'بزاريا', 'الرئيسي', 'سالك'],
#  ['الحمرا', 'الان', 'لا', 'الخارج', 'من', 'نابلس'],
#  ['بوابات',
#   'النبي',
#   'يونس',
#   'سعير',
#   'الحواور',
#   'العروب',
#   'عصيون',
#   'افرات',
#   'جورة',
#   'الشمعة',
#   'ام',
#   'سلمونا',
#   'المنشية'],
#  ['تقوع', 'بوابة', 'عش', 'الغراب', 'حاليا'],
#  ['عش', 'غراب', 'سالك', 'الكونتينر', 'تفتيش', 'باتجاه', 'الجنوب'],
#  ['فرش',
#   'الهوى',
#   'سالك',
#   'بالاتجاهين',
#   'راس',
#   'الجوره',
#   'سالك',
#   'للداخل',
#   'الخارج',
#   'حاجز',
#   'وتفتيش',
#   'جيب',
#   'شرطة',
#   'على',
#   'كف',
#   '٣٥'],
#  ['الان', 'فتحو', 'البوابتين'],
#  ['ازمة', 'عورتا', 'شوي', 'وبتوصل', 'المفرق'],
#  ['سياره', 'شرطه', 'للخارج', 'من', 'بيت', 'ايل'],
#  ['المربعة', 'ازمه'],
#  ['صرة',
#   'فاتح',
#   'وسالك',
#   'للخارج',
#   'من',
#   'نابلس',
#   'شاحنات',
#   'ضفة',
#   'ونمرا',
#   'صفرا',
#   'شوفيرية',
#   'الشحن',
#   'شو',
#   'بنستنو'],
#  ['دير', 'شرف', 'ما', 'يزال', 'ازمه', 'بالاتجاهين'],
#  ['العيزرية',
#   'للي',
#   'طالع',
#   'ع',
#   'الشمال',
#   'وجماعة',
#   'عكس',
#   'السير',
#   'مش',
#   'مقصرين',
#   'ربي',
#   'يحميهم'],
#  ['عيون', 'الحراميه', 'سالك', 'فش', 'سيارات'],
#  ['التريلا', 'يلي', 'قالبة', 'رمسا', 'واستنفار', 'للشرطة', 'بالمكان'],
#  ['الكونتير', 'بتجاه', 'الجنوب'],
#  ['دير', 'شرف', 'حاليا'],
#  ['الكونتينر', 'تفتيش', 'ع', 'داخل'],
#  ['جسر',
#   'بيت',
#   'كاحل',
#   'سالك',
#   'جسر',
#   'حلحول',
#   'سالك',
#   'راس',
#   'الجورة',
#   'حاليا',
#   'فاتح',
#   'مع',
#   'تواجد',
#   'للجيش'],
#  ['طريق', 'معرجات', 'اللبن', 'ازمه', 'قويه', 'الان'],
#  ['بيت', 'ايل', 'سالك', 'للداخل', 'تفتيش', 'للخارج', 'وازمة', 'بسيطة'],
#  ['شرطة',
#   'على',
#   'دوار',
#   'معالي',
#   'ادوميم',
#   'حاليا',
#   'جماعة',
#   'عكس',
#   'السير',
#   'دير',
#   'بالك',
#   'تتكحل'],
#  ['سيارة', 'شرطة', 'على', 'دوار', 'قدوميم', 'رابطين', 'للجاي', 'من', 'الفندق'],
#  ['ازمة',
#   'وتفتيش',
#   'باتجاه',
#   'الجنوب',
#   'على',
#   'الكونتينر',
#   'الشمال',
#   'سالك',
#   'بس',
#   'بتوقع',
#   'في',
#   'فخ',
#   'ازمة',
#   'العيزرية',
#   'الي',
#   'واصله',
#   'من',
#   'دوار',
#   'معالي',
#   'ادوميم',
#   'لدوار',
#   'البدو'],
#  ['المربعة', 'ودير', 'شرف', 'سالكات', 'الان'],
#  ['تم',
#   'التعميم',
#   'بالامس',
#   'عن',
#   'وجود',
#   'جنازة',
#   'في',
#   'منطقة',
#   'عيلي',
#   'يرجى',
#   'اخذ',
#   'الحيطة',
#   'والحذر'],
#  ['فرش', 'الهوى', 'سالك', 'بالاتجاهين', 'عقبي'],
#  ['الازمه', 'قبل', 'عيلي', 'لا', 'طلعوع', 'معرجات', 'اللبن'],
#  ['دير', 'شرف', 'فاضي'],
#  ['دير', 'شرف', 'سالك', 'بكلشي', 'خالي'],
#  ['العيزاريه',
#   'للخارج',
#   'الى',
#   'الشمال',
#   'مسكره',
#   'وطرقها',
#   'الفرعيه',
#   'سياراه',
#   'فل'],
#  ['زعترا', 'سالك', 'بكل', 'الاتجاهات'],
#  ['شمرون', 'سالك'],
#  ['المربعة', 'الوضع', 'تعيس', 'للاسف'],
#  ['باب', 'ترمسعيا', 'على', 'الشارع', 'الجيش', 'وقف', 'السير', 'كلو'],
#  ['لمربعه',
#   'علخارج',
#   'بلشت',
#   'تسلك',
#   'بس',
#   'شوي',
#   'ازمة',
#   'من',
#   'كثر',
#   'السيارات'],
#  ['دير', 'شرف', 'سالك', 'لداخل', 'راحت', 'الازمه', 'الخارج', 'سالك'],
#  ['بزاريا', 'سالك'],
#  ['بسبب', 'جنازة', 'عندهم', 'الله', 'لا', 'يرحمه'],
#  ['اغلاق', 'الشارع', 'شيلو', 'وعيلي', 'مغلق'],
#  ['تحويل',
#   'خط',
#   'سير',
#   'رام',
#   'الله',
#   'الى',
#   'منعطفات',
#   'اللبن',
#   'الطريق',
#   'القديمه',
#   'باتجاه',
#   'رام',
#   'الله',
#   'والعكس',
#   'بسبب',
#   'تواجد',
#   'المستوطنين'],
#  ['حاجز',
#   'صره',
#   'سالك',
#   'للشاحنات',
#   'ونمرا',
#   'صفراء',
#   'فقط',
#   'مع',
#   'وجود',
#   'ازمه'],
#  ['عيليه', 'عند', 'المقبره'],
#  ['اغلاق', 'كرمه'],
#  ['للتذكير',
#   'وضع',
#   'حاجز',
#   'عناب',
#   'مازال',
#   'مغلق',
#   'بالاتجاهين',
#   'حتى',
#   'الان',
#   'والجيش',
#   'برجع',
#   'السيارات',
#   'والسلامه',
#   'للجميع'],
#  ['دوار', 'الطنيب', 'سالك', 'مع', 'كثافة', 'سير'],
#  ['عورتا', 'لداخل', 'ع', 'نابلس'],
#  ['راس',
#   'الجوره',
#   'سالك',
#   'فرش',
#   'الهوى',
#   'سالك',
#   'الرمضين',
#   'سالك',
#   'كرمه',
#   'سالك'],
#  ['نعم',
#   'صحيح',
#   'أزمة',
#   'الداخل',
#   'ع',
#   'دير',
#   'شرف',
#   'طويله',
#   'جد',
#   'بس',
#   'اطلعو',
#   'بلفديو',
#   'المسافه',
#   'بين',
#   'للسيارات'],
#  ['ازمة', 'دير', 'شرف', 'واصلة', 'نزول', 'جيت'],
#  ['دير', 'شرف', 'الان', 'بمشي', 'وبوقف'],
#  ['عيون', 'الحرامية', 'سالك'],
#  ['فرش', 'الهوى', 'سالك', 'تماما'],
#  ['حومش', 'سيء', 'جدا', 'عالجهتين'],
#  ['الخليل', 'كرمه', 'فاتحه', 'وسالكه', 'الرمضين', 'فاتحه', 'وسالكه'],
#  ['2024',
#   'الاربعاء',
#   '8',
#   '00',
#   'صباحا',
#   'اللهم',
#   'اجمع',
#   'قلوبنا',
#   'على',
#   'خير',
#   'نابلس',
#   'صرة',
#   'مغلق',
#   'للداخل',
#   'صرة',
#   'مغلق',
#   'للخارج',
#   'ونمر',
#   'صفراء',
#   'فقط',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'سالك',
#   'المربعة',
#   'حاليا',
#   'ازمه',
#   'عورتا',
#   'ازمه',
#   'لا',
#   'الخارج',
#   'مفرق',
#   'جيت',
#   'سالك',
#   'حاليا',
#   'الطنيب',
#   'سالك',
#   'حاليا',
#   'دير',
#   'شرف',
#   'ازمه',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'مدخل',
#   'بزاريا',
#   'الرئيسي',
#   'سالك',
#   'طريق',
#   'الغرس',
#   'بزاريا',
#   'سالك',
#   'بيت',
#   'فوريك',
#   'ازمه',
#   'حوارة',
#   'البلد',
#   'سالكة',
#   'الباذان',
#   'سالك',
#   'بوابة',
#   'جماعين',
#   'سالك',
#   'حوارة',
#   'الالتفافي',
#   'الجديد',
#   'سالك',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'زعترة',
#   'سالك',
#   'بجميع',
#   'الاتجاهات',
#   'طريق',
#   'يتسهار',
#   'سالك',
#   'حاجز',
#   'حواره',
#   'مغلق',
#   'رام',
#   'الله',
#   'ال',
#   'dco',
#   'بيت',
#   'ائيل',
#   'مدخل',
#   'البيرة',
#   'الشمالي',
#   'مغلق',
#   'بفتح',
#   'من',
#   'الساعة',
#   '9',
#   'صباحا',
#   'ولغاية',
#   'الساعة',
#   'ال',
#   '3',
#   'عصرا',
#   'وحسب',
#   'المزاج',
#   'الجلزون',
#   'ازمه',
#   'مخماس',
#   'سالك',
#   'حاليا',
#   'عين',
#   'سينيا',
#   'سالك',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'عطارة',
#   'مغلق',
#   'روابي',
#   'حاجز',
#   'جسر',
#   'عطارة',
#   'سالك',
#   'طريق',
#   'رام',
#   'الله',
#   'دير',
#   'بلوط',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'حاليا',
#   'عيلي',
#   'سالك',
#   'حاليا',
#   'ك',
#   'سنجل',
#   'سالك',
#   'عوفرا',
#   'سالك',
#   'كرملو',
#   'وسالك',
#   'بوابة',
#   'عابود',
#   'مغلقة',
#   'سالك',
#   'طريق',
#   'عابود',
#   'الجدار',
#   'مغلق',
#   'بوابة',
#   'دير',
#   'ابو',
#   'مشعل',
#   'سالك',
#   'بوابة',
#   'النبي',
#   'صالح',
#   'مغلقة',
#   'سلفيت',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'باتجاه',
#   'بركان',
#   'مغلق',
#   'بوابة',
#   'سلفيت',
#   'سالك',
#   'البديل',
#   'بروقين',
#   'سلفيت',
#   'في',
#   'حال',
#   'بوابة',
#   'سلفيت',
#   'ارئيل',
#   'مغلقة',
#   'سدة',
#   'قراوة',
#   'سالك',
#   'اشارات',
#   'ارائيل',
#   'سالكة',
#   'اشارات',
#   'حارس',
#   'سالكة',
#   'كدوميم',
#   'سالك',
#   'مع',
#   'تواجد',
#   'شرطه',
#   'واد',
#   'قانا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'واد',
#   'قانا',
#   'سالك',
#   'بوابة',
#   'كفر',
#   'الديك',
#   'مغلقة',
#   'ياسوف',
#   'سلفيت',
#   'مغلقة',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'كفل',
#   'حارس',
#   'سالك',
#   'قلقيلية',
#   'عزبة',
#   'الطبيب',
#   'سالك',
#   'كرني',
#   'شمرون',
#   'سالك',
#   'النبي',
#   'الياس',
#   'حاليا',
#   'النفق',
#   'حبلة',
#   'سالك',
#   'بوابة',
#   'كفر',
#   'لاقف',
#   'سالك',
#   'عزون',
#   'الرئيسي',
#   'مغلق',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'سالك',
#   'طولكرم',
#   'عناب',
#   'مغلق',
#   'باالاتجاهين',
#   'طريق',
#   'الكفريات',
#   'سالك',
#   'جبارة',
#   'تحت',
#   'الجسر',
#   'سالك',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'اللدائن',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'واد',
#   'قانا',
#   'سالك',
#   'بيت',
#   'ليد',
#   'الرئيسي',
#   'مغلق',
#   'مدخل',
#   'رامين',
#   'مغلق',
#   'مدخل',
#   'سفارين',
#   'مغلق',
#   'عزبة',
#   'شوفة',
#   'مغلق',
#   'طريق',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'سهل',
#   'رامين',
#   'مغلق',
#   'جنين',
#   'حومش',
#   'سالك',
#   'مدخل',
#   'بزاريا',
#   'الرئيسي',
#   'سالك',
#   'بزاريا',
#   'الغرس',
#   'سالك',
#   'حاليا',
#   'جبع',
#   'حتى',
#   '١٧',
#   'عصيرة',
#   'نابلس',
#   'سالك',
#   'السيلة',
#   'حتى',
#   'عطارة',
#   'بلعا',
#   'سالك',
#   'دوتان',
#   'مغلق',
#   'حرميش',
#   'مغلق',
#   'طوباس',
#   'لحمرا',
#   'ازمه',
#   'للخارج',
#   'خانقه',
#   'تياسير',
#   'ازمه',
#   'خفيفه',
#   'طوباس',
#   'الباذان',
#   'نابلس',
#   'سالك',
#   'اريحا',
#   'الحمرا',
#   'ازمه',
#   'للخارج',
#   'خانقه',
#   'معالي',
#   'افرايم',
#   'سالك',
#   'خط',
#   '90',
#   'سالك',
#   'حاليا',
#   'المعرجات',
#   'سالك',
#   'ال',
#   'DCO',
#   'سالك',
#   'البوابة',
#   'الصفراء',
#   'حاجز',
#   'الهيئة',
#   'سالك',
#   'حاجز',
#   'البنانا',
#   'سالك',
#   'وضع',
#   'الطريق',
#   'متغير',
#   'بين',
#   'لحظة',
#   'واخرى',
#   'طريق',
#   'السلامة',
#   'للجميع',
#   'وضع',
#   'الطريق',
#   'متغير',
#   'في',
#   'لحظات',
#   'صفحه',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'من',
#   'موقعنا',
#   'على',
#   'التلجرام',
#   'إن',
#   'الله',
#   'وملائكته',
#   'يصلون',
#   'على',
#   'النبي',
#   'يا',
#   'أيها',
#   'الذين',
#   'آمنوا',
#   'صلوا',
#   'عليه',
#   'وسلموا',
#   'تسليما',
#   'اخوكم',
#   'سامر',
#   'ياسين',
#   'والمشرف',
#   'جميل'],
#  ['دير', 'شرف', 'بلش', 'يمشي', 'وفيه', 'ازمة', 'لسا', 'بس', 'خفت'],
#  ['والجيش', 'على', 'كدوميم', 'ما', 'زال', 'موجود', 'تفتيش', 'عشوائي'],
#  ['حاجز', 'جيتيت', 'معلى', 'افرايم', 'سالك', 'ونظيف'],
#  ['سالك', 'الان'],
#  ['بيت', 'ايل', 'فتح', 'مع', 'تفتيش', 'للخارج', 'وسالك', 'داخل'],
#  ['حاجز', 'عند', 'اللدائن'],
#  ['حادث',
#   'انقلاب',
#   'شاحنة',
#   'على',
#   'خط',
#   'اريحا',
#   'قرب',
#   'مدخل',
#   'قرية',
#   'فصائل'],
#  ['اللي', 'قريب', 'من', 'عند', 'اللدائن', 'يشوفلنا', 'وضع', 'المدخل'],
#  ['تحديث', 'دير', 'شرف', 'للداخل', 'على', 'نابلس', 'السير', 'واقف'],
#  ['الازمه',
#   'على',
#   'المربعه',
#   'للخارج',
#   'مش',
#   'طبيعيه',
#   'بس',
#   'للي',
#   'داخل',
#   'شبه',
#   'سالكه'],
#  ['قال',
#   'الله',
#   'تعالى',
#   'من',
#   'ذا',
#   'الذي',
#   'يقرض',
#   'الله',
#   'قرضا',
#   'حسنا',
#   'فيضاعفه',
#   'له',
#   'وله',
#   'أجر',
#   'كريم',
#   'صفحة',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'منطقة',
#   'ضواحي',
#   'القدس',
#   'قلنديا',
#   'سالكه',
#   'كفر',
#   'عقب',
#   'سالكه',
#   'جبع',
#   'ازمه',
#   'حزما',
#   'عناتا',
#   'الزعيم',
#   'ازمه',
#   'طريق',
#   'معالي',
#   'ادوميم',
#   'سالك',
#   'العيزرية',
#   'ازمه',
#   'حاجز',
#   'الكونتينر',
#   'منطقة',
#   'بيت',
#   'لحم',
#   'العبيدية',
#   'سالكة',
#   'جسر',
#   'بيت',
#   'ساحور',
#   'مغلق',
#   'تقوع',
#   'البلد',
#   'تل',
#   'الربيع',
#   'سالكه',
#   'الترابيه',
#   'بوابة',
#   'جناتا',
#   'مغلقه',
#   'النشاش',
#   'سالك',
#   'طريق',
#   'السدر',
#   'فاتحه',
#   'زعتره',
#   'بيت',
#   'لحم',
#   'مغلق',
#   'مدخل',
#   'بيت',
#   'فجار',
#   'مغلق',
#   'الخليل',
#   'مدخل',
#   'قرية',
#   'المنيا',
#   'سالك',
#   'بالاتجاهين',
#   'مدخل',
#   'بربرة',
#   'مغلق',
#   'جورة',
#   'الشمعه',
#   'سالكه',
#   'المنشية',
#   'صفحة',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'مدخل',
#   'الحواور',
#   'بوابة',
#   'سعير',
#   'بوابة',
#   'بيت',
#   'عينون',
#   'مغلقة',
#   'عصيون',
#   'سالك',
#   'دوار',
#   'فرات',
#   'رمزونات',
#   'فرات',
#   'سالكين',
#   'راس',
#   'الجوره',
#   'حاجز',
#   'للخارج',
#   'على',
#   'فرش',
#   'الهوى',
#   'جسر',
#   'حلحول',
#   'طريق',
#   'حسكه',
#   'سالكه',
#   'بوابة',
#   'بلدة',
#   'بيت',
#   'عوا',
#   'مغلقة',
#   'بوابة',
#   'مثلث',
#   'خرسا',
#   'فاتحة',
#   'بوابة',
#   'مستوطنة',
#   'نيجهوت',
#   'مغلقة',
#   'بوابة',
#   'الخطوط',
#   'الغربية',
#   'لمدينة',
#   'دورا',
#   'مغلقة',
#   'بوابة',
#   'بيت',
#   'عوا',
#   'مسكره',
#   'بوابة',
#   'اذنا',
#   'الليه',
#   'بوابة',
#   'زيف',
#   'خلة',
#   'المي',
#   'سالكه',
#   'كرمه',
#   'باتجاه',
#   'يطا',
#   'وكريم',
#   'سالكة',
#   'مدخل',
#   'الظاهرية',
#   'مغلق',
#   'بني',
#   'نعيم',
#   'بوابة',
#   'العروب',
#   'النبي',
#   'يونس',
#   'عش',
#   'غراب',
#   'ترقوميا',
#   'المصانع',
#   'سالكه',
#   'جسر',
#   'بيت',
#   'كاحل',
#   'سالك',
#   'بوابة',
#   'الفحص',
#   'مغلقه',
#   'الرجاء',
#   'من',
#   'الجميع',
#   'يقرأ',
#   'التقرير',
#   'ويضغطاو',
#   'غير',
#   'متواجد',
#   'خاص',
#   'نهائيا',
#   'العقبي'],
#  ['طريق', 'الباذان', 'الفارعة', 'طوباس', 'جنين', 'سالكة'],
#  ['الحمرا', 'ازمة', 'قوية', 'جهة', 'اريحا'],
#  ['تياسير', 'ازمة', 'خفيفة'],
#  ['عند', 'حلميش', 'حاجز', 'تفتيش', 'الهويات'],
#  ['الجيش', 'برجع', 'السيارات', 'عند', 'إشارات', 'بيت', 'ايل'],
#  ['العيزرية', 'مازم'],
#  ['كدميمم', 'سالك', 'مع', 'تواجد', 'الجيش'],
#  ['حاجز',
#   'تفتيش',
#   'على',
#   'الهيئة',
#   'اريحا',
#   'البوابه',
#   'الصفرا',
#   'خط',
#   'الجسر',
#   'سالكة'],
#  ['من', 'ازمه', 'الداخل', 'ع', 'نابلس', 'عن', 'طريق', 'دير', 'شرف'],
#  ['للداخل', 'عالسيلة', 'العكس', 'سالك'],
#  ['بالنسبة',
#   'للمربعة',
#   'ازمة',
#   'ع',
#   'الي',
#   'خارج',
#   'ع',
#   'الي',
#   'فايت',
#   'بسال',
#   'سيارة',
#   'سيارة',
#   'وين',
#   'رايح',
#   'ومن',
#   'هالحكي',
#   'انتبهوا'],
#  ['حاجز', 'ع', 'حومش'],
#  ['بزاريا', 'بحري', 'لا', 'المعني', 'بلفديو', 'في', 'كلام', 'توضيح'],
#  ['حاجز', 'ع', 'مدخل', 'دير', 'نظام'],
#  ['عطارة', 'سالك'],
#  ['سكرو', 'بوابة', 'دير', 'ابو', 'مشعل', 'وبوابة', 'عابود'],
#  ['عورتا',
#   'للداخل',
#   'ازمه',
#   'كف',
#   'والخارج',
#   'لبعد',
#   'كراج',
#   'ابو',
#   'عايش',
#   'اشوي',
#   'وتوصل',
#   'الروضه'],
#  ['حجة', 'والفندق', 'سالكين'],
#  ['حالة',
#   'الطرق',
#   'لبعض',
#   'مداخل',
#   'محافظة',
#   'الخليل',
#   '08',
#   '30',
#   'صباحا',
#   'مدخل',
#   'بلدة',
#   'السموع',
#   'السيميا',
#   'مغلق',
#   'مدخل',
#   'المرمله',
#   'سالك',
#   'مدخل',
#   'بير',
#   'المي',
#   'مغلق',
#   'مدخل',
#   'كرمه',
#   'مغلق',
#   'مدخل',
#   'البقارية',
#   'سالك',
#   'مدخل',
#   'الهجرة',
#   'مغلق',
#   'مدخل',
#   'ابو',
#   'العرقان',
#   'سالك',
#   'مدخل',
#   'العقد',
#   'مغلق',
#   'مدخل',
#   'قريه',
#   'عبده',
#   'مغلق',
#   'مدخل',
#   'طريق',
#   'القصر',
#   'سالك',
#   'مدخل',
#   'يطا',
#   'طريق',
#   'العمور',
#   'سالك',
#   'مدخل',
#   'مدينة',
#   'دورا',
#   'مغلق',
#   'مدخل',
#   'مخيم',
#   'الفوار',
#   'باتجاه',
#   'الالتفافي',
#   'مغلق',
#   'مدخل',
#   'مدينة',
#   'يطا',
#   'زيف',
#   'مغلق',
#   'مدخل',
#   'ترقوميا',
#   'المصانع',
#   'سالك',
#   'مدخل',
#   'الخليل',
#   'رأس',
#   'الجورة',
#   'سالك',
#   'للداخل',
#   'تفتيش',
#   'للخارج',
#   'مدخل',
#   'الخليل',
#   'فرش',
#   'الهوا',
#   'مغلق',
#   'مدخل',
#   'قلقس',
#   'مغلق',
#   'مدخل',
#   'الفحص',
#   'مغلق',
#   'مدخل',
#   'بني',
#   'نعيم',
#   'مغلق'],
#  ['حاجز',
#   'على',
#   'dco',
#   'وازمه',
#   'حاجز',
#   'على',
#   'الهيئه',
#   'وازمه',
#   'البنانا',
#   'مغلق',
#   'البوابه',
#   'صفرا',
#   'حتى',
#   'اللحظة',
#   'سالك',
#   'الداخل',
#   'سالك',
#   'لجميع',
#   'الحواجز'],
#  ['الجلزون', 'أزمة', 'خانقة'],
#  ['حاجز', 'بيت', 'فوريك', 'ازمة', 'بالاتجاهين'],
#  ['المربعة', 'واقفة'],
#  ['مدخل', 'حجة', 'سالك', 'مع', 'تواجد', 'لجيش'],
#  ['مدخل', 'قلقيلة', 'سالك'],
#  ['شارع', '55', 'سالك'],
#  ['الهيئة', 'حاجز', 'للخارج', 'وبداية', 'ازمة'],
#  ['دير', 'شرف', 'ازمة', 'بجميع', 'الاتجاهات'],
#  ['ازمة', 'الطالع', 'من', 'العيزرية', 'للواد'],
#  ['للمسافرين',
#   'على',
#   'طريق',
#   'رام',
#   'الله',
#   'يرجى',
#   'الانتباه',
#   'والأخذ',
#   'بالحسبان',
#   'اي',
#   'اعتداء',
#   'أو',
#   'تشويش',
#   'على',
#   'الطريق'],
#  ['حيث',
#   'ستكون',
#   'جنازة',
#   'لضابط',
#   'في',
#   'مقبرة',
#   'عيلي',
#   'قتل',
#   'في',
#   'الجنوب',
#   'اليوم',
#   'الساعة',
#   '10',
#   'صباحا'],
#  ['الدهيشة',
#   'للي',
#   'داخل',
#   'على',
#   'بيت',
#   'لحم',
#   'أزمة',
#   'الخارج',
#   'سالك',
#   'طريق',
#   'الاسكانات',
#   'سالكه',
#   'بيت',
#   'جالا',
#   'النفق',
#   'ع',
#   'القدس',
#   'سالك',
#   'تواجد',
#   'للشرطة',
#   'على',
#   'أول',
#   'إشارة',
#   'بعد',
#   'النفق'],
#  ['النبي', 'يونس', 'باتجاه', 'حلحول', 'مغلقة', 'باتجاه', 'سعير', 'سالكه'],
#  ['روابي', 'حاجز', 'وتفتيش'],
#  ['طريق', 'ال', '17', 'سالك'],
#  ['اليوم',
#   '6102024',
#   'الاحد',
#   '8',
#   '10',
#   'صباحا',
#   'اللهم',
#   'اجمع',
#   'قلوبنا',
#   'على',
#   'خير',
#   'نابلس',
#   'صرة',
#   'مغلق',
#   'للداخل',
#   'صرة',
#   'مغلق',
#   'للخارج',
#   'شاحنات',
#   'ونمر',
#   'صفراء',
#   'فقط',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'مغلق',
#   'المربعة',
#   'ازمه',
#   'خانقة',
#   'بالاتجاهين',
#   'عورتا',
#   'ازمه',
#   'للخارج',
#   'مفرق',
#   'جيت',
#   'سالك',
#   'حاليا',
#   'الطنيب',
#   'سالك',
#   'حاليا',
#   'دير',
#   'شرف',
#   'من',
#   'الاتجاهات',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'مدخل',
#   'بزاريا',
#   'الرئيسي',
#   'سالك',
#   'طريق',
#   'الغرس',
#   'بزاريا',
#   'سالك',
#   'بيت',
#   'فوريك',
#   'ازمه',
#   'خفيفه',
#   'حوارة',
#   'البلد',
#   'سالكة',
#   'الباذان',
#   'سالك',
#   'بوابة',
#   'جماعين',
#   'سالك',
#   'حوارة',
#   'الالتفافي',
#   'الجديد',
#   'سالك',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'زعترة',
#   'سالك',
#   'بجميع',
#   'الاتجاهات',
#   'طريق',
#   'يتسهار',
#   'سالك',
#   'حاجز',
#   'حواره',
#   'مغلق',
#   'رام',
#   'الله',
#   'ال',
#   'dco',
#   'بيت',
#   'ائيل',
#   'مدخل',
#   'البيرة',
#   'الشمالي',
#   'مغلق',
#   'بفتح',
#   'من',
#   'الساعة',
#   '9',
#   'صباحا',
#   'ولغاية',
#   'الساعة',
#   'ال',
#   '3',
#   'عصرا',
#   'وحسب',
#   'المزاج',
#   'الجلزون',
#   'ازمه',
#   'سير',
#   'مخماس',
#   'سالك',
#   'حاليا',
#   'عين',
#   'سينيا',
#   'سالك',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'عطارة',
#   'سالك',
#   'روابي',
#   'سالك',
#   'جسر',
#   'عطارة',
#   'سالك',
#   'طريق',
#   'رام',
#   'الله',
#   'دير',
#   'بلوط',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'حاليا',
#   'عيلي',
#   'سالك',
#   'حاليا',
#   'سنجل',
#   'سالك',
#   'عوفرا',
#   'سالك',
#   'كرملو',
#   'وسالك',
#   'بوابة',
#   'عابود',
#   'مغلقة',
#   'سالك',
#   'طريق',
#   'عابود',
#   'الجدار',
#   'سالكة',
#   'بوابة',
#   'دير',
#   'ابو',
#   'مشعل',
#   'سالك',
#   'بوابة',
#   'النبي',
#   'صالح',
#   'مغلقة',
#   'سلفيت',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'باتجاه',
#   'بركان',
#   'مغلق',
#   'بوابة',
#   'سلفيت',
#   'سالك',
#   'البديل',
#   'بروقين',
#   'سلفيت',
#   'في',
#   'حال',
#   'بوابة',
#   'سلفيت',
#   'ارئيل',
#   'مغلقة',
#   'سدة',
#   'قراوة',
#   'سالك',
#   'اشارات',
#   'ارائيل',
#   'سالكة',
#   'اشارات',
#   'حارس',
#   'سالكة',
#   'كدوميم',
#   'سالك',
#   'واد',
#   'قانا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'واد',
#   'قانا',
#   'سالك',
#   'بوابة',
#   'كفر',
#   'الديك',
#   'مغلقة',
#   'ياسوف',
#   'سلفيت',
#   'مغلقة',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'كفل',
#   'حارس',
#   'مغلق',
#   'قلقيلية',
#   'الفندق',
#   'حاجز',
#   'عزبة',
#   'الطبيب',
#   'سالك',
#   'كرني',
#   'شمرون',
#   'سالك',
#   'النبي',
#   'الياس',
#   'حاليا',
#   'النفق',
#   'حبلة',
#   'سالك',
#   'بوابة',
#   'كفر',
#   'لاقف',
#   'سالك',
#   'عزون',
#   'الرئيسي',
#   'مغلق',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'طولكرم',
#   'عناب',
#   'مغلق',
#   'باالاتجاهين',
#   'طريق',
#   'الكفريات',
#   'سالك',
#   'جبارة',
#   'تحت',
#   'الجسر',
#   'سالك',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'اللدائن',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'واد',
#   'قانا',
#   'سالك',
#   'بيت',
#   'ليد',
#   'الرئيسي',
#   'مغلق',
#   'مدخل',
#   'رامين',
#   'مغلق',
#   'مدخل',
#   'سفارين',
#   'مغلق',
#   'عزبة',
#   'شوفة',
#   'مغلق',
#   'طريق',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'سهل',
#   'رامين',
#   'مغلق',
#   'جنين',
#   'حومش',
#   'سالك',
#   'مدخل',
#   'بزاريا',
#   'الرئيسي',
#   'سالك',
#   'بزاريا',
#   'الغرس',
#   'سالك',
#   'حاليا',
#   'جبع',
#   'حتى',
#   '١٧',
#   'عصيرة',
#   'نابلس',
#   'سالك',
#   'السيلة',
#   'حتى',
#   'عطارة',
#   'بلعا',
#   'سالك',
#   'دوتان',
#   'مغلق',
#   'حرميش',
#   'مغلق',
#   'طوباس',
#   'لحمرا',
#   'ازمه',
#   'تياسير',
#   'ازمه',
#   'طوباس',
#   'الباذان',
#   'نابلس',
#   'سالك',
#   'اريحا',
#   'الحمرا',
#   'ازمه',
#   'معالي',
#   'افرايم',
#   'سالك',
#   'مع',
#   'تواجد',
#   'الجيش',
#   'خط',
#   '90',
#   'سالك',
#   'حاليا',
#   'المعرجات',
#   'سالك',
#   'حاليا',
#   'ال',
#   'DCO',
#   'سالك',
#   'البوابة',
#   'الصفراء',
#   'حاجز',
#   'الهيئة',
#   'حاجز',
#   'حاجز',
#   'البنانا',
#   'مغلق',
#   'وضع',
#   'الطريق',
#   'متغير',
#   'بين',
#   'لحظة',
#   'واخرى',
#   'طريق',
#   'السلامة',
#   'للجميع',
#   'وضع',
#   'الطريق',
#   'متغير',
#   'في',
#   'لحظات',
#   'صفحه',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'من',
#   'موقعنا',
#   'على',
#   'التلجرام',
#   'إن',
#   'الله',
#   'وملائكته',
#   'يصلون',
#   'على',
#   'النبي',
#   'يا',
#   'أيها',
#   'الذين',
#   'آمنوا',
#   'صلوا',
#   'عليه',
#   'وسلموا',
#   'تسليما',
#   'اخوكم',
#   'سامر',
#   'ياسين',
#   'والمشرف',
#   'جميل'],
#  ['اسعد',
#   'الله',
#   'صباحكم',
#   'قال',
#   'الله',
#   'تعالى',
#   'من',
#   'ذا',
#   'الذي',
#   'يقرض',
#   'الله',
#   'قرضا',
#   'حسنا',
#   'فيضاعفه',
#   'له',
#   'وله',
#   'أجر',
#   'كريم',
#   'صفحة',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'منطقة',
#   'ضواحي',
#   'القدس',
#   'قلنديا',
#   'ازمه',
#   'كفر',
#   'عقب',
#   'ازمة',
#   'جبع',
#   'سالك',
#   'حزما',
#   'سالك',
#   'عناتا',
#   'سالك',
#   'الزعيم',
#   'سالك',
#   'طريق',
#   'معالي',
#   'ادوميم',
#   'سالك',
#   'العيزرية',
#   'ازمة',
#   'خانقة',
#   'الكونتينر',
#   'سالك',
#   'منطقة',
#   'بيت',
#   'لحم',
#   'العبيدية',
#   'سالكة',
#   'جسر',
#   'بيت',
#   'ساحور',
#   'مغلق',
#   'تقوع',
#   'البلد',
#   'تل',
#   'الربيع',
#   'سالكه',
#   'الترابيه',
#   'بوابة',
#   'جناتا',
#   'مغلقه',
#   'النشاش',
#   'فاتح',
#   'طريق',
#   'السدر',
#   'فاتحه',
#   'زعتره',
#   'بيت',
#   'لحم',
#   'مغلق',
#   'مدخل',
#   'بيت',
#   'فجار',
#   'مغلق',
#   'الخليل',
#   'مدخل',
#   'قرية',
#   'المنيا',
#   'سالك',
#   'بالاتجاهين',
#   'مدخل',
#   'بربرة',
#   'مغلق',
#   'جورة',
#   'الشمعه',
#   'المنشيه',
#   'صفحة',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'مدخل',
#   'الحواور',
#   'بوابة',
#   'سعير',
#   'بوابة',
#   'بيت',
#   'عينون',
#   'مغلقة',
#   'عصيون',
#   'سالك',
#   'دوار',
#   'فرات',
#   'رمزونات',
#   'فرات',
#   'سالكين',
#   'راس',
#   'الجوره',
#   'فرش',
#   'الهوى',
#   'جسر',
#   'حلحول',
#   'طريق',
#   'حسكه',
#   'سالكه',
#   'بوابة',
#   'بلدة',
#   'بيت',
#   'عوا',
#   'مغلقة',
#   'بوابة',
#   'مثلث',
#   'خرسا',
#   'فاتحة',
#   'بوابة',
#   'مستوطنة',
#   'نيجهوت',
#   'مغلقة',
#   'بوابة',
#   'الخطوط',
#   'الغربية',
#   'لمدينة',
#   'دورا',
#   'مغلقة',
#   'بوابة',
#   'بيت',
#   'عوا',
#   'مسكره',
#   'بوابة',
#   'اذنا',
#   'الليه',
#   'كرمه',
#   'باتجاه',
#   'يطا',
#   'مدخل',
#   'الظاهرية',
#   'مغلق',
#   'بني',
#   'نعيم',
#   'بوابة',
#   'العروب',
#   'النبي',
#   'يونس',
#   'عش',
#   'غراب',
#   'سالك',
#   'ترقوميا',
#   'المصانع',
#   'الطريق',
#   'الترابيه',
#   'في',
#   'حال',
#   'عدم',
#   'تواجد',
#   'جيش',
#   'سالكه',
#   'جسر',
#   'بيت',
#   'كاحل',
#   'سالك',
#   'الرجاء',
#   'من',
#   'الجميع',
#   'يقرأ',
#   'التقرير',
#   'ويضغطاو',
#   'غير',
#   'متواجد',
#   'خاص',
#   'نهائيا',
#   'العقبي'],
#  ['كرمة', 'مغلق'],
#  ['بيت', 'ليد', 'اللدائن', 'حاجز', 'للخارج', 'من', 'بيت', 'ليد', 'و', 'أزمة'],
#  ['الآن', 'فتح', 'السير', 'للخارج', 'من', 'دير', 'شرف', 'لاكن', 'ببطئ'],
#  ['المربعة', 'الان'],
#  ['الزعيم', 'سالك'],
#  ['الداخل', 'على', 'العيزرية', 'وقوف', 'تام'],
#  ['الحمرا', 'الان'],
#  ['مدخل', 'قلقيلة', 'سالك'],
#  ['المربعة',
#   'عورتا',
#   'دير',
#   'شرف',
#   'الحمراا',
#   'ازمة',
#   'خانقةة',
#   'جداا',
#   'للخارج',
#   'من',
#   'نابلس'],
#  ['جسر',
#   'حلحول',
#   'فاتح',
#   'جهة',
#   'وحدة',
#   'للطالع',
#   'من',
#   'حلحول',
#   'بس',
#   'للداخل',
#   'السيارات',
#   'بتدخل',
#   'عكس',
#   'السير',
#   'عادي'],
#  ['حاجز',
#   'عمدخل',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'بعدو',
#   'موجود',
#   'وفي',
#   'ناس',
#   'الها',
#   'ساعة',
#   'تقريبا'],
#  ['العيزرية', 'فتح', 'الحاجز', 'لكن', 'أزمة', 'قوية'],
#  ['حاجز', 'للداخل', 'على', 'يتسهار', 'مع', 'تفتيش', 'عشوائي'],
#  ['من',
#   'ازمة',
#   'دير',
#   'شرف',
#   'للخارج',
#   'لقصر',
#   'الاحلام',
#   'ازمة',
#   'مش',
#   'طبيعية'],
#  ['حاجز', 'الحمرا', 'ازمة', 'لبعد', 'بركة', 'المي'],
#  ['بوابة',
#   'بروقين',
#   'سالكة',
#   'بوابة',
#   'كفر',
#   'الديك',
#   'مغلقة',
#   'مفرق',
#   'دير',
#   'بلوط',
#   'سالك',
#   'خط',
#   'دير',
#   'بلوط',
#   'اللبن',
#   'سالك'],
#  ['أزمة', 'دير', 'شرف', 'للداخل'],
#  ['اكم',
#   'قلب',
#   'يستاهل',
#   'منكم',
#   'ما',
#   'تبخلوا',
#   'علينا',
#   'بقلب',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'يتسهار',
#   'سالك',
#   'صرة',
#   'مغلق',
#   'للخارج',
#   'شاحنات',
#   'ونمر',
#   'صفراء',
#   'زعترا',
#   'سالك',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'مغلق',
#   'التفافي',
#   'زواتا',
#   'سالك',
#   'المربعه',
#   'ازمه',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'دير',
#   'شرف',
#   'ازمه',
#   'مع',
#   'كثافة',
#   'سير',
#   'عورتا',
#   'ازمه',
#   'للهارج',
#   'بيت',
#   'فوريك',
#   'سالك',
#   'بزاريا',
#   'الرئيسي',
#   'سالك',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'حومش',
#   'سالك',
#   'عناب',
#   'مغلق',
#   'بالاتجاهين',
#   'اليوم',
#   'التاسع',
#   'ع',
#   'التوالي',
#   'الكفريات',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'تواجد',
#   'الجيش',
#   'إشارات',
#   'حارس',
#   'سالك',
#   'طريق',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'سالك',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'حاجز',
#   'الحمرا',
#   'ازمه',
#   'عوفرا',
#   'سالك',
#   'اارئيل',
#   'سلفيت',
#   'سالك',
#   'خط',
#   'رام',
#   'الله',
#   'نابلس',
#   'سالك',
#   'عين',
#   'سينا',
#   'سالك',
#   'عطارة',
#   'سالك',
#   'عطاره',
#   'فوق',
#   'الجسر',
#   'سالك',
#   'روابي',
#   'سالك',
#   'اشارات',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'سنجل',
#   'مغلق',
#   'سنجل',
#   'المدخل',
#   'الشمالي',
#   'سالك',
#   'شيلو',
#   'سالك',
#   'عيلي',
#   'سالك',
#   'عيون',
#   'الحراميه',
#   'سالك',
#   'بيت',
#   'ايل',
#   'مغلق',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'تحت',
#   'جسر',
#   'جباره',
#   'سالك',
#   'جماعين',
#   'ساالك',
#   'بوابة',
#   'كفل',
#   'حارس'],
#  ['شارع', '55', 'سالك', 'مع', 'تواجد', 'لسيارة', 'شرطة'],
#  ['مغلق',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'مردا',
#   'الشرقيه',
#   'سالك',
#   'بديا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'مدخل',
#   'مردا',
#   'الغربي',
#   'سالك'],
#  ['ازمة', 'الحمرا'],
#  ['اربع', 'خمس', 'سيارات', 'شرطة', 'ع', 'رمزون', 'رامي', 'ليفي'],
#  ['دير',
#   'شرف',
#   'من',
#   'أكثر',
#   'من',
#   'عشر',
#   'دقائق',
#   'السير',
#   'واقف',
#   'وقوف',
#   'تام'],
#  ['حاجز', 'الهيئة', 'سالك', 'تمااما'],
#  ['حاجز', 'الحمرا', 'ازمة', 'للخااارج'],
#  ['المربعة', 'ازمة', 'بالاتجاهين'],
#  ['تفتيش', 'سيارات', 'عشوائي', 'ع', 'دوار', 'قدوميم'],
#  ['المربعة', 'حدث', 'ولا', 'حرج'],
#  ['ازمة', 'ماشية', 'حجة'],
#  ['حجة', 'الفندق', 'سالك'],
#  ['الحمدلله',
#   'بعد',
#   'ساعتين',
#   'في',
#   'الازمه',
#   'طلعنا',
#   'من',
#   'العيزرية',
#   'قرف',
#   'عكس',
#   'السير',
#   'غير',
#   'قرف',
#   'الجيش'],
#  ['معالي', 'افرايم', 'فش', 'عليه', 'حدا', 'بس', 'ازمه', 'سير', 'خفيفه'],
#  ['العبيدية',
#   'كثافة',
#   'سير',
#   'وطلاب',
#   'نرجو',
#   'التروي',
#   'من',
#   'الاوكتافيا',
#   'والكادي'],
#  ['من',
#   'ساعة',
#   'ولا',
#   'متر',
#   'مشي',
#   'السير',
#   'العيزرية',
#   '٦',
#   'مسالك',
#   'للخارج'],
#  ['طبعا', 'عورتا', 'للخارج', 'الازمة', 'لشارع', 'روجيب'],
#  ['من', 'راس', 'جورة', 'حتى', 'عش', 'غراب', 'سالك'],
#  ['كثافة', 'سير', 'ترمسعيا', 'سنجل'],
#  ['عورتا',
#   'سالك',
#   'ل',
#   'الداخل',
#   'وفش',
#   'ولا',
#   'سيارة',
#   'وازمة',
#   'مع',
#   'تفتيش',
#   'السيارات',
#   'والهويات',
#   'ل',
#   'الي',
#   'خارج',
#   'من',
#   'نابلس'],
#  ['دير', 'شرف', 'ازمة', 'للخارج'],
#  ['عورتاا', 'ازمة', 'للخارج', 'من', 'نابلس'],
#  ['جبارة', 'سالك'],
#  ['الجلزون', 'أزمة', 'ماشية', 'حاليا'],
#  ['تياسير', 'سالك'],
#  ['اللدائن', 'حاجز', 'مع', 'تفتيش'],
#  ['حجة', 'حاجز', 'وسط', 'البلد', 'يقوم', 'بتفتيش', 'المركبات'],
#  ['تواجد', 'جنود', 'وجيبات', 'دون', 'تفتيش', 'قبل'],
#  ['راس', 'الجورة', 'فاتح', 'بالاتجاهين'],
#  ['عين', 'سينا', 'سالك', 'بالاتجاهين'],
#  ['عقابا',
#   'تواجد',
#   'الجيش',
#   'للي',
#   'رايح',
#   'عجنين',
#   'البديل',
#   'من',
#   'القرى',
#   'الجديدة',
#   'سهل',
#   'الكفير',
#   'الزبابدة',
#   'سالكة'],
#  ['راس', 'الجوره', 'فتح', 'لا', 'الداخل', 'الان'],
#  ['حزما', 'ازمة', 'ماشيه'],
#  ['نزول', 'جفنا'],
#  ['نزول',
#   'شافي',
#   'شمرون',
#   'بتجاه',
#   'دير',
#   'شرف',
#   'طبعا',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'بدون',
#   'تواجد',
#   'الجيش'],
#  ['عش', 'الغراب', 'سالك'],
#  ['الخروج', 'من', 'الخليل', 'عن', 'طريق', 'ترقوميا'],
#  ['جبع', 'فاضي', 'وسالك', 'وما', 'في', 'عليه', 'سير'],
#  ['صباح',
#   'الخير',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'جيش',
#   'بفتشو',
#   'بفحصو',
#   'ع',
#   'الهويات'],
#  ['دير', 'شرف', 'فتح', 'الحاجز', 'حاليا', 'مع', 'وجود', 'أزمة', 'قوية'],
#  ['جبع', 'سالك', 'ونظيف', 'مع', 'كثافة', 'سير', 'ماشيه'],
#  ['قلنديا', 'وكفر', 'عقب', 'شبه', 'سالكات'],
#  ['زعتره', 'سالكه', 'بجميع', 'الاتجاهات'],
#  ['عناب', 'مغلق', 'بيت', 'ليد', 'المصانع', 'سالكه'],
#  ['من', 'اشارات', 'شيلو', 'باتجاه', 'ترمسعيا', 'ازمة'],
#  ['بزاريا', 'سالك', 'تماما', 'حومش', 'سالك', 'تماما', 'شافي', 'شمرون', 'سالك'],
#  ['دوار',
#   'الطنيب',
#   'سالك',
#   'مفرق',
#   'جيت',
#   'سالك',
#   'خط',
#   'يتسهار',
#   'سالك',
#   'صره',
#   'مغلق',
#   'بالاتجاهين'],
#  ['دير',
#   'شرف',
#   'ازمه',
#   'خانقة',
#   'لداخل',
#   'والخارج',
#   'والي',
#   'نازل',
#   'من',
#   'شافي',
#   'شمرون'],
#  ['Dso', 'اريحا', 'سالك', 'بالاتجاهين'],
#  ['جبارة', 'سالك'],
#  ['العيزريه', 'الازمه', 'واصله', 'مدخل', 'ابوديس', 'من', 'تحت'],
#  ['الوضع', 'كارثي', 'بمعنى', 'الكلمه'],
#  ['العيزرية'],
#  ['جبع', 'سالك'],
#  ['كرمه', 'مغلقه'],
#  ['دورا', 'مغلقة', 'الفحص', 'مغلقة', 'عش', 'الغراب', 'سالك', 'عبدة', 'مغلقة'],
#  ['المربعة', 'وقوف', 'تام', 'من', 'ساعه', 'يا', 'دوب', 'مرق', 'سيارتين'],
#  ['حال', 'العيزرية', 'الان'],
#  ['دير', 'شرف', 'من', 'الاتجاهات'],
#  ['العيزرية', 'للخارج'],
#  ['العيزريه', 'ازمه', 'واقفه', 'للخارج'],
#  ['جميع',
#   'حواجز',
#   'نابلس',
#   'ازمه',
#   'خانقة',
#   'دير',
#   'شرف',
#   'عورتا',
#   'المربعة',
#   'والحمرا'],
#  ['الكونتير', 'سالك', 'بالاتجاهين'],
#  ['العيزريه', 'لشمال'],
#  ['صباح', 'الخير'],
#  ['المدخل',
#   'الجنوبي',
#   'سالك',
#   'بكلا',
#   'الاتجاهين',
#   'البوابة',
#   'الصفرا',
#   'سالك',
#   'بكلا',
#   'الاتجاهين',
#   'حاجز',
#   'الهيئة',
#   'سالك',
#   'حاجز',
#   'البنانا',
#   'مغلق',
#   'الحمرا',
#   'باتجاه',
# ...
#   'واد',
#   'قانا',
#   'سالك',
#   'بوابة',
#   'كفر',
#   'الديك',
#   'مغلقة',
#   'ياسوف',
#   'سلفيت',
#   'مغلقة',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'كفل',
#   'حارس',
#   'سالك',
#   'قلقيلية',
#   'الفندق',
#   'حاجز',
#   'عزبة',
#   'الطبيب',
#   'سالك',
#   'كرني',
#   'شمرون',
#   'سالك',
#   'النبي',
#   'الياس',
#   'حاليا',
#   'النفق',
#   'حبلة',
#   'سالك',
#   'بوابة',
#   'كفر',
#   'لاقف',
#   'سالك',
#   'عزون',
#   'الرئيسي',
#   'مغلق',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'طولكرم',
#   'عناب',
#   'مغلق',
#   'باالاتجاهين',
#   'طريق',
#   'الكفريات',
#   'سالك',
#   'جبارة',
#   'تحت',
#   'الجسر',
#   'سالك',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'اللدائن',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'واد',
#   'قانا',
#   'سالك',
#   'بيت',
#   'ليد',
#   'الرئيسي',
#   'مغلق',
#   'مدخل',
#   'رامين',
#   'مغلق',
#   'مدخل',
#   'سفارين',
#   'مغلق',
#   'عزبة',
#   'شوفة',
#   'مغلق',
#   'طريق',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'سهل',
#   'رامين',
#   'مغلق',
#   'جنين',
#   'حومش',
#   'سالك',
#   'مدخل',
#   'بزاريا',
#   'الرئيسي',
#   'سالك',
#   'بزاريا',
#   'الغرس',
#   'سالك',
#   'حاليا',
#   'جبع',
#   'حتى',
#   '١٧',
#   'عصيرة',
#   'نابلس',
#   'سالك',
#   'السيلة',
#   'حتى',
#   'عطارة',
#   'بلعا',
#   'سالك',
#   'دوتان',
#   'مغلق',
#   'حرميش',
#   'مغلق',
#   'طوباس',
#   'لحمرا',
#   'ازمه',
#   'وبمشي',
#   'تياسير',
#   'ازمه',
#   'طوباس',
#   'الباذان',
#   'نابلس',
#   'سالك',
#   'اريحا',
#   'الحمرا',
#   'ازمه',
#   'وبمشي',
#   'معالي',
#   'افرايم',
#   'سالك',
#   'خط',
#   '90',
#   'سالك',
#   'حاليا',
#   'المعرجات',
#   'سالك',
#   'حاليا',
#   'ال',
#   'DCO',
#   'سالك',
#   'البوابة',
#   'الصفراء',
#   'حاجز',
#   'الهيئة',
#   'حاجز',
#   'حاجز',
#   'البنانا',
#   'حاجز',
#   'وضع',
#   'الطريق',
#   'متغير',
#   'بين',
#   'لحظة',
#   'واخرى',
#   'طريق',
#   'السلامة',
#   'للجميع',
#   'وضع',
#   'الطريق',
#   'متغير',
#   'في',
#   'لحظات',
#   'صفحه',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'من',
#   'موقعنا',
#   'على',
#   'التلجرام',
#   'إن',
#   'الله',
#   'وملائكته',
#   'يصلون',
#   'على',
#   'النبي',
#   'يا',
#   'أيها',
#   'الذين',
#   'آمنوا',
#   'صلوا',
#   'عليه',
#   'وسلموا',
#   'تسليما',
#   'اخوكم',
#   'سامر',
#   'ياسين',
#   'والمشرف',
#   'جميل'],
#  ['اسعد',
#   'الله',
#   'صباحكم',
#   'قال',
#   'تعالى',
#   'وما',
#   'تقدموا',
#   'لأنفسكم',
#   'من',
#   'خير',
#   'تجدوه',
#   'عند',
#   'الله',
#   'هو',
#   'خيرا',
#   'وأعظم',
#   'أجرا',
#   'واستغفروا',
#   'الله',
#   'إن',
#   'الله',
#   'غفور',
#   'رحيم',
#   'صفحة',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'منطقة',
#   'ضواحي',
#   'القدس',
#   'قلنديا',
#   'سالكه',
#   'كفر',
#   'عقب',
#   'سالك',
#   'جبع',
#   'سالك',
#   'حزما',
#   'سالك',
#   'عناتا',
#   'سالك',
#   'الزعيم',
#   'ازمه',
#   'طريق',
#   'معالي',
#   'ادوميم',
#   'سالك',
#   'العيزرية',
#   'سالكه',
#   'الكونتينر',
#   'سالك',
#   'منطقة',
#   'بيت',
#   'لحم',
#   'العبيدية',
#   'سالكة',
#   'قبر',
#   'حلوه',
#   'فاتح',
#   'تقوع',
#   'البلد',
#   'تل',
#   'الربيع',
#   'سالكه',
#   'الترابيه',
#   'بوابة',
#   'جناتا',
#   'مغلقه',
#   'النشاش',
#   'فاتح',
#   'طريق',
#   'السدر',
#   'فاتحه',
#   'زعتره',
#   'بيت',
#   'لحم',
#   'مغلق',
#   'مدخل',
#   'بيت',
#   'فجار',
#   'مغلق',
#   'الخليل',
#   'مدخل',
#   'قرية',
#   'المنيا',
#   'سالك',
#   'بالاتجاهين',
#   'مدخل',
#   'بربرة',
#   'مغلق',
#   'جورة',
#   'الشمعه',
#   'المنشية',
#   'صفحة',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'مدخل',
#   'الحواور',
#   'بوابة',
#   'سعير',
#   'بوابة',
#   'بيت',
#   'عينون',
#   'مغلقة',
#   'عصيون',
#   'سالك',
#   'دوار',
#   'فرات',
#   'رمزونات',
#   'فرات',
#   'سالكين',
#   'راس',
#   'الجوره',
#   'فرش',
#   'الهوى',
#   'مغلق',
#   'الخارج',
#   'مغلق',
#   'جسر',
#   'حلحول',
#   'طريق',
#   'حسكه',
#   'سالكه',
#   'بوابة',
#   'بلدة',
#   'بيت',
#   'عوا',
#   'مغلقة',
#   'بوابة',
#   'مثلث',
#   'خرسا',
#   'فاتحة',
#   'بوابة',
#   'مستوطنة',
#   'نيجهوت',
#   'مغلقة',
#   'بوابة',
#   'الخطوط',
#   'الغربية',
#   'لمدينة',
#   'دورا',
#   'مغلقة',
#   'بوابة',
#   'بيت',
#   'عوا',
#   'مسكره',
#   'بوابة',
#   'اذنا',
#   'الليه',
#   'كرمه',
#   'باتجاه',
#   'يطا',
#   'مدخل',
#   'الظاهرية',
#   'مغلق',
#   'بني',
#   'نعيم',
#   'بوابة',
#   'العروب',
#   'النبي',
#   'يونس',
#   'عش',
#   'غراب',
#   'سالك',
#   'ترقوميا',
#   'فاتحه',
#   'للخارج',
#   'عبده',
#   'ابو',
#   'العرقان',
#   'جسر',
#   'بيت',
#   'كاحل',
#   'سالك',
#   'القصر',
#   'الرجاء',
#   'من',
#   'الجميع',
#   'يقرأ',
#   'التقرير',
#   'ويضغطاو',
#   'غير',
#   'متواجد',
#   'خاص',
#   'نهائيا',
#   'العقبي'],
#  ['دير', 'شرف', 'الأن', 'سالك'],
#  ['دير', 'شرف', 'سالك', 'بحري'],
#  ['حاجز', 'ع', 'الهيئة'],
#  ['الحمرا', 'وضعوا', 'سيء', 'جدا', 'الأزمة', 'قطعت', 'الكوربة', 'الثانية'],
#  ['حاجز', 'بيت', 'فوريك', 'سالك', 'بالاتجاهين'],
#  ['راس', 'الجورة', 'مغلق', 'حتى', 'ممنوع', 'المرور', 'سيرا', 'مشي', 'ممنوع'],
#  ['اذا',
#   'حدا',
#   'موجود',
#   'ع',
#   'حاجز',
#   'الحمرا',
#   'يتواصل',
#   'معي',
#   'لا',
#   'الضروره'],
#  ['عورتا', 'الازمة', 'تقريبا', 'لمفرق', 'روجيب'],
#  ['اكم',
#   'قلب',
#   'يستاهل',
#   'منكم',
#   'ما',
#   'تبخلوا',
#   'علينا',
#   'بقلب',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'يتسهار',
#   'سالك',
#   'صرة',
#   'مغلق',
#   'للخارج',
#   'شاحنات',
#   'ونمر',
#   'صفراء',
#   'زعترا',
#   'سالك',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'مغلق',
#   'التفافي',
#   'زواتا',
#   'سالك',
#   'المربعه',
#   'ازمه',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'دير',
#   'شرف',
#   'ازمه',
#   'عورتا',
#   'ازمه',
#   'للهارج',
#   'بيت',
#   'فوريك',
#   'سالك',
#   'بزاريا',
#   'الرئيسي',
#   'سلك',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'حومش',
#   'سالك',
#   'عناب',
#   'مغلق',
#   'بالاتجاهين',
#   'اليوم',
#   'الثامن',
#   'ع',
#   'التوالي',
#   'الكفريات',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'تواجد',
#   'الجيش',
#   'إشارات',
#   'حارس',
#   'سالك',
#   'طريق',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'سالك',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'حاجز',
#   'الحمرا',
#   'ازمه',
#   'خفيفه',
#   'عوفرا',
#   'سالك',
#   'اارئيل',
#   'سلفيت',
#   'سالك',
#   'خط',
#   'رام',
#   'الله',
#   'نابلس',
#   'سالك',
#   'عين',
#   'سينا',
#   'سالك',
#   'عطارة',
#   'سالك',
#   'عطاره',
#   'فوق',
#   'الجسر',
#   'سالك',
#   'روابي',
#   'سالك',
#   'اشارات',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'سنجل',
#   'مغلق',
#   'سنجل',
#   'المدخل',
#   'الشمالي',
#   'سالك',
#   'شيلو',
#   'سالك',
#   'عيلي',
#   'سالك',
#   'عيون',
#   'الحراميه',
#   'سالك',
#   'بيت',
#   'ايل',
#   'مغلق',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'تحت',
#   'جسر',
#   'جباره',
#   'سالك',
#   'جماعين',
#   'سالك',
#   'بوابة',
#   'كفل',
#   'حارس'],
#  ['سالك',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'مردا',
#   'الشرقيه',
#   'سالك',
#   'بديا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'مدخل',
#   'مردا',
#   'الغربي',
#   'سالك',
#   'جبع',
#   'سالك',
#   'متواجد',
#   'معكم',
#   'عالخاص',
#   'لا',
#   'تحديث',
#   'أو',
#   'استفسار'],
#  ['حالة',
#   'الطرق',
#   'لمحافظة',
#   'الخليل',
#   'وبعض',
#   'مناطق',
#   'الجنوب',
#   'مدخل',
#   'الخليل',
#   'فرش',
#   'الهوا',
#   'مغلق',
#   'مدخل',
#   'الخليل',
#   'الشمالي',
#   'رأس',
#   'الجورة',
#   'مغلق',
#   'مدخل',
#   'ترقوميا',
#   'المصانع',
#   'مدخل',
#   'الفحص',
#   'مغلق',
#   'مدخل',
#   'بني',
#   'نعيم',
#   'مغلق',
#   'مدخل',
#   'بيت',
#   'كاحل',
#   'سالك',
#   'مدخل',
#   'جسر',
#   'حلحول',
#   'سالك',
#   'مدخل',
#   'قلقس',
#   'مغلق',
#   'مدخل',
#   'مدينة',
#   'اذنا',
#   'الليه',
#   'مغلق',
#   'مدخل',
#   'بيت',
#   'عوا',
#   'مغلق',
#   'مدخل',
#   'الخليل',
#   'الجنوبي',
#   'حجاي',
#   'مغلق',
#   'مدخل',
#   'مخيم',
#   'الفوار',
#   'باتجاه',
#   'دورا',
#   'مغلق',
#   'حاجز',
#   'الكونتينر',
#   'سالك',
#   'مدخل',
#   'واد',
#   'الشاجنة',
#   'باتجاه',
#   'الالتفافي',
#   'مغلق',
#   'مدخل',
#   'الظاهرية',
#   'باتجاه',
#   'الالتفافي',
#   'مغلق',
#   'بوابات',
#   'سعير',
#   '؛',
#   'الحواور',
#   '؛',
#   'النبي',
#   'يونس؛',
#   'العروب',
#   'مغلقه',
#   'مدخل',
#   'بلدة',
#   'السموع',
#   'السيميا',
#   'مغلق',
#   'مدخل',
#   'كرمه',
#   'سالك',
#   'مدخل',
#   'البقارية',
#   'سالك',
#   'مدخل',
#   'بير',
#   'المي',
#   'سالك',
#   'مدخل',
#   'قريه',
#   'عبده',
#   'مغلق',
#   'مدخل',
#   'ابو',
#   'العرقان',
#   'سالك',
#   'مدخل',
#   'الهجرة',
#   'مغلق',
#   'مدخل',
#   'مدينة',
#   'دورا',
#   'مغلق',
#   'مدخل',
#   'العقد',
#   'سالك',
#   'مدخل',
#   'مدينة',
#   'يطا',
#   'زيف',
#   'مغلق',
#   'مدخل',
#   'مدينة',
#   'يطا',
#   'العمور',
#   'سالك',
#   'ملاحظة',
#   'حالة',
#   'الطرق',
#   'تتغير',
#   'بأي',
#   'لحظه'],
#  ['حاجز',
#   'بيت',
#   'فوريك',
#   'مغلق',
#   'في',
#   'كلا',
#   'الاتجاهين',
#   'مع',
#   'اغلاق',
#   'البوابة'],
#  ['دير', 'شرف', 'الان', 'ازمه', 'وبمشي'],
#  ['عورتا', 'ازمه', 'للخارج'],
#  ['جباره', 'سالك'],
#  ['مداخل', 'اريحا', 'بشكل', 'عام', 'سالكات'],
#  ['ترقوميا', 'حاليا', 'عليها', 'جيش'],
#  ['الفحص', 'مغلق'],
#  ['راس', 'الجوره', 'مغلق', 'فرش', 'الهوى', 'مغلق'],
#  ['الكونتينر', 'سالك'],
#  ['الطريق', 'الرئيسيه', 'للخليل', 'قرب', 'جسر', 'دار', 'صلاح'],
#  ['ما',
#   'بنصحح',
#   'حد',
#   'يوصل',
#   'المنطقة',
#   'الشرقية',
#   'لمدينة',
#   'نابلس',
#   'اقتحامها',
#   'مستمر',
#   'الي',
#   'بدو',
#   'يطلع',
#   'يروح',
#   'ع',
#   'دير',
#   'شرف',
#   'او',
#   'لمربعة',
#   'ولمتابعة',
#   'الاقتحام',
#   'https',
#   't',
#   'merassd'],
#  ['اكم',
#   'قلب',
#   'يستاهل',
#   'منكم',
#   'ما',
#   'تبخلوا',
#   'علينا',
#   'بقلب',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'يتسهار',
#   'سالك',
#   'صرة',
#   'مغلق',
#   'للخارج',
#   'شاحنات',
#   'ونمر',
#   'صفراء',
#   'زعترا',
#   'سالك',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'مغلق',
#   'التفافي',
#   'زواتا',
#   'سالك',
#   'المربعه',
#   'بداية',
#   'ازمه',
#   'خفيفه',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'دير',
#   'شرف',
#   'ازمه',
#   'خفيفه',
#   'وماشيه',
#   'وسالكه',
#   'عورتا',
#   'ازمه',
#   'للهارج',
#   'بيت',
#   'فوريك',
#   'سالك',
#   'بزاريا',
#   'الرئيسي',
#   'سلك',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'حومش',
#   'سالك',
#   'عناب',
#   'مغلق',
#   'بالاتجاهين',
#   'اليوم',
#   'الثامن',
#   'ع',
#   'التوالي',
#   'الكفريات',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'تواجد',
#   'الجيش',
#   'إشارات',
#   'حارس',
#   'سالك',
#   'طريق',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'سالك',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'حاجز',
#   'الحمرا',
#   'ازمه',
#   'خفيفه',
#   'عوفرا',
#   'سالك',
#   'اارئيل',
#   'سلفيت',
#   'سالك',
#   'خط',
#   'رام',
#   'الله',
#   'نابلس',
#   'سالك',
#   'عين',
#   'سينا',
#   'سالك',
#   'عطارة',
#   'سالك',
#   'عطاره',
#   'فوق',
#   'الجسر',
#   'سالك',
#   'روابي',
#   'سالك',
#   'اشارات',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'سنجل',
#   'مغلق',
#   'سنجل',
#   'المدخل',
#   'الشمالي',
#   'سالك',
#   'شيلو',
#   'سالك',
#   'عيلي',
#   'سالك',
#   'عيون',
#   'الحراميه',
#   'سالك',
#   'بيت',
#   'ايل',
#   'مغلق',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'تحت',
#   'جسر',
#   'جباره',
#   'سالك',
#   'جماعين',
#   'سالك',
#   'بوابة',
#   'كفل',
#   'حارس'],
#  ['سالك',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'مردا',
#   'الشرقيه',
#   'سالك',
#   'بديا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'مدخل',
#   'مردا',
#   'الغربي',
#   'سالك',
#   'جبع',
#   'سالك',
#   'الكونتير',
#   'سالك',
#   'عش',
#   'الغراب',
#   'سالك',
#   'قلنديا',
#   'وكفر',
#   'عقب',
#   'سالك',
#   'العيزرية',
#   'سالك',
#   'مدخل',
#   'ترقوميا',
#   'المصانع',
#   'سالكه'],
#  ['العيزرية', 'سالك', 'قلنديا', 'سالك', 'جبع', 'حزما', 'سالك'],
#  ['المربعة', 'سالك', 'مع', 'تواجد', 'الجيش'],
#  ['عورتا', 'سالك', 'لداخل', 'الخارج', 'ازمه', 'متوسطه'],
#  ['حومش', 'بزاريا', 'سالك'],
#  ['الكونتير', 'سالك'],
#  ['الفارعه', 'حاجز'],
#  ['بوابة', 'بيت', 'ساحور', 'فاتحه', 'عش', 'الغراب', 'سالك'],
#  ['مدخل', 'ومخرج', 'الخليل', 'حاليا', 'ترقوميا'],
#  ['من', 'أحب', 'أن', 'تسره', 'صحيفته', 'فليكثر', 'فيها', 'من', 'الاستغفار'],
#  ['دير',
#   'شرف',
#   'سالك',
#   'للخارج',
#   'فقط',
#   'عليه',
#   'ازمه',
#   'من',
#   'جهة',
#   'شافي',
#   'شمرون'],
#  ['صباح', 'الخير'],
#  ['صباح',
#   'الخير',
#   'اللهم',
#   'اجبر',
#   'كسرنا',
#   'وعجل',
#   'نصرنا',
#   'وشافي',
#   'المريض',
#   'منا',
#   'وارحم',
#   'ضعفنا',
#   'وارحم',
#   'امواتنا',
#   'واموات',
#   'المسلمين'],
#  ['اكم',
#   'قلب',
#   'يستاهل',
#   'منكم',
#   'ما',
#   'تبخلوا',
#   'علينا',
#   'بقلب',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'يتسهار',
#   'سالك',
#   'صرة',
#   'مغلق',
#   'للخارج',
#   'شاحنات',
#   'ونمر',
#   'صفراء',
#   'زعترا',
#   'سالك',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'مغلق',
#   'التفافي',
#   'زواتا',
#   'سالك',
#   'المربعه',
#   'سالك',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'دير',
#   'شرف',
#   'شفت',
#   'سئ',
#   'مزاجي',
#   'عورتا',
#   'سالك',
#   'بيت',
#   'فوريك',
#   'سالك',
#   'بزاريا',
#   'الرئيسي',
#   'سلك',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'حومش',
#   'سالك',
#   'عناب',
#   'مغلق',
#   'بالاتجاهين',
#   'اليوم',
#   'السابع',
#   'ع',
#   'التوالي',
#   'الكفريات',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'تواجد',
#   'الجيش',
#   'إشارات',
#   'حارس',
#   'سالك',
#   'طريق',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'سالك',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'حاجز',
#   'الحمرا',
#   'شبه',
#   'سالك',
#   'كم',
#   'سياره',
#   'عوفرا',
#   'سالك',
#   'اارئيل',
#   'سلفيت',
#   'سالك',
#   'خط',
#   'رام',
#   'الله',
#   'نابلس',
#   'سالك',
#   'عين',
#   'سينا',
#   'سالك',
#   'عطارة',
#   'سالك',
#   'عطاره',
#   'فوق',
#   'الجسر',
#   'سالك',
#   'روابي',
#   'سالك',
#   'اشارات',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'سنجل',
#   'مغلق',
#   'سنجل',
#   'المدخل',
#   'الشمالي',
#   'سالك',
#   'شيلو',
#   'سالك',
#   'عيلي',
#   'سالك',
#   'عيون',
#   'الحراميه',
#   'سالك',
#   'بيت',
#   'ايل',
#   'مغلق',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'تحت',
#   'جسر',
#   'جباره',
#   'سالك',
#   'جماعين',
#   'سالك',
#   'بوابة',
#   'كفل',
#   'حارس'],
#  ['سالك',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'مردا',
#   'الشرقيه',
#   'سالك',
#   'بديا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'مدخل',
#   'مردا',
#   'الغربي',
#   'سالك',
#   'جبع',
#   'سالك',
#   'غير',
#   'متواجد',
#   'حاليا',
#   'طريقة',
#   'السلام',
#   'عليكم',
#   'تصبح',
#   'ع',
#   'خير',
#   'الخليل',
#   'بوابة',
#   'ترقوميا',
#   'سالك',
#   'الان'],
#  ['جيش', 'عدوار', 'كدوميم', 'موقفين', 'سيارة', 'بس', 'الطريق', 'سالكة'],
#  ['دير',
#   'شرف',
#   'سالك',
#   'بالاتجاهين',
#   'ازمه',
#   'متوسطه',
#   'ع',
#   'الخارج',
#   'وتفتيش',
#   'دقيق',
#   'بالاخص',
#   'يلي',
#   'جاي',
#   'من',
#   'شافي',
#   'شمرون'],
#  ['هاد',
#   'الجيش',
#   'واقف',
#   'ع',
#   'فرش',
#   'الهوى',
#   'وبحكي',
#   'للناس',
#   'ما',
#   'معو',
#   'امر',
#   'يفتح',
#   'لبكرا'],
#  ['سيارة',
#   'شرطة',
#   'عدوار',
#   'النبي',
#   'الياس',
#   'موقفين',
#   'سيارة',
#   'وبفتشو',
#   'فيها'],
#  ['صوره', 'مغلق', 'بالاتجاهين'],
#  ['والمستغفرين', 'بالأسحار'],
#  ['خط', 'يتسهار', 'سالك', 'ميه', 'ميه'],
#  ['المربعة',
#   'سالكة',
#   'وفاضية',
#   'مع',
#   'تواجد',
#   'للجيش',
#   'محجوزين',
#   '٣',
#   'شباب',
#   'سيارة',
#   'نمراصفرا'],
#  ['حاجز',
#   'سياره',
#   'كادي',
#   'سكنيه',
#   'ع',
#   'دير',
#   'شرف',
#   'ضاربينهم',
#   'ومكسرينهم',
#   'الله',
#   'يهونها'],
#  ['دير', 'شرف', 'ازمه', 'من', 'كلو'],
#  ['ما', 'زال', 'حاجز', 'الحمرا', 'سالك', 'بالاتجاهين'],
#  ['ما', 'في', 'حاجز', 'حاليا'],
#  ['اجا', 'عليها', 'الجيش', 'حاليا'],
#  ['حاجز', 'عطارة', 'بدقق', 'على', 'النمرة', 'الصفرا'],
#  ['سيارة', 'شرطة', 'عدوار', 'عين', 'سينيا'],
#  ['بوابة', 'ترقوميا', 'المصانع', 'برجع', 'بحكيلكم', 'فاتحة'],
#  ['استغفر',
#   'الله',
#   'عدد',
#   'ما',
#   'خلق',
#   'استغفر',
#   'الله',
#   'ملء',
#   'ما',
#   'خلق',
#   'استغفر',
#   'الله',
#   'عدد',
#   'ما',
#   'في',
#   'الأرض',
#   'والسماء',
#   'استغفر',
#   'الله',
#   'ملء',
#   'ما',
#   'في',
#   'الأرض',
#   'والسماء',
#   'استغفر',
#   'الله',
#   'عدد',
#   'ما',
#   'أحصى',
#   'كتابه',
#   'استغفر',
#   'الله',
#   'ملء',
#   'ما',
#   'أحصى',
#   'كتابه',
#   'استغفر',
#   'الله',
#   'عدد',
#   'كل',
#   'شيء',
#   'استغفر',
#   'الله',
#   'ملء',
#   'كل',
#   'شيء'],
#  ['عورتا', 'ازمة', 'للخارج', 'للمنجرة', 'الاولى'],
#  ['جسر', 'بيت', 'كاحل', 'سالك'],
#  ['الحمرا', 'سالك', 'بالاتجاهين'],
#  ['اللية', 'إذنا', 'مغلق', 'ترقوميا', 'الرئيسي', 'مغلق'],
#  ['عين', 'سينيا', 'حاجز', 'للخارج'],
#  ['فرش', 'الهوى', 'الشرق', 'الأوسط'],
#  ['قلنديا', 'كفر', 'عقب', 'رايح', 'جاي', 'سالكه'],
#  ['الناس', 'بتستنى', 'ع', 'راس', 'الجورة'],
#  ['بوابات',
#   'الخليل',
#   'دون',
#   'استثناء',
#   'اي',
#   'بوابة',
#   'مغلقات',
#   'كف',
#   '٣٥',
#   'سالك'],
#  ['دير', 'شرف', 'سالك', 'الان', 'ازمه', 'خفيفه'],
#  ['ضربوا',
#   'الرسول',
#   'وآذوه',
#   'وهو',
#   'يمسح',
#   'الدم',
#   'عن',
#   'وجهه',
#   'ويقول',
#   'اللهم',
#   'اغفر',
#   'لقومي',
#   'فهم',
#   'لا',
#   'يعلمون',
#   'صلوا',
#   'على',
#   'شفيع',
#   'الأمة'],
#  ['المنشية',
#   'ام',
#   'سلمونا',
#   'جورة',
#   'الشمعة',
#   'افرات',
#   'عصيون',
#   'من',
#   'عصيون',
#   'باتجاه',
#   'الجبعة',
#   'ونحالين',
#   'حاجز',
#   'وتفتيش',
#   'دقيق',
#   'مقابل',
#   'رامي',
#   'ليڤي',
#   'طبعا',
#   'احذرو',
#   'الاجواء',
#   'الضبابية'],
#  ['دوار', 'تقوع', 'سيارتين', 'شرطة'],
#  ['قلنديا', 'وكفر', 'عقب', 'ازمة'],
#  ['مفرق',
#   'بورين',
#   'سالك',
#   'دوار',
#   'سلمان',
#   'الفارسي',
#   'سالك',
#   'حوارة',
#   'البلد',
#   'سالكة'],
#  ['مداخل', 'أريحا', 'الأربعة', 'حاليا', 'كلها', 'سالكة'],
#  ['دير', 'شرف', 'ازمة', 'للخارج', 'واصلة', 'الرونق'],
#  ['دير', 'شرف', 'ازمة', 'ماشية', 'للداخل'],
#  ['مدخل', 'اريحا', 'الجنوبي', 'سالك', 'فش', 'جيش'],
#  ['مدخل', 'ديرستيا', 'حاليا', 'سالك', 'بدون', 'جيش'],
#  ['بوابة', 'عش', 'الغراب'],
#  ['تم', 'اغلاق', 'الفحص'],
#  ...]

# %%
from gensim.models import Word2Vec
import numpy as np

# Step 1: Initialize Word2Vec model
model = Word2Vec(vector_size=70, window=5, min_count=1, workers=4)

# Step 2: Build vocabulary
model.build_vocab(sentences)

# Step 3: Train the Word2Vec model
model.train(sentences, total_examples=model.corpus_count, epochs=50)

# Step 4: Store embeddings in X ndarray
X = np.array([model.wv[word] for sentence in sentences for word in sentence])

print(f"Shape of X: {X.shape}")
# Out:
# Shape of X: (303768, 70)

# %%
# Iterate through each word in the vocabulary and find most similar words
for word in model.wv.key_to_index:  # Get all words in the vocabulary
    print(f"Most similar words to '{word}':")
    most_similar_words = model.wv.most_similar(word, topn=5)  # Find top 5 similar words
    for similar_word, similarity in most_similar_words:
        print(f"  {similar_word}: {similarity:.4f}")
    print()
# Out:
# Most similar words to 'سالك':
#   مغلق: 0.8159
#   سالكة: 0.7839
#   بوابة: 0.6941
#   سالكه: 0.6611
#   تماما: 0.6256
#
# Most similar words to 'مغلق':
#   سالك: 0.8159
#   مغلقة: 0.6547
#   بوابة: 0.6002
#   سالكة: 0.5760
#   مغلقه: 0.5757
#
# Most similar words to 'حاجز':
#   وحاجز: 0.5703
#   سالك: 0.5655
#   ازمة: 0.5414
#   مغلق: 0.5075
#   أزمة: 0.4892
#
# Most similar words to 'بوابة':
#   سالك: 0.6941
#   سالكة: 0.6335
#   مغلقة: 0.6087
#   مدخل: 0.6022
#   مغلق: 0.6002
#
# Most similar words to 'ازمة':
#   أزمة: 0.8357
#   ازمه: 0.6713
#   وازمة: 0.6295
#   وأزمة: 0.6277
#   الأزمة: 0.5946
#
# Most similar words to 'من':
#   بعد: 0.5029
#   ومن: 0.4439
#   ع: 0.4429
#   قبل: 0.4199
#   وباتجاه: 0.4135
#
# Most similar words to 'للخارج':
#   الخارج: 0.7960
#   للخارجين: 0.7194
#   للطالع: 0.6818
#   والخارج: 0.6328
#   وللخارج: 0.5822
#
# Most similar words to 'دير':
#   ودير: 0.6449
#   عورتا: 0.5380
#   المربعة: 0.5047
#   بدير: 0.4472
#   لدير: 0.4471
#
# Most similar words to 'بالاتجاهين':
#   سالك: 0.6068
#   حاليا: 0.5764
#   للخارج: 0.5531
#   تماما: 0.5388
#   مغلق: 0.5371
#
# Most similar words to 'بيت':
#   وبيت: 0.5781
#   سالك: 0.5746
#   لبيت: 0.5474
#   بوابة: 0.5264
#   مغلق: 0.5141
#
# Most similar words to 'حاليا':
#   سالك: 0.6101
#   بالاتجاهين: 0.5764
#   الان: 0.5352
#   للخارج: 0.4954
#   مفرق: 0.4498
#
# Most similar words to 'سالكة':
#   سالك: 0.7839
#   مغلقة: 0.7014
#   سالكه: 0.6747
#   ونظيفة: 0.6428
#   بوابة: 0.6335
#
# Most similar words to 'مدخل':
#   بوابة: 0.6022
#   ساويه: 0.5656
#   سالك: 0.5580
#   مغلق: 0.5516
#   سالكة: 0.5139
#
# Most similar words to 'شرف':
#   عورتا: 0.7061
#   المربعة: 0.6774
#   المربعه: 0.5203
#   وبمشي: 0.4697
#   منيح: 0.4615
#
# Most similar words to 'على':
#   ع: 0.7052
#   قبل: 0.5953
#   بعد: 0.5323
#   عند: 0.5091
#   مشدد: 0.4888
#
# Most similar words to 'ازمه':
#   ازمة: 0.6713
#   وازمه: 0.6664
#   أزمة: 0.6404
#   الازمه: 0.5613
#   خفيفه: 0.5112
#
# Most similar words to 'دوار':
#   اشارات: 0.5038
#   عدوار: 0.4507
#   الدوار: 0.4443
#   طريق: 0.4277
#   إشارات: 0.4238
#
# Most similar words to 'عورتا':
#   المربعة: 0.7255
#   شرف: 0.7061
#   المربعه: 0.6488
#   وبمشي: 0.5479
#   دير: 0.5380
#
# Most similar words to 'المربعة':
#   المربعه: 0.7387
#   عورتا: 0.7255
#   شرف: 0.6774
#   دير: 0.5047
#   لمربعة: 0.4623
#
# Most similar words to 'باتجاه':
#   بتجاه: 0.6438
#   اتجاه: 0.6267
#   بإتجاه: 0.6231
#   جهة: 0.5322
#   واليمين: 0.5312
#
# Most similar words to 'طريق':
#   الطريق: 0.5266
#   بوابة: 0.5222
#   سالك: 0.5105
#   خط: 0.5042
#   مغلق: 0.4862
#
# Most similar words to 'للداخل':
#   لداخل: 0.7828
#   الداخل: 0.7387
#   عالداخل: 0.6631
#   داخل: 0.5874
#   والداخل: 0.5532
#
# Most similar words to 'الله':
#   المحطه: 0.4719
#   التحنا: 0.4382
#   أراد: 0.3860
#   الذي: 0.3819
#   لنازل: 0.3695
#
# Most similar words to 'المشرف':
#   Abu: 0.6243
#   Motaz: 0.5704
#   Ibrahim: 0.5646
#   جميل: 0.5513
#   yazan: 0.5370
#
# Most similar words to 'نابلس':
#   مفرق: 0.4242
#   الحمرا: 0.4217
#   اريحا: 0.3813
#   واقفة: 0.3708
#   شرف: 0.3667
#
# Most similar words to 'ع':
#   على: 0.7052
#   قبل: 0.5617
#   عند: 0.5295
#   بنص: 0.4442
#   من: 0.4429
#
# Most similar words to 'سالكه':
#   سالكة: 0.6747
#   سالك: 0.6611
#   مغلقه: 0.6535
#   سالكات: 0.5974
#   مغلقة: 0.5866
#
# Most similar words to 'الحمرا':
#   تياسير: 0.6638
#   وبمشي: 0.4861
#   الحمرة: 0.4804
#   لحمرا: 0.4701
#   النصارية: 0.4656
#
# Most similar words to 'عين':
#   وعين: 0.6289
#   لعين: 0.5626
#   بيرزيتجفناعين: 0.5141
#   عبن: 0.5111
#   الجلزون: 0.5073
#
# Most similar words to 'جبع':
#   اندماج: 0.6283
#   الرام: 0.6184
#   حزما: 0.5948
#   عناتا: 0.5710
#   العيزرية: 0.5573
#
# Most similar words to 'مع':
#   بدون: 0.6140
#   ولكن: 0.4735
#   انطلقو: 0.4570
#   دون: 0.4415
#   لكن: 0.4411
#
# Most similar words to 'مغلقة':
#   سالكة: 0.7014
#   مغلق: 0.6547
#   فاتحة: 0.6394
#   سالك: 0.6110
#   بوابة: 0.6087
#
# Most similar words to 'راس':
#   رأس: 0.6295
#   وراس: 0.6208
#   لرأس: 0.5959
#   ورأس: 0.5849
#   لراس: 0.5254
#
# Most similar words to 'أزمة':
#   ازمة: 0.8357
#   وأزمة: 0.7061
#   ازمه: 0.6404
#   كثافة: 0.5414
#   بطيء: 0.5329
#
# Most similar words to 'رام':
#   بعونو: 0.4991
#   اثابكم: 0.4790
#   عرام: 0.4400
#   ويفرجها: 0.4399
#   ورام: 0.4285
#
# Most similar words to 'جسر':
#   الجسر: 0.7411
#   جسو: 0.4910
#   بالجرافات: 0.4827
#   وجسر: 0.4486
#   حواور: 0.4143
#
# Most similar words to 'الان':
#   الآن: 0.6092
#   اللحظة: 0.5772
#   الحظة: 0.5634
#   حاليا: 0.5352
#   بسمحوا: 0.4204
#
# Most similar words to 'في':
#   وفي: 0.5259
#   فيه: 0.4796
#   أذڪروا: 0.4704
#   مشاة: 0.4688
#   ونسوان: 0.4614
#
# Most similar words to 'عطارة':
#   عطاره: 0.7027
#   ويدخل: 0.5608
#   وتحت: 0.5437
#   وعطارة: 0.5351
#   بيرزيت: 0.5083
#
# Most similar words to 'تواجد':
#   وجود: 0.7301
#   انتشار: 0.5837
#   استنفار: 0.5761
#   الحظر: 0.5738
#   توجد: 0.5121
#
# Most similar words to 'ما':
#   وما: 0.7415
#   متسع: 0.5633
#   تجود: 0.4982
#   إذنكم: 0.4936
#   صاح: 0.4758
#
# Most similar words to 'تحت':
#   الازرق: 0.5154
#   بحجاره: 0.4636
#   وتخبو: 0.4304
#   ومنطقة: 0.4171
#   مغلق: 0.4066
#
# Most similar words to 'اشارات':
#   إشارات: 0.7860
#   إشارة: 0.6738
#   رمزونات: 0.6188
#   وإشارات: 0.5707
#   واشارات: 0.5477
#
# Most similar words to 'العيزرية':
#   الزعيم: 0.6290
#   ادوميم: 0.6201
#   العيزريه: 0.6096
#   جبع: 0.5573
#   بأية: 0.5531
#
# Most similar words to 'شرطة':
#   شرطه: 0.7654
#   الشرطة: 0.6429
#   جيش: 0.5854
#   للشرطة: 0.5826
#   شرطي: 0.5557
#
# Most similar words to 'سينيا':
#   ايوب: 0.6036
#   بيرزيت: 0.5860
#   طرفة: 0.5756
#   شبلي: 0.5466
#   أيوب: 0.5305
#
# Most similar words to 'حارس':
#   ارائيل: 0.6109
#   العبارة: 0.4896
#   اريئيل: 0.4876
#   الفوقا: 0.4818
#   قانا: 0.4731
#
# Most similar words to 'بزاريا':
#   الغرس: 0.5193
#   شافي: 0.4618
#   بورين: 0.4560
#   الرئيسي: 0.4227
#   سألك: 0.4225
#
# Most similar words to 'خط':
#   وخط: 0.5889
#   شارع: 0.5514
#   بتجاه: 0.5050
#   طريق: 0.5042
#   بلفلفو: 0.4715
#
# Most similar words to 'الكونتينر':
#   الزعيم: 0.6062
#   الكونتير: 0.5724
#   العبيدية: 0.5448
#   النشاش: 0.5096
#   العيزرية: 0.5054
#
# Most similar words to 'عناب':
#   الكفريات: 0.5880
#   عطولكرم: 0.4844
#   جبارة: 0.4660
#   حجة: 0.4396
#   الحمرا: 0.4307
#
# Most similar words to 'تفتيش':
#   وتفتيش: 0.7759
#   وتوقيف: 0.6899
#   توقيف: 0.6114
#   يفتشوا: 0.6113
#   التوقيف: 0.6082
#
# Most similar words to 'عيون':
#   عيوم: 0.6688
#   بعيون: 0.6134
#   وعيون: 0.5676
#   لعيون: 0.5591
#   مخماس: 0.4453
#
# Most similar words to 'مفرق':
#   ومفرق: 0.5434
#   وكدميمم: 0.5179
#   يبعثلي: 0.5069
#   مغرق: 0.4951
#   لمفرق: 0.4603
#
# Most similar words to 'سير':
#   شير: 0.6464
#   حجم: 0.5431
#   كسير: 0.5205
#   باصات: 0.4265
#   السير: 0.4209
#
# Most similar words to 'كفر':
#   وكفر: 0.5936
#   لكفر: 0.5627
#   بكفر: 0.4898
#   مردا: 0.4546
#   عكفر: 0.4376
#
# Most similar words to 'شمرون':
#   شامرون: 0.7357
#   شومرون: 0.6619
#   شمرن: 0.6158
#   شيمرون: 0.5437
#   يصورلي: 0.3928
#
# Most similar words to 'عش':
#   لعش: 0.7108
#   النشاش: 0.5371
#   الفحص: 0.5115
#   راحووو: 0.4467
#   دورا: 0.4426
#
# Most similar words to 'تماما':
#   سالك: 0.6256
#   بحري: 0.5557
#   بالاتجاهين: 0.5388
#   سالكة: 0.5383
#   ونظيف: 0.5235
#
# Most similar words to 'يتسهار':
#   ايتسهار: 0.6973
#   بتسهار: 0.5226
#   امتداد: 0.5131
#   بيتللو: 0.4827
#   سيرها: 0.4814
#
# Most similar words to 'شافي':
#   شاڤي: 0.6062
#   كرنيه: 0.5912
#   شفي: 0.5490
#   كرني: 0.4845
#   شاافي: 0.4807
#
# Most similar words to 'الجسر':
#   جسر: 0.7411
#   لزعيم: 0.4225
#   فقطمن: 0.4153
#   شويه: 0.4108
#   وحاجز: 0.4038
#
# Most similar words to 'سيارة':
#   سيارتين: 0.6791
#   سياره: 0.5590
#   سيارات: 0.5516
#   طلعت: 0.5194
#   يفتشوها: 0.5175
#
# Most similar words to 'النبي':
#   والنبي: 0.8137
#   لنبي: 0.7330
#   النلي: 0.6779
#   عالنبي: 0.6204
#   نبي: 0.5998
#
# Most similar words to 'لا':
#   بتجاه: 0.4508
#   بعونو: 0.4147
#   يسلم: 0.3807
#   أما: 0.3625
#   منيحها: 0.3571
#
# Most similar words to 'السير':
#   وللأسف: 0.6744
#   بيزيدو: 0.6670
#   سيرانتبهو: 0.6274
#   والسير: 0.6230
#   الضغط: 0.5986
#
# Most similar words to 'سلفيت':
#   وبروقين: 0.5040
#   ارئيل: 0.4531
#   المدخل: 0.4137
#   عطارة: 0.4088
#   بتمسك: 0.3915
#
# Most similar words to 'اريحا':
#   أريحا: 0.7238
#   النصاريه: 0.6725
#   النصارية: 0.6532
#   الجفتلك: 0.6428
#   اريحاا: 0.5379
#
# Most similar words to 'الخارج':
#   والخارج: 0.8282
#   للخارج: 0.7960
#   وللخارج: 0.6874
#   للطالع: 0.6709
#   الطالع: 0.5866
#
# Most similar words to 'جميل':
#   شروق: 0.8819
#   Ibrahim: 0.7970
#   Abu: 0.7547
#   yazan: 0.7071
#   Motaz: 0.6542
#
# Most similar words to 'الجورة':
#   الجوره: 0.8437
#   االجوره: 0.6711
#   ومحروق: 0.6352
#   الجورا: 0.6239
#   الجور: 0.6129
#
# Most similar words to 'فرش':
#   وفرش: 0.7519
#   لفرش: 0.7073
#   راس: 0.4607
#   النشاش: 0.4567
#   زيف: 0.4371
#
# Most similar words to 'زعترة':
#   زعتره: 0.5377
#   سلكي: 0.4960
#   ارائيل: 0.4795
#   زعترا: 0.4659
#   حوارة: 0.4528
#
# Most similar words to 'عصيرة':
#   زواتا: 0.5318
#   المساكن: 0.5001
#   بالاااتجاهين: 0.4947
#   17: 0.4436
#   لصحة: 0.4272
#
# Most similar words to 'جيش':
#   للجيش: 0.7387
#   جنود: 0.6813
#   الجيش: 0.6733
#   شرطة: 0.5854
#   شرطه: 0.5596
#
# Most similar words to 'ايل':
#   إيل: 0.7273
#   أيل: 0.6000
#   عنون: 0.5331
#   ائيل: 0.5144
#   عور: 0.5027
#
# Most similar words to 'صرة':
#   شاحنات: 0.6853
#   صره: 0.6801
#   ونمر: 0.6545
#   صفراء: 0.6513
#   صفرا: 0.5682
#
# Most similar words to 'ال':
#   28: 0.5280
#   عمران: 0.5198
#   وال: 0.4255
#   بالاااتجاهين: 0.4142
#   عصيرا: 0.3921
#
# Most similar words to 'حزما':
#   الزعيم: 0.6506
#   الرام: 0.6274
#   وحزما: 0.6242
#   قلنديا: 0.6064
#   جبع: 0.5948
#
# Most similar words to 'حومش':
#   عنبتا: 0.4963
#   جبارة: 0.4556
#   مازال: 0.4427
#   التوالي: 0.4362
#   التاسع: 0.4356
#
# Most similar words to 'الرئيسي':
#   الغرس: 0.4934
#   الرأيسي: 0.4724
#   بزاريا: 0.4227
#   وراي: 0.4170
#   فقططط: 0.4018
#
# Most similar words to 'فوريك':
#   عورتا: 0.4920
#   فريك: 0.4512
#   شرف: 0.4467
#   خفيفه: 0.4177
#   المربعة: 0.4116
#
# Most similar words to 'الحرامية':
#   الحزامية: 0.7859
#   الحرمية: 0.7726
#   الحرميه: 0.7261
#   الحرامبة: 0.7181
#   حرامية: 0.7089
#
# Most similar words to 'الجيش':
#   للجيش: 0.7630
#   جيش: 0.6733
#   السلطة: 0.6186
#   حيوانات: 0.6115
#   للشرطة: 0.5698
#
# Most similar words to 'قلنديا':
#   المخيم: 0.6235
#   الرام: 0.6149
#   حزما: 0.6064
#   عقب: 0.6030
#   الزعيم: 0.5987
#
# Most similar words to 'بورين':
#   المساكن: 0.5768
#   والآخر: 0.4997
#   خفيفه: 0.4733
#   بزاريا: 0.4560
#   المربعة: 0.4470
#
# Most similar words to 'حوارة':
#   بساعدوا: 0.5421
#   حراره: 0.5311
#   التعيس: 0.4996
#   والتمهل: 0.4873
#   اودلا: 0.4764
#
# Most similar words to 'الفحص':
#   عبده: 0.6551
#   كرمة: 0.6467
#   عبدة: 0.6268
#   زيف: 0.6229
#   قلقس: 0.6222
#
# Most similar words to 'الداخل':
#   للداخل: 0.7387
#   لداخل: 0.7040
#   والداخل: 0.6061
#   عالداخل: 0.5948
#   داخل: 0.5943
#
# Most similar words to 'الهوى':
#   الهوا: 0.8353
#   الهواء: 0.7501
#   آلهوى: 0.7270
#   الهواى: 0.6033
#   رسالك: 0.5713
#
# Most similar words to 'سنجل':
#   ترمسعيا: 0.5058
#   شيلو: 0.5022
#   نظيفه: 0.4732
#   كركر: 0.4632
#   ك: 0.4412
#
# Most similar words to 'الاتجاهات':
#   لاتجاهات: 0.7020
#   اتجاهاتو: 0.6621
#   سهولة: 0.6424
#   حرية: 0.6273
#   ثقة: 0.5910
#
# Most similar words to 'خانقة':
#   طويلة: 0.7492
#   قوية: 0.6647
#   خانقةة: 0.6530
#   سيئة: 0.6104
#   خانقه: 0.5841
#
# Most similar words to 'بس':
#   لكن: 0.6760
#   ولكن: 0.4971
#   ولسا: 0.4923
#   منيح: 0.4842
#   وبوقف: 0.4588
#
# Most similar words to 'ترمسعيا':
#   ك: 0.5188
#   سنجل: 0.5058
#   عيلي: 0.5023
#   كركر: 0.4979
#   اللبن: 0.4970
#
# Most similar words to 'الجنوب':
#   الشمال: 0.8104
#   النقق: 0.5677
#   الجنووب: 0.5589
#   عوافرا: 0.5367
#   الزعيم: 0.5188
#
# Most similar words to 'البلد':
#   البد: 0.4464
#   لبلد: 0.4377
#   وبوابات: 0.4245
#   ترانزيت: 0.4018
#   وتمنع: 0.3863
#
# Most similar words to 'الطريق':
#   الشارع: 0.5527
#   طريق: 0.5266
#   عالطريق: 0.4838
#   وزعترة: 0.4202
#   إشارات: 0.4143
#
# Most similar words to 'الغراب':
#   عراب: 0.7901
#   الغرب: 0.7869
#   غراب: 0.7367
#   لغراب: 0.7164
#   ماتور: 0.4642
#
# Most similar words to 'معالي':
#   معاليه: 0.8174
#   معلي: 0.7045
#   عالميزان: 0.6866
#   ميشور: 0.6840
#   مشور: 0.6595
#
# Most similar words to 'بروقين':
#   بديا: 0.5500
#   مردا: 0.5299
#   نظام: 0.5051
#   بركان: 0.4737
#   تتحت: 0.4697
#
# Most similar words to 'واد':
#   وداي: 0.6841
#   وادي: 0.6529
#   ووادي: 0.6248
#   عذاب: 0.4983
#   لواد: 0.4784
#
# Most similar words to 'النشاش':
#   الفحص: 0.5662
#   جالا: 0.5397
#   عش: 0.5371
#   السدر: 0.5305
#   عصيون: 0.5182
#
# Most similar words to 'كثافة':
#   وكثافة: 0.7860
#   كثافه: 0.7182
#   كثاقة: 0.7080
#   وكثافه: 0.6832
#   كثاف: 0.6825
#
# Most similar words to 'وتفتيش':
#   تفتيش: 0.7759
#   وتوقيف: 0.6338
#   التوقيف: 0.6200
#   وبتفتش: 0.5406
#   يفتشوا: 0.5275
#
# Most similar words to 'إشارات':
#   اشارات: 0.7860
#   وإشارات: 0.6372
#   إشارة: 0.6323
#   رمزونات: 0.6195
#   وكفل: 0.5888
#
# Most similar words to 'فتح':
#   اغلاق: 0.6993
#   ازالتو: 0.6112
#   إغلاق: 0.6052
#   إزالة: 0.5967
#   سلك: 0.5873
#
# Most similar words to 'للجميع':
#   تتمنى: 0.6846
#   المحبة: 0.6452
#   صفحه: 0.6075
#   والوصول: 0.4984
#   التحيات: 0.4639
#
# Most similar words to 'جيت':
#   جت: 0.5852
#   أحكيلكم: 0.5090
#   فطور: 0.4923
#   الطنيب: 0.4765
#   المخماس: 0.4651
#
# Most similar words to 'روابي':
#   وابي: 0.5851
#   والبلد: 0.5034
#   مراحب: 0.4569
#   عطارة: 0.4497
#   للبيرة: 0.4454
#
# Most similar words to 'ونظيف':
#   سالكة: 0.6099
#   سالك: 0.6079
#   ونظيفة: 0.5983
#   تماما: 0.5235
#   مغلقة: 0.5140
#
# Most similar words to 'الفندق':
#   يختصر: 0.5856
#   حجة: 0.5415
#   عزبة: 0.5357
#   شارات: 0.5203
#   ووادي: 0.5171
#
# Most similar words to 'حتى':
#   لغاية: 0.6304
#   ل: 0.5536
#   لهاي: 0.5383
#   لحد: 0.4794
#   تماما: 0.4395
#
# Most similar words to 'شيلو':
#   وشيلو: 0.6367
#   كركر: 0.5220
#   سنجل: 0.5022
#   عيليي: 0.4988
#   أشارت: 0.4979
#
# Most similar words to 'الشمال':
#   الجنوب: 0.8104
#   اريحاا: 0.5657
#   والشمال: 0.5617
#   الجنووب: 0.5382
#   الزعيم: 0.5257
#
# Most similar words to 'سياره':
#   ليمرق: 0.5869
#   وبمشيك: 0.5638
#   سيارة: 0.5590
#   ساره: 0.5436
#   هيون: 0.5403
#
# Most similar words to 'مردا':
#   مرده: 0.6223
#   مردة: 0.5300
#   بروقين: 0.5299
#   استيا: 0.5130
#   نظام: 0.4808
#
# Most similar words to 'الخليل':
#   قلقس: 0.6263
#   اذنا: 0.5139
#   الظاهرية: 0.5014
#   الفوار: 0.4943
#   حلحول: 0.4894
#
# Most similar words to 'عند':
#   بعد: 0.6642
#   قبل: 0.6406
#   مقابل: 0.6067
#   باب: 0.5527
#   ع: 0.5295
#
# Most similar words to 'الطرق':
#   صفحة: 0.6836
#   وحواجز: 0.6527
#   طرق: 0.6204
#   احوال: 0.6158
#   الإسرائيلي: 0.6078
#
# Most similar words to 'عيلي':
#   وعيلي: 0.6483
#   اتجاع: 0.6043
#   عليلي: 0.5679
#   ترمسعيا: 0.5023
#   كركر: 0.4688
#
# Most similar words to 'الزعيم':
#   حزما: 0.6506
#   العيزرية: 0.6290
#   الكونتينر: 0.6062
#   قلنديا: 0.5987
#   ادوميم: 0.5836
#
# Most similar words to '17':
#   ࢪاحلين: 0.5711
#   القبلية: 0.5135
#   ال١٧: 0.5034
#   ١٧: 0.4954
#   للأحبة: 0.4909
#
# Most similar words to 'عزون':
#   جباره: 0.6023
#   لجيوس: 0.4811
#   أودلا: 0.4580
#   جبارة: 0.4552
#   لعزون: 0.4507
#
# Most similar words to 'دورا':
#   عبده: 0.6504
#   كرمة: 0.6490
#   كرمه: 0.6436
#   زيف: 0.6387
#   الهجرة: 0.6340
#
# Most similar words to 'الاتجاهين':
#   الاتجااهين: 0.7141
#   الإتجاهين: 0.6866
#   الاتجاهيين: 0.6843
#   بالاتجاهين: 0.5355
#   كلا: 0.5132
#
# Most similar words to 'جماعين':
#   ياسوف: 0.4935
#   بروقين: 0.4628
#   الديك: 0.4371
#   بالتين: 0.4370
#   لاقف: 0.4234
#
# Most similar words to 'المصانع':
#   شوفه: 0.5437
#   الدائن: 0.4501
#   الكساره: 0.4305
#   وفقط: 0.4156
#   اللدائن: 0.4108
#
# Most similar words to 'الي':
#   اللي: 0.7279
#   يلي: 0.7276
#   للي: 0.7032
#   والي: 0.6179
#   مين: 0.5665
#
# Most similar words to 'بوابات':
#   وبوابات: 0.6091
#   بوابة: 0.5487
#   البوابات: 0.5450
#   بوابه: 0.4758
#   ام: 0.4718
#
# Most similar words to 'بدون':
#   مع: 0.6140
#   وملااااانة: 0.5897
#   ماعليها: 0.5806
#   دون: 0.5736
#   وفش: 0.5701
#
# Most similar words to 'بعد':
#   قبل: 0.7063
#   عند: 0.6642
#   على: 0.5323
#   ليڤي: 0.5126
#   من: 0.5029
#
# Most similar words to 'عناتا':
#   ازعيم: 0.5779
#   جبع: 0.5710
#   حزما: 0.5485
#   الكسارات: 0.5467
#   اندماج: 0.5272
#
# Most similar words to 'الجلزون':
#   عين: 0.5073
#   المزاج: 0.5026
#   عطارة: 0.4326
#   سينيا: 0.4189
#   وعين: 0.3886
#
# Most similar words to 'الحاجز':
#   الخربانة: 0.4718
#   الاندماج: 0.4418
#   اندماج: 0.4317
#   الإعلان: 0.4220
#   حاجز: 0.4162
#
# Most similar words to 'داخل':
#   الداخل: 0.5943
#   للداخل: 0.5874
#   عالداخل: 0.5526
#   لداخل: 0.5199
#   فايت: 0.4886
#
# Most similar words to 'لحم':
#   جالا: 0.6774
#   العبيدية: 0.5965
#   ساحور: 0.5847
#   فجار: 0.5714
#   السدر: 0.5436
#
# Most similar words to 'ارئيل':
#   اارئيل: 0.7533
#   اريئيل: 0.5478
#   عوفرا: 0.5338
#   ارائيل: 0.5150
#   أرئيل: 0.4813
#
# Most similar words to 'الطنيب':
#   قدوميم: 0.5379
#   لخط: 0.5102
#   دبر: 0.5054
#   جيت: 0.4765
#   طنيب: 0.4730
#
# Most similar words to 'فقط':
#   النمرا: 0.4924
#   البوابة: 0.4890
#   ونمرا: 0.4714
#   صفرا: 0.4691
#   نمر: 0.4374
#
# Most similar words to 'عشوائي':
#   عشؤائي: 0.7153
#   هويات: 0.6873
#   دقيق: 0.6854
#   جوالات: 0.6575
#   انتقائي: 0.6535
#
# Most similar words to 'سينا':
#   عريك: 0.5338
#   وديربزيع: 0.5312
#   سينيا: 0.5214
#   وصابتو: 0.5095
#   عطاره: 0.5035
#
# Most similar words to 'بني':
#   بيني: 0.7096
#   اللوزي: 0.6528
#   وبني: 0.5575
#   قلقس: 0.5444
#   عبده: 0.5076
#
# Most similar words to 'Abu':
#   Hanish: 0.8013
#   Ibrahim: 0.7991
#   شروق: 0.7762
#   جميل: 0.7547
#   faris: 0.7280
#
# Most similar words to 'فوق':
#   وفوق: 0.5065
#   والبلد: 0.4872
#   قطعان: 0.4764
#   اوقات: 0.4526
#   معوسيارة: 0.4499
#
# Most similar words to 'لداخل':
#   للداخل: 0.7828
#   الداخل: 0.7040
#   والداخل: 0.5618
#   عالداخل: 0.5608
#   داخل: 0.5199
#
# Most similar words to 'عطاره':
#   عطارة: 0.7027
#   وتحت: 0.5089
#   سينا: 0.5035
#   وعطارة: 0.4559
#   فوق: 0.4319
#
# Most similar words to 'ليد':
#   شوفه: 0.5427
#   اللدائن: 0.5314
#   الكفريات: 0.4781
#   ترقوميا: 0.4346
#   قانا: 0.4334
#
# Most similar words to 'الاحتلال':
#   وحواجز: 0.6931
#   الإحتلال: 0.5744
#   التلجرام: 0.5706
#   تابعة: 0.5617
#   قوات: 0.5356
#
# Most similar words to 'المربعه':
#   المربعة: 0.7387
#   عورتا: 0.6488
#   لمربعه: 0.6355
#   لمربعة: 0.5302
#   شرف: 0.5203
#
# Most similar words to 'قانا':
#   الجوز: 0.6556
#   العرايس: 0.6260
#   البلاط: 0.6168
#   كانا: 0.6049
#   اللبان: 0.5893
#
# Most similar words to 'للجيش':
#   الجيش: 0.7630
#   للشرطة: 0.7510
#   للمستوطنين: 0.7481
#   جيش: 0.7387
#   حيوانات: 0.7354
#
# Most similar words to 'يونس':
#   يونس؛: 0.7155
#   دانييل: 0.6900
#   اليونس: 0.6727
#   صاللح: 0.6676
#   اللياس: 0.6617
#
# Most similar words to 'بين':
#   عند: 0.4516
#   كثيف: 0.4262
#   الواصل: 0.4095
#   وسير: 0.4022
#   بالقرب: 0.3920
#
# Most similar words to 'عقب':
#   قلنديا: 0.6030
#   رمانة: 0.5481
#   نعمة: 0.5456
#   عجائب: 0.5260
#   نعمه: 0.5116
#
# Most similar words to 'واقف':
#   خادث: 0.6368
#   متوقف: 0.6272
#   مشى: 0.6258
#   وقف: 0.5992
#   وبحول: 0.5960
#
# Most similar words to 'كل':
#   صارلو: 0.6466
#   بسط: 0.5851
#   لكل: 0.5734
#   وقيمة: 0.5607
#   هون: 0.5361
#
# Most similar words to 'كفل':
#   وكفل: 0.6498
#   لكفل: 0.6356
#   وديراستيا: 0.5965
#   بإشارات: 0.5746
#   والعباره: 0.5745
#
# Most similar words to 'الخير':
#   ااخير: 0.7682
#   الأحد: 0.6834
#   _جفنا: 0.6646
#   الخيرات: 0.6505
#   15092024: 0.6117
#
# Most similar words to 'ولا':
#   ١٥: 0.5633
#   حوالي: 0.5434
#   حوالي١٥: 0.5369
#   ٤٠: 0.5317
#   ٣٠: 0.5316
#
# Most similar words to 'سيارات':
#   سيارتين: 0.6402
#   سيارت: 0.6155
#   مسالك: 0.5899
#   مسارب: 0.5683
#   سيارة: 0.5516
#
# Most similar words to 'نعيم':
#   حارث: 0.7458
#   مجدل: 0.6846
#   النعيم: 0.6679
#   فاضل: 0.6026
#   خربثا: 0.5871
#
# Most similar words to 'جبارة':
#   باالاتجاهين: 0.5839
#   جباره: 0.5657
#   الكفريات: 0.5457
#   يختصر: 0.5012
#   طولكرم: 0.4748
#
# Most similar words to 'حجة':
#   الفندق: 0.5415
#   حجه: 0.5267
#   التاسع: 0.5022
#   التوالي: 0.4952
#   عللى: 0.4802
#
# Most similar words to 'قلقيلية':
#   اماتين: 0.5043
#   كدوميم: 0.4958
#   عزبة: 0.4777
#   إماتين: 0.4716
#   زاقفة: 0.4633
#
# Most similar words to 'احوال':
#   صفحه: 0.7383
#   صفحة: 0.7265
#   أحوال: 0.6928
#   لأحوال: 0.6773
#   والحواجز: 0.6612
#
# Most similar words to 'ابو':
#   بالاتجاهينابو: 0.5515
#   سيارهابو: 0.5445
#   الجدار: 0.5002
#   عنابابو: 0.4977
#   أبو: 0.4966
#
# Most similar words to 'وازمة':
#   وأزمة: 0.7141
#   ازمة: 0.6295
#   وازمه: 0.5957
#   أزمة: 0.5224
#   للعبيدية: 0.5080
#
# Most similar words to 'يا':
#   ويا: 0.6514
#   تجهزوا: 0.6193
#   با: 0.6052
#   يـ: 0.6021
#   isarPalestine: 0.5973
#
# Most similar words to 'الكفريات':
#   عناب: 0.5880
#   جبارة: 0.5457
#   الرابع: 0.5146
#   العاشرع: 0.4921
#   لليوم: 0.4907
#
# Most similar words to 'وحواجز':
#   الاحتلال: 0.6931
#   التلجرام: 0.6685
#   الطرق: 0.6527
#   الإحتلال: 0.6423
#   صفحة: 0.6203
#
# Most similar words to 'عوفرا':
#   اارئيل: 0.6836
#   ارئيل: 0.5338
#   ازمهوخانقه: 0.4696
#   شيلوا: 0.4270
#   بحزر: 0.4023
#
# Most similar words to 'فاتحه':
#   مغلقه: 0.5862
#   سالكه: 0.5716
#   وسالكه: 0.5491
#   زيف: 0.5281
#   فاتح: 0.5253
#
# Most similar words to 'البوابة':
#   عالبوابة: 0.6513
#   والبوابة: 0.6177
#   والجنوبي: 0.5565
#   البوابه: 0.5392
#   لنمراء: 0.5331
#
# Most similar words to 'كلا':
#   سلكلل: 0.6659
#   فى: 0.6311
#   بحريييي: 0.6200
#   ألمربعه: 0.5994
#   موحش: 0.5887
#
# Most similar words to 'غراب':
#   عراب: 0.7750
#   الغراب: 0.7367
#   الغرب: 0.7359
#   لغراب: 0.7239
#   سلمونه: 0.5367
#
# Most similar words to 'بسبب':
#   شكله: 0.5468
#   سبب: 0.4934
#   عاملة: 0.4892
#   خذوا: 0.4517
#   العموم: 0.4451
#
# Most similar words to 'مغلقه':
#   سالكه: 0.6535
#   بوابه: 0.6433
#   فاتحه: 0.5862
#   مغلق: 0.5757
#   مغلقة: 0.5735
#
# Most similar words to 'فاتحة':
#   فتحت: 0.6426
#   مغلقة: 0.6394
#   مغلفة: 0.5351
#   فاتح: 0.5323
#   مفتوحة: 0.5130
#
# Most similar words to 'الغرس':
#   فقططط: 0.5925
#   عصيرا: 0.5442
#   بزاريا: 0.5193
#   عنبتا: 0.5157
#   سبسطية: 0.5095
#
# Most similar words to 'صباح':
#   مسا: 0.8335
#   أمطار: 0.7604
#   مساء: 0.7575
#   وعلمنا: 0.7441
#   وفعل: 0.7147
#
# Most similar words to 'و':
#   تضج: 0.6097
#   قلوبا: 0.5996
#   ࢪت: 0.5755
#   ࢪيح: 0.5567
#   بالألم: 0.5461
#
# Most similar words to 'جدا':
#   سيء: 0.6571
#   بطيء: 0.6547
#   اوضاع: 0.6245
#   سيئة: 0.6223
#   سيئ: 0.5824
#
# Most similar words to 'بكل':
#   بكلى: 0.6696
#   عكل: 0.6474
#   بجميع: 0.5724
#   جميع: 0.5346
#   لكل: 0.5155
#
# Most similar words to 'تحديث':
#   استفسار: 0.4726
#   لمعرجات: 0.4567
#   للتذكير: 0.4249
#   ومرا: 0.4228
#   شفت: 0.4188
#
# Most similar words to 'عليه':
#   حوالي: 0.5952
#   النصاريه: 0.5286
#   ٣٠: 0.5228
#   وبفتشو: 0.5191
#   عليها: 0.4837
#
# Most similar words to 'عصيون':
#   افرات: 0.7032
#   المنشية: 0.6465
#   فرات: 0.5819
#   لتقوع: 0.5625
#   جورة: 0.5587
#
# Most similar words to 'شارع':
#   خط: 0.5514
#   غزه: 0.4837
#   وخط: 0.4662
#   واصل: 0.4459
#   محاصرة: 0.4414
#
# Most similar words to 'الجوره':
#   الجورة: 0.8437
#   االجوره: 0.6970
#   ومحروق: 0.6618
#   الجور: 0.6394
#   جوره: 0.6238
#
# Most similar words to 'yazan':
#   شروق: 0.7478
#   جميل: 0.7071
#   Ibrahim: 0.6186
#   Abu: 0.6150
#   Fathi: 0.5520
#
# Most similar words to 'الحراميه':
#   حرامية: 0.7097
#   الحزامية: 0.6754
#   الحرميه: 0.6567
#   الحرمية: 0.6324
#   الحرامبة: 0.5935
#
# Most similar words to 'ghreefe':
#   شروق: 0.6783
#   Hattab: 0.6423
#   Fathi: 0.6110
#   Anas: 0.6069
#   جميل: 0.6069
#
# Most similar words to 'ادوميم':
#   ادمييم: 0.7152
#   ادميمم: 0.7093
#   أدوميم: 0.7042
#   ادومبم: 0.6569
#   افرام: 0.6324
#
# Most similar words to 'اللبد':
#   شوفه: 0.6448
#   رمانة: 0.5468
#   تياسير: 0.4870
#   راعي: 0.4622
#   علار: 0.4568
#
# Most similar words to 'المساكن':
#   بورين: 0.5768
#   زواتا: 0.5719
#   عصيرة: 0.5001
#   وبشيلو: 0.4784
#   وماشيه: 0.4768
#
# Most similar words to 'بحري':
#   خلصنا: 0.5834
#   وجوي: 0.5808
#   تماما: 0.5557
#   تماماا: 0.5095
#   وجوى: 0.4992
#
# Most similar words to 'فاتح':
#   مفتوح: 0.7507
#   فاتحة: 0.5323
#   عجوري: 0.5281
#   فاتحه: 0.5253
#   مغلق: 0.5038
#
# Most similar words to 'عكس':
#   وعكس: 0.7321
#   بعكس: 0.6700
#   عسكس: 0.6700
#   لعكس: 0.6516
#   جزاهم: 0.6487
#
# Most similar words to 'شرطه':
#   شرطة: 0.7654
#   الشرطه: 0.6184
#   للشرطه: 0.5909
#   جيش: 0.5596
#   مستوطنين: 0.5377
#
# Most similar words to 'جهة':
#   جاي: 0.6783
#   نازل: 0.6067
#   باتجاه: 0.5322
#   للقادم: 0.5154
#   اتجاه: 0.4962
#
# Most similar words to 'وسالك':
#   DOC: 0.5807
#   وازمة: 0.4122
#   حاليا: 0.4106
#   فقط: 0.4057
#   والسموع: 0.4023
#
# Most similar words to 'معكم':
#   لنستمر: 0.8334
#   بي: 0.6672
#   عالخاص: 0.5814
#   زعترا: 0.5537
#   ونمر: 0.5344
#
# Most similar words to 'الشمالي':
#   الجنوبي: 0.6540
#   البيرة: 0.5717
#   ائيل: 0.5081
#   شمالي: 0.4493
#   ديراستيا: 0.4424
#
# Most similar words to 'العروب':
#   الشيوخ: 0.6712
#   الحواور: 0.6024
#   البقر: 0.5780
#   عينون: 0.5764
#   يونس: 0.5509
#
# Most similar words to 'خفيفة':
#   متوسطة: 0.7661
#   ماشية: 0.6487
#   قوية: 0.6441
#   شديدة: 0.6057
#   طويلة: 0.5951
#
# Most similar words to 'جباره':
#   أودلا: 0.6055
#   عزون: 0.6023
#   اودلا: 0.5717
#   جبارة: 0.5657
#   عوزي: 0.4774
#
# Most similar words to 'شوفه':
#   اللبد: 0.6448
#   المصانع: 0.5437
#   ليد: 0.5427
#   لذنابة: 0.4987
#   العزبة: 0.4292
#
# Most similar words to 'بديا':
#   استيا: 0.5516
#   بروقين: 0.5500
#   الشرقيه: 0.5240
#   ارائيل: 0.4929
#   قانا: 0.4351
#
# Most similar words to 'حلحول':
#   كاحل: 0.6204
#   حسكه: 0.6106
#   حلحوول: 0.5204
#   عوزي: 0.5201
#   نركيس: 0.5165
#
# Most similar words to 'استيا':
#   الشرقيه: 0.5647
#   بديا: 0.5516
#   مردا: 0.5130
#   نظام: 0.4824
#   الغربي: 0.4772
#
# Most similar words to 'مش':
#   ومش: 0.5868
#   معناتو: 0.5681
#   يضل: 0.5597
#   سيئ: 0.5514
#   وغير: 0.5374
#
# Most similar words to 'سعير':
#   الحواور: 0.7083
#   عينون: 0.6832
#   قلقس: 0.6454
#   الشاجنة: 0.6380
#   المنشية: 0.5985
#
# Most similar words to 'حادث':
#   كثاقة: 0.7206
#   شاحنة: 0.6724
#   وكثافه: 0.6095
#   وكثافة: 0.6093
#   واماتين: 0.5765
#
# Most similar words to 'بجميع':
#   بكل: 0.5724
#   بكلى: 0.5627
#   عكل: 0.5307
#   حواره: 0.5042
#   لكل: 0.4516
#
# Most similar words to 'تياسير':
#   طوباس: 0.7778
#   الحمرا: 0.6638
#   لحمرا: 0.6060
#   وبمشي: 0.5042
#   اللبد: 0.4870
#
# Most similar words to 'طولكرم':
#   عنبتا: 0.6202
#   ذنابة: 0.5650
#   العطاره: 0.5522
#   للأعمال: 0.5322
#   باالاتجاهين: 0.5289
#
# Most similar words to 'السلامة':
#   صفحه: 0.7308
#   السلامه: 0.7274
#   واخرى: 0.6079
#   بالسلامه: 0.6076
#   وألطف: 0.6071
#
# Most similar words to 'قبل':
#   بعد: 0.7063
#   عند: 0.6406
#   على: 0.5953
#   ع: 0.5617
#   اول: 0.5350
#
# Most similar words to 'اغلاق':
#   إغلاق: 0.7435
#   فتح: 0.6993
#   وقراها: 0.5252
#   نقلها: 0.5225
#   واغلاق: 0.5212
#
# Most similar words to 'اللبن':
#   معرجات: 0.5994
#   الساوية: 0.5928
#   عيليي: 0.5630
#   بقدروا: 0.5502
#   الكوربات: 0.5306
#
# Most similar words to 'إلى':
#   الى: 0.4890
#   كركر: 0.4674
#   لرمزونات: 0.4139
#   ك: 0.4042
#   باتجله: 0.4035
#
# Most similar words to 'تقوع':
#   المنشية: 0.7118
#   الربيع: 0.6298
#   جناتا: 0.6261
#   تل: 0.5957
#   حرملة: 0.5879
#
# Most similar words to 'بداية':
#   وبداية: 0.5760
#   بدايه: 0.5563
#   ماشية: 0.5396
#   خفيفة: 0.5354
#   فل: 0.5106
#
# Most similar words to 'خفيفه':
#   خانقه: 0.7091
#   متوسطه: 0.7078
#   ماشيه: 0.6936
#   وماشيه: 0.6336
#   بدايه: 0.5718
#
# Most similar words to 'ترقوميا':
#   الهجرة: 0.6268
#   إذنا: 0.6002
#   اللية: 0.5946
#   السموع: 0.5784
#   القصر: 0.5346
#
# Most similar words to 'كدوميم':
#   كدميمم: 0.7531
#   قدوميم: 0.6403
#   كدومييم: 0.6362
#   ملثمين: 0.5349
#   جينصافوط: 0.5269
#
# Most similar words to 'زعترا':
#   معكم: 0.5537
#   لنستمر: 0.4984
#   ونمر: 0.4913
#   الساويه: 0.4813
#   صره: 0.4789
#
# Most similar words to 'البنانا':
#   الهيئة: 0.8446
#   الصفراء: 0.7477
#   المعابر: 0.7428
#   الصفرا: 0.6442
#   المشروع: 0.6348
#
# Most similar words to 'شروق':
#   جميل: 0.8819
#   Abu: 0.7762
#   Ibrahim: 0.7760
#   yazan: 0.7478
#   Fathi: 0.7463
#
# Most similar words to 'اللهم':
#   وبارك: 0.8368
#   ويسر: 0.8312
#   لنا: 0.8220
#   ائنا: 0.8152
#   كسر: 0.8145
#
# Most similar words to 'شاحنات':
#   ونمر: 0.8312
#   نمر: 0.7536
#   صرة: 0.6853
#   صفراء: 0.6682
#   نمرة: 0.6624
#
# Most similar words to 'الهيئة':
#   البنانا: 0.8446
#   الصفراء: 0.7522
#   المعابر: 0.7425
#   الصفرا: 0.6624
#   DCO: 0.6540
#
# Most similar words to 'ونظيفة':
#   سالكة: 0.6428
#   شرقيه: 0.6125
#   ونظيف: 0.5983
#   الخروبة: 0.5609
#   الشرقية: 0.5557
#
# Most similar words to 'تم':
#   اعادة: 0.7244
#   إعادة: 0.6338
#   يتم: 0.5899
#   الارتباط: 0.5309
#   سيتم: 0.5226
#
# Most similar words to 'عن':
#   مراسلته: 0.5771
#   لنفس: 0.5670
#   لعدم: 0.5641
#   عندو: 0.5466
#   عبر: 0.5414
#
# Most similar words to 'الساعة':
#   السادسة: 0.8159
#   ظهرا: 0.7781
#   صباحا: 0.7770
#   السـادسة: 0.7569
#   الواحدة: 0.7495
#
# Most similar words to 'للي':
#   يلي: 0.7228
#   الي: 0.7032
#   عاللي: 0.6103
#   والي: 0.6011
#   رايح: 0.5977
#
# Most similar words to 'الفارسي':
#   سلمان: 0.9311
#   سليمان: 0.7845
#   عينبوس: 0.6465
#   وبالبوابات: 0.6371
#   الرئسي: 0.6201
#
# Most similar words to 'dco':
#   DCO: 0.7366
#   ائيل: 0.6714
#   ࢪاحلين: 0.6243
#   Dco: 0.5717
#   للأحبة: 0.5249
#
# Most similar words to 'مخماس':
#   لقبلان: 0.4918
#   الجهالين: 0.4824
#   المروح: 0.4680
#   ليفي: 0.4534
#   جبع: 0.4476
#
# Most similar words to 'ماشية':
#   وماشية: 0.6659
#   خفيفة: 0.6487
#   طويلة: 0.6132
#   برضه: 0.6057
#   قوية: 0.6043
#
# Most similar words to 'صفراء':
#   ونمر: 0.8075
#   نمر: 0.7505
#   شاحنات: 0.6682
#   صرة: 0.6513
#   بحكيلك: 0.6136
#
# Most similar words to 'الياس':
#   صالحشقبا: 0.7654
#   إلياس: 0.7442
#   لياس: 0.7426
#   اللياس: 0.7303
#   دانييل: 0.6945
#
# Most similar words to 'السيارات':
#   السيارة: 0.5477
#   برجع: 0.5162
#   تجاوز: 0.5136
#   لوراا: 0.4980
#   بمر: 0.4979
#
# Most similar words to 'ونمر':
#   شاحنات: 0.8312
#   صفراء: 0.8075
#   نمر: 0.7764
#   صرة: 0.6545
#   تخصص: 0.6452
#
# Most similar words to 'ل':
#   حتى: 0.5536
#   تماما: 0.5218
#   لعيون: 0.4994
#   لغاية: 0.4864
#   لجيت: 0.4819
#
# Most similar words to 'كف':
#   لكف: 0.6792
#   ٣٥: 0.6383
#   كريات: 0.5846
#   35: 0.5735
#   واسحببببب: 0.5625
#
# Most similar words to 'اتجاهين':
#   بالاتجاهين: 0.5025
#   للخارج: 0.4281
#   للجهتين: 0.4183
#   الكونتينر: 0.3913
#   الكونيتنر: 0.3913
#
# Most similar words to 'او':
#   عبيوتهم: 0.6070
#   سمايل: 0.5881
#   الادارة: 0.5829
#   يتواصل: 0.5768
#   خاطئ: 0.5749
#
# Most similar words to 'شبه':
#   ازمه: 0.4926
#   وشبه: 0.4578
#   شبيه: 0.4289
#   الحمرا: 0.4281
#   كم: 0.4069
#
# Most similar words to 'طوباس':
#   تياسير: 0.7778
#   لحمرا: 0.6741
#   الباذان: 0.6135
#   حرميش: 0.5908
#   دوتان: 0.5735
#
# Most similar words to 'معنا':
#   تفاعلوا: 0.9202
#   بعدي: 0.8476
#   يؤمنون: 0.8380
#   بي: 0.7896
#   بقلب: 0.7818
#
# Most similar words to 'تام':
#   تااام: 0.8151
#   تاام: 0.7495
#   تان: 0.6942
#   تامما: 0.6839
#   ولداخل: 0.6730
#
# Most similar words to 'جورة':
#   الشمعه: 0.8487
#   المنشيه: 0.7569
#   الشمعة: 0.7561
#   وجورة: 0.7361
#   المنشية: 0.7309
#
# Most similar words to 'زيف':
#   كرمه: 0.7651
#   يطا: 0.7524
#   عبده: 0.7492
#   السموع: 0.6762
#   عبدة: 0.6697
#
# Most similar words to 'بير':
#   زيت: 0.7925
#   المحجر: 0.7351
#   وبطئ: 0.6790
#   لسيارتو: 0.6697
#   خلة: 0.6151
#
# Most similar words to 'سلمان':
#   الفارسي: 0.9311
#   سليمان: 0.7166
#   بحوارة: 0.5954
#   عينبوس: 0.5912
#   وبالبوابات: 0.5575
#
# Most similar words to 'الغربي':
#   السلامة: 0.4987
#   استيا: 0.4772
#   مردا: 0.4682
#   متواجد: 0.4609
#   صفحه: 0.4262
#
# Most similar words to 'Ibrahim':
#   Abu: 0.7991
#   جميل: 0.7970
#   شروق: 0.7760
#   Hanish: 0.7732
#   yazan: 0.6186
#
# Most similar words to 'كركر':
#   ومحروق: 0.6001
#   جوره: 0.5403
#   شيلو: 0.5220
#   الجورا: 0.5079
#   الجور: 0.5043
#
# Most similar words to 'Hanish':
#   Abu: 0.8013
#   Ibrahim: 0.7732
#   sunineh: 0.7391
#   Anas: 0.6141
#   Hattab: 0.5785
#
# Most similar words to 'سالكين':
#   مغلقاااات: 0.5049
#   سالكه: 0.4680
#   سالك: 0.4632
#   الطيبه: 0.4201
#   سالكيييين: 0.4192
#
# Most similar words to 'بيرزيت':
#   مراحب: 0.6056
#   سينيا: 0.5860
#   للبيرة: 0.5763
#   بير: 0.5134
#   عطارة: 0.5083
#
# Most similar words to 'متواجد':
#   عالخاص: 0.6924
#   بكملوا: 0.6600
#   خاص: 0.6061
#   سهران: 0.5954
#   طريقة: 0.5559
#
# Most similar words to 'اللي':
#   الي: 0.7279
#   مين: 0.5723
#   الاعياد: 0.5696
#   انواع: 0.5601
#   وللي: 0.5570
#
# Most similar words to 'القدس':
#   قلنديا: 0.5714
#   الجيب: 0.5522
#   عالقدس: 0.5487
#   المخيم: 0.5468
#   اندماج: 0.5209
#
# Most similar words to 'خانقه':
#   خفيفه: 0.7091
#   طويله: 0.6889
#   متوسطه: 0.6733
#   بدايه: 0.6165
#   قويه: 0.5974
#
# Most similar words to 'افرايم':
#   فرايم: 0.7719
#   ادومبم: 0.7289
#   ادمييم: 0.7035
#   أدوميم: 0.6954
#   والأغوار: 0.6954
#
# Most similar words to 'التلجرام':
#   موقعنا: 0.8756
#   لاتنسونا: 0.8076
#   احترنا: 0.7366
#   جروبات: 0.7244
#   فئة: 0.7231
#
# Most similar words to 'حواره':
#   بجميع: 0.5042
#   حراره: 0.4256
#   الاتجاهات: 0.3989
#   حوارة: 0.3946
#   ووجيب: 0.3929
#
# Most similar words to 'وقوف':
#   وقووف: 0.7921
#   ووقوف: 0.7840
#   وفوف: 0.7802
#   حاليٱ: 0.7285
#   الجنب: 0.7284
#
# Most similar words to 'جنين':
#   الصياح: 0.5658
#   سبسطية: 0.5601
#   سهل: 0.5436
#   المسعوديه: 0.5424
#   برقه: 0.5412
#
# Most similar words to 'faris':
#   Motaz: 0.9605
#   sunineh: 0.7335
#   Abu: 0.7280
#   العقبي: 0.6778
#   Fathi: 0.6112
#
# Most similar words to 'sunineh':
#   Hanish: 0.7391
#   faris: 0.7335
#   Abu: 0.6394
#   Motaz: 0.6153
#   Fathi: 0.5748
#
# Most similar words to 'Motaz':
#   faris: 0.9605
#   Abu: 0.7232
#   جميل: 0.6542
#   العقبي: 0.6448
#   شروق: 0.6214
#
# Most similar words to 'بوابه':
#   مغلقه: 0.6433
#   مدخل: 0.5072
#   الهجره: 0.5023
#   بقر: 0.4940
#   الشيوخ: 0.4889
#
# Most similar words to 'بي':
#   لنستمر: 0.8316
#   معنا: 0.7896
#   تفاعلوا: 0.7287
#   معكم: 0.6672
#   يؤمنون: 0.6347
#
# Most similar words to 'الشرقيه':
#   استيا: 0.5647
#   بديا: 0.5240
#   بروقين: 0.4390
#   قراه: 0.4360
#   رمل: 0.4091
#
# Most similar words to 'صفحه':
#   احوال: 0.7383
#   السلامة: 0.7308
#   متغير: 0.6982
#   للجميع: 0.6075
#   لحظات: 0.5837
#
# Most similar words to 'المنشية':
#   الشمعة: 0.7330
#   جورة: 0.7309
#   المنشيه: 0.7300
#   تقوع: 0.7118
#   الشمعه: 0.6992
#
# Most similar words to 'افرات':
#   عصيون: 0.7032
#   المنشيه: 0.6037
#   عتصيون: 0.5950
#   فرات: 0.5844
#   كرمي: 0.5799
#
# Most similar words to 'المعرجات':
#   90: 0.6887
#   الهيئة: 0.5984
#   أريحا: 0.5364
#   ٩٠: 0.5331
#   العوجا: 0.4911
#
# Most similar words to 'التفافي':
#   عالتفافي: 0.6251
#   إلتفافي: 0.6199
#   البد: 0.5607
#   ترانزيت: 0.5594
#   عينابوس: 0.5452
#
# Most similar words to 'بلوط':
#   استيا: 0.4765
#   عابود: 0.4591
#   ترمسعيا: 0.4487
#   اللبن: 0.4412
#   نظامالخروبة: 0.4412
#
# Most similar words to 'جالا':
#   لحم: 0.6774
#   عنون: 0.6223
#   نصار: 0.6186
#   سي: 0.5613
#   أيل: 0.5543
#
# Most similar words to 'وضع':
#   متغير: 0.6110
#   ازالة: 0.4770
#   وبوصل: 0.4745
#   فتاه: 0.4720
#   إزالة: 0.4569
#
# Most similar words to 'الباذان':
#   طوباس: 0.6135
#   تياسير: 0.4865
#   لداخل: 0.4508
#   وبمشي: 0.4329
#   صايد: 0.4309
#
# Most similar words to 'سدة':
#   قراوة: 0.7156
#   سدت: 0.5453
#   لنفي: 0.5187
#   حسان: 0.5048
#   يفحص: 0.5040
#
# Most similar words to 'ضوئية':
#   عيليي: 0.5289
#   المفتوحة: 0.4999
#   اشارات: 0.4926
#   التحنا: 0.4880
#   العزر: 0.4672
#
# Most similar words to 'ارائيل':
#   اريئيل: 0.6888
#   حارس: 0.6109
#   الفوقا: 0.5222
#   ونظيفة: 0.5215
#   ارئيل: 0.5150
#
# Most similar words to 'الرام':
#   الفواكه: 0.6343
#   حزما: 0.6274
#   جبع: 0.6184
#   قلنديا: 0.6149
#   المخيم: 0.6139
#
# Most similar words to 'الشارع':
#   عالشارع: 0.5874
#   مية: 0.5785
#   الطريق: 0.5527
#   انعدام: 0.5362
#   والشارع: 0.5287
#
# Most similar words to 'زيت':
#   بير: 0.7925
#   المحجر: 0.6918
#   تقلقش: 0.6342
#   وبطئ: 0.5631
#   لسيارتو: 0.5424
#
# Most similar words to 'ماشيه':
#   خفيفه: 0.6936
#   متوسطه: 0.6435
#   طويله: 0.6326
#   وماشيه: 0.6026
#   خانقه: 0.5958
#
# Most similar words to 'يتما':
#   قبلان: 0.7747
#   عقربا: 0.7254
#   وقبلان: 0.6522
#   بيتا: 0.6254
#   الساوية: 0.6176
#
# Most similar words to 'لنستمر':
#   معكم: 0.8334
#   بي: 0.8316
#   معنا: 0.6328
#   صفراء: 0.5501
#   سهران: 0.5419
#
# Most similar words to 'تفاعلوا':
#   معنا: 0.9202
#   بقلب: 0.9171
#   بعدي: 0.8829
#   يؤمنون: 0.8703
#   الأوائل: 0.8547
#
# Most similar words to 'والخارج':
#   الخارج: 0.8282
#   وللخارج: 0.7112
#   للخارج: 0.6328
#   للطالع: 0.6099
#   وشوية: 0.5844
#
# Most similar words to 'الحواور':
#   عينون: 0.7243
#   سعير: 0.7083
#   العروب: 0.6024
#   قلقس: 0.5772
#   وحواجز: 0.5662
#
# Most similar words to 'فرات':
#   البلوطه: 0.5913
#   افرات: 0.5844
#   عصيون: 0.5819
#   اسارات: 0.5795
#   رمزونات: 0.5761
#
# Most similar words to 'شوي':
#   وبتسلك: 0.6839
#   وبتوصل: 0.6812
#   بتوصل: 0.6544
#   خفوا: 0.6419
#   ليقيموا: 0.6205
#
# Most similar words to 'عابود':
#   الجدار: 0.7923
#   مشعل: 0.6285
#   نظام: 0.5905
#   كرملو: 0.5409
#   الخروبة: 0.5378
#
# Most similar words to 'النفق':
#   نفق: 0.5778
#   حبلة: 0.5740
#   عنفق: 0.5342
#   الاسكانات: 0.5185
#   الكونتيتر: 0.5149
#
# Most similar words to 'انتبهوا':
#   انتبهو: 0.6290
#   رادار: 0.5603
#   دورية: 0.5598
#   جب: 0.5253
#   حملة: 0.5179
#
# Most similar words to 'الكونتير':
#   الكونتينر: 0.5724
#   الطيب: 0.4884
#   الزعيم: 0.4718
#   ازعيم: 0.4695
#   استفسار: 0.4530
#
# Most similar words to 'كم':
#   اكم: 0.7648
#   ١٥: 0.6790
#   أكم: 0.6618
#   ولى: 0.6544
#   ٢٠٣٠: 0.6319
#
# Most similar words to 'يطا':
#   كرمه: 0.8228
#   وكريم: 0.7617
#   زيف: 0.7524
#   الظاهرية: 0.7415
#   الليه: 0.7315
#
# Most similar words to 'المي':
#   وبطئ: 0.6719
#   خله: 0.6403
#   المحجر: 0.6334
#   خربه: 0.6260
#   خلة: 0.6137
#
# Most similar words to 'جناتا':
#   الربيع: 0.7586
#   تل: 0.6694
#   المنشية: 0.6324
#   تقوع: 0.6261
#   السدر: 0.6147
#
# Most similar words to 'جماعة':
#   جماعه: 0.7026
#   عديمي: 0.6516
#   تنضيم: 0.6486
#   بيزيدو: 0.6374
#   كلنا: 0.6237
#
# Most similar words to 'السدر':
#   نصار: 0.8349
#   الاسكانات: 0.7945
#   سي: 0.6764
#   ونصار: 0.6757
#   دي: 0.6702
#
# Most similar words to 'بتجاه':
#   باتجاه: 0.6438
#   بأتجاه: 0.6046
#   بإتجاه: 0.5523
#   اتجاه: 0.5496
#   خط: 0.5050
#
# Most similar words to 'زعتره':
#   زعترة: 0.5377
#   فجار: 0.5363
#   الدهيشة: 0.4702
#   بساچوت: 0.4623
#   حوسان: 0.4512
#
# Most similar words to 'اي':
#   نود: 0.6392
#   واي: 0.6373
#   تتواصل: 0.6114
#   لاي: 0.6042
#   ومعكم: 0.5958
#
# Most similar words to 'المدخل':
#   لقرية: 0.4532
#   البيرة: 0.4318
#   عبوين: 0.4226
#   مدخل: 0.4160
#   سلفيت: 0.4137
#
# Most similar words to 'زال':
#   يزال: 0.6641
#   ورة: 0.6603
#   لحق: 0.6479
#   تزال: 0.6479
#   تقربو: 0.6395
#
# Most similar words to 'طبعا':
#   هاي: 0.6095
#   وخبرنا: 0.5074
#   راح: 0.4992
#   قبلها: 0.4909
#   وطبعا: 0.4755
#
# Most similar words to '٣٥':
#   35: 0.7200
#   كدار: 0.6967
#   ٣٥ل: 0.6910
#   كف: 0.6383
#   كريات: 0.5879
#
# Most similar words to 'عوا':
#   مثلث: 0.8443
#   خرسا: 0.8062
#   اذنا: 0.7056
#   لمدينة: 0.6986
#   فقيقيس: 0.6963
#
# Most similar words to 'صالح':
#   صاللح: 0.7025
#   صالحشقبا: 0.6504
#   إلياس: 0.6477
#   بنوار: 0.6391
#   عشاق: 0.6245
#
# Most similar words to 'حدا':
#   بحكو: 0.7899
#   بحكي: 0.6727
#   حداا: 0.6678
#   بحكوا: 0.6420
#   حد: 0.6289
#
# Most similar words to 'يبرود':
#   سلواد: 0.7966
#   والحركة: 0.7586
#   ييرود: 0.6675
#   بلده: 0.5859
#   ويبرود: 0.5814
#
# Most similar words to 'أريحا':
#   اريحا: 0.7238
#   النصارية: 0.6247
#   الجفتلك: 0.5723
#   كرملوا: 0.5511
#   ومخارج: 0.5412
#
# Most similar words to 'الصفرا':
#   الصفراء: 0.7812
#   بسيارتو: 0.6783
#   الهيئة: 0.6624
#   الصفراا: 0.6614
#   البنانا: 0.6442
#
# Most similar words to 'الالتفافي':
#   الجديد: 0.6312
#   الضاحية: 0.5707
#   الليه: 0.5676
#   يطا: 0.4980
#   عقربا: 0.4974
#
# Most similar words to 'لحد':
#   لهاي: 0.6008
#   لغاية: 0.5523
#   حفرو: 0.5142
#   سياراه: 0.5057
#   ودقائق: 0.4855
#
# Most similar words to 'الخاص':
#   تصبح: 0.7354
#   رسالة: 0.7154
#   والرد: 0.6987
#   ولاي: 0.6737
#   ومعكم: 0.6726
#
# Most similar words to 'فى':
#   كلا: 0.6311
#   وفاضية: 0.6190
#   موحش: 0.5650
#   يعنى: 0.5446
#   بلأتجاهين: 0.5371
#
# Most similar words to 'الوضع':
#   وضعه: 0.6468
#   كتيرر: 0.6437
#   دندره: 0.6222
#   وضعها: 0.6190
#   سيء: 0.6123
#
# Most similar words to 'منيح':
#   ممتاز: 0.7217
#   ببطئ: 0.7214
#   عالبطيء: 0.6680
#   داحل: 0.6418
#   سريع: 0.6384
#
# Most similar words to 'عبده':
#   الهجرة: 0.8283
#   كرمه: 0.7983
#   العقد: 0.7794
#   كرمة: 0.7756
#   السموع: 0.7604
#
# Most similar words to 'ماشي':
#   داحل: 0.6697
#   وعكس: 0.6588
#   بمشي: 0.6395
#   يمشي: 0.6130
#   فجأة: 0.6100
#
# Most similar words to 'علينا':
#   بقلب: 0.9342
#   تبخلوا: 0.9101
#   وثبت: 0.9028
#   أفرغ: 0.8977
#   فاحفظ: 0.8934
#
# Most similar words to 'بمشي':
#   بمشو: 0.7020
#   ويمشي: 0.6490
#   بسلك: 0.6466
#   ماشي: 0.6395
#   وبمشي: 0.6359
#
# Most similar words to 'الازمة':
#   الأزمة: 0.6760
#   الازمه: 0.6293
#   روتانا: 0.6121
#   والازمة: 0.6081
#   بتبلش: 0.5982
#
# Most similar words to 'صباحا':
#   السـادسة: 0.8698
#   00: 0.8330
#   للقيام: 0.8252
#   30: 0.8244
#   السادسة: 0.8223
#
# Most similar words to 'اليوم':
#   ٨: 0.6887
#   الموافق: 0.6713
#   طوال: 0.6712
#   غد: 0.6655
#   الخميس: 0.6532
#
# Most similar words to 'للجهتين':
#   خفيفة: 0.5106
#   لزمة: 0.4992
#   والوضع: 0.4987
#   لسا: 0.4856
#   رهيبة: 0.4843
#
# Most similar words to 'فاضي':
#   عالنازل: 0.5979
#   رايق: 0.5864
#   عجوري: 0.5821
#   كفرعقب: 0.5374
#   عالطالع: 0.5328
#
# Most similar words to 'DCO':
#   dco: 0.7366
#   ࢪاحلين: 0.6958
#   الهيئة: 0.6540
#   Dco: 0.6188
#   للأحبة: 0.6095
#
# Most similar words to 'البديل':
#   استخدام: 0.5627
#   وسوف: 0.5495
#   البديلة: 0.5200
#   الترابي: 0.5155
#   البديله: 0.4960
#
# Most similar words to 'لكن':
#   بس: 0.6760
#   ولكن: 0.5351
#   لحومش: 0.4895
#   ولسا: 0.4872
#   والوضع: 0.4828
#
# Most similar words to 'فتحت':
#   سكرت: 0.6928
#   فاتحة: 0.6426
#   مسكرة: 0.5439
#   بتسكر: 0.5264
#   فاضية: 0.5070
#
# Most similar words to 'وسالكة':
#   البناء: 0.5884
#   مبينة: 0.5729
#   اصورها: 0.5603
#   صرا: 0.5535
#   القبور: 0.5122
#
# Most similar words to 'واصلة':
#   وصلت: 0.7884
#   واصله: 0.6073
#   لبعد: 0.6001
#   بتبلش: 0.5716
#   الأزمة: 0.5695
#
# Most similar words to 'كرمه':
#   يطا: 0.8228
#   عبده: 0.7983
#   السموع: 0.7788
#   زيف: 0.7651
#   الهجرة: 0.7484
#
# Most similar words to 'مستوطنين':
#   للمستوطنين: 0.7061
#   المستوطنين: 0.7004
#   حجار: 0.6799
#   مستوطن: 0.6227
#   للجيش: 0.5974
#
# Most similar words to 'قراوة':
#   حسان: 0.7573
#   سدة: 0.7156
#   يدير: 0.6677
#   قراوه: 0.6673
#   باله: 0.6412
#
# Most similar words to 'دعائكم':
#   الطيب: 0.9311
#   لاتنسونا: 0.9080
#   تحبس: 0.7149
#   اثني: 0.7005
#   التلجرام: 0.6817
#
# Most similar words to 'الساوية':
#   ولعند: 0.6223
#   يتما: 0.6176
#   قوربة: 0.5973
#   اللبن: 0.5928
#   والساوية: 0.5857
#
# Most similar words to 'سامر':
#   ياسين: 0.9396
#   شروق: 0.6525
#   جميل: 0.6266
#   Ibrahim: 0.6055
#   Fathi: 0.5960
#
# Most similar words to 'سلك':
#   مشا: 0.6365
#   وقف: 0.6215
#   فتح: 0.5873
#   فك: 0.5752
#   ولحد: 0.5558
#
# Most similar words to 'الهوا':
#   الهوى: 0.8353
#   الهواء: 0.8074
#   آلهوى: 0.7675
#   الهواى: 0.6359
#   هوا: 0.6257
#
# Most similar words to 'والبلد':
#   وسلفيت: 0.5185
#   روابي: 0.5034
#   فوق: 0.4872
#   وعارورة: 0.4810
#   سين: 0.4160
#
# Most similar words to 'الطيب':
#   دعائكم: 0.9311
#   لاتنسونا: 0.7724
#   تحبس: 0.6941
#   الخاص: 0.6324
#   اثني: 0.6316
#
# Most similar words to 'رامين':
#   سفارين: 0.8544
#   شوفة: 0.6311
#   عزبة: 0.5728
#   بلحجارة: 0.5611
#   برقه: 0.5224
#
# Most similar words to 'عزبة':
#   الطبيب: 0.7670
#   حجه: 0.6623
#   سفارين: 0.6474
#   شوفة: 0.6389
#   اماتين: 0.5963
#
# Most similar words to 'وازمه':
#   ازمه: 0.6664
#   وازمة: 0.5957
#   وجهتين: 0.5765
#   وأزمة: 0.5637
#   أزمه: 0.5055
#
# Most similar words to 'مداخل':
#   ومخارج: 0.7863
#   حواجز: 0.7341
#   كافة: 0.6950
#   الاربعه: 0.6730
#   ومداخل: 0.6638
#
# Most similar words to 'الصفراء':
#   الصفرا: 0.7812
#   الهيئة: 0.7522
#   البنانا: 0.7477
#   المشروع: 0.6506
#   الصفراا: 0.6047
#
# Most similar words to 'سلواد':
#   يبرود: 0.7966
#   والحركة: 0.7403
#   ويلحق: 0.6639
#   وسلواد: 0.6143
#   ييرود: 0.6030
#
# Most similar words to 'ياسين':
#   سامر: 0.9396
#   اخوكم: 0.6114
#   والمشرف: 0.5832
#   Bder: 0.5816
#   حطاب: 0.5811
#
# Most similar words to 'صفحة':
#   كريم: 0.7820
#   انتظرونا: 0.7712
#   أجر: 0.7575
#   لأحوال: 0.7382
#   بتقرير: 0.7287
#
# Most similar words to 'بلدة':
#   حسكه: 0.7151
#   عوا: 0.6127
#   مثلث: 0.5983
#   السموع: 0.5328
#   مرملة: 0.5045
#
# Most similar words to 'الآن':
#   اللحظة: 0.6758
#   الان: 0.6092
#   الحظة: 0.5250
#   اشعار: 0.5218
#   اللحظه: 0.4960
#
# Most similar words to 'لاتنسونا':
#   دعائكم: 0.9080
#   التلجرام: 0.8076
#   الطيب: 0.7724
#   اثني: 0.7613
#   تحبس: 0.7440
#
# Most similar words to 'الجديد':
#   الالتفافي: 0.6312
#   الرئسي: 0.5507
#   والالنفافبي: 0.5431
#   عينابوس: 0.5025
#   القبلية: 0.4880
#
# Most similar words to 'عينون':
#   الحواور: 0.7243
#   امر: 0.6864
#   سعير: 0.6832
#   عوا: 0.6670
#   عنون: 0.6415
#
# Most similar words to 'الجميع':
#   يقرأ: 0.7431
#   الرجاء: 0.7001
#   الاخوة: 0.6248
#   التقرير: 0.6196
#   شخص: 0.5969
#
# Most similar words to 'متوسطة':
#   شديدة: 0.8209
#   خفيفة: 0.7661
#   مخيفة: 0.5812
#   للمنجرة: 0.5524
#   مخارج: 0.5386
#
# Most similar words to 'كامل':
#   مراقب: 0.5655
#   0599321685: 0.5560
#   092940178: 0.5550
#   انشاء: 0.5290
#   092399939: 0.5236
#
# Most similar words to 'اودلا':
#   أودلا: 0.8291
#   ببرود: 0.7025
#   اللونا: 0.6977
#   المالكي: 0.5946
#   وبالبوابات: 0.5903
#
# Most similar words to 'غير':
#   خاص: 0.8064
#   نهائيا: 0.7000
#   مؤكد: 0.6453
#   وايضا: 0.6405
#   عالاكيد: 0.6263
#
# Most similar words to 'ساحور':
#   العبيدية: 0.7755
#   قبر: 0.6314
#   حلوه: 0.6259
#   حلوة: 0.5971
#   كاحل: 0.5848
#
# Most similar words to 'قرية':
#   المنيا: 0.6374
#   فجار: 0.5921
#   قلقيلة: 0.5757
#   بربرة: 0.5633
#   فصائل: 0.5242
#
# Most similar words to 'العبيدية':
#   ساحور: 0.7755
#   لحم: 0.5965
#   منطقة: 0.5671
#   مزموريا: 0.5541
#   الكونتينر: 0.5448
#
# Most similar words to 'العقبي':
#   Fathi: 0.7198
#   Anas: 0.7186
#   عمر: 0.7155
#   لدية: 0.6805
#   faris: 0.6778
#
# Most similar words to 'الظاهرية':
#   وكريم: 0.7762
#   يطا: 0.7415
#   كرمه: 0.7155
#   شويكه: 0.7033
#   قلقس: 0.6870
#
# Most similar words to 'بمشو':
#   بمشي: 0.7020
#   منيح: 0.5944
#   وبمشو: 0.5756
#   ماشيه: 0.5641
#   ومابمشو: 0.5544
#
# Most similar words to 'الرجاء':
#   يقرأ: 0.8250
#   الجميع: 0.7001
#   التقرير: 0.6671
#   السائقين: 0.5821
#   ويضغطاو: 0.5630
#
# Most similar words to 'طالع':
#   نازل: 0.7680
#   خارج: 0.7609
#   رايح: 0.7601
#   جاي: 0.7110
#   ببالي: 0.6692
#
# Most similar words to 'كمان':
#   مسروق: 0.4852
#   والدخله: 0.4643
#   والارض: 0.4614
#   ونص: 0.4598
#   جنب: 0.4502
#
# Most similar words to 'الشمعة':
#   سلمونا: 0.7784
#   جورة: 0.7561
#   المنشية: 0.7330
#   ام: 0.6626
#   وجورة: 0.6512
#
# Most similar words to 'رمزونات':
#   إشارات: 0.6195
#   اشارات: 0.6188
#   فرات: 0.5761
#   رمزون: 0.5213
#   لرمزونات: 0.4940
#
# Most similar words to 'حسب':
#   وصلني: 0.8395
#   لغة: 0.6873
#   وصل: 0.6612
#   ادعائته: 0.6553
#   المعلنة: 0.6231
#
# Most similar words to 'عليها':
#   وعليها: 0.6192
#   فش: 0.5680
#   حاجزين: 0.5555
#   بوقفو: 0.5376
#   بحارس: 0.5228
#
# Most similar words to 'يسعد':
#   مساك: 0.6486
#   صباحك: 0.6359
#   واسعد: 0.6121
#   مساكم: 0.5980
#   اوقاتك: 0.5768
#
# Most similar words to 'منطقة':
#   ضواحي: 0.5851
#   العبيدية: 0.5671
#   تخيلو: 0.4662
#   متجهين: 0.4647
#   للم: 0.4640
#
# Most similar words to 'بقلب':
#   علينا: 0.9342
#   تبخلوا: 0.9189
#   تفاعلوا: 0.9171
#   فاحفظ: 0.9009
#   أفرغ: 0.8844
#
# Most similar words to 'ياسوف':
#   092518222: 0.6359
#   042501229: 0.6054
#   الديك: 0.5764
#   ديرستيا: 0.5381
#   وبديا: 0.5369
#
# Most similar words to 'جميع':
#   اصلح: 0.5809
#   ومخارج: 0.5807
#   ومداخل: 0.5676
#   لكل: 0.5415
#   بكل: 0.5346
#
# Most similar words to 'تبخلوا':
#   منكم: 0.9598
#   يستاهل: 0.9446
#   بستاهل: 0.9303
#   بقلب: 0.9189
#   علينا: 0.9101
#
# Most similar words to 'اقتحام':
#   تابع: 0.6308
#   لمتابعة: 0.6299
#   مستمر: 0.6261
#   اقتحاااام: 0.6126
#   للمنطقة: 0.5966
#
# Most similar words to 'اللدائن':
#   يختصر: 0.5773
#   بتحركشوا: 0.5531
#   ليد: 0.5314
#   الطفل: 0.5051
#   الدائن: 0.4663
#
# Most similar words to 'اللحظة':
#   الحظة: 0.7493
#   التصليح: 0.7203
#   اللحظه: 0.6836
#   الآن: 0.6758
#   انتهاء: 0.6507
#
# Most similar words to 'خير':
#   قلوبنا: 0.8121
#   اجمع: 0.7276
#   اللهم: 0.6758
#   الأسرى: 0.6411
#   تصبحون: 0.6359
#
# Most similar words to 'اذنا':
#   الليه: 0.8587
#   عوا: 0.7056
#   يطا: 0.6758
#   زيف: 0.6557
#   كرمه: 0.6539
#
# Most similar words to 'مدينة':
#   السيميا: 0.6025
#   السموع: 0.6010
#   بلقرب: 0.5618
#   العرقان: 0.5506
#   الرابط: 0.5323
#
# Most similar words to 'دقيق':
#   وتدقيق: 0.7191
#   تلفونات: 0.7183
#   جوالات: 0.7111
#   عشوائي: 0.6854
#   انتقائي: 0.6790
#
# Most similar words to 'ساعة':
#   ساعه: 0.8509
#   ربع: 0.7639
#   ساعتين: 0.7515
#   اقل: 0.6924
#   واكتر: 0.6917
#
# Most similar words to 'ازعيم':
#   ازعبم: 0.7547
#   زعيم: 0.6008
#   عناتا: 0.5779
#   حزما: 0.5361
#   للجنوب: 0.4975
#
# Most similar words to 'تمام':
#   الأمور: 0.6436
#   الميت: 0.5093
#   تماما: 0.4850
#   لغاية: 0.4817
#   ورايق: 0.4737
#
# Most similar words to 'شديدة':
#   متوسطة: 0.8209
#   مخيفة: 0.6133
#   خفيفة: 0.6057
#   رهيبة: 0.5975
#   وبداية: 0.5692
#
# Most similar words to 'متغير':
#   لحظة: 0.8093
#   واخرى: 0.7600
#   لحظات: 0.7323
#   صفحه: 0.6982
#   وضع: 0.6110
#
# Most similar words to 'الديك':
#   راعي: 0.6424
#   نعمه: 0.6302
#   علار: 0.6287
#   نعمة: 0.6187
#   عبوش: 0.6032
#
# Most similar words to 'حد':
#   بحكي: 0.7180
#   قصرت: 0.6958
#   اعجاب: 0.6546
#   الموضوع: 0.6354
#   للغرس: 0.6343
#
# Most similar words to 'تل':
#   الربيع: 0.8873
#   جناتا: 0.6694
#   بحوارة: 0.6160
#   وعطاره: 0.5979
#   تقوع: 0.5957
#
# Most similar words to 'صره':
#   صرة: 0.6801
#   صفرا: 0.6598
#   نمرا: 0.6298
#   صفراء: 0.5831
#   النمرا: 0.5418
#
# Most similar words to 'كرملو':
#   ك: 0.5716
#   عابود: 0.5409
#   رمزونات: 0.4315
#   سنجل: 0.4281
#   نظيف: 0.3836
#
# Most similar words to 'مشعل':
#   نظام: 0.8021
#   الخروبة: 0.7121
#   الجدار: 0.7017
#   عابود: 0.6285
#   نظامالخروبة: 0.6069
#
# Most similar words to 'وبمشي':
#   بمشي: 0.6359
#   وبمشو: 0.6254
#   متوسطه: 0.6060
#   وماشيه: 0.5900
#   خفيفه: 0.5715
#
# Most similar words to 'ام':
#   صفا: 0.7587
#   شقحان: 0.7571
#   سلمونا: 0.7535
#   الشقحان: 0.7494
#   الشيقل: 0.7163
#
# Most similar words to 'رنتيس':
#   شقبا: 0.8161
#   شبتين: 0.7192
#   المهلل: 0.6827
#   نيلي: 0.5764
#   نعلين: 0.5393
#
# Most similar words to 'الخط':
#   والسير: 0.5695
#   السير: 0.5685
#   وبخابف: 0.5313
#   مابخالف: 0.5291
#   موتي: 0.5283
#
# Most similar words to 'طلوع':
#   نزول: 0.6399
#   للمتجهين: 0.4682
#   روتانا: 0.4665
#   لمفرق: 0.4522
#   اندلاع: 0.4509
#
# Most similar words to 'العيزريه':
#   العيزرية: 0.6096
#   الكونتيىر: 0.5020
#   الحنوب: 0.4993
#   إيلون: 0.4694
#   المربعه: 0.4651
#
# Most similar words to 'كاحل':
#   حلحول: 0.6204
#   عنون: 0.5897
#   ساحور: 0.5848
#   عينون: 0.5662
#   عوزي: 0.5623
#
# Most similar words to 'اعمال':
#   أعمال: 0.7775
#   الاعمال: 0.6969
#   اشغال: 0.6730
#   شاحنة: 0.6535
#   حريق: 0.6508
#
# Most similar words to '90':
#   المعرجات: 0.6887
#   بيتللو: 0.6420
#   ٩٠: 0.6275
#   انتهو: 0.6185
#   مونيت: 0.6119
#
# Most similar words to 'لاقف':
#   حبلة: 0.7151
#   نعمه: 0.6694
#   عبوش: 0.6547
#   راعي: 0.6407
#   جمال: 0.6378
#
# Most similar words to 'مسكره':
#   الليه: 0.6786
#   عوا: 0.6440
#   اذنا: 0.6298
#   لمدينة: 0.5976
#   خرسا: 0.5741
#
# Most similar words to 'وسالكه':
#   تضل: 0.6615
#   بحارس: 0.6458
#   فاتحه: 0.5491
#   مستتفر: 0.5398
#   عبدا: 0.5162
#
# Most similar words to 'الغربية':
#   الشرقية: 0.7327
#   الخطوط: 0.7282
#   الغربيه: 0.6817
#   لمدينة: 0.6811
#   نيجهوت: 0.6586
#
# Most similar words to 'للطالع':
#   للخارج: 0.6818
#   الخارج: 0.6709
#   وللخارج: 0.6351
#   والخارج: 0.6099
#   الطالع: 0.5888
#
# Most similar words to 'للمتجه':
#   للجنوب: 0.7321
#   جنوبا: 0.7035
#   شمالا: 0.6736
#   لشمال: 0.6704
#   للمتجهين: 0.6639
#
# Most similar words to 'سالكات':
#   سالكه: 0.5974
#   مغلقه: 0.5097
#   والغربيه: 0.5090
#   سالكة: 0.5007
#   الاربعه: 0.4771
#
# Most similar words to 'جب':
#   تندر: 0.7476
#   دورية: 0.7450
#   جيب: 0.7395
#   جبين: 0.6929
#   حدود: 0.6688
#
# Most similar words to 'بيتا':
#   عينبوس: 0.6728
# ...
#   لأنو: 0.8692
#   زوجها: 0.8638
#   فاشل: 0.8551
#   تواجهكم: 0.8545
#   ابنها: 0.8510
#
# Most similar words to 'سماعها':
#   محفوظة: 0.8160
#   للمشرف: 0.8066
#   سلامى: 0.7806
#   جنيت: 0.7781
#   مكسر: 0.7711
#
# Most similar words to 'محفوظة':
#   وصولكم: 0.8768
#   العظام: 0.8741
#   الاساسي: 0.8734
#   هدفنا: 0.8733
#   وبسرقو: 0.8713
#
# Most similar words to 'تسجيلات':
#   الصوت: 0.9569
#   بالمنشور: 0.9464
#   ورجعوهم: 0.9220
#   وبستغلو: 0.9190
#   حكيتلك: 0.9153
#
# Most similar words to 'بالمنشور':
#   تسجيلات: 0.9464
#   وبجاوزو: 0.9190
#   ساوقتنا: 0.9190
#   امامكم: 0.9177
#   وبستغلو: 0.9092
#
# Most similar words to 'امامكم':
#   عمهلها: 0.9198
#   بالمنشور: 0.9177
#   بتحس: 0.9078
#   وبتعمي: 0.9053
#   مضت: 0.9028
#
# Most similar words to 'بتولدن':
#   ولد: 0.8078
#   خرقت: 0.6875
#   اكل: 0.6610
#   يتجنب: 0.6395
#   ولجيش: 0.5955
#
# Most similar words to 'يتجنب':
#   بفدر: 0.9686
#   مفق: 0.6755
#   وكارميلو: 0.6458
#   بتولدن: 0.6395
#   بنانا: 0.6137
#
# Most similar words to 'ابلش':
#   اسالتو: 0.8680
#   تنزلها: 0.8599
#   معاكم: 0.8594
#   شيقل: 0.8466
#   كبنت: 0.8420
#
# Most similar words to 'ضغطك':
#   اسالتو: 0.9704
#   وبرفع: 0.9642
#   نرفعها: 0.9287
#   تستعجلوا: 0.9122
#   وطرح: 0.9022
#
# Most similar words to 'تروحو':
#   تحاولو: 0.9861
#   تستثقل: 0.9138
#   تدركه: 0.9114
#   أبصارنا: 0.9100
#   يشغلك: 0.8998
#
# Most similar words to 'كفي':
#   اورجن: 0.8793
#   الض: 0.8149
#   بجوارك: 0.7972
#   بنزلوهم: 0.7965
#   بنات: 0.7950
#
# Most similar words to 'قوووووم':
#   نايمين: 0.9767
#   اتفضل: 0.9596
#   عبي: 0.9583
#   حكيتلك: 0.9576
#   ترتيبها: 0.9571
#
# Most similar words to 'نايمين':
#   قوووووم: 0.9767
#   حكيتلك: 0.9632
#   ستقوم: 0.9595
#   الوقود: 0.9594
#   اتفضل: 0.9577
#
# Most similar words to 'غدروكم':
#   والكازيات: 0.9891
#   وانتو: 0.9052
#   البنزين: 0.8791
#   محترمين: 0.8650
#   نايمين: 0.8645
#
# Most similar words to 'والكازيات':
#   غدروكم: 0.9891
#   وانتو: 0.8827
#   البنزين: 0.8782
#   محترمين: 0.8741
#   isarPalestine: 0.8733
#
# Most similar words to 'واشدد':
#   ضعفنا: 0.8504
#   وارحم: 0.8466
#   ازرنا: 0.8385
#   المسلمين: 0.8324
#   امواتنا: 0.8222
#
# Most similar words to 'المليون':
#   للمره: 0.9692
#   الفترة: 0.8944
#   عملها: 0.8891
#   القادمة: 0.8804
#   التالفة: 0.8324
#
# Most similar words to 'للمره':
#   المليون: 0.9692
#   الفترة: 0.8292
#   عملها: 0.8169
#   القادمة: 0.8120
#   ليوم: 0.8110
#
# Most similar words to 'النقطة':
#   عيلى: 0.5215
#   محاصر: 0.4935
#   واجه: 0.4800
#   وانسحبوا: 0.4400
#   احتمال: 0.4351
#
# Most similar words to 'اورجن':
#   كفي: 0.8793
#   تحديدا: 0.8736
#   ازنة: 0.5973
#   بوسعو: 0.5941
#   مزاجية: 0.5804
#
# Most similar words to 'وسولار':
#   قووووم: 0.9797
#   بسيدر: 0.9361
#   كين: 0.9348
#   عبي: 0.9195
#   مافيا: 0.9140
#
# Most similar words to 'تحديدا':
#   اورجن: 0.8736
#   كفي: 0.5917
#   زواتا: 0.5260
#   بسواتر: 0.4626
#   القبلية: 0.4385
#
# Most similar words to 'بدخله':
#   وشرطي: 0.6801
#   مستتفر: 0.5485
#   سبسطه: 0.5007
#   منفوق: 0.4649
#   بوابك: 0.4619
#
# Most similar words to 'واخذ':
#   التمهل: 0.9592
#   التزحلق: 0.9008
#   اللازم: 0.8513
#   أخذ: 0.8273
#   الخذر: 0.8165
#
# Most similar words to 'التمهل':
#   واخذ: 0.9592
#   التزحلق: 0.8194
#   ماطر: 0.8172
#   وعن: 0.8044
#   مداخلها: 0.8033
#
# Most similar words to 'ماطر':
#   خضرا: 0.9055
#   والخلفية: 0.8823
#   والغاز: 0.8755
#   الأمامية: 0.8673
#   منخفض: 0.8672
#
# Most similar words to 'منخفض':
#   المؤسسات: 0.8737
#   المتواصلة: 0.8723
#   ماطر: 0.8672
#   ملحنه: 0.8638
#   النقد: 0.8607
#
# Most similar words to 'قدس':
#   بوابةجبارة: 0.7024
#   زعتررة: 0.5778
#   ٣٤: 0.5521
#   وتحر: 0.5452
#   ورايح: 0.5317
#
# Most similar words to 'ومسح':
#   وقش: 0.9720
#   تنظيف: 0.9526
#   ذنيك: 0.9337
#   بشلعوا: 0.9320
#   ومازال: 0.9039
#
# Most similar words to 'عبي':
#   قوووووم: 0.9583
#   مستحقاتها: 0.9567
#   نايمين: 0.9552
#   حكيتلك: 0.9536
#   بتسديد: 0.9523
#
# Most similar words to 'قووووم':
#   وسولار: 0.9797
#   بسيدر: 0.9652
#   اعجقلي: 0.9626
#   كين: 0.9564
#   مافيا: 0.9533
#
# Most similar words to 'وبرفع':
#   ضغطك: 0.9642
#   نرفعها: 0.9363
#   سيدي: 0.9359
#   اسالتو: 0.9331
#   نابلسيه: 0.9162
#
# Most similar words to 'حلحلول':
#   سكرها: 0.9137
#   وميسره: 0.8979
#   لوحات: 0.8923
#   احسنت: 0.8915
#   بهمش: 0.8913
#
# Most similar words to 'المغسلة':
#   ضربو: 0.6336
#   عدة: 0.6317
#   أماكن: 0.6031
#   الجنازة: 0.5968
#   تخالف: 0.5896
#
# Most similar words to 'قللنديا':
#   قاتلة: 0.8702
#   للنابلس: 0.8678
#   وصايد: 0.8572
#   الطالعين: 0.8511
#   إعمال: 0.8403
#
# Most similar words to 'انام':
#   حولت: 0.8941
#   شياب: 0.8731
#   وشكلنا: 0.8425
#   ناقصكم: 0.8412
#   بتشترو: 0.8405
#
# Most similar words to 'حولت':
#   شياب: 0.9570
#   انام: 0.8941
#   مكانو: 0.8028
#   والا: 0.7575
#   للعالق: 0.7508
#
# Most similar words to 'شياب':
#   حولت: 0.9570
#   انام: 0.8731
#   مكانو: 0.7518
#   والا: 0.7197
#   الماشيين: 0.6902
#
# Most similar words to '٣٢':
#   ٣٧: 0.6858
#   اضعاف: 0.6543
#   محجوزين: 0.6502
#   وبتسكر: 0.6380
#   جيبات: 0.6330
#
# Most similar words to 'بوابةجبارة':
#   قدس: 0.7024
#   الثامنة: 0.5646
#   و٢٦د: 0.5521
#   زاقفة: 0.5440
#   الكونيتنر: 0.5168
#
# Most similar words to 'بتأمل':
#   و٣٢د: 0.8335
#   ١: 0.7034
#   مستمرة: 0.6983
#   بسكر: 0.6715
#   ٤: 0.6692
#
# Most similar words to 'التبسم':
#   دائم: 0.9614
#   الضحك: 0.9152
#   _عليـﷺـه_وسلموا: 0.8785
#   عظيما: 0.8735
#   وقائدنا: 0.8641
#
# Most similar words to 'اعجقلي':
#   مافيا: 0.9722
#   بسيدر: 0.9673
#   قووووم: 0.9626
#   كين: 0.9463
#   لعطارة: 0.9163
#
# Most similar words to 'دائم':
#   الضحك: 0.9697
#   التبسم: 0.9614
#   الذكر: 0.9337
#   حميد: 0.8552
#   وقائدنا: 0.8500
#
# Most similar words to 'الضحك':
#   دائم: 0.9697
#   الذكر: 0.9601
#   التبسم: 0.9152
#   الصمت: 0.8445
#   والغربة: 0.8227
#
# Most similar words to 'الذكر':
#   الضحك: 0.9601
#   الصمت: 0.9363
#   دائم: 0.9337
#   التبسم: 0.8570
#   حميد: 0.7828
#
# Most similar words to 'الصمت':
#   الذكر: 0.9363
#   الضحك: 0.8445
#   دائم: 0.8121
#   أيام: 0.7239
#   مهو: 0.7239
#
# Most similar words to 'اليوميه':
#   سالكبالاتجاهين: 0.9145
#   فااااضي: 0.9090
#   سلاك: 0.8928
#   للجامع: 0.8856
#   شرفبالاتجاهين: 0.8777
#
# Most similar words to '٢٧٠':
#   بدلو: 0.7695
#   أمورها: 0.7503
#   مزاجية: 0.7382
#   صارو: 0.7292
#   ازنة: 0.7237
#
# Most similar words to 'اشاران':
#   وكفل: 0.6131
#   اشارتين: 0.5973
#   إشارات: 0.5598
#   وديراستيا: 0.5519
#   اللن: 0.5240
#
# Most similar words to 'بضب':
#   العده: 0.9038
#   أبعدنا: 0.8412
#   طرونا: 0.7069
#   وانسحبوا: 0.7009
#   بتسلا: 0.6821
#
# Most similar words to 'الاطاله':
#   اعليه: 0.8760
#   اتاخر: 0.8177
#   ضروروي: 0.7734
#   صدقا: 0.7662
#   يشوفوا: 0.7598
#
# Most similar words to 'التعب':
#   صدقا: 0.9113
#   بعطيه: 0.8765
#   لناس: 0.8341
#   الارباك: 0.8134
#   جزر: 0.8103
#
# Most similar words to 'بعطيه':
#   ليوصلك: 0.9443
#   التعب: 0.8765
#   خلاط: 0.7617
#   المعلومه: 0.7555
#   صدقا: 0.7320
#
# Most similar words to 'بالرد':
#   الاستفسارات: 0.8722
#   ونورا: 0.8629
#   وتيسيرا: 0.8451
#   ربوع: 0.8409
#   اختيار: 0.8369
#
# Most similar words to 'الحد':
#   17112024: 0.9780
#   2692024: 0.9361
#   2592024: 0.9356
#   6102024: 0.9340
#   26102024: 0.9324
#
# Most similar words to 'تتم':
#   قراءة: 0.8705
#   الحقيقية: 0.8275
#   واتمنى: 0.8252
#   الكلمات: 0.8237
#   الخساره: 0.8230
#
# Most similar words to 'واتمنى':
#   بسببنا: 0.8935
#   تتم: 0.8252
#   تمشط: 0.7916
#   امكن: 0.7808
#   شعرها: 0.7580
#
# Most similar words to 'بسببنا':
#   واتمنى: 0.8935
#   جروبات: 0.6606
#   المحادثة: 0.6446
#   سياسة: 0.6087
#   ان: 0.5953
#
# Most similar words to 'المحادثة':
#   نستطيع: 0.9044
#   الاقتحمات: 0.6539
#   بسببنا: 0.6446
#   الحديث: 0.5961
#   سياسة: 0.5940
#
# Most similar words to 'نستطيع':
#   المحادثة: 0.9044
#   وابلغونا: 0.7351
#   الحديث: 0.7067
#   بالارتباط: 0.6991
#   ختام: 0.6957
#
# Most similar words to 'ختام':
#   الاستفسارات: 0.9398
#   تفاصيل: 0.8138
#   مراسلة: 0.8121
#   ومتابعته: 0.8064
#   الدعم: 0.7922
#
# Most similar words to 'الاستفسارات':
#   ختام: 0.9398
#   ومتابعته: 0.8767
#   بالرد: 0.8722
#   ونورا: 0.8535
#   ساكنة: 0.8430
#
# Most similar words to 'نود':
#   ينضم: 0.9082
#   لفت: 0.8344
#   0569470241: 0.8161
#   لذلك: 0.8047
#   بالحسبان: 0.7799
#
# Most similar words to '58':
#   السابق: 0.8425
#   المسبحة: 0.8399
#   البرنامج: 0.8345
#   الحد: 0.8323
#   17112024: 0.8289
#
# Most similar words to 'عبيد':
#   ولسنا: 0.9714
#   لديك: 0.8959
#   العبرية: 0.7694
#   شك: 0.7504
#   اب: 0.7452
#
# Most similar words to 'ولسنا':
#   عبيد: 0.9714
#   لديك: 0.9558
#   يشغلك: 0.8316
#   شك: 0.8258
#   العبرية: 0.8188
#
# Most similar words to 'لديك':
#   ولسنا: 0.9558
#   يشغلك: 0.9064
#   عبيد: 0.8959
#   أبصارنا: 0.8896
#   تنس: 0.8863
#
# Most similar words to 'انساني':
#   منطلق: 0.9594
#   كمشرفين: 0.8466
#   نحن: 0.8210
#   وتكرار: 0.7984
#   نصبر: 0.7951
#
# Most similar words to 'منطلق':
#   انساني: 0.9594
#   الوحيدين: 0.8354
#   مرفوض: 0.8302
#   وهذا: 0.8227
#   أخبركم: 0.8214
#
# Most similar words to 'جريمة':
#   لدقائق: 0.9478
#   وإنساني: 0.9147
#   نركض: 0.9142
#   لدنيا: 0.9124
#   بلامعنى: 0.9122
#
# Most similar words to 'لدقائق':
#   جريمة: 0.9478
#   مثقل: 0.9138
#   وإنساني: 0.9133
#   وأخلاقي: 0.9109
#   بلامعنى: 0.9079
#
# Most similar words to 'تاخر':
#   لديها: 0.8256
#   برد: 0.8129
#   لسنا: 0.7693
#   الوحيدين: 0.7465
#   لدقائق: 0.7356
#
# Most similar words to '17112024':
#   الحد: 0.9780
#   2692024: 0.9297
#   االسبت: 0.9295
#   السابق: 0.9264
#   2592024: 0.9254
#
# Most similar words to '51':
#   حمرة: 0.7105
#   47: 0.6813
#   احكو: 0.6606
#   ارتياح: 0.6380
#   البريك: 0.6295
#
# Most similar words to 'ليوصلك':
#   بعطيه: 0.9443
#   المعلومه: 0.8175
#   يستحق: 0.7930
#   التعب: 0.7378
#   منذر: 0.7159
#
# Most similar words to 'ازنة':
#   مزاجية: 0.9412
#   وازمتها: 0.9129
#   ماشبة: 0.8903
#   صحراء: 0.8792
#   وفارغ: 0.8653
#
# Most similar words to 'تحاولو':
#   تروحو: 0.9861
#   تدركه: 0.9145
#   أبصارنا: 0.9105
#   فوضى: 0.9083
#   تستثقل: 0.9057
#
# Most similar words to 'سلكي':
#   بالسلامه: 0.6273
#   والسلامه: 0.5971
#   تحياتي: 0.5666
#   سفره: 0.5626
#   زعتر: 0.5487
#
# Most similar words to 'بتعملو':
#   انسميهم: 0.6899
#   دندره: 0.6653
#   فهموني: 0.6642
#   بسياراتها: 0.6322
#   وعورتا: 0.6248
#
# Most similar words to 'اشجار':
#   حج: 0.8766
#   والمزارع: 0.8683
#   الزيتون: 0.8578
#   مطور: 0.8526
#   بنجيبلكم: 0.8436
#
# Most similar words to 'ابلغك':
#   حبيت: 0.9335
#   للاحتياط: 0.8632
#   للمستو: 0.8022
#   اشجار: 0.7698
#   طنين: 0.7624
#
# Most similar words to 'حبيت':
#   للاحتياط: 0.9731
#   ابلغك: 0.9335
#   طنين: 0.8459
#   للمستو: 0.8447
#   الأحتلال: 0.8186
#
# Most similar words to 'للاحتياط':
#   حبيت: 0.9731
#   طنين: 0.8779
#   للمستو: 0.8765
#   ابلغك: 0.8632
#   الأحتلال: 0.8459
#
# Most similar words to 'الشرف':
#   واقفلكم: 0.7657
#   طرونا: 0.7505
#   بجهز: 0.7438
#   بتسلا: 0.7419
#   مصعبينها: 0.7373
#
# Most similar words to 'ببعض':
#   دقوا: 0.9863
#   ايوة: 0.9814
#   بالغبره: 0.9204
#   مهوه: 0.9189
#   وبعموهم: 0.9133
#
# Most similar words to 'للمنتجين':
#   لتل: 0.9696
#   _لأجلكم: 0.9041
#   يافه: 0.8771
#   السكة: 0.8757
#   ولحضر: 0.8737
#
# Most similar words to 'دقوا':
#   ببعض: 0.9863
#   ايوة: 0.9859
#   ستقوم: 0.9287
#   ٢٠٠٠: 0.9287
#   وبعموهم: 0.9237
#
# Most similar words to 'ايوة':
#   دقوا: 0.9859
#   ببعض: 0.9814
#   ٢٠٠٠: 0.9343
#   حصريا: 0.9202
#   اغضبني: 0.9202
#
# Most similar words to 'وبتروح':
#   بشفت: 0.7508
#   العرباي: 0.7437
#   اموه: 0.7429
#   بإمكاني: 0.7425
#   الهريبه: 0.7391
#
# Most similar words to 'لنشاش':
#   الصـلاة: 0.7818
#   الكرة: 0.7687
#   وقفنا: 0.7674
#   مالفينا: 0.7575
#   لحما: 0.7558
#
# Most similar words to '١٥٦٥٧':
#   وبعتدو: 0.6225
#   سكلت: 0.6087
#   الحياة: 0.6024
#   الراجعه: 0.5998
#   كتانه: 0.5977
#
# Most similar words to 'ونشهد':
#   رضيت: 0.8340
#   عبدك: 0.8031
#   امكن: 0.7731
#   ويصورلنا: 0.7479
#   الخساره: 0.7338
#
# Most similar words to 'نشهد':
#   محسوب: 0.8916
#   بعنبتا: 0.8916
#   وياك: 0.8790
#   مسكرو: 0.8603
#   بزفه: 0.8508
#
# Most similar words to 'لتل':
#   للمنتجين: 0.9696
#   _لأجلكم: 0.8897
#   ولحضر: 0.8693
#   الرامه: 0.8693
#   يافه: 0.8660
#
# Most similar words to 'لديها':
#   شعرها: 0.9451
#   تمشط: 0.8493
#   تاخر: 0.8256
#   اضراب: 0.7998
#   لهيئة: 0.7959
#
# Most similar words to 'شعرها':
#   تمشط: 0.9543
#   لديها: 0.9451
#   اضراب: 0.8714
#   لهيئة: 0.8671
#   مجندة: 0.8587
#
# Most similar words to 'تمشط':
#   شعرها: 0.9543
#   مجندة: 0.9050
#   الذكرى: 0.8949
#   بمجرد: 0.8924
#   الخساره: 0.8888
#
# Most similar words to 'يصدر':
#   تصرفات: 0.8581
#   تحكو: 0.8293
#   وينها: 0.8236
#   ياخد: 0.8233
#   وشر: 0.8118
#
# Most similar words to 'يظن':
#   الاشخاص: 0.9602
#   ويجب: 0.8732
#   بطريقة: 0.8355
#   اهلو: 0.8000
#   الخساره: 0.7996
#
# Most similar words to 'الاشخاص':
#   يظن: 0.9602
#   ويجب: 0.8289
#   بطريقة: 0.8213
#   العينة: 0.8102
#   لتامين: 0.8099
#
# Most similar words to 'بحظر':
#   العينة: 0.9274
#   فاشل: 0.9009
#   حبيبهم: 0.8971
#   المقاطعة: 0.8968
#   وهذا: 0.8965
#
# Most similar words to 'وتكرار':
#   بحدوث: 0.9808
#   فوضى: 0.9542
#   بتوفيقك: 0.9517
#   وتيسيرك: 0.9466
#   تقلقك: 0.9410
#
# Most similar words to 'بحدوث':
#   وتكرار: 0.9808
#   فوضى: 0.9695
#   وتيسيرك: 0.9678
#   نسمح: 0.9677
#   بتوفيقك: 0.9662
#
# Most similar words to 'نسمح':
#   بحدوث: 0.9677
#   تدركه: 0.9559
#   وتيسيرك: 0.9508
#   بتوفيقك: 0.9471
#   فوضى: 0.9468
#
# Most similar words to 'تسيء':
#   تصرفات: 0.9717
#   سؤالو: 0.8721
#   أجلو: 0.8661
#   تعلمون: 0.8609
#   معلش: 0.8486
#
# Most similar words to 'تصرفات':
#   تسيء: 0.9717
#   يصدر: 0.8581
#   أجلو: 0.8364
#   اكتسبت: 0.8322
#   سؤالو: 0.8237
#
# Most similar words to 'عددها':
#   لفئة: 0.9471
#   قسوة: 0.9165
#   موجه: 0.9133
#   أخبركم: 0.8734
#   الوحيدين: 0.8650
#
# Most similar words to 'بمجرد':
#   لساعات: 0.9041
#   تمشط: 0.8924
#   حلوها: 0.8674
#   مجندة: 0.8672
#   الذكرى: 0.8669
#
# Most similar words to 'لفئة':
#   موجه: 0.9765
#   عددها: 0.9471
#   وخشعت: 0.8999
#   قسوة: 0.8787
#   الغرفة: 0.8398
#
# Most similar words to 'موجه':
#   لفئة: 0.9765
#   وخشعت: 0.9149
#   عددها: 0.9133
#   التالفة: 0.8802
#   الأدب: 0.8704
#
# Most similar words to 'محترم':
#   واحترامنا: 0.8785
#   وايضا: 0.6794
#   ولقبه: 0.6214
#   5109: 0.6043
#   قناة: 0.5937
#
# Most similar words to 'واحترامنا':
#   ولقبه: 0.8850
#   محترم: 0.8785
#   شخص: 0.7107
#   ومجاهدينـا: 0.6930
#   الرد: 0.6930
#
# Most similar words to 'ولقبه':
#   واحترامنا: 0.8850
#   فرد: 0.8466
#   لتامين: 0.8383
#   الاهالي: 0.8378
#   اطفالنا: 0.8322
#
# Most similar words to 'فرد':
#   وفضله: 0.8530
#   وقدرته: 0.8484
#   ولقبه: 0.8466
#   الفردوس: 0.8431
#   غزهہ: 0.8373
#
# Most similar words to 'تعامل':
#   بخير: 0.6661
#   دمتم: 0.6416
#   يستحق: 0.6120
#   بن: 0.5809
#   النفايات: 0.5776
#
# Most similar words to 'يستحق':
#   وتكرار: 0.8664
#   مقاومتنا: 0.8638
#   رجل: 0.8612
#   بحدوث: 0.8570
#   نسمح: 0.8561
#
# Most similar words to 'لدية':
#   بتحديث: 0.8045
#   يظن: 0.7907
#   moataz: 0.7838
#   ويجب: 0.7790
#   بطريقة: 0.7684
#
# Most similar words to 'ويجب':
#   الامر: 0.9473
#   بطريقة: 0.9213
#   يظن: 0.8732
#   اهلو: 0.8441
#   تنفع: 0.8371
#
# Most similar words to 'حاضر':
#   الذكرى: 0.9251
#   تنفع: 0.9162
#   حلوها: 0.9159
#   مكمل: 0.9116
#   المؤمنين: 0.9092
#
# Most similar words to 'فاشل':
#   وهذا: 0.9896
#   مرفوض: 0.9615
#   وتوخذ: 0.9425
#   التكذيب: 0.9415
#   اسمعوا: 0.9385
#
# Most similar words to 'لساعات':
#   بمجرد: 0.9041
#   فمه: 0.8144
#   المنشور: 0.7839
#   تكبيركم: 0.7813
#   وأعمارهم: 0.7742
#
# Most similar words to 'فمه':
#   يحرك: 0.8464
#   لساعات: 0.8144
#   بمجرد: 0.6955
#   ترضى: 0.6838
#   نلقاك: 0.6577
#
# Most similar words to 'يحرك':
#   فمه: 0.8464
#   ينتظر: 0.7831
#   اللحظه: 0.5222
#   فوته: 0.5120
#   حاكيين: 0.4960
#
# Most similar words to 'تحديثه':
#   ريموتمن: 0.8347
#   العبريه: 0.8311
#   تاكيد: 0.8306
#   كلامنا: 0.8230
#   فقدان: 0.8209
#
# Most similar words to 'سريعا':
#   حاضر: 0.8804
#   لدقائق: 0.8667
#   مثقل: 0.8497
#   واجهه: 0.8470
#   فاشل: 0.8392
#
# Most similar words to 'ابسط':
#   بمخالفة: 0.8212
#   تزحلق: 0.6967
#   التسبب: 0.6959
#   خود: 0.6641
#   ينقل: 0.6538
#
# Most similar words to 'بمخالفة':
#   التسبب: 0.9374
#   لعدم: 0.8686
#   ابسط: 0.8212
#   وأظهر: 0.7565
#   بالأوبة: 0.7475
#
# Most similar words to 'التسبب':
#   بمخالفة: 0.9374
#   لعدم: 0.8880
#   ابسط: 0.6959
#   مراسلته: 0.6292
#   وأظهر: 0.6154
#
# Most similar words to 'لعدم':
#   التسبب: 0.8880
#   بمخالفة: 0.8686
#   مراسلته: 0.8588
#   لنفس: 0.7612
#   عبر: 0.7568
#
# Most similar words to 'مراسلته':
#   لعدم: 0.8588
#   لنفس: 0.8385
#   عبر: 0.8240
#   اخواني: 0.8037
#   ارسال: 0.7894
#
# Most similar words to 'بتحديث':
#   لدية: 0.8045
#   moataz: 0.7457
#   hattab: 0.7372
#   عمر: 0.7270
#   منذر: 0.6663
#
# Most similar words to 'ويعطيك':
#   منقول: 0.7694
#   التحديث: 0.7235
#   حاقد: 0.7115
#   المسرب: 0.7061
#   اندخلها: 0.7014
#
# Most similar words to 'وايضا':
#   الصحيح: 0.8138
#   المشرفين: 0.8008
#   محترم: 0.6794
#   اخواني: 0.6788
#   الرد: 0.6757
#
# Most similar words to 'لتامين':
#   الأحياء: 0.9129
#   بقية: 0.9093
#   وفضله: 0.8993
#   تلطف: 0.8979
#   الاهالي: 0.8960
#
# Most similar words to 'نتاخر':
#   تنتهي: 0.8934
#   وتغلق: 0.8890
#   أخاف: 0.8479
#   دنياه: 0.8471
#   لتامين: 0.8464
#
# Most similar words to 'مرفوض':
#   وهذا: 0.9739
#   فاشل: 0.9615
#   الوقود: 0.9214
#   المقاطعة: 0.9173
#   لدنيا: 0.9168
#
# Most similar words to 'وهذا':
#   فاشل: 0.9896
#   مرفوض: 0.9739
#   وتوخذ: 0.9411
#   المقاطعة: 0.9287
#   الوقود: 0.9280
#
# Most similar words to 'مفتاحها':
#   مضروبة: 0.8507
#   سرطة: 0.8465
#   وبصعوبة: 0.8375
#   لونها: 0.8288
#   جولف: 0.8147

# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import arabic_reshaper
from bidi.algorithm import get_display

# Step 1: Extract Word Vectors and Words
words = list(model.wv.key_to_index)  # Vocabulary words
word_vectors = np.array([model.wv[word] for word in words])  # Corresponding vectors

# Step 2: Apply PCA for Dimensionality Reduction to 2D
pca = PCA(n_components=2)  # Reduce to 2 dimensions for visualization
word_vectors_2d = pca.fit_transform(word_vectors)

# Step 3: Select the First 50 Words and Corresponding Vectors
first_50_words = words[:100]
first_50_vectors_2d = word_vectors_2d[:100]
reshaped_words = [get_display(arabic_reshaper.reshape(word)) for word in first_50_words]

# Step 4: Plot the First 50 Words in 2D Space
plt.figure(figsize=(12, 8))
for i, (x, y) in enumerate(first_50_vectors_2d):
    plt.scatter(x, y, color="blue")
    plt.text(x + 0.02, y + 0.02, reshaped_words[i], fontsize=12, color="black", alpha=0.7)

plt.title("PCA Visualization of First 50 Word2Vec Embeddings (Arabic)", fontsize=14)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.grid(alpha=0.3)

# Save the figure to a file
plt.savefig("/teamspace/studios/this_studio/ROADWATCH/Road/w2v_visualize/W2V_lastV/pca_word2vec_visualization_v1.0.1.png", dpi=300, bbox_inches="tight", format="png")

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_6921/1744558669.py:32: UserWarning: Glyph 65010 (\N{ARABIC LIGATURE ALLAH ISOLATED FORM}) missing from font(s) DejaVu Sans.
#   plt.savefig("/teamspace/studios/this_studio/ROADWATCH/Road/w2v_visualize/W2V_lastV/pca_word2vec_visualization_v1.0.1.png", dpi=300, bbox_inches="tight", format="png")
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 65010 (\N{ARABIC LIGATURE ALLAH ISOLATED FORM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
len(sentences)
# Out:
# 32899

# %%
X
# Out:
# array([[-3.096457  ,  2.6506023 , -7.2182713 , ...,  3.9028823 ,
#          1.1087964 , -1.8061281 ],
#        [-0.13741384, -0.31172496,  0.29706535, ..., -0.2006345 ,
#         -0.50586236,  0.15537266],
#        [-1.0471536 , -3.5681934 , -0.33753708, ...,  1.2199253 ,
#          0.7748119 , -1.5156361 ],
#        ...,
#        [-2.297851  ,  0.31078357,  1.2708827 , ...,  1.4971316 ,
#          0.52573067,  2.8821108 ],
#        [-1.3501627 , -1.3380594 ,  0.1729493 , ...,  3.270846  ,
#          1.591497  ,  2.539275  ],
#        [-1.7666111 ,  2.466106  , -1.7754463 , ...,  2.0488896 ,
#          0.69864565, -1.1911345 ]], dtype=float32)

# %%
print(tokenized_df.columns)
# Out:
# Index(['Similarity Score', 'Word Index', 'label_encoded', 'label', 'Word',
#        'Length Word', 'Original Message', 'Sentence'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming your 'label' column exists
label_encoder = LabelEncoder()
tokenized_df['label_encoded'] = label_encoder.fit_transform(tokenized_df['label'])

# %%
labels = tokenized_df["label_encoded"]

# %%
sentences
# Out:
# [['شرطه', 'نازله', 'من', 'عيلي'],
#  ['قلنديا', 'لا', 'الداخل', 'سالك', 'الخارج', 'ازمه'],
#  ['من', 'كف', '٣٥', 'لراس', 'الجورة', 'سالك'],
#  ['مشوا', 'السيارات', 'ع', 'اشارات', 'بيت', 'ايل'],
#  ['ديرشرف', 'سالك', 'بالاتجاهين', 'حاليا'],
#  ['المربعه', 'خبط', 'قنابل', 'صوت', 'وغاز', 'خنقوا', 'الناس'],
#  ['بوابة', 'عزون', 'تحت', 'الجسر'],
#  ['عورتا', 'ازمه', 'للداخل', 'على', 'نابلس'],
#  ['انتبهوا', 'حاجز', 'عورتا', 'حجز', 'سيارات', 'اثناء', 'التجاوز'],
#  ['اللي', 'بتجاوز', 'ع', 'عورتا', 'بوخدو', 'سيارته'],
#  ['الكونتينر', 'سالك', 'حاليا', 'بالاتجاهين'],
#  ['فتح', 'البوابة', 'تحت', 'جسر', 'عزون', 'حاليا'],
#  ['جبارة', 'سالك', 'حاليا'],
#  ['سلفيت', 'حاجز', 'شرطة', 'وتفتيش', 'سيارة', 'سيارة', 'بالاتجاهين'],
#  ['زيف', 'مغلقة', 'خلة', 'المي', 'سالكة'],
#  ['اريحا',
#   'حاجز',
#   'الهيئة',
#   'سالك',
#   'حاجز',
#   'البنانا',
#   'فتح',
#   'مع',
#   'تواجد',
#   'الجيش',
#   'المدخل',
#   'الجنوبي',
#   'لمدينة',
#   'أريحا',
#   'سالك',
#   'البوابة',
#   'الصفراء',
#   'سالك'],
#  ['الي',
#   'جاي',
#   'من',
#   'جهة',
#   'جنين',
#   'او',
#   'نابلس',
#   'الى',
#   'مدخل',
#   'بزاريا',
#   'الطريق',
#   'كمان',
#   'بتكون',
#   'عايدكم',
#   'اليمين',
#   'عند',
#   'كوم',
#   'التراب',
#   'القديم',
#   'بتطلعوها',
#   'وبتنزلو',
#   'بعد',
#   'كوم',
#   'الرمل'],
#  ['وفيه',
#   'اقاويل',
#   'مش',
#   'ب',
#   '300',
#   'متر',
#   'في',
#   '50',
#   'متر',
#   'شوفو',
#   'المناسب'],
#  ['مدخل', 'حجة', 'حاجز', 'وتفتيش', 'مدخل', 'النبي', 'الياس', 'حاجز', 'وازمة'],
#  ['بالنسبة',
#   'للطريق',
#   'الترابي',
#   'الغرس',
#   'بديل',
#   'بزاريا',
#   'في',
#   'قبلو',
#   'ب٣٠٠',
#   'متر',
#   'طلعة',
#   'طبعا',
#   'طريق',
#   'مزفتة',
#   'وممتازة',
#   'بتجيبكم',
#   'بعد',
#   'كوم',
#   'التراب',
#   'واسهل',
#   'واحسن',
#   'من',
#   'طريق',
#   'الغرس',
#   'الكل',
#   'مفكر',
#   'انو',
#   'مسكرة',
#   'بس',
#   'الطريق',
#   'مفتوحة',
#   'بالسلامة',
#   'للجميع'],
#  ['ملاحظة', 'بخصوص', 'المربعة', 'مزعج', 'خاصة', 'للصبايا', 'حاليا', 'للخارج'],
#  ['تفتيش', 'دقيق', 'ونبش', 'مرمطه', 'الله', 'يهونها'],
#  ['دير', 'شرف', 'الان'],
#  ['وضع', 'المربعة'],
#  ['شافي', 'شمرون', 'سالك', 'بدون', 'تواجد', 'الجيش'],
#  ['الفحص', 'فتحت', 'هلا'],
#  ['صرة', 'حاليا', 'حوالي', '١٠', 'سيارات', 'عليه'],
#  ['أزمة', 'دير', 'شرف'],
#  ['عورتا', 'أزمة', 'بالاتجاهين'],
#  ['طريق', 'الغرس', 'بزاريا'],
#  ['سدة', 'قراوة', 'سالكة', 'بس', 'عليها', 'جب', 'جيش', 'حاليا'],
#  ['حاجز', 'الهيئة', 'اريحا', 'سالك', 'حاليا', 'بالاتجاهين'],
#  ['طريق', 'المساكن', 'عصيرة', 'لا', 'ينصح', 'بالمرور', 'منها'],
#  ['ال', '17', 'سالك', 'حاليا'],
#  ['المربعة', 'حاليا', 'الجيش', 'اتهجم', 'على', 'الناس', 'والسيارات'],
#  ['عورتاا', 'ازمة', 'للخارج', 'لشارع', 'روجيب'],
#  ['عطارة', 'البلد', 'سالك'],
#  ['فرش', 'الهوى', 'سالكة'],
#  ['الكونتينر',
#   'سالك',
#   'اتجاهين',
#   'عش',
#   'غراب',
#   'سالك',
#   'اتجاهين',
#   'العيزرية',
#   'ازمة',
#   'اتجاه',
#   'الجنوب',
#   'باتجاه',
#   'الشمال',
#   'سالك'],
#  ['جميع', 'مخارج', 'نابلس', 'ازمة', 'خانقة'],
#  ['دوار', 'كدميمم', 'جيش', 'وشرطه'],
#  ['قلنديا', 'داخل', 'وخارج', 'ازمة'],
#  ['عش', 'غراب', 'لازال', 'فاتح', 'وسالك'],
#  ['صرة',
#   'عليها',
#   'اربع',
#   'سيارات',
#   'طبعا',
#   'للشاحنات',
#   'ونمرا',
#   'صفراء',
#   'فقط'],
#  ['الفندق', 'للخارج', 'ازمه', 'وحاجز', 'تفتيش'],
#  ['طريق', 'زعيم', 'ازمه', 'ماشيه'],
#  ['الجيب',
#   'هلأ',
#   'وقف',
#   'قدام',
#   'السيارات',
#   'الي',
#   'طالعه',
#   'من',
#   'نابلس',
#   'ع',
#   'دير',
#   'شرف'],
#  ['راس',
#   'الجورة',
#   'سالك',
#   'بوابة',
#   'بني',
#   'نعيم',
#   'سالكة',
#   'مع',
#   'تواجد',
#   'للجيش',
#   'دورا',
#   'مغلقة'],
#  ['زيف', 'يطا'],
#  ['واد', 'الحرامية', 'ازمة', 'ماشية'],
#  ['سلفيت', 'ارئيل', 'حاجز', 'شرطه', 'وجيش'],
#  ['وهي', 'دي', 'شرف', 'لا', 'الداخل'],
#  ['دير', 'شرف'],
#  ['العيزاريه', 'سالكه', 'عشمال', 'ازمه', 'خفيفه', 'عجنوب'],
#  ['الغرس', 'بزاريا', 'سالكة', 'واغلبها', 'مزفتة', 'ومرتبة'],
#  ['اكم',
#   'قلب',
#   'يستاهل',
#   'منكم',
#   'ما',
#   'تبخلوا',
#   'علينا',
#   'بقلب',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'يتسهار',
#   'سالك',
#   'صرة',
#   'سالك',
#   'للخارج',
#   'شاحنات',
#   'ونمر',
#   'صفراء',
#   'وحاليا',
#   'ازمه',
#   'للخارجين',
#   'زعترا',
#   'سالك',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'مغلق',
#   'التفافي',
#   'زواتا',
#   'سالك',
#   'المربعه',
#   'ازمه',
#   'بالاتجاهين',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'دير',
#   'شرف',
#   'ازمه',
#   'مع',
#   'كثافة',
#   'سير',
#   'عورتا',
#   'ازمه',
#   'للخارج',
#   'بيت',
#   'فوريك',
#   'ازمه',
#   'لداخل',
#   'بزاريا',
#   'الرئيسي',
#   'مغلق',
#   'البديل',
#   'الغرس',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'حومش',
#   'سالك',
#   'عناب',
#   'مغلق',
#   'بالاتجاهين',
#   'اليوم',
#   'التاسع',
#   'ع',
#   'التوالي',
#   'الكفريات',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'تواجد',
#   'الجيش',
#   'إشارات',
#   'حارس',
#   'سالك',
#   'طريق',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'سالك',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'حاجز',
#   'الحمرا',
#   'ازمه',
#   'عوفرا',
#   'سالك',
#   'اارئيل',
#   'سلفيت',
#   'سالك',
#   'خط',
#   'رام',
#   'الله',
#   'نابلس',
#   'سالك',
#   'عين',
#   'سينا',
#   'سالك',
#   'عطارة',
#   'سالك',
#   'عطاره',
#   'فوق',
#   'الجسر',
#   'سالك',
#   'روابي',
#   'سالك',
#   'اشارات',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'سنجل',
#   'مغلق',
#   'سنجل',
#   'المدخل',
#   'الشمالي',
#   'سالك',
#   'شيلو',
#   'سالك',
#   'عيلي',
#   'سالك',
#   'عيون',
#   'الحراميه',
#   'سالك',
#   'بيت',
#   'ايل',
#   'مغلق',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'تحت',
#   'جسر',
#   'جباره',
#   'سالك',
#   'جماعين',
#   'ساالك',
#   'بوابة',
#   'كفل',
#   'حارس'],
#  ['مغلق',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'مردا',
#   'الشرقيه',
#   'سالك',
#   'بديا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'مدخل',
#   'مردا',
#   'الغربي',
#   'سالك',
#   'متواجد',
#   'معكم',
#   'عالخاص',
#   'لا',
#   'اب',
#   'تحديث',
#   'إستفسار'],
#  ['سبسطية', 'سالكة'],
#  ['اخوي',
#   'طلعنا',
#   'ع',
#   'اشارة',
#   'بيت',
#   'ايل',
#   'رجعوا',
#   'نمر',
#   'الضفة',
#   'بس',
#   'النمر',
#   'الصفرا',
#   'بمرقوا',
#   'من',
#   'الإشارات',
#   'تحت'],
#  ['وازمة', 'من', 'ساعه', 'ولا', 'سيارة', 'خرجت'],
#  ['المربعه', 'تفتيش', 'سياره', 'سيارة'],
#  ['زعترا', 'سالك'],
#  ['خط', 'يتسهار', 'سالك', 'ونظيف'],
#  ['من', 'ازمه', 'عورتا', 'الان'],
#  ['مع', 'تواجد', 'الجيش', 'الان', 'والطريق', 'سالك'],
#  ['كدميمم', 'سالك', 'تماما'],
#  ['الفندق', 'سالكة', 'بس', 'في', 'جيش', 'تفتيش', 'عشوائي'],
#  ['جميع', 'حواجز', 'نابلس', 'ازمة'],
#  ['قلنديا', 'ازمة', 'داخل'],
#  ['قلنديا', 'كفر', 'عقب', 'سالك', 'للداخل', 'الخارج', 'العجل', 'ماشي'],
#  ['الكونتينر', 'سالك', 'بالاتجاهين'],
#  ['عورتا', 'ازمة', 'للخارج', 'الداخل', 'سالك'],
#  ['ازمه', 'مفرق', 'جيت', 'ماشيه'],
#  ['الكونتينر', 'سالك', 'تماما', 'اتجاهين'],
#  ['لا', 'رجعتهم', 'حكيتلهم', 'حلو', 'عن', 'صدورنا', 'الغرس', 'سالكة'],
#  ['يعني', 'ممكن', 'يوصل', 'الموضوع', 'للغرس'],
#  ['طريق',
#   'شافي',
#   'شمرون',
#   'كل',
#   'ما',
#   'يشوفو',
#   'فتحة',
#   'بوقفو',
#   'السير',
#   'وبسكروها'],
#  ['من', 'ازمه', 'الداخل', 'ع', 'دير', 'شرف'],
#  ['الكونتينر',
#   'سالك',
#   'شمالا',
#   'العجل',
#   'ماشي',
#   'مع',
#   'تفتيش',
#   'عشوائي',
#   'باتجاه',
#   'الجنوب'],
#  ['لتاكيد', 'بوابة', 'زيف', 'سالكه', 'وفاتحه'],
#  ['الكونتينر', 'سالكه', 'عبده', 'مغلقه', 'كرمة', 'فاتحه', 'السموع', 'سالكه'],
#  ['طريق',
#   'العمور',
#   'ازمة',
#   'وتفتيش',
#   'سياره',
#   'سياره',
#   'العبيدية',
#   'ازمة',
#   'باتجاه',
#   'الجنوب'],
#  ['بزاريا', 'مبينة', 'فاتحة', 'بس', 'التسكير', 'لقدام', 'تنغروش', 'وتقدمو'],
#  ['عش',
#   'غراب',
#   'فاتح',
#   'وسالك',
#   'جبع',
#   'فاتح',
#   'وسالك',
#   'قلنديا',
#   'ازمة',
#   'بالاتجاهين'],
#  ['بوابة', 'زيف', 'يطا', 'فاتحه', 'وسالكه'],
#  ['تواجد', 'لقوات', 'الاحتلال', 'على', 'شارع', 'المزرعة', 'الشرقية'],
#  ['ازمة', 'العيزرية', 'والزعيم'],
#  ['حومش', 'سالك'],
#  ['راس', 'الجورة', 'سالك', 'اتجاهين', 'فرش', 'الهوى', 'مغلق'],
#  ['راس',
#   'الجوره',
#   'سالك',
#   'مع',
#   'تواجد',
#   'جيش',
#   'طريق',
#   'لعمور',
#   'يطا',
#   'ازمة',
#   'بوابة',
#   'زيف',
#   'تم',
#   'فتحها',
#   'ويمكن',
#   'عشان',
#   'الجيش',
#   'دخل',
#   'في',
#   'اي',
#   'لحظة',
#   'بتسكر',
#   'حاجز',
#   'على',
#   'طريق',
#   'يبرود'],
#  ['https',
#   'vt',
#   'tiktok',
#   'comZS2WEgAWE',
#   'الطريق',
#   'البديلة',
#   'الغرس',
#   'بزاريا',
#   'واعملولي',
#   'متابعة',
#   'ع',
#   'التيكتوك'],
#  ['بوابة', 'دورا', 'مغلقة', 'القصر', 'سالكه'],
#  ['النشاش', 'سالك', 'ازمه', 'الاشاره'],
#  ['الان', 'العيزرية', 'ازمة', 'اتجاهين', 'حتى', 'الزعيم'],
#  ['الغرس', 'بزاريا', 'الآن'],
#  ['راس', 'الجورة', 'سالك'],
#  ['حاجز', 'الهيئة', 'اريحا', 'سالكة'],
#  ['الزعيم',
#   'ازمه',
#   'بالاتجاهين',
#   'العيزرية',
#   'ازمة',
#   'باتجاه',
#   'الجنوب',
#   'الكونتينر',
#   'سالك',
#   'شمالا',
#   'ازمه',
#   'وفتح',
#   'باتجاه',
#   'الجنوب',
#   'وما',
#   'بوقفوا',
#   'حد',
#   'واد',
#   'النار',
#   'سالك',
#   'النشاش',
#   'سالك'],
#  ['دير', 'شر', 'من', 'جهة', 'شافي', 'شمرون'],
#  ['باتجاه', 'الخان', 'الاحمر', 'بعد', 'العيزرية', 'كثافة', 'سير'],
#  ['مش', 'معدلها', 'خليها', 'صمن'],
#  ['الحمرا', 'الان', 'سالكة'],
#  ['النشاش', 'سالك', 'بالاتجاهين'],
#  ['عناب', 'مغلق', 'من', 'سبع', 'صمن', 'ايام', 'حتى', 'اللحظة'],
#  ['بيت', 'ايل', 'الان', 'مغلق'],
#  ['بديل', 'الزعيم', 'طريق', 'كسارات', 'ابو', 'جورج'],
#  ['الغرس', 'بزاريا', 'الان', 'بس', 'بدها', 'شوية', 'أولويات', 'مش', 'اكتر'],
#  ['مدخل',
#   'رنتيس',
#   'سالك',
#   'ونظيف',
#   'خط',
#   'رنتيس',
#   'اللبن',
#   'سالك',
#   'ونظيف',
#   'خط',
#   'اللبن',
#   'دير',
#   'بلوط',
#   'سالك',
#   'ونظيف',
#   'مفرق',
#   'دير',
#   'بلوط',
#   'سالك',
#   'ونظيف',
#   'بوابة',
#   'كفر',
#   'الديك',
#   'مغلقة',
#   'بوابة',
#   'بروقين',
#   'سالكة',
#   'ونظيفة'],
#  ['الغرس', 'بزاريا', 'العالم', 'فوق', 'بعض', 'ازمة', 'خانقة'],
#  ['الزعيم', 'ازمة', 'اتجاهين'],
#  ['سيارة', 'شرطة', 'على', 'اشارات', 'كرمي', 'سور'],
#  ['الحمرا', 'ازمة', 'للخارج', 'مع', 'تفتيش', 'الشحن', 'بحكيش', 'معه'],
#  ['ما', 'زال', 'الكونتينر', 'فل', 'ازمة', 'باتجاه', 'الجنوب'],
#  ['كف', '٣٥', 'سالك', 'ونظيف', 'بكل', 'الاتجاهات'],
#  ['دير', 'شرف', 'فتح', 'الخط', 'للخارج'],
#  ['دير', 'شرف', 'الان', 'ازمة', 'اتجاهين'],
#  ['قلنديا', 'داخل', 'وخارج', 'ازمة', 'ماشية'],
#  ['حومش', 'سلك', 'بحري', 'الان'],
#  ['الي',
#   'جاي',
#   'من',
#   'نابلس',
#   'ل',
#   'طولكرم',
#   'من',
#   'دير',
#   'شرف',
#   'ع',
#   'مدخل',
#   'برقه',
#   'الرئيسي',
#   'عقبالو',
#   'في',
#   'مدخل',
#   'صغير',
#   'بدايتو',
#   'باطون',
#   'بوصلك',
#   'ل',
#   'ب',
#   'زاريا',
#   'اسمو',
#   'طريق',
#   'الغرس',
#   'الطريق',
#   'ممتاز',
#   'ومزفت',
#   'بنسبة',
#   '90',
#   'ومن',
#   'بزاريا',
#   'ل',
#   'عنبتا',
#   'ل',
#   'طولكرم'],
#  ['الزعيم', 'ازمة', 'باتجاه', 'الجنوب'],
#  ['حاجز', 'جبع', 'سالك'],
#  ['ال', '17', 'سالك', 'عصيره', 'الشماليه'],
#  ['عين', 'سينيا', 'سالك', 'حاجز', 'تحت', 'جسر', 'يبرود'],
#  ['الكونتينر',
#   'ازمة',
#   'باتجاه',
#   'الجنوب',
#   'عش',
#   'الغراب',
#   'سالك',
#   'كثافة',
#   'سير',
#   'تحت',
#   'جسر',
#   'بيت',
#   'ساحور',
#   'وماشي',
#   'السير'],
#  ['ما', 'تخجل', 'يا', 'انس', 'كمل', 'عورتا', 'ازمه', 'خانقة', 'كمان'],
#  ['الخارج',
#   'من',
#   'النصاريه',
#   'ازمة',
#   'خانقة',
#   'الحمرا',
#   'تياسير',
#   'اكم',
#   'سياره',
#   'وسالك'],
#  ['دير', 'شرف', 'شخصيا'],
#  ['المربعة', 'ازمة'],
#  ['حومش', 'حاجز', 'دير', 'شرف', 'ازمة'],
#  ['أزمة', 'جسر', 'بيت', 'ساحور'],
#  ['اخوي', 'البوابه', 'الصفرا', 'والهيئة', 'سالكات', 'مع', 'تواجد', 'للجيش'],
#  ['بديل',
#   'بزاريا',
#   'طريق',
#   'الغرس',
#   'او',
#   'من',
#   'جبارة',
#   'للدخول',
#   'الى',
#   'طولكرم',
#   'او',
#   'العكس'],
#  ['بزاريا'],
#  ['الان', 'تم', 'تسكير', 'مدخل', 'بزاريا'],
#  ['تواجد',
#   'جرافه',
#   'مع',
#   'جيش',
#   'ع',
#   'مدخل',
#   'بزاريا',
#   'الرئيسي',
#   'الله',
#   'يستر'],
#  ['دير', 'شرف', 'الازمه', 'لاعند', 'الجامع', 'لا', 'الخارج'],
#  ['عش',
#   'غراب',
#   'سالكه',
#   'بالاتجاهين',
#   'راس',
#   'الجوره',
#   'سالك',
#   'كف',
#   '٣٥',
#   'سالك',
#   'عصيون',
#   'سالك',
#   'مدخل',
#   'سعير',
#   'سالك',
#   'النبي',
#   'يونس',
#   'مغلق',
#   'كفر',
#   'عقب',
#   'سالك',
#   'وازمة',
#   'خفيفة'],
#  ['اريحا', 'الجنوبي', 'سالك', 'تماما', 'مع', 'عدم', 'تواجد', 'جيش'],
#  ['راس', 'الجوره', 'سالك'],
#  ['جسر', 'حلحول', 'مغلق'],
#  ['اكم',
#   'قلب',
#   'يستاهل',
#   'منكم',
#   'ما',
#   'تبخلوا',
#   'علينا',
#   'بقلب',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'يتسهار',
#   'سالك',
#   'صرة',
#   'سالك',
#   'للخارج',
#   'شاحنات',
#   'ونمر',
#   'صفراء',
#   'وحاليا',
#   'ازمه',
#   'للخارجين',
#   'زعترا',
#   'سالك',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'مغلق',
#   'التفافي',
#   'زواتا',
#   'سالك',
#   'المربعه',
#   'ازمه',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'دير',
#   'شرف',
#   'كثافة',
#   'سير',
#   'عورتا',
#   'ازمه',
#   'للهارج',
#   'بيت',
#   'فوريك',
#   'سالك',
#   'بزاريا',
#   'الرئيسي',
#   'سالك',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'حومش',
#   'حاجز',
#   'عناب',
#   'مغلق',
#   'بالاتجاهين',
#   'اليوم',
#   'التاسع',
#   'ع',
#   'التوالي',
#   'الكفريات',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'تواجد',
#   'الجيش',
#   'إشارات',
#   'حارس',
#   'سالك',
#   'طريق',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'سالك',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'حاجز',
#   'الحمرا',
#   'ازمه',
#   'عوفرا',
#   'سالك',
#   'اارئيل',
#   'سلفيت',
#   'سالك',
#   'خط',
#   'رام',
#   'الله',
#   'نابلس',
#   'سالك',
#   'عين',
#   'سينا',
#   'سالك',
#   'عطارة',
#   'سالك',
#   'عطاره',
#   'فوق',
#   'الجسر',
#   'سالك',
#   'روابي',
#   'سالك',
#   'اشارات',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'سنجل',
#   'مغلق',
#   'سنجل',
#   'المدخل',
#   'الشمالي',
#   'سالك',
#   'شيلو',
#   'سالك',
#   'عيلي',
#   'سالك',
#   'عيون',
#   'الحراميه',
#   'سالك',
#   'بيت',
#   'ايل',
#   'ازمه',
#   'للخارج',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'تحت',
#   'جسر',
#   'جباره',
#   'سالك',
#   'جماعين',
#   'ساالك',
#   'بوابة',
#   'كفل',
#   'حارس'],
#  ['مغلق',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'مردا',
#   'الشرقيه',
#   'سالك',
#   'بديا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'مدخل',
#   'مردا',
#   'الغربي',
#   'سالك',
#   'متواجد',
#   'معكم',
#   'عالخاص',
#   'لا',
#   'اب',
#   'تحديث',
#   'إستفسار'],
#  ['حاجز', 'البنانا', 'مغلق', 'بالبوابات', 'حتى', 'الان'],
#  ['الكونتينر', 'ازمة', 'وتفتيش', 'بتجاه', 'الجنوب'],
#  ['دير', 'شرف', 'سالك', 'بالاتجاهين', 'بحري', 'حالبا'],
#  ['حومش', 'ما', 'تزال', 'حومش', 'حتى', 'اللحظه'],
#  ['حاجز', 'للطالع', 'من', 'اريحا', 'من', 'جهة', 'الجسر'],
#  ['جبع', 'سالك', 'تماما'],
#  ['الحمرا',
#   'للي',
#   'نازل',
#   'على',
#   'اريحا',
#   'ازمة',
#   'شديدة',
#   'للي',
#   'داخل',
#   'على',
#   'نابلس',
#   'ولا',
#   'سياره',
#   'حرفيا'],
#  ['قلنديا', 'داخل', 'وخارج', 'في', 'ازمة', 'عادية'],
#  ['كفر', 'عقب', 'فيها', 'شويت', 'ازمة'],
#  ['جبع', 'حزما', 'سالكه', 'داخل', 'وخارج'],
#  ['دير', 'شرف', 'ازمه', 'ماشيه', 'الان'],
#  ['مدخل',
#   'رنتيس',
#   'سالك',
#   'ونظيف',
#   'خط',
#   'رنتيس',
#   'اللبن',
#   'سالك',
#   'ونظيف',
#   'خط',
#   'اللبن',
#   'دير',
#   'بلوط',
#   'سالك',
#   'ونظيف',
#   'مفرق',
#   'دير',
#   'بلوط',
#   'سالك',
#   'ونظيف',
#   'بوابة',
#   'كفر',
#   'الديك',
#   'مغلقة',
#   'بوابة',
#   'بروقين',
#   'سالكة',
#   'ونظيفة'],
#  ['النشاش', 'سالك', 'بالاتجاهين'],
#  ['الخليل', 'المنشية', 'مغلقة'],
#  ['اكم',
#   'قلب',
#   'يستاهل',
#   'منكم',
#   'ما',
#   'تبخلوا',
#   'علينا',
#   'بقلب',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'يتسهار',
#   'سالك',
#   'صرة',
#   'سالك',
#   'للخارج',
#   'شاحنات',
#   'ونمر',
#   'صفراء',
#   'وحاليا',
#   'ازمه',
#   'للخارجين',
#   'زعترا',
#   'سالك',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'مغلق',
#   'التفافي',
#   'زواتا',
#   'سالك',
#   'المربعه',
#   'ازمه',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'دير',
#   'شرف',
#   'سالك',
#   'حاليا',
#   'عورتا',
#   'ازمه',
#   'للهارج',
#   'بيت',
#   'فوريك',
#   'سالك',
#   'بزاريا',
#   'الرئيسي',
#   'سالك',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'حومش',
#   'حاجز',
#   'عناب',
#   'مغلق',
#   'بالاتجاهين',
#   'اليوم',
#   'التاسع',
#   'ع',
#   'التوالي',
#   'الكفريات',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'تواجد',
#   'الجيش',
#   'إشارات',
#   'حارس',
#   'سالك',
#   'طريق',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'سالك',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'حاجز',
#   'الحمرا',
#   'شبه',
#   'يالك',
#   'عوفرا',
#   'سالك',
#   'اارئيل',
#   'سلفيت',
#   'سالك',
#   'خط',
#   'رام',
#   'الله',
#   'نابلس',
#   'سالك',
#   'عين',
#   'سينا',
#   'سالك',
#   'عطارة',
#   'سالك',
#   'عطاره',
#   'فوق',
#   'الجسر',
#   'سالك',
#   'روابي',
#   'سالك',
#   'اشارات',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'سنجل',
#   'مغلق',
#   'سنجل',
#   'المدخل',
#   'الشمالي',
#   'سالك',
#   'شيلو',
#   'سالك',
#   'عيلي',
#   'سالك',
#   'عيون',
#   'الحراميه',
#   'سالك',
#   'بيت',
#   'ايل',
#   'ازمه',
#   'للخارج',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'تحت',
#   'جسر',
#   'جباره',
#   'سالك',
#   'جماعين',
#   'ساالك',
#   'بوابة',
#   'كفل',
#   'حارس'],
#  ['مغلق',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'مردا',
#   'الشرقيه',
#   'سالك',
#   'بديا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'مدخل',
#   'مردا',
#   'الغربي',
#   'سالك',
#   'جبع',
#   'سالك',
#   'قلنديا',
#   'كفر',
#   'عقب',
#   'سالك',
#   'حزما',
#   'سالك'],
#  ['طبعا',
#   'صاحب',
#   'التريلا',
#   'هاد',
#   'كلو',
#   'ذوق',
#   'ع',
#   'دير',
#   'شرف',
#   'اجا',
#   'بعكس',
#   'وطلع',
#   'ع',
#   'الدوار',
#   'وكسر',
#   'مراية',
#   'سياره',
#   'لا',
#   'اهتم',
#   'معلوم',
#   'مركن',
#   'نمرا',
#   'صفرا',
#   'بس',
#   'لا',
#   'حولا',
#   'ولا',
#   'قوه',
#   'الا',
#   'بالله'],
#  ['دير', 'شرف', 'الان'],
#  ['حاجز', 'الحمرا', 'للخارح', 'ابو', '20', 'سيارة', 'وبمشو'],
#  ['عصيرة', 'ال', '17', 'سالك'],
#  ['حاليا', 'مشو', 'السير'],
#  ['حاليا', 'اصلح', 'مخارج', 'ومداخل', 'دير', 'شرف'],
#  ['حاجز', 'الحمرا', 'ازمة', 'للداخل', 'عالنصارية'],
#  ['من', 'دير', 'شرف', 'لا', 'شافي', 'شمرون', 'بحري'],
#  ['عيلي', 'سالك', 'مع', 'تواجد', 'الجيش', 'والشرطه', 'والطريق', 'سالك'],
#  ['دير', 'شرف', 'الان', 'وضعو', 'ممتاز', 'لا', 'الخارج', '٢٠', 'سياره'],
#  ['المربعه', 'من', 'ساعهع', 'ها', 'الوقفه'],
#  ['واد', 'كانا', 'سالك'],
#  ['للتاكيد', 'ولا', 'سيارة', 'عالحمرا', 'للخارج'],
#  ['دير', 'شرف', 'سالك', 'لداخل', 'الخارج', 'بمشي', 'بس', 'ازمه'],
#  ['جبع', 'سالك', 'حزما', 'سالكه'],
#  ['سنجل',
#   'المدخل',
#   'الغربي',
#   'طبعا',
#   'مغلق',
#   'من',
#   'فتره',
#   'المدخل',
#   'الشمالي',
#   'سالك'],
#  ['عورتا', 'سالك', 'لداخل', 'تماما', 'الخارج', 'الله', 'يكون', 'بلعون'],
#  ['بالنسبة',
#   'الحمرا',
#   'عالداخل',
#   'ما',
#   'زال',
#   'ازمة',
#   'اللي',
#   'خارج',
#   'باتجاه',
#   'اريحا',
#   'ولا',
#   'سيارة'],
#  ['خط', 'ستين', 'عند', 'ترمسعيا', 'سالك', 'حاليا', 'راحو', 'الجيش'],
#  ['إشارات', 'بيت', 'ايل', 'سالك'],
#  ['ما', 'بكلمو', 'حدا'],
#  ['عيلي', 'سالك', 'مع', 'تواجد', 'الجيش', 'والشرطه', 'والمستوطنين'],
#  ['أبو', 'إسكندر', 'دير', 'شرف', 'أزمة', 'خانقة'],
#  ['خط',
#   '٩٠',
#   'سالك',
#   'تماما',
#   'مفرق',
#   'آدم',
#   'سالك',
#   'البوابة',
#   'الصفرا',
#   'اريحا',
#   'مشى',
#   'الوضع',
#   'وفكو',
#   'الحاجز',
#   'الحمرا',
#   'حاليا',
#   'للداخل',
#   'باتجاه',
#   'النصارية',
#   'ازمة',
#   'الخارج',
#   'باتجاه',
#   'اريحا',
#   'ولا',
#   'سيارة',
#   'عليه'],
#  ['حزما', 'للمخماس', 'سالك'],
#  ['حزما', 'سالك'],
#  ['Dso', 'اريحا', 'سالك', 'بحري'],
#  ['الكونتينر', 'سالك', 'بالانجاهين'],
#  ['فرش', 'الهوى', 'مغلق'],
#  ['دير', 'شرف', 'سيء', 'جدا', 'وبكسروا', 'السيارات', 'عالدوار'],
#  ['عيلي', 'لحد', 'اللحظة'],
#  ['المدخل',
#   'الشمالي',
#   'اريحا',
#   'ازمة',
#   'خانقة',
#   'وطويلة',
#   'على',
#   'ما',
#   'يبو',
#   'مغلق'],
#  ['واد', 'كانا', 'ارئيل', 'سالك'],
#  ['عناب', 'مغلق', 'بالاتجاهين'],
#  ['بروقين', 'سالك'],
#  ['مدخل', 'سلفيت', 'الشمالي', 'سالك'],
#  ['من',
#   'دوار',
#   'معالي',
#   'ادوميم',
#   'ل',
#   'إشارات',
#   'البحر',
#   'الميت',
#   'سالك',
#   'تماما',
#   'جسر',
#   'اللنبي',
#   'فاتح',
#   'امام',
#   'حركة',
#   'المسافرين',
#   'والبضائع',
#   'البوابة',
#   'الصفرا',
#   'حاليا',
#   'ازمة',
#   'خانقة',
#   'للخارج',
#   'من',
#   'اريحا'],
#  ['حومش', 'بتجاه', 'نابلس', 'مغلق'],
#  ['خط', 'يتسهار', 'سالك', 'ونظيف', 'تمام'],
#  ['حاجز', 'صره', 'للخارج'],
#  ['تياسير', 'سالك', 'بكل', 'الاتجاهات'],
#  ['هاي', 'لمربعة', 'للداخل'],
#  ['بزاريا', 'سالك', 'تماما'],
#  ['انتبهو'],
#  ['حاجز', 'الحمرا', 'أزمة', 'خانقة'],
#  ['راس', 'الجوره', 'سالك', 'تماما'],
#  ['عطاره', 'روابي'],
#  ['عين', 'سينا', 'سالك', 'تماما'],
#  ['من',
#   'ازمة',
#   'العيزرية',
#   'حاليا',
#   'باتجاه',
#   'الشمال',
#   'رحلة',
#   'العادة',
#   'وزيادة',
#   'بس',
#   'اطلع',
#   'منها',
#   'ان',
#   'شاء',
#   'الله',
#   'راح',
#   'انسى',
#   'وين',
#   'رايح'],
#  ['ازمة', 'المربعة', 'واصلة', 'العين', 'اللي', 'تحت'],
#  ['طريق',
#   'معالي',
#   'ادوميم',
#   'سالكه',
#   'بعد',
#   'ما',
#   'تطلع',
#   'من',
#   'ازمة',
#   'العيزرية',
#   'الزعيم',
#   'عناتا',
#   'حزما',
#   'سالكين'],
#  ['عورتا',
#   'لداخل',
#   'ع',
#   'نابلس',
#   'سالك',
#   'تماما',
#   'الخارج',
#   'الله',
#   'يكون',
#   'بلعون'],
#  ['طازه', 'الان', 'لداخل', 'هاي', 'الازم', 'ع', 'دير', 'شرف', 'الان'],
#  ['تم', 'اغلاق', 'فرش', 'الهوى'],
#  ['شرطة', 'على', 'دوار', 'يتما', 'زعترة'],
#  ['النبي', 'يونس', 'باتجاه', 'سعير', 'فاتحه', 'باتجاه', 'حلحول', 'مغلق'],
#  ['من', 'ازمة', 'المربعة'],
#  ['السير', 'واقف', 'بجميع', 'الاتجاهات', 'ع', 'دير', 'شرف'],
#  ['الكونتينر', 'حاليا'],
#  ['طريق',
#   'رام',
#   'لله',
#   'تحويل',
#   'السيارات',
#   'الى',
#   'معرجات',
#   'اللبن',
#   'بسبب',
#   'الجنازة',
#   'في',
#   'مقبرة',
#   'عيلي'],
#  ['جبع', 'سالك'],
#  ['جسر',
#   'حلحول',
#   'فاتح',
#   'للخارج',
#   'من',
#   'حلحول',
#   'فقط',
#   'والناس',
#   'بتدخل',
#   'بعكس',
#   'السير',
#   'المسلك',
#   'مستخدم',
#   'للاتجاهين'],
#  ['دير', 'شرف', 'حدث', 'بلا', 'حرج'],
#  ['ازمة', 'دير', 'شرف', 'للداخل'],
#  ['اعتذر',
#   'عن',
#   'الخاص',
#   'اخواني',
#   'بسبب',
#   'ظروف',
#   'العمل',
#   'ساقوم',
#   'بنشر',
#   'التحديثات',
#   'كالعاده',
#   'من',
#   'القناة'],
#  ['العيزرية',
#   'العجل',
#   'ماشي',
#   'وان',
#   'شاء',
#   'الله',
#   'شوية',
#   'صبر',
#   'بتكون',
#   'سالكه'],
#  ['من', 'رمزونات', 'النبي', 'يونس', 'لكف', '٣٥', 'سالك', 'بالاتجاهين'],
#  ['تياسير', 'سالك', 'ازمة', 'خفيقة', 'للخارج', 'باتجاه', 'اريحا'],
#  ['حاجز',
#   'بيت',
#   'ايل',
#   'سالك',
#   'للداخل',
#   'الخارج',
#   'حوالي',
#   '١٠',
#   'سيارات',
#   'وسالك'],
#  ['الحمرا', 'حاليا', 'الداخل', 'سالك', 'الخارج', 'لكوربة', 'المي'],
#  ['دير',
#   'شرف',
#   'ازمة',
#   'واقف',
#   'للخارج',
#   'وواقفة',
#   'للخارج',
#   'عكس',
#   'السير',
#   'كمان'],
#  ['المربعة', 'وحسب', 'اللي', 'وصلني', 'احنا', 'سبب', 'الأزمة'],
#  ['اخوي',
#   'حاجز',
#   'البنانا',
#   'مغلق',
#   'العوجا',
#   'والهيئه',
#   'والبوابه',
#   'الصفرا',
#   'سالكات'],
#  ['الحمرا', 'سلك', 'حاليا', 'حوالي', '٣٠', 'سيارة'],
#  ['بوابة', 'كرمه', 'الان'],
#  ['دير',
#   'شرف',
#   'الان',
#   'نزول',
#   'شافي',
#   'شمرون',
#   'لا',
#   'حولا',
#   'ولا',
#   'قوه',
#   'الا',
#   'بالله',
#   'العلي',
#   'العظيم'],
#  ['دير', 'شرف', 'للخارج'],
#  ['دير', 'شرف', 'لداخل'],
#  ['شافي', 'شمرون', 'سالك', 'بزاريا', 'الرئيسي', 'سالك'],
#  ['الحمرا', 'الان', 'لا', 'الخارج', 'من', 'نابلس'],
#  ['بوابات',
#   'النبي',
#   'يونس',
#   'سعير',
#   'الحواور',
#   'العروب',
#   'عصيون',
#   'افرات',
#   'جورة',
#   'الشمعة',
#   'ام',
#   'سلمونا',
#   'المنشية'],
#  ['تقوع', 'بوابة', 'عش', 'الغراب', 'حاليا'],
#  ['عش', 'غراب', 'سالك', 'الكونتينر', 'تفتيش', 'باتجاه', 'الجنوب'],
#  ['فرش',
#   'الهوى',
#   'سالك',
#   'بالاتجاهين',
#   'راس',
#   'الجوره',
#   'سالك',
#   'للداخل',
#   'الخارج',
#   'حاجز',
#   'وتفتيش',
#   'جيب',
#   'شرطة',
#   'على',
#   'كف',
#   '٣٥'],
#  ['الان', 'فتحو', 'البوابتين'],
#  ['ازمة', 'عورتا', 'شوي', 'وبتوصل', 'المفرق'],
#  ['سياره', 'شرطه', 'للخارج', 'من', 'بيت', 'ايل'],
#  ['المربعة', 'ازمه'],
#  ['صرة',
#   'فاتح',
#   'وسالك',
#   'للخارج',
#   'من',
#   'نابلس',
#   'شاحنات',
#   'ضفة',
#   'ونمرا',
#   'صفرا',
#   'شوفيرية',
#   'الشحن',
#   'شو',
#   'بنستنو'],
#  ['دير', 'شرف', 'ما', 'يزال', 'ازمه', 'بالاتجاهين'],
#  ['العيزرية',
#   'للي',
#   'طالع',
#   'ع',
#   'الشمال',
#   'وجماعة',
#   'عكس',
#   'السير',
#   'مش',
#   'مقصرين',
#   'ربي',
#   'يحميهم'],
#  ['عيون', 'الحراميه', 'سالك', 'فش', 'سيارات'],
#  ['التريلا', 'يلي', 'قالبة', 'رمسا', 'واستنفار', 'للشرطة', 'بالمكان'],
#  ['الكونتير', 'بتجاه', 'الجنوب'],
#  ['دير', 'شرف', 'حاليا'],
#  ['الكونتينر', 'تفتيش', 'ع', 'داخل'],
#  ['جسر',
#   'بيت',
#   'كاحل',
#   'سالك',
#   'جسر',
#   'حلحول',
#   'سالك',
#   'راس',
#   'الجورة',
#   'حاليا',
#   'فاتح',
#   'مع',
#   'تواجد',
#   'للجيش'],
#  ['طريق', 'معرجات', 'اللبن', 'ازمه', 'قويه', 'الان'],
#  ['بيت', 'ايل', 'سالك', 'للداخل', 'تفتيش', 'للخارج', 'وازمة', 'بسيطة'],
#  ['شرطة',
#   'على',
#   'دوار',
#   'معالي',
#   'ادوميم',
#   'حاليا',
#   'جماعة',
#   'عكس',
#   'السير',
#   'دير',
#   'بالك',
#   'تتكحل'],
#  ['سيارة', 'شرطة', 'على', 'دوار', 'قدوميم', 'رابطين', 'للجاي', 'من', 'الفندق'],
#  ['ازمة',
#   'وتفتيش',
#   'باتجاه',
#   'الجنوب',
#   'على',
#   'الكونتينر',
#   'الشمال',
#   'سالك',
#   'بس',
#   'بتوقع',
#   'في',
#   'فخ',
#   'ازمة',
#   'العيزرية',
#   'الي',
#   'واصله',
#   'من',
#   'دوار',
#   'معالي',
#   'ادوميم',
#   'لدوار',
#   'البدو'],
#  ['المربعة', 'ودير', 'شرف', 'سالكات', 'الان'],
#  ['تم',
#   'التعميم',
#   'بالامس',
#   'عن',
#   'وجود',
#   'جنازة',
#   'في',
#   'منطقة',
#   'عيلي',
#   'يرجى',
#   'اخذ',
#   'الحيطة',
#   'والحذر'],
#  ['فرش', 'الهوى', 'سالك', 'بالاتجاهين', 'عقبي'],
#  ['الازمه', 'قبل', 'عيلي', 'لا', 'طلعوع', 'معرجات', 'اللبن'],
#  ['دير', 'شرف', 'فاضي'],
#  ['دير', 'شرف', 'سالك', 'بكلشي', 'خالي'],
#  ['العيزاريه',
#   'للخارج',
#   'الى',
#   'الشمال',
#   'مسكره',
#   'وطرقها',
#   'الفرعيه',
#   'سياراه',
#   'فل'],
#  ['زعترا', 'سالك', 'بكل', 'الاتجاهات'],
#  ['شمرون', 'سالك'],
#  ['المربعة', 'الوضع', 'تعيس', 'للاسف'],
#  ['باب', 'ترمسعيا', 'على', 'الشارع', 'الجيش', 'وقف', 'السير', 'كلو'],
#  ['لمربعه',
#   'علخارج',
#   'بلشت',
#   'تسلك',
#   'بس',
#   'شوي',
#   'ازمة',
#   'من',
#   'كثر',
#   'السيارات'],
#  ['دير', 'شرف', 'سالك', 'لداخل', 'راحت', 'الازمه', 'الخارج', 'سالك'],
#  ['بزاريا', 'سالك'],
#  ['بسبب', 'جنازة', 'عندهم', 'الله', 'لا', 'يرحمه'],
#  ['اغلاق', 'الشارع', 'شيلو', 'وعيلي', 'مغلق'],
#  ['تحويل',
#   'خط',
#   'سير',
#   'رام',
#   'الله',
#   'الى',
#   'منعطفات',
#   'اللبن',
#   'الطريق',
#   'القديمه',
#   'باتجاه',
#   'رام',
#   'الله',
#   'والعكس',
#   'بسبب',
#   'تواجد',
#   'المستوطنين'],
#  ['حاجز',
#   'صره',
#   'سالك',
#   'للشاحنات',
#   'ونمرا',
#   'صفراء',
#   'فقط',
#   'مع',
#   'وجود',
#   'ازمه'],
#  ['عيليه', 'عند', 'المقبره'],
#  ['اغلاق', 'كرمه'],
#  ['للتذكير',
#   'وضع',
#   'حاجز',
#   'عناب',
#   'مازال',
#   'مغلق',
#   'بالاتجاهين',
#   'حتى',
#   'الان',
#   'والجيش',
#   'برجع',
#   'السيارات',
#   'والسلامه',
#   'للجميع'],
#  ['دوار', 'الطنيب', 'سالك', 'مع', 'كثافة', 'سير'],
#  ['عورتا', 'لداخل', 'ع', 'نابلس'],
#  ['راس',
#   'الجوره',
#   'سالك',
#   'فرش',
#   'الهوى',
#   'سالك',
#   'الرمضين',
#   'سالك',
#   'كرمه',
#   'سالك'],
#  ['نعم',
#   'صحيح',
#   'أزمة',
#   'الداخل',
#   'ع',
#   'دير',
#   'شرف',
#   'طويله',
#   'جد',
#   'بس',
#   'اطلعو',
#   'بلفديو',
#   'المسافه',
#   'بين',
#   'للسيارات'],
#  ['ازمة', 'دير', 'شرف', 'واصلة', 'نزول', 'جيت'],
#  ['دير', 'شرف', 'الان', 'بمشي', 'وبوقف'],
#  ['عيون', 'الحرامية', 'سالك'],
#  ['فرش', 'الهوى', 'سالك', 'تماما'],
#  ['حومش', 'سيء', 'جدا', 'عالجهتين'],
#  ['الخليل', 'كرمه', 'فاتحه', 'وسالكه', 'الرمضين', 'فاتحه', 'وسالكه'],
#  ['2024',
#   'الاربعاء',
#   '8',
#   '00',
#   'صباحا',
#   'اللهم',
#   'اجمع',
#   'قلوبنا',
#   'على',
#   'خير',
#   'نابلس',
#   'صرة',
#   'مغلق',
#   'للداخل',
#   'صرة',
#   'مغلق',
#   'للخارج',
#   'ونمر',
#   'صفراء',
#   'فقط',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'سالك',
#   'المربعة',
#   'حاليا',
#   'ازمه',
#   'عورتا',
#   'ازمه',
#   'لا',
#   'الخارج',
#   'مفرق',
#   'جيت',
#   'سالك',
#   'حاليا',
#   'الطنيب',
#   'سالك',
#   'حاليا',
#   'دير',
#   'شرف',
#   'ازمه',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'مدخل',
#   'بزاريا',
#   'الرئيسي',
#   'سالك',
#   'طريق',
#   'الغرس',
#   'بزاريا',
#   'سالك',
#   'بيت',
#   'فوريك',
#   'ازمه',
#   'حوارة',
#   'البلد',
#   'سالكة',
#   'الباذان',
#   'سالك',
#   'بوابة',
#   'جماعين',
#   'سالك',
#   'حوارة',
#   'الالتفافي',
#   'الجديد',
#   'سالك',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'زعترة',
#   'سالك',
#   'بجميع',
#   'الاتجاهات',
#   'طريق',
#   'يتسهار',
#   'سالك',
#   'حاجز',
#   'حواره',
#   'مغلق',
#   'رام',
#   'الله',
#   'ال',
#   'dco',
#   'بيت',
#   'ائيل',
#   'مدخل',
#   'البيرة',
#   'الشمالي',
#   'مغلق',
#   'بفتح',
#   'من',
#   'الساعة',
#   '9',
#   'صباحا',
#   'ولغاية',
#   'الساعة',
#   'ال',
#   '3',
#   'عصرا',
#   'وحسب',
#   'المزاج',
#   'الجلزون',
#   'ازمه',
#   'مخماس',
#   'سالك',
#   'حاليا',
#   'عين',
#   'سينيا',
#   'سالك',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'عطارة',
#   'مغلق',
#   'روابي',
#   'حاجز',
#   'جسر',
#   'عطارة',
#   'سالك',
#   'طريق',
#   'رام',
#   'الله',
#   'دير',
#   'بلوط',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'حاليا',
#   'عيلي',
#   'سالك',
#   'حاليا',
#   'ك',
#   'سنجل',
#   'سالك',
#   'عوفرا',
#   'سالك',
#   'كرملو',
#   'وسالك',
#   'بوابة',
#   'عابود',
#   'مغلقة',
#   'سالك',
#   'طريق',
#   'عابود',
#   'الجدار',
#   'مغلق',
#   'بوابة',
#   'دير',
#   'ابو',
#   'مشعل',
#   'سالك',
#   'بوابة',
#   'النبي',
#   'صالح',
#   'مغلقة',
#   'سلفيت',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'باتجاه',
#   'بركان',
#   'مغلق',
#   'بوابة',
#   'سلفيت',
#   'سالك',
#   'البديل',
#   'بروقين',
#   'سلفيت',
#   'في',
#   'حال',
#   'بوابة',
#   'سلفيت',
#   'ارئيل',
#   'مغلقة',
#   'سدة',
#   'قراوة',
#   'سالك',
#   'اشارات',
#   'ارائيل',
#   'سالكة',
#   'اشارات',
#   'حارس',
#   'سالكة',
#   'كدوميم',
#   'سالك',
#   'مع',
#   'تواجد',
#   'شرطه',
#   'واد',
#   'قانا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'واد',
#   'قانا',
#   'سالك',
#   'بوابة',
#   'كفر',
#   'الديك',
#   'مغلقة',
#   'ياسوف',
#   'سلفيت',
#   'مغلقة',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'كفل',
#   'حارس',
#   'سالك',
#   'قلقيلية',
#   'عزبة',
#   'الطبيب',
#   'سالك',
#   'كرني',
#   'شمرون',
#   'سالك',
#   'النبي',
#   'الياس',
#   'حاليا',
#   'النفق',
#   'حبلة',
#   'سالك',
#   'بوابة',
#   'كفر',
#   'لاقف',
#   'سالك',
#   'عزون',
#   'الرئيسي',
#   'مغلق',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'سالك',
#   'طولكرم',
#   'عناب',
#   'مغلق',
#   'باالاتجاهين',
#   'طريق',
#   'الكفريات',
#   'سالك',
#   'جبارة',
#   'تحت',
#   'الجسر',
#   'سالك',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'اللدائن',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'واد',
#   'قانا',
#   'سالك',
#   'بيت',
#   'ليد',
#   'الرئيسي',
#   'مغلق',
#   'مدخل',
#   'رامين',
#   'مغلق',
#   'مدخل',
#   'سفارين',
#   'مغلق',
#   'عزبة',
#   'شوفة',
#   'مغلق',
#   'طريق',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'سهل',
#   'رامين',
#   'مغلق',
#   'جنين',
#   'حومش',
#   'سالك',
#   'مدخل',
#   'بزاريا',
#   'الرئيسي',
#   'سالك',
#   'بزاريا',
#   'الغرس',
#   'سالك',
#   'حاليا',
#   'جبع',
#   'حتى',
#   '١٧',
#   'عصيرة',
#   'نابلس',
#   'سالك',
#   'السيلة',
#   'حتى',
#   'عطارة',
#   'بلعا',
#   'سالك',
#   'دوتان',
#   'مغلق',
#   'حرميش',
#   'مغلق',
#   'طوباس',
#   'لحمرا',
#   'ازمه',
#   'للخارج',
#   'خانقه',
#   'تياسير',
#   'ازمه',
#   'خفيفه',
#   'طوباس',
#   'الباذان',
#   'نابلس',
#   'سالك',
#   'اريحا',
#   'الحمرا',
#   'ازمه',
#   'للخارج',
#   'خانقه',
#   'معالي',
#   'افرايم',
#   'سالك',
#   'خط',
#   '90',
#   'سالك',
#   'حاليا',
#   'المعرجات',
#   'سالك',
#   'ال',
#   'DCO',
#   'سالك',
#   'البوابة',
#   'الصفراء',
#   'حاجز',
#   'الهيئة',
#   'سالك',
#   'حاجز',
#   'البنانا',
#   'سالك',
#   'وضع',
#   'الطريق',
#   'متغير',
#   'بين',
#   'لحظة',
#   'واخرى',
#   'طريق',
#   'السلامة',
#   'للجميع',
#   'وضع',
#   'الطريق',
#   'متغير',
#   'في',
#   'لحظات',
#   'صفحه',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'من',
#   'موقعنا',
#   'على',
#   'التلجرام',
#   'إن',
#   'الله',
#   'وملائكته',
#   'يصلون',
#   'على',
#   'النبي',
#   'يا',
#   'أيها',
#   'الذين',
#   'آمنوا',
#   'صلوا',
#   'عليه',
#   'وسلموا',
#   'تسليما',
#   'اخوكم',
#   'سامر',
#   'ياسين',
#   'والمشرف',
#   'جميل'],
#  ['دير', 'شرف', 'بلش', 'يمشي', 'وفيه', 'ازمة', 'لسا', 'بس', 'خفت'],
#  ['والجيش', 'على', 'كدوميم', 'ما', 'زال', 'موجود', 'تفتيش', 'عشوائي'],
#  ['حاجز', 'جيتيت', 'معلى', 'افرايم', 'سالك', 'ونظيف'],
#  ['سالك', 'الان'],
#  ['بيت', 'ايل', 'فتح', 'مع', 'تفتيش', 'للخارج', 'وسالك', 'داخل'],
#  ['حاجز', 'عند', 'اللدائن'],
#  ['حادث',
#   'انقلاب',
#   'شاحنة',
#   'على',
#   'خط',
#   'اريحا',
#   'قرب',
#   'مدخل',
#   'قرية',
#   'فصائل'],
#  ['اللي', 'قريب', 'من', 'عند', 'اللدائن', 'يشوفلنا', 'وضع', 'المدخل'],
#  ['تحديث', 'دير', 'شرف', 'للداخل', 'على', 'نابلس', 'السير', 'واقف'],
#  ['الازمه',
#   'على',
#   'المربعه',
#   'للخارج',
#   'مش',
#   'طبيعيه',
#   'بس',
#   'للي',
#   'داخل',
#   'شبه',
#   'سالكه'],
#  ['قال',
#   'الله',
#   'تعالى',
#   'من',
#   'ذا',
#   'الذي',
#   'يقرض',
#   'الله',
#   'قرضا',
#   'حسنا',
#   'فيضاعفه',
#   'له',
#   'وله',
#   'أجر',
#   'كريم',
#   'صفحة',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'منطقة',
#   'ضواحي',
#   'القدس',
#   'قلنديا',
#   'سالكه',
#   'كفر',
#   'عقب',
#   'سالكه',
#   'جبع',
#   'ازمه',
#   'حزما',
#   'عناتا',
#   'الزعيم',
#   'ازمه',
#   'طريق',
#   'معالي',
#   'ادوميم',
#   'سالك',
#   'العيزرية',
#   'ازمه',
#   'حاجز',
#   'الكونتينر',
#   'منطقة',
#   'بيت',
#   'لحم',
#   'العبيدية',
#   'سالكة',
#   'جسر',
#   'بيت',
#   'ساحور',
#   'مغلق',
#   'تقوع',
#   'البلد',
#   'تل',
#   'الربيع',
#   'سالكه',
#   'الترابيه',
#   'بوابة',
#   'جناتا',
#   'مغلقه',
#   'النشاش',
#   'سالك',
#   'طريق',
#   'السدر',
#   'فاتحه',
#   'زعتره',
#   'بيت',
#   'لحم',
#   'مغلق',
#   'مدخل',
#   'بيت',
#   'فجار',
#   'مغلق',
#   'الخليل',
#   'مدخل',
#   'قرية',
#   'المنيا',
#   'سالك',
#   'بالاتجاهين',
#   'مدخل',
#   'بربرة',
#   'مغلق',
#   'جورة',
#   'الشمعه',
#   'سالكه',
#   'المنشية',
#   'صفحة',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'مدخل',
#   'الحواور',
#   'بوابة',
#   'سعير',
#   'بوابة',
#   'بيت',
#   'عينون',
#   'مغلقة',
#   'عصيون',
#   'سالك',
#   'دوار',
#   'فرات',
#   'رمزونات',
#   'فرات',
#   'سالكين',
#   'راس',
#   'الجوره',
#   'حاجز',
#   'للخارج',
#   'على',
#   'فرش',
#   'الهوى',
#   'جسر',
#   'حلحول',
#   'طريق',
#   'حسكه',
#   'سالكه',
#   'بوابة',
#   'بلدة',
#   'بيت',
#   'عوا',
#   'مغلقة',
#   'بوابة',
#   'مثلث',
#   'خرسا',
#   'فاتحة',
#   'بوابة',
#   'مستوطنة',
#   'نيجهوت',
#   'مغلقة',
#   'بوابة',
#   'الخطوط',
#   'الغربية',
#   'لمدينة',
#   'دورا',
#   'مغلقة',
#   'بوابة',
#   'بيت',
#   'عوا',
#   'مسكره',
#   'بوابة',
#   'اذنا',
#   'الليه',
#   'بوابة',
#   'زيف',
#   'خلة',
#   'المي',
#   'سالكه',
#   'كرمه',
#   'باتجاه',
#   'يطا',
#   'وكريم',
#   'سالكة',
#   'مدخل',
#   'الظاهرية',
#   'مغلق',
#   'بني',
#   'نعيم',
#   'بوابة',
#   'العروب',
#   'النبي',
#   'يونس',
#   'عش',
#   'غراب',
#   'ترقوميا',
#   'المصانع',
#   'سالكه',
#   'جسر',
#   'بيت',
#   'كاحل',
#   'سالك',
#   'بوابة',
#   'الفحص',
#   'مغلقه',
#   'الرجاء',
#   'من',
#   'الجميع',
#   'يقرأ',
#   'التقرير',
#   'ويضغطاو',
#   'غير',
#   'متواجد',
#   'خاص',
#   'نهائيا',
#   'العقبي'],
#  ['طريق', 'الباذان', 'الفارعة', 'طوباس', 'جنين', 'سالكة'],
#  ['الحمرا', 'ازمة', 'قوية', 'جهة', 'اريحا'],
#  ['تياسير', 'ازمة', 'خفيفة'],
#  ['عند', 'حلميش', 'حاجز', 'تفتيش', 'الهويات'],
#  ['الجيش', 'برجع', 'السيارات', 'عند', 'إشارات', 'بيت', 'ايل'],
#  ['العيزرية', 'مازم'],
#  ['كدميمم', 'سالك', 'مع', 'تواجد', 'الجيش'],
#  ['حاجز',
#   'تفتيش',
#   'على',
#   'الهيئة',
#   'اريحا',
#   'البوابه',
#   'الصفرا',
#   'خط',
#   'الجسر',
#   'سالكة'],
#  ['من', 'ازمه', 'الداخل', 'ع', 'نابلس', 'عن', 'طريق', 'دير', 'شرف'],
#  ['للداخل', 'عالسيلة', 'العكس', 'سالك'],
#  ['بالنسبة',
#   'للمربعة',
#   'ازمة',
#   'ع',
#   'الي',
#   'خارج',
#   'ع',
#   'الي',
#   'فايت',
#   'بسال',
#   'سيارة',
#   'سيارة',
#   'وين',
#   'رايح',
#   'ومن',
#   'هالحكي',
#   'انتبهوا'],
#  ['حاجز', 'ع', 'حومش'],
#  ['بزاريا', 'بحري', 'لا', 'المعني', 'بلفديو', 'في', 'كلام', 'توضيح'],
#  ['حاجز', 'ع', 'مدخل', 'دير', 'نظام'],
#  ['عطارة', 'سالك'],
#  ['سكرو', 'بوابة', 'دير', 'ابو', 'مشعل', 'وبوابة', 'عابود'],
#  ['عورتا',
#   'للداخل',
#   'ازمه',
#   'كف',
#   'والخارج',
#   'لبعد',
#   'كراج',
#   'ابو',
#   'عايش',
#   'اشوي',
#   'وتوصل',
#   'الروضه'],
#  ['حجة', 'والفندق', 'سالكين'],
#  ['حالة',
#   'الطرق',
#   'لبعض',
#   'مداخل',
#   'محافظة',
#   'الخليل',
#   '08',
#   '30',
#   'صباحا',
#   'مدخل',
#   'بلدة',
#   'السموع',
#   'السيميا',
#   'مغلق',
#   'مدخل',
#   'المرمله',
#   'سالك',
#   'مدخل',
#   'بير',
#   'المي',
#   'مغلق',
#   'مدخل',
#   'كرمه',
#   'مغلق',
#   'مدخل',
#   'البقارية',
#   'سالك',
#   'مدخل',
#   'الهجرة',
#   'مغلق',
#   'مدخل',
#   'ابو',
#   'العرقان',
#   'سالك',
#   'مدخل',
#   'العقد',
#   'مغلق',
#   'مدخل',
#   'قريه',
#   'عبده',
#   'مغلق',
#   'مدخل',
#   'طريق',
#   'القصر',
#   'سالك',
#   'مدخل',
#   'يطا',
#   'طريق',
#   'العمور',
#   'سالك',
#   'مدخل',
#   'مدينة',
#   'دورا',
#   'مغلق',
#   'مدخل',
#   'مخيم',
#   'الفوار',
#   'باتجاه',
#   'الالتفافي',
#   'مغلق',
#   'مدخل',
#   'مدينة',
#   'يطا',
#   'زيف',
#   'مغلق',
#   'مدخل',
#   'ترقوميا',
#   'المصانع',
#   'سالك',
#   'مدخل',
#   'الخليل',
#   'رأس',
#   'الجورة',
#   'سالك',
#   'للداخل',
#   'تفتيش',
#   'للخارج',
#   'مدخل',
#   'الخليل',
#   'فرش',
#   'الهوا',
#   'مغلق',
#   'مدخل',
#   'قلقس',
#   'مغلق',
#   'مدخل',
#   'الفحص',
#   'مغلق',
#   'مدخل',
#   'بني',
#   'نعيم',
#   'مغلق'],
#  ['حاجز',
#   'على',
#   'dco',
#   'وازمه',
#   'حاجز',
#   'على',
#   'الهيئه',
#   'وازمه',
#   'البنانا',
#   'مغلق',
#   'البوابه',
#   'صفرا',
#   'حتى',
#   'اللحظة',
#   'سالك',
#   'الداخل',
#   'سالك',
#   'لجميع',
#   'الحواجز'],
#  ['الجلزون', 'أزمة', 'خانقة'],
#  ['حاجز', 'بيت', 'فوريك', 'ازمة', 'بالاتجاهين'],
#  ['المربعة', 'واقفة'],
#  ['مدخل', 'حجة', 'سالك', 'مع', 'تواجد', 'لجيش'],
#  ['مدخل', 'قلقيلة', 'سالك'],
#  ['شارع', '55', 'سالك'],
#  ['الهيئة', 'حاجز', 'للخارج', 'وبداية', 'ازمة'],
#  ['دير', 'شرف', 'ازمة', 'بجميع', 'الاتجاهات'],
#  ['ازمة', 'الطالع', 'من', 'العيزرية', 'للواد'],
#  ['للمسافرين',
#   'على',
#   'طريق',
#   'رام',
#   'الله',
#   'يرجى',
#   'الانتباه',
#   'والأخذ',
#   'بالحسبان',
#   'اي',
#   'اعتداء',
#   'أو',
#   'تشويش',
#   'على',
#   'الطريق'],
#  ['حيث',
#   'ستكون',
#   'جنازة',
#   'لضابط',
#   'في',
#   'مقبرة',
#   'عيلي',
#   'قتل',
#   'في',
#   'الجنوب',
#   'اليوم',
#   'الساعة',
#   '10',
#   'صباحا'],
#  ['الدهيشة',
#   'للي',
#   'داخل',
#   'على',
#   'بيت',
#   'لحم',
#   'أزمة',
#   'الخارج',
#   'سالك',
#   'طريق',
#   'الاسكانات',
#   'سالكه',
#   'بيت',
#   'جالا',
#   'النفق',
#   'ع',
#   'القدس',
#   'سالك',
#   'تواجد',
#   'للشرطة',
#   'على',
#   'أول',
#   'إشارة',
#   'بعد',
#   'النفق'],
#  ['النبي', 'يونس', 'باتجاه', 'حلحول', 'مغلقة', 'باتجاه', 'سعير', 'سالكه'],
#  ['روابي', 'حاجز', 'وتفتيش'],
#  ['طريق', 'ال', '17', 'سالك'],
#  ['اليوم',
#   '6102024',
#   'الاحد',
#   '8',
#   '10',
#   'صباحا',
#   'اللهم',
#   'اجمع',
#   'قلوبنا',
#   'على',
#   'خير',
#   'نابلس',
#   'صرة',
#   'مغلق',
#   'للداخل',
#   'صرة',
#   'مغلق',
#   'للخارج',
#   'شاحنات',
#   'ونمر',
#   'صفراء',
#   'فقط',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'مغلق',
#   'المربعة',
#   'ازمه',
#   'خانقة',
#   'بالاتجاهين',
#   'عورتا',
#   'ازمه',
#   'للخارج',
#   'مفرق',
#   'جيت',
#   'سالك',
#   'حاليا',
#   'الطنيب',
#   'سالك',
#   'حاليا',
#   'دير',
#   'شرف',
#   'من',
#   'الاتجاهات',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'مدخل',
#   'بزاريا',
#   'الرئيسي',
#   'سالك',
#   'طريق',
#   'الغرس',
#   'بزاريا',
#   'سالك',
#   'بيت',
#   'فوريك',
#   'ازمه',
#   'خفيفه',
#   'حوارة',
#   'البلد',
#   'سالكة',
#   'الباذان',
#   'سالك',
#   'بوابة',
#   'جماعين',
#   'سالك',
#   'حوارة',
#   'الالتفافي',
#   'الجديد',
#   'سالك',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'زعترة',
#   'سالك',
#   'بجميع',
#   'الاتجاهات',
#   'طريق',
#   'يتسهار',
#   'سالك',
#   'حاجز',
#   'حواره',
#   'مغلق',
#   'رام',
#   'الله',
#   'ال',
#   'dco',
#   'بيت',
#   'ائيل',
#   'مدخل',
#   'البيرة',
#   'الشمالي',
#   'مغلق',
#   'بفتح',
#   'من',
#   'الساعة',
#   '9',
#   'صباحا',
#   'ولغاية',
#   'الساعة',
#   'ال',
#   '3',
#   'عصرا',
#   'وحسب',
#   'المزاج',
#   'الجلزون',
#   'ازمه',
#   'سير',
#   'مخماس',
#   'سالك',
#   'حاليا',
#   'عين',
#   'سينيا',
#   'سالك',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'عطارة',
#   'سالك',
#   'روابي',
#   'سالك',
#   'جسر',
#   'عطارة',
#   'سالك',
#   'طريق',
#   'رام',
#   'الله',
#   'دير',
#   'بلوط',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'حاليا',
#   'عيلي',
#   'سالك',
#   'حاليا',
#   'سنجل',
#   'سالك',
#   'عوفرا',
#   'سالك',
#   'كرملو',
#   'وسالك',
#   'بوابة',
#   'عابود',
#   'مغلقة',
#   'سالك',
#   'طريق',
#   'عابود',
#   'الجدار',
#   'سالكة',
#   'بوابة',
#   'دير',
#   'ابو',
#   'مشعل',
#   'سالك',
#   'بوابة',
#   'النبي',
#   'صالح',
#   'مغلقة',
#   'سلفيت',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'باتجاه',
#   'بركان',
#   'مغلق',
#   'بوابة',
#   'سلفيت',
#   'سالك',
#   'البديل',
#   'بروقين',
#   'سلفيت',
#   'في',
#   'حال',
#   'بوابة',
#   'سلفيت',
#   'ارئيل',
#   'مغلقة',
#   'سدة',
#   'قراوة',
#   'سالك',
#   'اشارات',
#   'ارائيل',
#   'سالكة',
#   'اشارات',
#   'حارس',
#   'سالكة',
#   'كدوميم',
#   'سالك',
#   'واد',
#   'قانا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'واد',
#   'قانا',
#   'سالك',
#   'بوابة',
#   'كفر',
#   'الديك',
#   'مغلقة',
#   'ياسوف',
#   'سلفيت',
#   'مغلقة',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'كفل',
#   'حارس',
#   'مغلق',
#   'قلقيلية',
#   'الفندق',
#   'حاجز',
#   'عزبة',
#   'الطبيب',
#   'سالك',
#   'كرني',
#   'شمرون',
#   'سالك',
#   'النبي',
#   'الياس',
#   'حاليا',
#   'النفق',
#   'حبلة',
#   'سالك',
#   'بوابة',
#   'كفر',
#   'لاقف',
#   'سالك',
#   'عزون',
#   'الرئيسي',
#   'مغلق',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'طولكرم',
#   'عناب',
#   'مغلق',
#   'باالاتجاهين',
#   'طريق',
#   'الكفريات',
#   'سالك',
#   'جبارة',
#   'تحت',
#   'الجسر',
#   'سالك',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'اللدائن',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'واد',
#   'قانا',
#   'سالك',
#   'بيت',
#   'ليد',
#   'الرئيسي',
#   'مغلق',
#   'مدخل',
#   'رامين',
#   'مغلق',
#   'مدخل',
#   'سفارين',
#   'مغلق',
#   'عزبة',
#   'شوفة',
#   'مغلق',
#   'طريق',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'سهل',
#   'رامين',
#   'مغلق',
#   'جنين',
#   'حومش',
#   'سالك',
#   'مدخل',
#   'بزاريا',
#   'الرئيسي',
#   'سالك',
#   'بزاريا',
#   'الغرس',
#   'سالك',
#   'حاليا',
#   'جبع',
#   'حتى',
#   '١٧',
#   'عصيرة',
#   'نابلس',
#   'سالك',
#   'السيلة',
#   'حتى',
#   'عطارة',
#   'بلعا',
#   'سالك',
#   'دوتان',
#   'مغلق',
#   'حرميش',
#   'مغلق',
#   'طوباس',
#   'لحمرا',
#   'ازمه',
#   'تياسير',
#   'ازمه',
#   'طوباس',
#   'الباذان',
#   'نابلس',
#   'سالك',
#   'اريحا',
#   'الحمرا',
#   'ازمه',
#   'معالي',
#   'افرايم',
#   'سالك',
#   'مع',
#   'تواجد',
#   'الجيش',
#   'خط',
#   '90',
#   'سالك',
#   'حاليا',
#   'المعرجات',
#   'سالك',
#   'حاليا',
#   'ال',
#   'DCO',
#   'سالك',
#   'البوابة',
#   'الصفراء',
#   'حاجز',
#   'الهيئة',
#   'حاجز',
#   'حاجز',
#   'البنانا',
#   'مغلق',
#   'وضع',
#   'الطريق',
#   'متغير',
#   'بين',
#   'لحظة',
#   'واخرى',
#   'طريق',
#   'السلامة',
#   'للجميع',
#   'وضع',
#   'الطريق',
#   'متغير',
#   'في',
#   'لحظات',
#   'صفحه',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'من',
#   'موقعنا',
#   'على',
#   'التلجرام',
#   'إن',
#   'الله',
#   'وملائكته',
#   'يصلون',
#   'على',
#   'النبي',
#   'يا',
#   'أيها',
#   'الذين',
#   'آمنوا',
#   'صلوا',
#   'عليه',
#   'وسلموا',
#   'تسليما',
#   'اخوكم',
#   'سامر',
#   'ياسين',
#   'والمشرف',
#   'جميل'],
#  ['اسعد',
#   'الله',
#   'صباحكم',
#   'قال',
#   'الله',
#   'تعالى',
#   'من',
#   'ذا',
#   'الذي',
#   'يقرض',
#   'الله',
#   'قرضا',
#   'حسنا',
#   'فيضاعفه',
#   'له',
#   'وله',
#   'أجر',
#   'كريم',
#   'صفحة',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'منطقة',
#   'ضواحي',
#   'القدس',
#   'قلنديا',
#   'ازمه',
#   'كفر',
#   'عقب',
#   'ازمة',
#   'جبع',
#   'سالك',
#   'حزما',
#   'سالك',
#   'عناتا',
#   'سالك',
#   'الزعيم',
#   'سالك',
#   'طريق',
#   'معالي',
#   'ادوميم',
#   'سالك',
#   'العيزرية',
#   'ازمة',
#   'خانقة',
#   'الكونتينر',
#   'سالك',
#   'منطقة',
#   'بيت',
#   'لحم',
#   'العبيدية',
#   'سالكة',
#   'جسر',
#   'بيت',
#   'ساحور',
#   'مغلق',
#   'تقوع',
#   'البلد',
#   'تل',
#   'الربيع',
#   'سالكه',
#   'الترابيه',
#   'بوابة',
#   'جناتا',
#   'مغلقه',
#   'النشاش',
#   'فاتح',
#   'طريق',
#   'السدر',
#   'فاتحه',
#   'زعتره',
#   'بيت',
#   'لحم',
#   'مغلق',
#   'مدخل',
#   'بيت',
#   'فجار',
#   'مغلق',
#   'الخليل',
#   'مدخل',
#   'قرية',
#   'المنيا',
#   'سالك',
#   'بالاتجاهين',
#   'مدخل',
#   'بربرة',
#   'مغلق',
#   'جورة',
#   'الشمعه',
#   'المنشيه',
#   'صفحة',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'مدخل',
#   'الحواور',
#   'بوابة',
#   'سعير',
#   'بوابة',
#   'بيت',
#   'عينون',
#   'مغلقة',
#   'عصيون',
#   'سالك',
#   'دوار',
#   'فرات',
#   'رمزونات',
#   'فرات',
#   'سالكين',
#   'راس',
#   'الجوره',
#   'فرش',
#   'الهوى',
#   'جسر',
#   'حلحول',
#   'طريق',
#   'حسكه',
#   'سالكه',
#   'بوابة',
#   'بلدة',
#   'بيت',
#   'عوا',
#   'مغلقة',
#   'بوابة',
#   'مثلث',
#   'خرسا',
#   'فاتحة',
#   'بوابة',
#   'مستوطنة',
#   'نيجهوت',
#   'مغلقة',
#   'بوابة',
#   'الخطوط',
#   'الغربية',
#   'لمدينة',
#   'دورا',
#   'مغلقة',
#   'بوابة',
#   'بيت',
#   'عوا',
#   'مسكره',
#   'بوابة',
#   'اذنا',
#   'الليه',
#   'كرمه',
#   'باتجاه',
#   'يطا',
#   'مدخل',
#   'الظاهرية',
#   'مغلق',
#   'بني',
#   'نعيم',
#   'بوابة',
#   'العروب',
#   'النبي',
#   'يونس',
#   'عش',
#   'غراب',
#   'سالك',
#   'ترقوميا',
#   'المصانع',
#   'الطريق',
#   'الترابيه',
#   'في',
#   'حال',
#   'عدم',
#   'تواجد',
#   'جيش',
#   'سالكه',
#   'جسر',
#   'بيت',
#   'كاحل',
#   'سالك',
#   'الرجاء',
#   'من',
#   'الجميع',
#   'يقرأ',
#   'التقرير',
#   'ويضغطاو',
#   'غير',
#   'متواجد',
#   'خاص',
#   'نهائيا',
#   'العقبي'],
#  ['كرمة', 'مغلق'],
#  ['بيت', 'ليد', 'اللدائن', 'حاجز', 'للخارج', 'من', 'بيت', 'ليد', 'و', 'أزمة'],
#  ['الآن', 'فتح', 'السير', 'للخارج', 'من', 'دير', 'شرف', 'لاكن', 'ببطئ'],
#  ['المربعة', 'الان'],
#  ['الزعيم', 'سالك'],
#  ['الداخل', 'على', 'العيزرية', 'وقوف', 'تام'],
#  ['الحمرا', 'الان'],
#  ['مدخل', 'قلقيلة', 'سالك'],
#  ['المربعة',
#   'عورتا',
#   'دير',
#   'شرف',
#   'الحمراا',
#   'ازمة',
#   'خانقةة',
#   'جداا',
#   'للخارج',
#   'من',
#   'نابلس'],
#  ['جسر',
#   'حلحول',
#   'فاتح',
#   'جهة',
#   'وحدة',
#   'للطالع',
#   'من',
#   'حلحول',
#   'بس',
#   'للداخل',
#   'السيارات',
#   'بتدخل',
#   'عكس',
#   'السير',
#   'عادي'],
#  ['حاجز',
#   'عمدخل',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'بعدو',
#   'موجود',
#   'وفي',
#   'ناس',
#   'الها',
#   'ساعة',
#   'تقريبا'],
#  ['العيزرية', 'فتح', 'الحاجز', 'لكن', 'أزمة', 'قوية'],
#  ['حاجز', 'للداخل', 'على', 'يتسهار', 'مع', 'تفتيش', 'عشوائي'],
#  ['من',
#   'ازمة',
#   'دير',
#   'شرف',
#   'للخارج',
#   'لقصر',
#   'الاحلام',
#   'ازمة',
#   'مش',
#   'طبيعية'],
#  ['حاجز', 'الحمرا', 'ازمة', 'لبعد', 'بركة', 'المي'],
#  ['بوابة',
#   'بروقين',
#   'سالكة',
#   'بوابة',
#   'كفر',
#   'الديك',
#   'مغلقة',
#   'مفرق',
#   'دير',
#   'بلوط',
#   'سالك',
#   'خط',
#   'دير',
#   'بلوط',
#   'اللبن',
#   'سالك'],
#  ['أزمة', 'دير', 'شرف', 'للداخل'],
#  ['اكم',
#   'قلب',
#   'يستاهل',
#   'منكم',
#   'ما',
#   'تبخلوا',
#   'علينا',
#   'بقلب',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'يتسهار',
#   'سالك',
#   'صرة',
#   'مغلق',
#   'للخارج',
#   'شاحنات',
#   'ونمر',
#   'صفراء',
#   'زعترا',
#   'سالك',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'مغلق',
#   'التفافي',
#   'زواتا',
#   'سالك',
#   'المربعه',
#   'ازمه',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'دير',
#   'شرف',
#   'ازمه',
#   'مع',
#   'كثافة',
#   'سير',
#   'عورتا',
#   'ازمه',
#   'للهارج',
#   'بيت',
#   'فوريك',
#   'سالك',
#   'بزاريا',
#   'الرئيسي',
#   'سالك',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'حومش',
#   'سالك',
#   'عناب',
#   'مغلق',
#   'بالاتجاهين',
#   'اليوم',
#   'التاسع',
#   'ع',
#   'التوالي',
#   'الكفريات',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'تواجد',
#   'الجيش',
#   'إشارات',
#   'حارس',
#   'سالك',
#   'طريق',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'سالك',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'حاجز',
#   'الحمرا',
#   'ازمه',
#   'عوفرا',
#   'سالك',
#   'اارئيل',
#   'سلفيت',
#   'سالك',
#   'خط',
#   'رام',
#   'الله',
#   'نابلس',
#   'سالك',
#   'عين',
#   'سينا',
#   'سالك',
#   'عطارة',
#   'سالك',
#   'عطاره',
#   'فوق',
#   'الجسر',
#   'سالك',
#   'روابي',
#   'سالك',
#   'اشارات',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'سنجل',
#   'مغلق',
#   'سنجل',
#   'المدخل',
#   'الشمالي',
#   'سالك',
#   'شيلو',
#   'سالك',
#   'عيلي',
#   'سالك',
#   'عيون',
#   'الحراميه',
#   'سالك',
#   'بيت',
#   'ايل',
#   'مغلق',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'تحت',
#   'جسر',
#   'جباره',
#   'سالك',
#   'جماعين',
#   'ساالك',
#   'بوابة',
#   'كفل',
#   'حارس'],
#  ['شارع', '55', 'سالك', 'مع', 'تواجد', 'لسيارة', 'شرطة'],
#  ['مغلق',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'مردا',
#   'الشرقيه',
#   'سالك',
#   'بديا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'مدخل',
#   'مردا',
#   'الغربي',
#   'سالك'],
#  ['ازمة', 'الحمرا'],
#  ['اربع', 'خمس', 'سيارات', 'شرطة', 'ع', 'رمزون', 'رامي', 'ليفي'],
#  ['دير',
#   'شرف',
#   'من',
#   'أكثر',
#   'من',
#   'عشر',
#   'دقائق',
#   'السير',
#   'واقف',
#   'وقوف',
#   'تام'],
#  ['حاجز', 'الهيئة', 'سالك', 'تمااما'],
#  ['حاجز', 'الحمرا', 'ازمة', 'للخااارج'],
#  ['المربعة', 'ازمة', 'بالاتجاهين'],
#  ['تفتيش', 'سيارات', 'عشوائي', 'ع', 'دوار', 'قدوميم'],
#  ['المربعة', 'حدث', 'ولا', 'حرج'],
#  ['ازمة', 'ماشية', 'حجة'],
#  ['حجة', 'الفندق', 'سالك'],
#  ['الحمدلله',
#   'بعد',
#   'ساعتين',
#   'في',
#   'الازمه',
#   'طلعنا',
#   'من',
#   'العيزرية',
#   'قرف',
#   'عكس',
#   'السير',
#   'غير',
#   'قرف',
#   'الجيش'],
#  ['معالي', 'افرايم', 'فش', 'عليه', 'حدا', 'بس', 'ازمه', 'سير', 'خفيفه'],
#  ['العبيدية',
#   'كثافة',
#   'سير',
#   'وطلاب',
#   'نرجو',
#   'التروي',
#   'من',
#   'الاوكتافيا',
#   'والكادي'],
#  ['من',
#   'ساعة',
#   'ولا',
#   'متر',
#   'مشي',
#   'السير',
#   'العيزرية',
#   '٦',
#   'مسالك',
#   'للخارج'],
#  ['طبعا', 'عورتا', 'للخارج', 'الازمة', 'لشارع', 'روجيب'],
#  ['من', 'راس', 'جورة', 'حتى', 'عش', 'غراب', 'سالك'],
#  ['كثافة', 'سير', 'ترمسعيا', 'سنجل'],
#  ['عورتا',
#   'سالك',
#   'ل',
#   'الداخل',
#   'وفش',
#   'ولا',
#   'سيارة',
#   'وازمة',
#   'مع',
#   'تفتيش',
#   'السيارات',
#   'والهويات',
#   'ل',
#   'الي',
#   'خارج',
#   'من',
#   'نابلس'],
#  ['دير', 'شرف', 'ازمة', 'للخارج'],
#  ['عورتاا', 'ازمة', 'للخارج', 'من', 'نابلس'],
#  ['جبارة', 'سالك'],
#  ['الجلزون', 'أزمة', 'ماشية', 'حاليا'],
#  ['تياسير', 'سالك'],
#  ['اللدائن', 'حاجز', 'مع', 'تفتيش'],
#  ['حجة', 'حاجز', 'وسط', 'البلد', 'يقوم', 'بتفتيش', 'المركبات'],
#  ['تواجد', 'جنود', 'وجيبات', 'دون', 'تفتيش', 'قبل'],
#  ['راس', 'الجورة', 'فاتح', 'بالاتجاهين'],
#  ['عين', 'سينا', 'سالك', 'بالاتجاهين'],
#  ['عقابا',
#   'تواجد',
#   'الجيش',
#   'للي',
#   'رايح',
#   'عجنين',
#   'البديل',
#   'من',
#   'القرى',
#   'الجديدة',
#   'سهل',
#   'الكفير',
#   'الزبابدة',
#   'سالكة'],
#  ['راس', 'الجوره', 'فتح', 'لا', 'الداخل', 'الان'],
#  ['حزما', 'ازمة', 'ماشيه'],
#  ['نزول', 'جفنا'],
#  ['نزول',
#   'شافي',
#   'شمرون',
#   'بتجاه',
#   'دير',
#   'شرف',
#   'طبعا',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'بدون',
#   'تواجد',
#   'الجيش'],
#  ['عش', 'الغراب', 'سالك'],
#  ['الخروج', 'من', 'الخليل', 'عن', 'طريق', 'ترقوميا'],
#  ['جبع', 'فاضي', 'وسالك', 'وما', 'في', 'عليه', 'سير'],
#  ['صباح',
#   'الخير',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'جيش',
#   'بفتشو',
#   'بفحصو',
#   'ع',
#   'الهويات'],
#  ['دير', 'شرف', 'فتح', 'الحاجز', 'حاليا', 'مع', 'وجود', 'أزمة', 'قوية'],
#  ['جبع', 'سالك', 'ونظيف', 'مع', 'كثافة', 'سير', 'ماشيه'],
#  ['قلنديا', 'وكفر', 'عقب', 'شبه', 'سالكات'],
#  ['زعتره', 'سالكه', 'بجميع', 'الاتجاهات'],
#  ['عناب', 'مغلق', 'بيت', 'ليد', 'المصانع', 'سالكه'],
#  ['من', 'اشارات', 'شيلو', 'باتجاه', 'ترمسعيا', 'ازمة'],
#  ['بزاريا', 'سالك', 'تماما', 'حومش', 'سالك', 'تماما', 'شافي', 'شمرون', 'سالك'],
#  ['دوار',
#   'الطنيب',
#   'سالك',
#   'مفرق',
#   'جيت',
#   'سالك',
#   'خط',
#   'يتسهار',
#   'سالك',
#   'صره',
#   'مغلق',
#   'بالاتجاهين'],
#  ['دير',
#   'شرف',
#   'ازمه',
#   'خانقة',
#   'لداخل',
#   'والخارج',
#   'والي',
#   'نازل',
#   'من',
#   'شافي',
#   'شمرون'],
#  ['Dso', 'اريحا', 'سالك', 'بالاتجاهين'],
#  ['جبارة', 'سالك'],
#  ['العيزريه', 'الازمه', 'واصله', 'مدخل', 'ابوديس', 'من', 'تحت'],
#  ['الوضع', 'كارثي', 'بمعنى', 'الكلمه'],
#  ['العيزرية'],
#  ['جبع', 'سالك'],
#  ['كرمه', 'مغلقه'],
#  ['دورا', 'مغلقة', 'الفحص', 'مغلقة', 'عش', 'الغراب', 'سالك', 'عبدة', 'مغلقة'],
#  ['المربعة', 'وقوف', 'تام', 'من', 'ساعه', 'يا', 'دوب', 'مرق', 'سيارتين'],
#  ['حال', 'العيزرية', 'الان'],
#  ['دير', 'شرف', 'من', 'الاتجاهات'],
#  ['العيزرية', 'للخارج'],
#  ['العيزريه', 'ازمه', 'واقفه', 'للخارج'],
#  ['جميع',
#   'حواجز',
#   'نابلس',
#   'ازمه',
#   'خانقة',
#   'دير',
#   'شرف',
#   'عورتا',
#   'المربعة',
#   'والحمرا'],
#  ['الكونتير', 'سالك', 'بالاتجاهين'],
#  ['العيزريه', 'لشمال'],
#  ['صباح', 'الخير'],
#  ['المدخل',
#   'الجنوبي',
#   'سالك',
#   'بكلا',
#   'الاتجاهين',
#   'البوابة',
#   'الصفرا',
#   'سالك',
#   'بكلا',
#   'الاتجاهين',
#   'حاجز',
#   'الهيئة',
#   'سالك',
#   'حاجز',
#   'البنانا',
#   'مغلق',
#   'الحمرا',
#   'باتجاه',
# ...
#   'واد',
#   'قانا',
#   'سالك',
#   'بوابة',
#   'كفر',
#   'الديك',
#   'مغلقة',
#   'ياسوف',
#   'سلفيت',
#   'مغلقة',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'كفل',
#   'حارس',
#   'سالك',
#   'قلقيلية',
#   'الفندق',
#   'حاجز',
#   'عزبة',
#   'الطبيب',
#   'سالك',
#   'كرني',
#   'شمرون',
#   'سالك',
#   'النبي',
#   'الياس',
#   'حاليا',
#   'النفق',
#   'حبلة',
#   'سالك',
#   'بوابة',
#   'كفر',
#   'لاقف',
#   'سالك',
#   'عزون',
#   'الرئيسي',
#   'مغلق',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'طولكرم',
#   'عناب',
#   'مغلق',
#   'باالاتجاهين',
#   'طريق',
#   'الكفريات',
#   'سالك',
#   'جبارة',
#   'تحت',
#   'الجسر',
#   'سالك',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'اللدائن',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'واد',
#   'قانا',
#   'سالك',
#   'بيت',
#   'ليد',
#   'الرئيسي',
#   'مغلق',
#   'مدخل',
#   'رامين',
#   'مغلق',
#   'مدخل',
#   'سفارين',
#   'مغلق',
#   'عزبة',
#   'شوفة',
#   'مغلق',
#   'طريق',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'سهل',
#   'رامين',
#   'مغلق',
#   'جنين',
#   'حومش',
#   'سالك',
#   'مدخل',
#   'بزاريا',
#   'الرئيسي',
#   'سالك',
#   'بزاريا',
#   'الغرس',
#   'سالك',
#   'حاليا',
#   'جبع',
#   'حتى',
#   '١٧',
#   'عصيرة',
#   'نابلس',
#   'سالك',
#   'السيلة',
#   'حتى',
#   'عطارة',
#   'بلعا',
#   'سالك',
#   'دوتان',
#   'مغلق',
#   'حرميش',
#   'مغلق',
#   'طوباس',
#   'لحمرا',
#   'ازمه',
#   'وبمشي',
#   'تياسير',
#   'ازمه',
#   'طوباس',
#   'الباذان',
#   'نابلس',
#   'سالك',
#   'اريحا',
#   'الحمرا',
#   'ازمه',
#   'وبمشي',
#   'معالي',
#   'افرايم',
#   'سالك',
#   'خط',
#   '90',
#   'سالك',
#   'حاليا',
#   'المعرجات',
#   'سالك',
#   'حاليا',
#   'ال',
#   'DCO',
#   'سالك',
#   'البوابة',
#   'الصفراء',
#   'حاجز',
#   'الهيئة',
#   'حاجز',
#   'حاجز',
#   'البنانا',
#   'حاجز',
#   'وضع',
#   'الطريق',
#   'متغير',
#   'بين',
#   'لحظة',
#   'واخرى',
#   'طريق',
#   'السلامة',
#   'للجميع',
#   'وضع',
#   'الطريق',
#   'متغير',
#   'في',
#   'لحظات',
#   'صفحه',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'من',
#   'موقعنا',
#   'على',
#   'التلجرام',
#   'إن',
#   'الله',
#   'وملائكته',
#   'يصلون',
#   'على',
#   'النبي',
#   'يا',
#   'أيها',
#   'الذين',
#   'آمنوا',
#   'صلوا',
#   'عليه',
#   'وسلموا',
#   'تسليما',
#   'اخوكم',
#   'سامر',
#   'ياسين',
#   'والمشرف',
#   'جميل'],
#  ['اسعد',
#   'الله',
#   'صباحكم',
#   'قال',
#   'تعالى',
#   'وما',
#   'تقدموا',
#   'لأنفسكم',
#   'من',
#   'خير',
#   'تجدوه',
#   'عند',
#   'الله',
#   'هو',
#   'خيرا',
#   'وأعظم',
#   'أجرا',
#   'واستغفروا',
#   'الله',
#   'إن',
#   'الله',
#   'غفور',
#   'رحيم',
#   'صفحة',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'منطقة',
#   'ضواحي',
#   'القدس',
#   'قلنديا',
#   'سالكه',
#   'كفر',
#   'عقب',
#   'سالك',
#   'جبع',
#   'سالك',
#   'حزما',
#   'سالك',
#   'عناتا',
#   'سالك',
#   'الزعيم',
#   'ازمه',
#   'طريق',
#   'معالي',
#   'ادوميم',
#   'سالك',
#   'العيزرية',
#   'سالكه',
#   'الكونتينر',
#   'سالك',
#   'منطقة',
#   'بيت',
#   'لحم',
#   'العبيدية',
#   'سالكة',
#   'قبر',
#   'حلوه',
#   'فاتح',
#   'تقوع',
#   'البلد',
#   'تل',
#   'الربيع',
#   'سالكه',
#   'الترابيه',
#   'بوابة',
#   'جناتا',
#   'مغلقه',
#   'النشاش',
#   'فاتح',
#   'طريق',
#   'السدر',
#   'فاتحه',
#   'زعتره',
#   'بيت',
#   'لحم',
#   'مغلق',
#   'مدخل',
#   'بيت',
#   'فجار',
#   'مغلق',
#   'الخليل',
#   'مدخل',
#   'قرية',
#   'المنيا',
#   'سالك',
#   'بالاتجاهين',
#   'مدخل',
#   'بربرة',
#   'مغلق',
#   'جورة',
#   'الشمعه',
#   'المنشية',
#   'صفحة',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'مدخل',
#   'الحواور',
#   'بوابة',
#   'سعير',
#   'بوابة',
#   'بيت',
#   'عينون',
#   'مغلقة',
#   'عصيون',
#   'سالك',
#   'دوار',
#   'فرات',
#   'رمزونات',
#   'فرات',
#   'سالكين',
#   'راس',
#   'الجوره',
#   'فرش',
#   'الهوى',
#   'مغلق',
#   'الخارج',
#   'مغلق',
#   'جسر',
#   'حلحول',
#   'طريق',
#   'حسكه',
#   'سالكه',
#   'بوابة',
#   'بلدة',
#   'بيت',
#   'عوا',
#   'مغلقة',
#   'بوابة',
#   'مثلث',
#   'خرسا',
#   'فاتحة',
#   'بوابة',
#   'مستوطنة',
#   'نيجهوت',
#   'مغلقة',
#   'بوابة',
#   'الخطوط',
#   'الغربية',
#   'لمدينة',
#   'دورا',
#   'مغلقة',
#   'بوابة',
#   'بيت',
#   'عوا',
#   'مسكره',
#   'بوابة',
#   'اذنا',
#   'الليه',
#   'كرمه',
#   'باتجاه',
#   'يطا',
#   'مدخل',
#   'الظاهرية',
#   'مغلق',
#   'بني',
#   'نعيم',
#   'بوابة',
#   'العروب',
#   'النبي',
#   'يونس',
#   'عش',
#   'غراب',
#   'سالك',
#   'ترقوميا',
#   'فاتحه',
#   'للخارج',
#   'عبده',
#   'ابو',
#   'العرقان',
#   'جسر',
#   'بيت',
#   'كاحل',
#   'سالك',
#   'القصر',
#   'الرجاء',
#   'من',
#   'الجميع',
#   'يقرأ',
#   'التقرير',
#   'ويضغطاو',
#   'غير',
#   'متواجد',
#   'خاص',
#   'نهائيا',
#   'العقبي'],
#  ['دير', 'شرف', 'الأن', 'سالك'],
#  ['دير', 'شرف', 'سالك', 'بحري'],
#  ['حاجز', 'ع', 'الهيئة'],
#  ['الحمرا', 'وضعوا', 'سيء', 'جدا', 'الأزمة', 'قطعت', 'الكوربة', 'الثانية'],
#  ['حاجز', 'بيت', 'فوريك', 'سالك', 'بالاتجاهين'],
#  ['راس', 'الجورة', 'مغلق', 'حتى', 'ممنوع', 'المرور', 'سيرا', 'مشي', 'ممنوع'],
#  ['اذا',
#   'حدا',
#   'موجود',
#   'ع',
#   'حاجز',
#   'الحمرا',
#   'يتواصل',
#   'معي',
#   'لا',
#   'الضروره'],
#  ['عورتا', 'الازمة', 'تقريبا', 'لمفرق', 'روجيب'],
#  ['اكم',
#   'قلب',
#   'يستاهل',
#   'منكم',
#   'ما',
#   'تبخلوا',
#   'علينا',
#   'بقلب',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'يتسهار',
#   'سالك',
#   'صرة',
#   'مغلق',
#   'للخارج',
#   'شاحنات',
#   'ونمر',
#   'صفراء',
#   'زعترا',
#   'سالك',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'مغلق',
#   'التفافي',
#   'زواتا',
#   'سالك',
#   'المربعه',
#   'ازمه',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'دير',
#   'شرف',
#   'ازمه',
#   'عورتا',
#   'ازمه',
#   'للهارج',
#   'بيت',
#   'فوريك',
#   'سالك',
#   'بزاريا',
#   'الرئيسي',
#   'سلك',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'حومش',
#   'سالك',
#   'عناب',
#   'مغلق',
#   'بالاتجاهين',
#   'اليوم',
#   'الثامن',
#   'ع',
#   'التوالي',
#   'الكفريات',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'تواجد',
#   'الجيش',
#   'إشارات',
#   'حارس',
#   'سالك',
#   'طريق',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'سالك',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'حاجز',
#   'الحمرا',
#   'ازمه',
#   'خفيفه',
#   'عوفرا',
#   'سالك',
#   'اارئيل',
#   'سلفيت',
#   'سالك',
#   'خط',
#   'رام',
#   'الله',
#   'نابلس',
#   'سالك',
#   'عين',
#   'سينا',
#   'سالك',
#   'عطارة',
#   'سالك',
#   'عطاره',
#   'فوق',
#   'الجسر',
#   'سالك',
#   'روابي',
#   'سالك',
#   'اشارات',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'سنجل',
#   'مغلق',
#   'سنجل',
#   'المدخل',
#   'الشمالي',
#   'سالك',
#   'شيلو',
#   'سالك',
#   'عيلي',
#   'سالك',
#   'عيون',
#   'الحراميه',
#   'سالك',
#   'بيت',
#   'ايل',
#   'مغلق',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'تحت',
#   'جسر',
#   'جباره',
#   'سالك',
#   'جماعين',
#   'سالك',
#   'بوابة',
#   'كفل',
#   'حارس'],
#  ['سالك',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'مردا',
#   'الشرقيه',
#   'سالك',
#   'بديا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'مدخل',
#   'مردا',
#   'الغربي',
#   'سالك',
#   'جبع',
#   'سالك',
#   'متواجد',
#   'معكم',
#   'عالخاص',
#   'لا',
#   'تحديث',
#   'أو',
#   'استفسار'],
#  ['حالة',
#   'الطرق',
#   'لمحافظة',
#   'الخليل',
#   'وبعض',
#   'مناطق',
#   'الجنوب',
#   'مدخل',
#   'الخليل',
#   'فرش',
#   'الهوا',
#   'مغلق',
#   'مدخل',
#   'الخليل',
#   'الشمالي',
#   'رأس',
#   'الجورة',
#   'مغلق',
#   'مدخل',
#   'ترقوميا',
#   'المصانع',
#   'مدخل',
#   'الفحص',
#   'مغلق',
#   'مدخل',
#   'بني',
#   'نعيم',
#   'مغلق',
#   'مدخل',
#   'بيت',
#   'كاحل',
#   'سالك',
#   'مدخل',
#   'جسر',
#   'حلحول',
#   'سالك',
#   'مدخل',
#   'قلقس',
#   'مغلق',
#   'مدخل',
#   'مدينة',
#   'اذنا',
#   'الليه',
#   'مغلق',
#   'مدخل',
#   'بيت',
#   'عوا',
#   'مغلق',
#   'مدخل',
#   'الخليل',
#   'الجنوبي',
#   'حجاي',
#   'مغلق',
#   'مدخل',
#   'مخيم',
#   'الفوار',
#   'باتجاه',
#   'دورا',
#   'مغلق',
#   'حاجز',
#   'الكونتينر',
#   'سالك',
#   'مدخل',
#   'واد',
#   'الشاجنة',
#   'باتجاه',
#   'الالتفافي',
#   'مغلق',
#   'مدخل',
#   'الظاهرية',
#   'باتجاه',
#   'الالتفافي',
#   'مغلق',
#   'بوابات',
#   'سعير',
#   '؛',
#   'الحواور',
#   '؛',
#   'النبي',
#   'يونس؛',
#   'العروب',
#   'مغلقه',
#   'مدخل',
#   'بلدة',
#   'السموع',
#   'السيميا',
#   'مغلق',
#   'مدخل',
#   'كرمه',
#   'سالك',
#   'مدخل',
#   'البقارية',
#   'سالك',
#   'مدخل',
#   'بير',
#   'المي',
#   'سالك',
#   'مدخل',
#   'قريه',
#   'عبده',
#   'مغلق',
#   'مدخل',
#   'ابو',
#   'العرقان',
#   'سالك',
#   'مدخل',
#   'الهجرة',
#   'مغلق',
#   'مدخل',
#   'مدينة',
#   'دورا',
#   'مغلق',
#   'مدخل',
#   'العقد',
#   'سالك',
#   'مدخل',
#   'مدينة',
#   'يطا',
#   'زيف',
#   'مغلق',
#   'مدخل',
#   'مدينة',
#   'يطا',
#   'العمور',
#   'سالك',
#   'ملاحظة',
#   'حالة',
#   'الطرق',
#   'تتغير',
#   'بأي',
#   'لحظه'],
#  ['حاجز',
#   'بيت',
#   'فوريك',
#   'مغلق',
#   'في',
#   'كلا',
#   'الاتجاهين',
#   'مع',
#   'اغلاق',
#   'البوابة'],
#  ['دير', 'شرف', 'الان', 'ازمه', 'وبمشي'],
#  ['عورتا', 'ازمه', 'للخارج'],
#  ['جباره', 'سالك'],
#  ['مداخل', 'اريحا', 'بشكل', 'عام', 'سالكات'],
#  ['ترقوميا', 'حاليا', 'عليها', 'جيش'],
#  ['الفحص', 'مغلق'],
#  ['راس', 'الجوره', 'مغلق', 'فرش', 'الهوى', 'مغلق'],
#  ['الكونتينر', 'سالك'],
#  ['الطريق', 'الرئيسيه', 'للخليل', 'قرب', 'جسر', 'دار', 'صلاح'],
#  ['ما',
#   'بنصحح',
#   'حد',
#   'يوصل',
#   'المنطقة',
#   'الشرقية',
#   'لمدينة',
#   'نابلس',
#   'اقتحامها',
#   'مستمر',
#   'الي',
#   'بدو',
#   'يطلع',
#   'يروح',
#   'ع',
#   'دير',
#   'شرف',
#   'او',
#   'لمربعة',
#   'ولمتابعة',
#   'الاقتحام',
#   'https',
#   't',
#   'merassd'],
#  ['اكم',
#   'قلب',
#   'يستاهل',
#   'منكم',
#   'ما',
#   'تبخلوا',
#   'علينا',
#   'بقلب',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'يتسهار',
#   'سالك',
#   'صرة',
#   'مغلق',
#   'للخارج',
#   'شاحنات',
#   'ونمر',
#   'صفراء',
#   'زعترا',
#   'سالك',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'مغلق',
#   'التفافي',
#   'زواتا',
#   'سالك',
#   'المربعه',
#   'بداية',
#   'ازمه',
#   'خفيفه',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'دير',
#   'شرف',
#   'ازمه',
#   'خفيفه',
#   'وماشيه',
#   'وسالكه',
#   'عورتا',
#   'ازمه',
#   'للهارج',
#   'بيت',
#   'فوريك',
#   'سالك',
#   'بزاريا',
#   'الرئيسي',
#   'سلك',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'حومش',
#   'سالك',
#   'عناب',
#   'مغلق',
#   'بالاتجاهين',
#   'اليوم',
#   'الثامن',
#   'ع',
#   'التوالي',
#   'الكفريات',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'تواجد',
#   'الجيش',
#   'إشارات',
#   'حارس',
#   'سالك',
#   'طريق',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'سالك',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'حاجز',
#   'الحمرا',
#   'ازمه',
#   'خفيفه',
#   'عوفرا',
#   'سالك',
#   'اارئيل',
#   'سلفيت',
#   'سالك',
#   'خط',
#   'رام',
#   'الله',
#   'نابلس',
#   'سالك',
#   'عين',
#   'سينا',
#   'سالك',
#   'عطارة',
#   'سالك',
#   'عطاره',
#   'فوق',
#   'الجسر',
#   'سالك',
#   'روابي',
#   'سالك',
#   'اشارات',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'سنجل',
#   'مغلق',
#   'سنجل',
#   'المدخل',
#   'الشمالي',
#   'سالك',
#   'شيلو',
#   'سالك',
#   'عيلي',
#   'سالك',
#   'عيون',
#   'الحراميه',
#   'سالك',
#   'بيت',
#   'ايل',
#   'مغلق',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'تحت',
#   'جسر',
#   'جباره',
#   'سالك',
#   'جماعين',
#   'سالك',
#   'بوابة',
#   'كفل',
#   'حارس'],
#  ['سالك',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'مردا',
#   'الشرقيه',
#   'سالك',
#   'بديا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'مدخل',
#   'مردا',
#   'الغربي',
#   'سالك',
#   'جبع',
#   'سالك',
#   'الكونتير',
#   'سالك',
#   'عش',
#   'الغراب',
#   'سالك',
#   'قلنديا',
#   'وكفر',
#   'عقب',
#   'سالك',
#   'العيزرية',
#   'سالك',
#   'مدخل',
#   'ترقوميا',
#   'المصانع',
#   'سالكه'],
#  ['العيزرية', 'سالك', 'قلنديا', 'سالك', 'جبع', 'حزما', 'سالك'],
#  ['المربعة', 'سالك', 'مع', 'تواجد', 'الجيش'],
#  ['عورتا', 'سالك', 'لداخل', 'الخارج', 'ازمه', 'متوسطه'],
#  ['حومش', 'بزاريا', 'سالك'],
#  ['الكونتير', 'سالك'],
#  ['الفارعه', 'حاجز'],
#  ['بوابة', 'بيت', 'ساحور', 'فاتحه', 'عش', 'الغراب', 'سالك'],
#  ['مدخل', 'ومخرج', 'الخليل', 'حاليا', 'ترقوميا'],
#  ['من', 'أحب', 'أن', 'تسره', 'صحيفته', 'فليكثر', 'فيها', 'من', 'الاستغفار'],
#  ['دير',
#   'شرف',
#   'سالك',
#   'للخارج',
#   'فقط',
#   'عليه',
#   'ازمه',
#   'من',
#   'جهة',
#   'شافي',
#   'شمرون'],
#  ['صباح', 'الخير'],
#  ['صباح',
#   'الخير',
#   'اللهم',
#   'اجبر',
#   'كسرنا',
#   'وعجل',
#   'نصرنا',
#   'وشافي',
#   'المريض',
#   'منا',
#   'وارحم',
#   'ضعفنا',
#   'وارحم',
#   'امواتنا',
#   'واموات',
#   'المسلمين'],
#  ['اكم',
#   'قلب',
#   'يستاهل',
#   'منكم',
#   'ما',
#   'تبخلوا',
#   'علينا',
#   'بقلب',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'يتسهار',
#   'سالك',
#   'صرة',
#   'مغلق',
#   'للخارج',
#   'شاحنات',
#   'ونمر',
#   'صفراء',
#   'زعترا',
#   'سالك',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'عصيرة',
#   'سالك',
#   'عصيرة',
#   'المساكن',
#   'مغلق',
#   'التفافي',
#   'زواتا',
#   'سالك',
#   'المربعه',
#   'سالك',
#   'بوابة',
#   'بورين',
#   'سالك',
#   'دير',
#   'شرف',
#   'شفت',
#   'سئ',
#   'مزاجي',
#   'عورتا',
#   'سالك',
#   'بيت',
#   'فوريك',
#   'سالك',
#   'بزاريا',
#   'الرئيسي',
#   'سلك',
#   'شافي',
#   'شمرون',
#   'سالك',
#   'حومش',
#   'سالك',
#   'عناب',
#   'مغلق',
#   'بالاتجاهين',
#   'اليوم',
#   'السابع',
#   'ع',
#   'التوالي',
#   'الكفريات',
#   'سالك',
#   'حجة',
#   'الفندق',
#   'تواجد',
#   'الجيش',
#   'إشارات',
#   'حارس',
#   'سالك',
#   'طريق',
#   'بيت',
#   'ليد',
#   'المصانع',
#   'سالك',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'مغلق',
#   'حاجز',
#   'الحمرا',
#   'شبه',
#   'سالك',
#   'كم',
#   'سياره',
#   'عوفرا',
#   'سالك',
#   'اارئيل',
#   'سلفيت',
#   'سالك',
#   'خط',
#   'رام',
#   'الله',
#   'نابلس',
#   'سالك',
#   'عين',
#   'سينا',
#   'سالك',
#   'عطارة',
#   'سالك',
#   'عطاره',
#   'فوق',
#   'الجسر',
#   'سالك',
#   'روابي',
#   'سالك',
#   'اشارات',
#   'عيون',
#   'الحرامية',
#   'سالك',
#   'ترمسعيا',
#   'سالك',
#   'سنجل',
#   'مغلق',
#   'سنجل',
#   'المدخل',
#   'الشمالي',
#   'سالك',
#   'شيلو',
#   'سالك',
#   'عيلي',
#   'سالك',
#   'عيون',
#   'الحراميه',
#   'سالك',
#   'بيت',
#   'ايل',
#   'مغلق',
#   'عزون',
#   'تحت',
#   'الجسر',
#   'مغلق',
#   'تحت',
#   'جسر',
#   'جباره',
#   'سالك',
#   'جماعين',
#   'سالك',
#   'بوابة',
#   'كفل',
#   'حارس'],
#  ['سالك',
#   'بوابة',
#   'حارس',
#   'سالك',
#   'بوابة',
#   'مردا',
#   'الشرقيه',
#   'سالك',
#   'بديا',
#   'سالك',
#   'مدخل',
#   'دير',
#   'استيا',
#   'سالك',
#   'بوابة',
#   'بروقين',
#   'سالك',
#   'مدخل',
#   'مردا',
#   'الغربي',
#   'سالك',
#   'جبع',
#   'سالك',
#   'غير',
#   'متواجد',
#   'حاليا',
#   'طريقة',
#   'السلام',
#   'عليكم',
#   'تصبح',
#   'ع',
#   'خير',
#   'الخليل',
#   'بوابة',
#   'ترقوميا',
#   'سالك',
#   'الان'],
#  ['جيش', 'عدوار', 'كدوميم', 'موقفين', 'سيارة', 'بس', 'الطريق', 'سالكة'],
#  ['دير',
#   'شرف',
#   'سالك',
#   'بالاتجاهين',
#   'ازمه',
#   'متوسطه',
#   'ع',
#   'الخارج',
#   'وتفتيش',
#   'دقيق',
#   'بالاخص',
#   'يلي',
#   'جاي',
#   'من',
#   'شافي',
#   'شمرون'],
#  ['هاد',
#   'الجيش',
#   'واقف',
#   'ع',
#   'فرش',
#   'الهوى',
#   'وبحكي',
#   'للناس',
#   'ما',
#   'معو',
#   'امر',
#   'يفتح',
#   'لبكرا'],
#  ['سيارة',
#   'شرطة',
#   'عدوار',
#   'النبي',
#   'الياس',
#   'موقفين',
#   'سيارة',
#   'وبفتشو',
#   'فيها'],
#  ['صوره', 'مغلق', 'بالاتجاهين'],
#  ['والمستغفرين', 'بالأسحار'],
#  ['خط', 'يتسهار', 'سالك', 'ميه', 'ميه'],
#  ['المربعة',
#   'سالكة',
#   'وفاضية',
#   'مع',
#   'تواجد',
#   'للجيش',
#   'محجوزين',
#   '٣',
#   'شباب',
#   'سيارة',
#   'نمراصفرا'],
#  ['حاجز',
#   'سياره',
#   'كادي',
#   'سكنيه',
#   'ع',
#   'دير',
#   'شرف',
#   'ضاربينهم',
#   'ومكسرينهم',
#   'الله',
#   'يهونها'],
#  ['دير', 'شرف', 'ازمه', 'من', 'كلو'],
#  ['ما', 'زال', 'حاجز', 'الحمرا', 'سالك', 'بالاتجاهين'],
#  ['ما', 'في', 'حاجز', 'حاليا'],
#  ['اجا', 'عليها', 'الجيش', 'حاليا'],
#  ['حاجز', 'عطارة', 'بدقق', 'على', 'النمرة', 'الصفرا'],
#  ['سيارة', 'شرطة', 'عدوار', 'عين', 'سينيا'],
#  ['بوابة', 'ترقوميا', 'المصانع', 'برجع', 'بحكيلكم', 'فاتحة'],
#  ['استغفر',
#   'الله',
#   'عدد',
#   'ما',
#   'خلق',
#   'استغفر',
#   'الله',
#   'ملء',
#   'ما',
#   'خلق',
#   'استغفر',
#   'الله',
#   'عدد',
#   'ما',
#   'في',
#   'الأرض',
#   'والسماء',
#   'استغفر',
#   'الله',
#   'ملء',
#   'ما',
#   'في',
#   'الأرض',
#   'والسماء',
#   'استغفر',
#   'الله',
#   'عدد',
#   'ما',
#   'أحصى',
#   'كتابه',
#   'استغفر',
#   'الله',
#   'ملء',
#   'ما',
#   'أحصى',
#   'كتابه',
#   'استغفر',
#   'الله',
#   'عدد',
#   'كل',
#   'شيء',
#   'استغفر',
#   'الله',
#   'ملء',
#   'كل',
#   'شيء'],
#  ['عورتا', 'ازمة', 'للخارج', 'للمنجرة', 'الاولى'],
#  ['جسر', 'بيت', 'كاحل', 'سالك'],
#  ['الحمرا', 'سالك', 'بالاتجاهين'],
#  ['اللية', 'إذنا', 'مغلق', 'ترقوميا', 'الرئيسي', 'مغلق'],
#  ['عين', 'سينيا', 'حاجز', 'للخارج'],
#  ['فرش', 'الهوى', 'الشرق', 'الأوسط'],
#  ['قلنديا', 'كفر', 'عقب', 'رايح', 'جاي', 'سالكه'],
#  ['الناس', 'بتستنى', 'ع', 'راس', 'الجورة'],
#  ['بوابات',
#   'الخليل',
#   'دون',
#   'استثناء',
#   'اي',
#   'بوابة',
#   'مغلقات',
#   'كف',
#   '٣٥',
#   'سالك'],
#  ['دير', 'شرف', 'سالك', 'الان', 'ازمه', 'خفيفه'],
#  ['ضربوا',
#   'الرسول',
#   'وآذوه',
#   'وهو',
#   'يمسح',
#   'الدم',
#   'عن',
#   'وجهه',
#   'ويقول',
#   'اللهم',
#   'اغفر',
#   'لقومي',
#   'فهم',
#   'لا',
#   'يعلمون',
#   'صلوا',
#   'على',
#   'شفيع',
#   'الأمة'],
#  ['المنشية',
#   'ام',
#   'سلمونا',
#   'جورة',
#   'الشمعة',
#   'افرات',
#   'عصيون',
#   'من',
#   'عصيون',
#   'باتجاه',
#   'الجبعة',
#   'ونحالين',
#   'حاجز',
#   'وتفتيش',
#   'دقيق',
#   'مقابل',
#   'رامي',
#   'ليڤي',
#   'طبعا',
#   'احذرو',
#   'الاجواء',
#   'الضبابية'],
#  ['دوار', 'تقوع', 'سيارتين', 'شرطة'],
#  ['قلنديا', 'وكفر', 'عقب', 'ازمة'],
#  ['مفرق',
#   'بورين',
#   'سالك',
#   'دوار',
#   'سلمان',
#   'الفارسي',
#   'سالك',
#   'حوارة',
#   'البلد',
#   'سالكة'],
#  ['مداخل', 'أريحا', 'الأربعة', 'حاليا', 'كلها', 'سالكة'],
#  ['دير', 'شرف', 'ازمة', 'للخارج', 'واصلة', 'الرونق'],
#  ['دير', 'شرف', 'ازمة', 'ماشية', 'للداخل'],
#  ['مدخل', 'اريحا', 'الجنوبي', 'سالك', 'فش', 'جيش'],
#  ['مدخل', 'ديرستيا', 'حاليا', 'سالك', 'بدون', 'جيش'],
#  ['بوابة', 'عش', 'الغراب'],
#  ['تم', 'اغلاق', 'الفحص'],
#  ...]

# %%
set(labels)
# Out:
# {0, 1, 2}

# %%
# add word index to X

# %%
labels
# Out:
# 0         2
# 1         2
# 2         2
# 3         0
# 4         2
#          ..
# 303763    2
# 303764    2
# 303765    2
# 303766    0
# 303767    2
# Name: label_encoded, Length: 303768, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=42)

# %%
set(y_train)
# Out:
# {0, 1, 2}

# %% [markdown]
# Now, use XGBoost.
# Let`s look to the result

# %%
from sklearn.utils.class_weight import compute_sample_weight
sample_weights = compute_sample_weight(class_weight='balanced', y =y_train)
sample_weights
# Out:
# array([2.22576982, 0.55883401, 2.22576982, ..., 0.55883401, 0.55883401,
#        1.31358209])

# %%
from catboost import CatBoostClassifier

# %%
model = CatBoostClassifier(iterations=1000, depth=8, learning_rate=0.1,
                            loss_function='MultiClass', verbose = True, l2_leaf_reg=2 )

# %%
model.fit(X_train, y_train, sample_weight= sample_weights)
# Out:
# 0:	learn: 1.0984446	total: 405ms	remaining: 6m 44s
# 1:	learn: 1.0982984	total: 743ms	remaining: 6m 10s
# 2:	learn: 1.0981470	total: 1.1s	remaining: 6m 5s
# 984:	learn: 1.0883448	total: 3m 51s	remaining: 3.53s
# 985:	learn: 1.0883384	total: 3m 51s	remaining: 3.29s
# 986:	learn: 1.0883318	total: 3m 52s	remaining: 3.06s
# 987:	learn: 1.0883254	total: 3m 52s	remaining: 2.82s
# 988:	learn: 1.0883218	total: 3m 52s	remaining: 2.59s
# 989:	learn: 1.0883217	total: 3m 52s	remaining: 2.35s
# 990:	learn: 1.0883215	total: 3m 53s	remaining: 2.12s
# 991:	learn: 1.0883213	total: 3m 53s	remaining: 1.88s
# 992:	learn: 1.0883195	total: 3m 53s	remaining: 1.65s
# 993:	learn: 1.0883182	total: 3m 53s	remaining: 1.41s
# 994:	learn: 1.0883176	total: 3m 53s	remaining: 1.18s
# 995:	learn: 1.0883159	total: 3m 54s	remaining: 941ms
# 996:	learn: 1.0883146	total: 3m 54s	remaining: 705ms
# 997:	learn: 1.0883144	total: 3m 54s	remaining: 470ms
# 998:	learn: 1.0882902	total: 3m 54s	remaining: 235ms
# 999:	learn: 1.0882891	total: 3m 55s	remaining: 0us

# %%
prediction = model.predict(X_test)

# %%
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.28      0.26     15460
#            1       0.15      0.32      0.20      9063
#            2       0.59      0.39      0.47     36231
#
#     accuracy                           0.35     60754
#    macro avg       0.33      0.33      0.31     60754
# weighted avg       0.44      0.35      0.38     60754

# %%
print(classification_report(y_test, prediction))
# iterations=5000, depth=8, learning_rate=0.1,
#                             loss_function='MultiClass', verbose = True, l2_leaf_reg=2
# Out:
#               precision    recall  f1-score   support
#
#            0       0.26      0.24      0.25     15191
#            1       0.17      0.40      0.23      9202
#            2       0.62      0.42      0.50     36258
#
#     accuracy                           0.37     60651
#    macro avg       0.35      0.35      0.33     60651
# weighted avg       0.46      0.37      0.40     60651

# %%
print(classification_report(y_test, prediction))
# iterations=1500, depth=8, learning_rate=0.1,
#                             loss_function='MultiClass', verbose= False
# version v1.0.5
# Out:
#               precision    recall  f1-score   support
#
#            0       0.26      0.23      0.25     15191
#            1       0.16      0.40      0.23      9202
#            2       0.62      0.43      0.51     36258
#
#     accuracy                           0.37     60651
#    macro avg       0.35      0.35      0.33     60651
# weighted avg       0.46      0.37      0.40     60651

# %%
print(classification_report(y_test, prediction))
# model = CatBoostClassifier(iterations=1000, depth=6, learning_rate=0.1,
                            # loss_function='MultiClass', verbose= False )
# with this parameter v1.0.4
# Out:
#               precision    recall  f1-score   support
#
#            0       0.26      0.22      0.24     15191
#            1       0.17      0.39      0.23      9202
#            2       0.62      0.45      0.52     36258
#
#     accuracy                           0.38     60651
#    macro avg       0.35      0.35      0.33     60651
# weighted avg       0.46      0.38      0.41     60651

# %%
print(classification_report(y_test, prediction))

# model = CatBoostClassifier(iterations=100, depth=6, learning_rate=0.1,
                            # loss_function='MultiClass', verbose= False )
# with this parameter v1.0.3
# Out:
#               precision    recall  f1-score   support
#
#            0       0.26      0.18      0.21     15191
#            1       0.17      0.38      0.23      9202
#            2       0.62      0.51      0.56     36258
#
#     accuracy                           0.41     60651
#    macro avg       0.35      0.35      0.33     60651
# weighted avg       0.46      0.41      0.42     60651

# %%
print(classification_report(y_test, prediction))
# with compute sample (in .fit())
# Out:
#               precision    recall  f1-score   support
#
#            0       0.26      0.22      0.24     15191
#            1       0.16      0.39      0.23      9202
#            2       0.62      0.45      0.52     36258
#
#     accuracy                           0.38     60651
#    macro avg       0.35      0.35      0.33     60651
# weighted avg       0.46      0.38      0.41     60651

# %%
print(classification_report(y_test, prediction))
# without compute sample weight (and without any parameter)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.30      0.00      0.00     15191
#            1       0.00      0.00      0.00      9202
#            2       0.60      1.00      0.75     36258
#
#     accuracy                           0.60     60651
#    macro avg       0.30      0.33      0.25     60651
# weighted avg       0.43      0.60      0.45     60651
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
