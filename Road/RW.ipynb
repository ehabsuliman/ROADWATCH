# %%
import pandas as pd 

data = pd.read_csv('/Users/mac2/University/Machine Learning/new repo/ROADWATCH/Road/messages_cleanedNEW.csv')

data
# Out:
#             id                       date     sender_id  \
# 0      1705274  2024-11-01T12:53:19+00:00  6.415259e+09
# 1      1705273  2024-11-01T12:52:29+00:00  6.415259e+09
# 2      1705272  2024-11-01T12:48:24+00:00  6.415259e+09
# 3      1705271  2024-11-01T12:44:55+00:00  6.415259e+09
# 4      1705270  2024-11-01T12:39:22+00:00  6.415259e+09
# ...        ...                        ...           ...
# 33986  1705279  2024-11-01T13:34:50+00:00  6.415259e+09
# 33987  1705278  2024-11-01T13:34:43+00:00  6.415259e+09
# 33988  1705277  2024-11-01T13:18:29+00:00  6.415259e+09
# 33989  1705276  2024-11-01T13:18:29+00:00  6.415259e+09
# 33990  1705275  2024-11-01T13:17:13+00:00  6.415259e+09
#
#                                                  message
# 0                                     شرطه نازله من عيلي
# 1                   حادث سير بعد اشارات شيلو باتجاه عيلي
# 2                     المنشية تواجد جيش مع شرطة ومخالفات
# 3      الرجاء من كل شخص بقرا التقرير يكبس ❤️ أو 👍\n\n...
# 4                  تم فتح حاجز عناب الان بالاتجاهين ✅✅✅✅
# ...                                                  ...
# 33986                               عناب على الطالع ازمه
# 33987                      راس الجورة سالك لداخل والخارج
# 33988  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 33989                                                NaN
# 33990                                        عورتا لداخل
#
# [33991 rows x 4 columns]

# %%
import re
def remove_emojis(text):
    if isinstance(text, str):
        return re.sub(r'[^\w\s,.!?؛:\n]', '', text)
    return text

data['message'] = data['message'].apply(remove_emojis)

data
# Out:
#             id                       date     sender_id  \
# 0      1705274  2024-11-01T12:53:19+00:00  6.415259e+09
# 1      1705273  2024-11-01T12:52:29+00:00  6.415259e+09
# 2      1705272  2024-11-01T12:48:24+00:00  6.415259e+09
# 3      1705271  2024-11-01T12:44:55+00:00  6.415259e+09
# 4      1705270  2024-11-01T12:39:22+00:00  6.415259e+09
# ...        ...                        ...           ...
# 33986  1705279  2024-11-01T13:34:50+00:00  6.415259e+09
# 33987  1705278  2024-11-01T13:34:43+00:00  6.415259e+09
# 33988  1705277  2024-11-01T13:18:29+00:00  6.415259e+09
# 33989  1705276  2024-11-01T13:18:29+00:00  6.415259e+09
# 33990  1705275  2024-11-01T13:17:13+00:00  6.415259e+09
#
#                                                  message
# 0                                     شرطه نازله من عيلي
# 1                   حادث سير بعد اشارات شيلو باتجاه عيلي
# 2                     المنشية تواجد جيش مع شرطة ومخالفات
# 3      الرجاء من كل شخص بقرا التقرير يكبس  أو \n\nتفا...
# 4                      تم فتح حاجز عناب الان بالاتجاهين
# ...                                                  ...
# 33986                               عناب على الطالع ازمه
# 33987                      راس الجورة سالك لداخل والخارج
# 33988  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 33989                                                NaN
# 33990                                        عورتا لداخل
#
# [33991 rows x 4 columns]

# %%
def remove_jargon(data, jargon_terms):
      def clean_message(message):
        pattern = re.compile(r'\b(' + '|'.join(re.escape(term) for term in jargon_terms) + r')\b', re.IGNORECASE)
        return pattern.sub('', message)

        data['message'] = data['message'].apply(clean_message)

        data['message'] = data['message'].str.strip().replace(r'\s+', ' ', regex=True)
      return data

data
# Out:
#             id                       date     sender_id  \
# 0      1705274  2024-11-01T12:53:19+00:00  6.415259e+09
# 1      1705273  2024-11-01T12:52:29+00:00  6.415259e+09
# 2      1705272  2024-11-01T12:48:24+00:00  6.415259e+09
# 3      1705271  2024-11-01T12:44:55+00:00  6.415259e+09
# 4      1705270  2024-11-01T12:39:22+00:00  6.415259e+09
# ...        ...                        ...           ...
# 33986  1705279  2024-11-01T13:34:50+00:00  6.415259e+09
# 33987  1705278  2024-11-01T13:34:43+00:00  6.415259e+09
# 33988  1705277  2024-11-01T13:18:29+00:00  6.415259e+09
# 33989  1705276  2024-11-01T13:18:29+00:00  6.415259e+09
# 33990  1705275  2024-11-01T13:17:13+00:00  6.415259e+09
#
#                                                  message
# 0                                     شرطه نازله من عيلي
# 1                   حادث سير بعد اشارات شيلو باتجاه عيلي
# 2                     المنشية تواجد جيش مع شرطة ومخالفات
# 3      الرجاء من كل شخص بقرا التقرير يكبس  أو \n\nتفا...
# 4                      تم فتح حاجز عناب الان بالاتجاهين
# ...                                                  ...
# 33986                               عناب على الطالع ازمه
# 33987                      راس الجورة سالك لداخل والخارج
# 33988  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 33989                                                NaN
# 33990                                        عورتا لداخل
#
# [33991 rows x 4 columns]

# %%
print(data['message'].isnull().sum())
# Out:
# 1472

# %%
data.dropna(subset=['message'], inplace=True)

# %%
print(data['message'].isnull().sum())
# Out:
# 0

# %%
for index, message in enumerate(data['message']):
    if not isinstance(message, str):
        print(f"Row {index}: {message} (Type: {type(message)})")

# %%
data = data[data['message'].apply(lambda x: isinstance(x, str))]

# %%
def regex_tokenize(data):
    sentence_splitter = re.compile(r'(?<=[.!?]) +')
    word_splitter = re.compile(r'[\u0600-\u06FF]+|\d+|\w+')

    sentences_list = []
    words_list = []
    original_messages = []
    word_indices = []
    sentence_count = 1

    for index, message in data['message'].items():
        if isinstance(message, str):
            sentences = sentence_splitter.split(message.strip())
            for sentence in sentences:
                words = word_splitter.findall(sentence)
                for word_index, word in enumerate(words):
                    sentences_list.append(f"Sentence: {sentence_count} (Message {index})")
                    words_list.append(word)
                    original_messages.append(message)
                    word_indices.append(word_index + 1)
                sentence_count += 1
        else:
            print(f"Warning: Message at index {index} is not a string. Skipping...")

    tokenized_df = pd.DataFrame({
        'Sentence #': sentences_list,
        'Word': words_list,
        'Original Message': original_messages,
        'Word Index': word_indices
    })

    return tokenized_df

tokenized_df = regex_tokenize(data)

tokenized_df[['Sentence', 'Message']] = tokenized_df['Sentence #'].str.extract(r'Sentence: (\d+) \(Message (\d+)\)')

tokenized_df = tokenized_df.drop(columns=['Sentence #'])

tokenized_df
# Out:
#           Word                                   Original Message  Word Index  \
# 0         شرطه                                 شرطه نازله من عيلي           1
# 1        نازله                                 شرطه نازله من عيلي           2
# 2           من                                 شرطه نازله من عيلي           3
# 3         عيلي                                 شرطه نازله من عيلي           4
# 4         حادث               حادث سير بعد اشارات شيلو باتجاه عيلي           1
# ...        ...                                                ...         ...
# 303763  وتفتيش  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           6
# 303764   سياره  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           7
# 303765   سياره  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           8
# 303766   عورتا                                        عورتا لداخل           1
# 303767   لداخل                                        عورتا لداخل           2
#
#        Sentence Message
# 0             1       0
# 1             1       0
# 2             1       0
# 3             1       0
# 4             2       1
# ...         ...     ...
# 303763    32976   33988
# 303764    32976   33988
# 303765    32976   33988
# 303766    32977   33990
# 303767    32977   33990
#
# [303768 rows x 5 columns]

# %%
tokenized_df.drop(columns='Message', inplace=True)
tokenized_df
# Out:
#           Word                                   Original Message  Word Index  \
# 0         شرطه                                 شرطه نازله من عيلي           1
# 1        نازله                                 شرطه نازله من عيلي           2
# 2           من                                 شرطه نازله من عيلي           3
# 3         عيلي                                 شرطه نازله من عيلي           4
# 4         حادث               حادث سير بعد اشارات شيلو باتجاه عيلي           1
# ...        ...                                                ...         ...
# 303763  وتفتيش  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           6
# 303764   سياره  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           7
# 303765   سياره  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           8
# 303766   عورتا                                        عورتا لداخل           1
# 303767   لداخل                                        عورتا لداخل           2
#
#        Sentence
# 0             1
# 1             1
# 2             1
# 3             1
# 4             2
# ...         ...
# 303763    32976
# 303764    32976
# 303765    32976
# 303766    32977
# 303767    32977
#
# [303768 rows x 4 columns]

# %%
from collections import Counter
import re

all_text = ' '.join(data['message'].dropna())


words = re.findall(r'\b\w+\b', all_text)
word_counts = Counter(words)

word_count = pd.DataFrame(word_counts.items(), columns=['word', 'count'])

word_count
# Out:
#          word  count
# 0        شرطه    293
# 1       نازله      2
# 2          من   3877
# 3        عيلي    459
# 4        حادث    265
# ...       ...    ...
# 13282  مابمرق      1
# 13283   حالين      1
# 13284   بتفرج      1
# 13285   وقامو      1
# 13286  بأغلاق      1
#
# [13287 rows x 2 columns]

# %%
from rapidfuzz import fuzz

location_names = [
    "المنشية", "يتسهار", "صرة", "زعترة", "عصيرة", "المساكن", "المربعة", 
    "بوابة بورين", "دير شرف", "عورتا", "بيت فوريك", "بزاريا", "شافي شمرون",
    "حومش", "عناب", "الكفريات", "حجة", "وادي قانا", "بيت ليد", "كفر لاقف", 
    "الحمرا", "عوفرا", "ارئيل", "سلفيت", "رام الله", "نابلس", "عين سينيا", 
    "عطارة", "روابي", "عيون الحرامية", "ترمسعيا", "سنجل", "كركر", "بيت ايل", 
    "عزون", "جماعين", "كفل حارس", "مردا", "اللبن الشرقية", "بديا", "برقين", 
    "الزعيم", "العيزرية", "قلنديا", "جبع", "الكونتينر", "عش الغراب", 
    "مخماس", "جيت", "بيتا", "دير بلوط", "ياسوف", "النبي الياس", "سعير", 
    "حلحول", "حوارة", "راس الجورة", "عناتا", "حزما", "اماتين", "بيرزيت", 
    "النبي صالح", "افرات", "تقوع", "دورا", "عتصيون", "العروب", "فرش الهوى", 
    "حاجز النفق", "شارع بيجن", "الخليل", "واد النار", "DCO", "بيت جالا", 
    "اريحا", "برقة", "الغرس", "يتما", "الساوية", "يبرود", "سلواد", 
    "الطيبة", "النشاش", "طولكرم", "المسعودية", "بيت ايل", "جنين", 
    "قلقيلية", "عيلي", "كدوميم", "مخيم الجلزون", "روجيب", "شعفاط", 
    "الرام", "بيت لحم", "حوارة", "قبلان", "عينبوس", "بيت عور", "القرع", 
    "اودلا", "معالي ادوميم", "حزما", "السيلة", "نور شمس", "بلعا", 
    "الجفتلك", "الباذان", "البيرة", "بركان", "حبلة", "حرميش", "طوباس", 
    "السيلة", "افرايم", "ضواحي القدس", "القدس", "العبيدية", "بيت ساحور", 
    "تل الربيع", "يطا", "الظاهرية", "ترقوميا", "دير شرف", "شقبا", 
    "النفق", "شيلو", "عطروت", "حلميش", "المشتل", "عقربا", "قلنديا", 
    "سبسطية", "الفوار", "ادوميم", "العبيدية", "جين صافوت", "زواتا", 
    "حومش", "دير استيا", "العوجا", "بيت امر", "قباطية", "الجلزون", 
    "عطارة", "الخروبة", "عارورة", "الاحراش", "عصيرة الشمالية", "جيوس", "عين يبرود", 
    "عنبتا", "الناقورة", "الدهيشة", "بيت امرين", "قوصين", "عناتا", 
    "باب الزاوية", "الصيرفي", "صوريف", "ضاحية الريحان", "ابو ديس", "سالم", 
    "العيسوية", "بيت حنينا", "البيرة", "الاسكانات", "الزاوية", "النصارية",
    "واد قانا", "المصانع", "كفر عقب", "بير زيت", "عصيرة القبلية", "الفندق"
]

close_words = [
    'مغلق', 'مغلقة', 'وقوف', 'واقفه', 'سكروه', 'مسكره', 'سكر', 
    'مسكرين', 'متوقفه', 'اغلاق', 'اغلاقه'
]
open_words = [
    'فتح', 'فاضي', 'سالك', 'سالكه', 'فاتحة', 'فاتح', 'سلك', 'فتحت',
    'فاتحين', 'بمشو', 'مفتوحة', 'بسلك', 'بمشي', 'مشوا', 'فتحوها', 'سالكات', 'وسلك'
]

def regex_tokenize_with_similarity(data, location_names, similarity_threshold=80, close_threshold=80, open_threshold=80):
    sentence_splitter = re.compile(r'(?<=[.!?]) +')
    word_splitter = re.compile(r'[\u0600-\u06FF]+|\d+|\w+')

    sentences_list = []
    words_list = []
    original_messages = []
    word_indices = []
    labels = []
    similarities = []
    sentence_count = 1

    for index, message in data['message'].items():
        if isinstance(message, str):
            sentences = sentence_splitter.split(message.strip())
            for sentence in sentences:
                words = word_splitter.findall(sentence)
                
                i = 0
                while i < len(words):
                    if i + 1 < len(words) and f"{words[i]} {words[i+1]}" in location_names:
                        labels.extend(["B-LOC", "I-LOC"])
                        similarities.extend([100, 100])  
                        
                        sentences_list.extend([f"Sentence: {sentence_count} (Message {index})"] * 2)
                        words_list.extend([words[i], words[i + 1]])
                        original_messages.extend([message] * 2)
                        word_indices.extend([i + 1, i + 2])
                        
                        i += 2
                        continue
                    elif words[i] in location_names:
                        labels.append("B-LOC")
                        similarities.append(100)
                    else:
                        max_close_similarity = max(fuzz.ratio(words[i], word) for word in close_words)
                        if max_close_similarity >= close_threshold:
                            labels.append("B-close")
                            similarities.append(max_close_similarity)
                        else:
                            max_open_similarity = max(fuzz.ratio(words[i], word) for word in open_words)
                            if max_open_similarity >= open_threshold:
                                labels.append("B-open")
                                similarities.append(max_open_similarity)
                            else:
                                max_loc_similarity = max(fuzz.ratio(words[i], loc) for loc in location_names)
                                labels.append("B-LOC" if max_loc_similarity >= similarity_threshold else "O")
                                similarities.append(max_loc_similarity if max_loc_similarity >= similarity_threshold else 0)

                    sentences_list.append(f"Sentence: {sentence_count} (Message {index})")
                    words_list.append(words[i])
                    original_messages.append(message)
                    word_indices.append(i + 1)
                    i += 1
                    
                sentence_count += 1
        else:
            print(f"Warning: Message at index {index} is not a string. Skipping...")

    tokenized_df = pd.DataFrame({
        'Sentence #': sentences_list,
        'Word': words_list,
        'Original Message': original_messages,
        'Word Index': word_indices,
        'label': labels,
        'Similarity Score': similarities
    })

    return tokenized_df



tokenized_df = regex_tokenize_with_similarity(pd.DataFrame(data), location_names)

tokenized_df[['Sentence', 'Message']] = tokenized_df['Sentence #'].str.extract(r'Sentence: (\d+) \(Message (\d+)\)')


tokenized_df = tokenized_df.drop(columns=['Sentence #'])

# %%
tokenized_df
# Out:
#           Word                                   Original Message  Word Index  \
# 0         شرطه                                 شرطه نازله من عيلي           1
# 1        نازله                                 شرطه نازله من عيلي           2
# 2           من                                 شرطه نازله من عيلي           3
# 3         عيلي                                 شرطه نازله من عيلي           4
# 4         حادث               حادث سير بعد اشارات شيلو باتجاه عيلي           1
# ...        ...                                                ...         ...
# 303763  وتفتيش  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           6
# 303764   سياره  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           7
# 303765   سياره  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...           8
# 303766   عورتا                                        عورتا لداخل           1
# 303767   لداخل                                        عورتا لداخل           2
#
#         label  Similarity Score Sentence Message
# 0           O               0.0        1       0
# 1           O               0.0        1       0
# 2           O               0.0        1       0
# 3       B-LOC             100.0        1       0
# 4           O               0.0        2       1
# ...       ...               ...      ...     ...
# 303763      O               0.0    32976   33988
# 303764      O               0.0    32976   33988
# 303765      O               0.0    32976   33988
# 303766  B-LOC             100.0    32977   33990
# 303767      O               0.0    32977   33990
#
# [303768 rows x 7 columns]

# %%
tokenized_df.drop(columns='Message', inplace=True)
tokenized_df = tokenized_df[['Similarity Score', 'Word Index', 'label', 'Word', 'Original Message', 'Sentence']]

# %%
tokenized_df
# Out:
#         Similarity Score  Word Index  label    Word  \
# 0                    0.0           1      O    شرطه
# 1                    0.0           2      O   نازله
# 2                    0.0           3      O      من
# 3                  100.0           4  B-LOC    عيلي
# 4                    0.0           1      O    حادث
# ...                  ...         ...    ...     ...
# 303763               0.0           6      O  وتفتيش
# 303764               0.0           7      O   سياره
# 303765               0.0           8      O   سياره
# 303766             100.0           1  B-LOC   عورتا
# 303767               0.0           2      O   لداخل
#
#                                          Original Message Sentence
# 0                                      شرطه نازله من عيلي        1
# 1                                      شرطه نازله من عيلي        1
# 2                                      شرطه نازله من عيلي        1
# 3                                      شرطه نازله من عيلي        1
# 4                    حادث سير بعد اشارات شيلو باتجاه عيلي        2
# ...                                                   ...      ...
# 303763  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...    32976
# 303764  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...    32976
# 303765  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...    32976
# 303766                                        عورتا لداخل    32977
# 303767                                        عورتا لداخل    32977
#
# [303768 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count occurrences of each label
label_counts = tokenized_df['label'].value_counts()

# Plot the label distribution
plt.figure(figsize=(10, 6))
sns.barplot(x=label_counts.index, y=label_counts.values, palette="viridis")
plt.title("Distribution of Labels in Tokenized Data")
plt.xlabel("Label")
plt.ylabel("Frequency")
plt.show()
# Out:
# /var/folders/60/jh6gqjyn3vg6kq4wh79wmvkc0000gp/T/ipykernel_15109/1390820595.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=label_counts.index, y=label_counts.values, palette="viridis")

# %%
tokenized_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303768 entries, 0 to 303767
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Similarity Score  303768 non-null  float64
#  1   Word Index        303768 non-null  int64
#  2   label             303768 non-null  object
#  3   Word              303768 non-null  object
#  4   Original Message  303768 non-null  object
#  5   Sentence          303768 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 13.9+ MB

# %%
tokenized_df['Length Word'] = tokenized_df['Word'].apply(len)
# Out:
# /var/folders/60/jh6gqjyn3vg6kq4wh79wmvkc0000gp/T/ipykernel_15109/1357070171.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tokenized_df['Length Word'] = tokenized_df['Word'].apply(len)

# %%
tokenized_df
# Out:
#         Similarity Score  Word Index  label    Word  \
# 0                    0.0           1      O    شرطه
# 1                    0.0           2      O   نازله
# 2                    0.0           3      O      من
# 3                  100.0           4  B-LOC    عيلي
# 4                    0.0           1      O    حادث
# ...                  ...         ...    ...     ...
# 303763               0.0           6      O  وتفتيش
# 303764               0.0           7      O   سياره
# 303765               0.0           8      O   سياره
# 303766             100.0           1  B-LOC   عورتا
# 303767               0.0           2      O   لداخل
#
#                                          Original Message Sentence  \
# 0                                      شرطه نازله من عيلي        1
# 1                                      شرطه نازله من عيلي        1
# 2                                      شرطه نازله من عيلي        1
# 3                                      شرطه نازله من عيلي        1
# 4                    حادث سير بعد اشارات شيلو باتجاه عيلي        2
# ...                                                   ...      ...
# 303763  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...    32976
# 303764  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...    32976
# 303765  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...    32976
# 303766                                        عورتا لداخل    32977
# 303767                                        عورتا لداخل    32977
#
#         Length Word
# 0                 4
# 1                 5
# 2                 2
# 3                 4
# 4                 4
# ...             ...
# 303763            6
# 303764            5
# 303765            5
# 303766            5
# 303767            5
#
# [303768 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import numpy as np

# %%
label_encoder = LabelEncoder()
tokenized_df['label_encoded'] = label_encoder.fit_transform(tokenized_df['label'])
# Out:
# /var/folders/60/jh6gqjyn3vg6kq4wh79wmvkc0000gp/T/ipykernel_15109/146951505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tokenized_df['label_encoded'] = label_encoder.fit_transform(tokenized_df['label'])

# %%
tokenized_df = tokenized_df[['Similarity Score', 'Word Index', 'label_encoded' ,'label', 'Word', 'Length Word', 'Original Message', 'Sentence']]

tokenized_df
# Out:
#         Similarity Score  Word Index  label_encoded  label    Word  \
# 0                    0.0           1              4      O    شرطه
# 1                    0.0           2              4      O   نازله
# 2                    0.0           3              4      O      من
# 3                  100.0           4              0  B-LOC    عيلي
# 4                    0.0           1              4      O    حادث
# ...                  ...         ...            ...    ...     ...
# 303763               0.0           6              4      O  وتفتيش
# 303764               0.0           7              4      O   سياره
# 303765               0.0           8              4      O   سياره
# 303766             100.0           1              0  B-LOC   عورتا
# 303767               0.0           2              4      O   لداخل
#
#         Length Word                                   Original Message  \
# 0                 4                                 شرطه نازله من عيلي
# 1                 5                                 شرطه نازله من عيلي
# 2                 2                                 شرطه نازله من عيلي
# 3                 4                                 شرطه نازله من عيلي
# 4                 4               حادث سير بعد اشارات شيلو باتجاه عيلي
# ...             ...                                                ...
# 303763            6  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303764            5  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303765            5  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303766            5                                        عورتا لداخل
# 303767            5                                        عورتا لداخل
#
#        Sentence
# 0             1
# 1             1
# 2             1
# 3             1
# 4             2
# ...         ...
# 303763    32976
# 303764    32976
# 303765    32976
# 303766    32977
# 303767    32977
#
# [303768 rows x 8 columns]

# %%
tokenized_df['Index_plus_1'] = tokenized_df.index + 1
# Out:
# /var/folders/60/jh6gqjyn3vg6kq4wh79wmvkc0000gp/T/ipykernel_15109/3174506871.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tokenized_df['Index_plus_1'] = tokenized_df.index + 1

# %%
tokenized_df
# Out:
#         Similarity Score  Word Index  label_encoded  label    Word  \
# 0                    0.0           1              4      O    شرطه
# 1                    0.0           2              4      O   نازله
# 2                    0.0           3              4      O      من
# 3                  100.0           4              0  B-LOC    عيلي
# 4                    0.0           1              4      O    حادث
# ...                  ...         ...            ...    ...     ...
# 303763               0.0           6              4      O  وتفتيش
# 303764               0.0           7              4      O   سياره
# 303765               0.0           8              4      O   سياره
# 303766             100.0           1              0  B-LOC   عورتا
# 303767               0.0           2              4      O   لداخل
#
#         Length Word                                   Original Message  \
# 0                 4                                 شرطه نازله من عيلي
# 1                 5                                 شرطه نازله من عيلي
# 2                 2                                 شرطه نازله من عيلي
# 3                 4                                 شرطه نازله من عيلي
# 4                 4               حادث سير بعد اشارات شيلو باتجاه عيلي
# ...             ...                                                ...
# 303763            6  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303764            5  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303765            5  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303766            5                                        عورتا لداخل
# 303767            5                                        عورتا لداخل
#
#        Sentence  Index_plus_1
# 0             1             1
# 1             1             2
# 2             1             3
# 3             1             4
# 4             2             5
# ...         ...           ...
# 303763    32976        303764
# 303764    32976        303765
# 303765    32976        303766
# 303766    32977        303767
# 303767    32977        303768
#
# [303768 rows x 9 columns]

# %%
tokenized_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303768 entries, 0 to 303767
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Similarity Score  303768 non-null  float64
#  1   Word Index        303768 non-null  int64
#  2   label_encoded     303768 non-null  int64
#  3   label             303768 non-null  object
#  4   Word              303768 non-null  object
#  5   Length Word       303768 non-null  int64
#  6   Original Message  303768 non-null  object
#  7   Sentence          303768 non-null  object
#  8   Index_plus_1      303768 non-null  int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 20.9+ MB

# %%
tokenized_words = tokenized_df['Word'].tolist()

len(tokenized_words)
# Out:
# 303768

# %%
tokenized_df.tail(20)
# Out:
#         Similarity Score  Word Index  label_encoded   label      Word  \
# 303748          0.000000           5              4       O    سيارات
# 303749        100.000000           1              0   B-LOC      عناب
# 303750          0.000000           2              4       O       على
# 303751          0.000000           3              4       O    الطالع
# 303752          0.000000           4              4       O      ازمه
# 303753        100.000000           1              0   B-LOC       راس
# 303754        100.000000           2              3   I-LOC    الجورة
# 303755        100.000000           3              2  B-open      سالك
# 303756          0.000000           4              4       O     لداخل
# 303757          0.000000           5              4       O   والخارج
# 303758         94.117647           1              0   B-LOC  الكونتير
# 303759          0.000000           2              4       O     بدايه
# 303760          0.000000           3              4       O      ازمه
# 303761          0.000000           4              4       O    باتجاه
# 303762          0.000000           5              4       O    الجنوب
# 303763          0.000000           6              4       O    وتفتيش
# 303764          0.000000           7              4       O     سياره
# 303765          0.000000           8              4       O     سياره
# 303766        100.000000           1              0   B-LOC     عورتا
# 303767          0.000000           2              4       O     لداخل
#
#         Length Word                                   Original Message  \
# 303748            6                         عورتا لا الخارج ١٠ سيارات
# 303749            4                               عناب على الطالع ازمه
# 303750            3                               عناب على الطالع ازمه
# 303751            6                               عناب على الطالع ازمه
# 303752            4                               عناب على الطالع ازمه
# 303753            3                      راس الجورة سالك لداخل والخارج
# 303754            6                      راس الجورة سالك لداخل والخارج
# 303755            4                      راس الجورة سالك لداخل والخارج
# 303756            5                      راس الجورة سالك لداخل والخارج
# 303757            7                      راس الجورة سالك لداخل والخارج
# 303758            8  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303759            5  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303760            4  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303761            6  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303762            6  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303763            6  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303764            5  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303765            5  الكونتير بدايه ازمه باتجاه الجنوب وتفتيش سياره...
# 303766            5                                        عورتا لداخل
# 303767            5                                        عورتا لداخل
#
#        Sentence  Index_plus_1
# 303748    32973        303749
# 303749    32974        303750
# 303750    32974        303751
# 303751    32974        303752
# 303752    32974        303753
# 303753    32975        303754
# 303754    32975        303755
# 303755    32975        303756
# 303756    32975        303757
# 303757    32975        303758
# 303758    32976        303759
# 303759    32976        303760
# 303760    32976        303761
# 303761    32976        303762
# 303762    32976        303763
# 303763    32976        303764
# 303764    32976        303765
# 303765    32976        303766
# 303766    32977        303767
# 303767    32977        303768

# %%
sentences = [
    list(group['Word'])
    for _, group in tokenized_df.groupby('label')
]
sentences
# Out:
# [['عيلي',
#   'سير',
#   'شيلو',
#   'عيلي',
#   'المنشية',
#   'يتسهار',
#   'صرة',
#   'صرة',
#   'زعترا',
#   'عصيرة',
#   'عصيرة',
#   'المساكن',
#   'المربعة',
#   'بوابة',
#   'دير',
#   'عورتا',
#   'بيت',
#   'بزاريا',
#   'شافي',
#   'حومش',
#   'عناب',
#   'الكفريات',
#   'حجة',
#   'الفندق',
#   'واد',
#   'بيت',
#   'المصانع',
#   'الحمرا',
#   'عوفرا',
#   'ارئيل',
#   'سلفيت',
#   'رام',
#   'نابلس',
#   'عطارة',
#   'عطاره',
#   'روابي',
#   'عيون',
#   'ترمسعيا',
#   'سنجل',
#   'كركر',
#   'شيلو',
#   'عيلي',
#   'عيون',
#   'بيت',
#   'عزون',
#   'جماعين',
#   'كفل',
#   'مردا',
#   'بديا',
#   'دير',
#   'بروقين',
#   'مردا',
#   'الطيب',
#   'عناب',
#   'الزعيم',
#   'العيزرية',
#   'عورتا',
#   'قلنديا',
#   'جبع',
#   'لبزاريا',
#   'جبع',
#   'الكونتير',
#   'شافي',
#   'عش',
#   'مخماس',
#   'دير',
#   'بزاريا',
#   'دير',
#   'شافي',
#   'جيت',
#   'دير',
#   'بيت',
#   'المصانع',
#   'الطنيب',
#   'الزعيم',
#   'جماعين',
#   'ومردا',
#   'يا',
#   'يا',
#   'يتسهار',
#   'صرة',
#   'صرة',
#   'زعترا',
#   'عصيرة',
#   'عصيرة',
#   'المساكن',
#   'المربعة',
#   'بوابة',
#   'دير',
#   'عورتا',
#   'بيت',
#   'بزاريا',
#   'شافي',
#   'حومش',
#   'عناب',
#   'الكفريات',
#   'حجة',
#   'الفندق',
#   'واد',
#   'بيت',
#   'المصانع',
#   'الحمرا',
#   'عوفرا',
#   'ارئيل',
#   'سلفيت',
#   'رام',
#   'نابلس',
#   'عطارة',
#   'عطاره',
#   'روابي',
#   'عيون',
#   'ترمسعيا',
#   'سنجل',
#   'كركر',
#   'شيلو',
#   'عيلي',
#   'عيون',
#   'بيت',
#   'عزون',
#   'جماعين',
#   'كفل',
#   'مردا',
#   'بديا',
#   'دير',
#   'بروقين',
#   'مردا',
#   'الطيب',
#   'ترمسعيا',
#   'ترمسعيا',
#   'سير',
#   'الكونتير',
#   'سير',
#   'زعتره',
#   'عناب',
#   'عورتا',
#   'اودلا',
#   'المربعة',
#   'دير',
#   'بيتا',
#   'دير',
#   'بروقين',
#   'المربعة',
#   'دير',
#   'ياسوف',
#   'سلفيت',
#   'المربعة',
#   'سعير',
#   'حلحول',
#   'حوارة',
#   'اودلا',
#   'عورتا',
#   'ترمسعيا',
#   'ترمسعيا',
#   'عناب',
#   'راس',
#   'عناب',
#   'عيون',
#   'زعترة',
#   'الكونتينر',
#   'عورتا',
#   'عورتا',
#   'شيلو',
#   'ترمسعيا',
#   'مخماس',
#   'عيون',
#   'مخماس',
#   'عناب',
#   'عناتا',
#   'حزما',
#   'جبع',
#   'عطاره',
#   'دير',
#   'العيزرية',
#   'اماتين',
#   'عناب',
#   'قلنديا',
#   'عالقدس',
#   'عناب',
#   'جبع',
#   'كفر',
#   'قلنديا',
#   'الكونتينر',
#   'يتسهار',
#   'صرة',
#   'صرة',
#   'زعترا',
#   'عصيرة',
#   'عصيرة',
#   'المساكن',
#   'المربعة',
#   'بوابة',
#   'دير',
#   'عورتا',
#   'بيت',
#   'بزاريا',
#   'شافي',
#   'حومش',
#   'عناب',
#   'الكفريات',
#   'حجة',
#   'الفندق',
#   'واد',
#   'بيت',
#   'المصانع',
#   'الحمرا',
#   'عوفرا',
#   'ارئيل',
#   'سلفيت',
#   'رام',
#   'نابلس',
#   'عطارة',
#   'عطاره',
#   'روابي',
#   'عيون',
#   'ترمسعيا',
#   'سنجل',
#   'كركر',
#   'شيلو',
#   'عيلي',
#   'عيون',
#   'بيت',
#   'عزون',
#   'جماعين',
#   'كفل',
#   'مردا',
#   'بديا',
#   'دير',
#   'بروقين',
#   'مردا',
#   'الطيب',
#   'دير',
#   'عطاره',
#   'بير',
#   'عطاره',
#   'روابي',
#   'بورين',
#   'يتسهار',
#   'المربعة',
#   'الحمرا',
#   'الكفريات',
#   'حومش',
#   'بزرايا',
#   'شافي',
#   'دير',
#   'لعناب',
#   'النبي',
#   'عطاره',
#   'بير',
#   'روابي',
#   'افرات',
#   'المنشية',
#   'تقوع',
#   'عش',
#   'الطنيب',
#   'بيت',
#   'المصانع',
#   'دورا',
#   'دير',
#   'عين',
#   'يتسهار',
#   'الفندق',
#   'العروب',
#   'عصيون',
#   'المربعة',
#   'حلحول',
#   'راس',
#   'المربعة',
#   'حلحول',
#   'راس',
#   'حلحول',
#   'سعير',
#   'عصيون',
#   'للعروب',
#   'العروب',
#   'افرات',
#   'افرات',
#   'لعصيون',
#   'فرش',
#   'راس',
#   'عورتا',
#   'الحمرا',
#   'جبع',
#   'جبع',
#   'دورا',
#   'يتم',
#   'راس',
#   'شارع',
#   'النفق',
#   'العيزرية',
#   'الكونتينر',
#   'الزعيم',
#   'الزعيم',
#   'عناتا',
#   'عناتا',
#   'حزما',
#   'الخليل',
#   'واد',
#   'العيزرية',
#   'الكونتير',
#   'دير',
#   'عش',
#   'الحمرا',
#   'المربعه',
#   'طيبة',
#   'النفس',
#   'يا',
#   'نابلس',
#   'القرب',
#   'الليل',
#   'الليل',
#   'الليل',
#   'بيت',
#   'العيزرية',
#   'أريحا',
#   'الكونتينر',
#   'علي',
#   'علي',
#   'ويبرد',
#   'ليلة',
#   'جبع',
#   'جبع',
#   'الفوقا',
#   'زعترة',
#   'ارائيل',
#   'حومش',
#   'بزاريا',
#   'بزاريا',
#   'الغرس',
#   'برقة',
#   'الكونتينر',
#   'ترمسعيا',
#   'سنجل',
#   'اللبن',
#   'يتما',
#   'الساوية',
#   'برقة',
#   'يبرود',
#   'سلواد',
#   'المخماس',
#   'الطيبة',
#   'بيت',
#   'عوفرا',
#   'عيون',
#   'شيلو',
#   'عيلي',
#   'العيزريه',
#   'عين',
#   'العيزريه',
#   'حزما',
#   'حجة',
#   'المربعة',
#   'اريحا',
#   'DCO',
#   'فرش',
#   'راس',
#   'علي',
#   'أجمعين',
#   'تقوع',
#   'تقوع',
#   'النبي',
#   'عناب',
#   'الكفريات',
#   'بيت',
#   'المصانع',
#   'عورتا',
#   'المربعة',
#   'عش',
#   'ترمسعيا',
#   'فرش',
#   'راس',
#   'دير',
#   'دورا',
#   'النشاش',
#   'بزاريا',
#   'العيزريه',
#   'واد',
#   'العيزريه',
#   'الكونتينر',
#   'عورتا',
#   'المسعودية',
#   'الزعيم',
#   'زعيم',
#   'بزاريا',
#   'يزاريا',
#   'بزاريا',
#   'ومش',
#   'يلي',
#   'طولكرم',
#   'نابلس',
#   'المسعوديه',
#   'حزما',
#   'عطارة',
#   'بير',
#   'عطارة',
#   'جبع',
#   'والظاهر',
#   'عيون',
#   'عوفرا',
#   'بيت',
#   'مخماس',
#   'دورا',
#   'قلنديا',
#   'عطارة',
#   'بيرزيت',
#   'عطارة',
#   'ترمسعيا',
#   'نابلس',
#   'جنين',
#   'بورين',
#   'حوار',
#   'حوارة',
#   'زعترة',
#   'اريئيل',
#   'قلقيلية',
#   'عطارة',
#   'بيرزيت',
#   'عورتا',
#   'شيلو',
#   'وعيلي',
#   'دير',
#   'عطارة',
#   'بير',
#   'شيلو',
#   'الطنيب',
#   'دورا',
#   'جيت',
#   'صرة',
#   'حومش',
#   'كدوميم',
#   'عورتا',
#   'دير',
#   'المربعة',
#   'الحمرا',
#   'راس',
#   'اماتين',
#   'المربعة',
#   'عورتا',
#   'واد',
#   'العيزرية',
#   'عالخليل',
#   'لعتصيوون',
#   'الحمرا',
#   'بديا',
#   'ارئيل',
#   'دير',
#   'عورتا',
#   'ارائيل',
#   'زعترة',
#   'جماعين',
#   'كونتينر',
#   'الحمرا',
#   'أريحا',
#   'الأربعة',
#   'المربعة',
#   'روابي',
#   'بير',
#   'عين',
#   'مخيم',
#   'عين',
#   'رام',
#   'يبرود',
#   'وسلواد',
#   'يبرود',
#   'سلواد',
#   'عش',
#   'عصيون',
#   'الكونتينر',
#   'ياسوف',
#   'سلفيت',
#   'دير',
#   'سير',
#   'سير',
#   'الخليل',
#   'عين',
#   'عطارة',
#   'بير',
#   'شافي',
#   'المساكن',
#   'عصيرة',
#   'بزاريا',
#   'المربعة',
#   'حومش',
#   'عورتا',
#   'عورتا',
#   'روجيب',
#   'الطنيب',
#   'عيون',
#   'عوفرا',
#   'دير',
#   'الطنيب',
#   'بيت',
#   'قلنديا',
#   'كفر',
#   'عطارة',
#   'بير',
#   'سلواد',
#   'فرش',
#   'جبع',
#   'العروب',
#   'جبع',
#   'حزما',
#   'النشاش',
#   'عين',
#   'شعفاط',
#   'عورتا',
#   'الكونتينر',
#   'قلنديا',
#   'الرام',
#   'الجلزون',
#   'عين',
#   'بيت',
#   'والخليل',
#   'دير',
#   'الجلزون',
#   'يتسهار',
#   'الحمرا',
#   'النبي',
#   'سعير',
#   'بيت',
#   'سير',
#   'عش',
#   'بيت',
#   'عناب',
#   'عطارة',
#   'بيرزيت',
#   'المربعة',
#   'دير',
#   'عورتا',
#   'عورتا',
#   'سلفيت',
#   'عناب',
#   'قلنديا',
#   'عورتا',
#   'عين',
#   'حوارة',
#   'حوارة',
#   'بيتا',
#   'بيتا',
#   'عينبوس',
#   'دير',
#   'قبلان',
#   'سير',
#   'راس',
#   'الحمرا',
#   'بيت',
#   'شيلو',
#   'عيلي',
#   'اللبن',
#   'يتما',
#   'الساوية',
#   'جبع',
#   'الرام',
#   'الجلزون',
#   'بيت',
#   'رام',
#   'نابلس',
#   'المربعة',
#   'عورتا',
#   'دير',
#   'الحمرا',
#   'سنجل',
#   'ترمسعيا',
#   'عش',
#   'عورتا',
#   'عيون',
#   'يتسهار',
#   'عناب',
#   'دير',
#   'عوفرا',
#   'يبرود',
#   'سلواد',
#   'الحمرا',
#   'دورا',
#   'بيت',
#   'زعترة',
#   'مخماس',
#   'مخماس',
#   'الطيبة',
#   'سير',
#   'دورا',
#   'القرع',
#   'أودلا',
#   'سلواد',
#   'يبرود',
#   'جبع',
#   'حزما',
#   'حزما',
#   'سير',
#   'زعترة',
#   'حوارة',
#   'بورين',
#   'المربعة',
#   'دير',
#   'حزما',
#   'عالقدس',
#   'عناتا',
#   'عناتا',
#   'الزعيم',
#   'عالقدس',
#   'معالي',
#   'العيزرية',
#   'معالي',
#   'العيزرية',
#   'سير',
#   'العيزرية',
#   'الحمرا',
#   'عناب',
#   'شافي',
#   'دير',
#   'الطنيب',
#   'بيت',
#   'الكونتينر',
#   'راس',
#   'دورا',
#   'سير',
#   'رام',
#   'عناب',
#   'بيت',
#   'DCO',
#   'بزاريا',
#   'حومش',
#   'دير',
#   'بزاريا',
#   'والسيلة',
#   'المربعة',
#   'شافي',
#   'سير',
#   'الحمرا',
#   'عورتا',
#   'الطنيب',
#   'تقوع',
#   'المنشية',
#   'الطنيب',
#   'بزاريا',
#   'فرات',
#   'فرات',
#   'المربعة',
#   'عناتا',
#   'الزعيم',
#   'عناتا',
#   'الزعيم',
#   'معالي',
#   'العيزرية',
#   'عتصيون',
#   'العروب',
#   'العروب',
#   'جيت',
#   'الطنيب',
#   'سعير',
#   'شعفاط',
#   'جيت',
#   'راس',
#   'راس',
#   'دير',
#   'حلحوول',
#   'عطارة',
#   'عين',
#   'الطنيب',
#   'قلنديا',
#   'الرام',
#   'جيت',
#   'يستهار',
#   'عطاره',
#   'بير',
#   'حومش',
#   'بزاريا',
#   'شافي',
#   'دير',
#   'عش',
#   'دورا',
#   'جبع',
#   'سنجل',
#   'سير',
#   'رام',
#   'عطاره',
#   'سير',
#   'زعتره',
#   'عيلي',
#   'جبع',
#   'يتسهار',
#   'المسلكين',
#   'شيلو',
#   'عيون',
#   'وادي',
#   'دير',
#   'بروقين',
#   'جبع',
#   'جبع',
#   'قلنديا',
#   'عين',
#   'الطنيب',
#   'جيت',
#   'ايتسهار',
#   'كدومييم',
#   'إماتين',
#   'الفندق',
#   'الفندق',
#   'كفر',
#   'رام',
#   'عناب',
#   'دير',
#   'المربعة',
#   'يتسهار',
#   'صرة',
#   'صرة',
#   'زعترا',
#   'عصيرة',
#   'عصيرة',
#   'المساكن',
#   'المربعة',
#   'بوابة',
#   'دير',
#   'عورتا',
#   'بيت',
#   'بزاريا',
#   'شافي',
#   'حومش',
#   'عناب',
#   'الكفريات',
#   'حجة',
#   'الفندق',
#   'واد',
#   'بيت',
#   'المصانع',
#   'الحمرا',
#   'عوفرا',
#   'ارئيل',
#   'سلفيت',
#   'رام',
#   'نابلس',
#   'عطارة',
#   'عطاره',
#   'روابي',
#   'عيون',
#   'ترمسعيا',
#   'سنجل',
#   'كركر',
#   'شيلو',
#   'عيلي',
#   'عيون',
#   'بيت',
#   'عزون',
#   'جماعين',
#   'كفل',
#   'مردا',
#   'بديا',
#   'دير',
#   'بروقين',
#   'مردا',
#   'الطيب',
#   'نور',
#   'بلعا',
#   'دير',
#   'الكونتير',
#   'عناب',
#   'المربعه',
#   'الخليل',
#   'دير',
#   'شافي',
#   'بزاريا',
#   'الغرس',
#   'بزاريا',
#   'حومش',
#   'عناب',
#   'عصيون',
#   'راس',
#   'فرش',
#   'عورتا',
#   'عورتا',
#   'الكونتينر',
#   'عش',
#   'العيزرية',
#   'معالي',
#   'عطارة',
#   'بيرزيت',
#   'عطارة',
#   'المربعه',
#   'حلحول',
#   'وسعير',
#   'راس',
#   'عورتا',
#   'لعورتا',
#   'عش',
#   'الكونتير',
#   'طولكرم',
#   'الكونتينر',
#   'عناب',
#   'سعير',
#   'قلقيليه',
#   'جيت',
#   'دير',
#   'المربعة',
#   'عورتا',
#   'عورتا',
#   'دير',
#   'شافي',
#   'نابلس',
#   'سير',
#   'عورتا',
#   'سير',
#   'عورتا',
#   'الزعيم',
#   'عناب',
#   'عطارة',
#   'أودلا',
#   'سعير',
#   'حلحول',
#   'النشاش',
#   'زعترة',
#   'الحمرا',
#   'بروقين',
#   'كفل',
#   'مردا',
#   'مردا',
#   'جماعين',
#   'اريئيل',
#   'زعترة',
#   'الكنتينر',
#   'كدميمم',
#   'المربعه',
#   'الكونتينر',
#   'بير',
#   'سلفيت',
#   'بيت',
#   'الكونتينر',
#   'عين',
#   'بيت',
#   'الحمرا',
#   'الجفتلك',
#   'عيون',
#   'اللي',
#   'بيت',
#   'عطاره',
#   'المربعه',
#   'الجلزون',
#   'عورتا',
#   'عطارة',
#   'بير',
#   'عطارة',
#   'روابي',
#   'دير',
#   'دير',
#   'الحمرة',
#   'النمرا',
#   'النفق',
#   'بيت',
#   'سعير',
#   'حلحول',
#   'العروب',
#   'العيزرية',
#   'معالي',
#   'جبع',
#   'نابلس',
#   'صرة',
#   'صرة',
#   'عصيرة',
#   'عصيرة',
#   'المساكن',
#   'المربعة',
#   'عورتا',
#   'جيت',
#   'الطنيب',
#   'دير',
#   'شافي',
#   'بزاريا',
#   'الغرس',
#   'بزاريا',
#   'بيت',
#   'حوارة',
#   'الباذان',
#   'جماعين',
#   'حوارة',
#   'بوابة',
#   'زعترة',
#   'يتسهار',
#   'حواره',
#   'رام',
#   'بيت',
#   'ائيل',
#   'البيرة',
#   'الجلزون',
#   'مخماس',
#   'عين',
#   'عيون',
#   'عطارة',
#   'روابي',
#   'عطارة',
#   'رام',
#   'دير',
#   'ترمسعيا',
#   'عيلي',
#   'سنجل',
#   'عوفرا',
#   'النبي',
#   'سلفيت',
#   'بروقين',
#   'بروقين',
#   'بركان',
#   'سلفيت',
#   'بروقين',
#   'سلفيت',
#   'سلفيت',
#   'ارئيل',
#   'ارائيل',
#   'كدوميم',
#   'واد',
#   'دير',
#   'واد',
#   'ياسوف',
#   'سلفيت',
#   'كفل',
#   'قلقيلية',
#   'الطبيب',
#   'النبي',
#   'النفق',
#   'حبلة',
#   'كفر',
#   'عزون',
#   'عزون',
#   'طولكرم',
#   'عناب',
#   'الكفريات',
#   'بيت',
#   'المصانع',
#   'حجة',
#   'الفندق',
#   'واد',
#   'بيت',
#   'جنين',
#   'حومش',
#   'بزاريا',
#   'بزاريا',
#   'الغرس',
#   'جبع',
#   'عصيرة',
#   'نابلس',
#   'السيلة',
#   'عطارة',
#   'بلعا',
#   'حرميش',
#   'طوباس',
#   'لحمرا',
#   'طوباس',
#   'الباذان',
#   'نابلس',
#   'اريحا',
#   'الحمرا',
#   'افرايم',
#   'DCO',
#   'يا',
#   'ضواحي',
#   'قلنديا',
#   'كفر',
#   'جبع',
#   'حزما',
#   'عناتا',
#   'الزعيم',
#   'معالي',
#   'العيزرية',
#   'الكونتينر',
#   'بيت',
#   'العبيدية',
#   'بيت',
#   'تقوع',
#   'تل',
#   'جناتا',
#   'النشاش',
#   'زعتره',
#   'بيت',
#   'بيت',
#   'الخليل',
#   'المنشية',
#   'سعير',
#   'بيت',
#   'عصيون',
#   'فرات',
#   'فرات',
#   'فرش',
#   'حلحول',
#   'بيت',
#   'دورا',
#   'بيت',
#   'يطا',
#   'الظاهرية',
#   'العروب',
#   'دورا',
#   'ترقوميا',
#   'المصانع',
#   'بيت',
#   'دير',
#   'المربعة',
#   'الحمرا',
#   'اريحا',
#   'راس',
#   'فرش',
#   'دورا',
#   'المربعة',
#   'قصيرة',
#   'عطاره',
#   'بير',
#   ...],
#  ['مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'واقف',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلقه',
#   'اغلاق',
#   'مغلقة',
#   'مغلقه',
#   'اغلاقة',
#   'وقووف',
#   'واقف',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'اغلاق',
#   'مغلق',
#   'مغلقة',
#   'واقفة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'وقوف',
#   'مسكرينو',
#   'مغلقة',
#   'مغلقة',
#   'سكر',
#   'مغلقة',
#   'مغلقة',
#   'سكرو',
#   'اغلا',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'سكروها',
#   'مغلقة',
#   'واقف',
#   'اغلاق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقه',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مسكره',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مسكره',
#   'مسكر',
#   'واقفه',
#   'مغلق',
#   'مغلق',
#   'واقف',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'واقفة',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلقه',
#   'اغلاق',
#   'مغلق',
#   'مغلق',
#   'تسكر',
#   'مغلق',
#   'مغلق',
#   'وقف',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'واقف',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'بسكر',
#   'واقف',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'بسكر',
#   'مسكرة',
#   'مغلقة',
#   'مغلقة',
#   'واقفه',
#   'وسكرو',
#   'مسكر',
#   'واقف',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'ماسكين',
#   'اغلاق',
#   'اغلاق',
#   'الوقوف',
#   'مغلقه',
#   'مغلقة',
#   'مغلقه',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'موقف',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقه',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقه',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مسكره',
#   'مغلق',
#   'مغلقه',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'اغلاق',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'سكرت',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'وقوف',
#   'مغلق',
#   'اغلاق',
#   'مغلقة',
#   'مغلق',
#   'وقووف',
#   'اغلاق',
#   'وقووف',
#   'اغلاق',
#   'وقوف',
#   'توقف',
#   'مغلقة',
#   'اغلاق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'وقوف',
#   'وقوف',
#   'وقوف',
#   'سكرت',
#   'وقوف',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'واقفه',
#   'واقف',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'وسكر',
#   'وقووف',
#   'مغلقة',
#   'متوقف',
#   'مغلق',
#   'وقوف',
#   'واقفة',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'سكرت',
#   'مغلقة',
#   'مغلقة',
#   'اغلاق',
#   'مغلق',
#   'واقف',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقه',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مسكره',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'يسكرو',
#   'مغلقة',
#   'مغلقة',
#   'سكر',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقه',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'واقف',
#   'مغلقة',
#   'واقف',
#   'سكرت',
#   'مغلق',
#   'مغلق',
#   'مغلقه',
#   'واقف',
#   'واقف',
#   'مغلق',
#   'مغلقة',
#   'وقوف',
#   'مغلقة',
#   'اخلاق',
#   'مغلق',
#   'مغلق',
#   'بسكر',
#   'واقف',
#   'مغلق',
#   'مغلقة',
#   'واقفة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'واقف',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'واقف',
#   'مغلقه',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقه',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مسكره',
#   'مغلق',
#   'مغلقه',
#   'واقف',
#   'واقف',
#   'اغلاق',
#   'مغلقه',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مسكرينو',
#   'مغلق',
#   'مغلق',
#   'مغلقه',
#   'مغلق',
#   'مغلقه',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مسكرين',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'اغلاق',
#   'اغلاق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'الاغلاق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'واقفة',
#   'وقوف',
#   'مغلقة',
#   'وقوف',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'وقف',
#   'وقوف',
#   'مغلق',
#   'مغلق',
#   'اغلاق',
#   'مغلق',
#   'واقف',
#   'مغلق',
#   'وقف',
#   'مغلق',
#   'مغلق',
#   'ومسكرين',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقه',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مسكره',
#   'مغلق',
#   'وقوف',
#   'مسكر',
#   'مغلق',
#   'واقف',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'وقوف',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقه',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'وقف',
#   'مغلقة',
#   'اغلاق',
#   'مغلق',
#   'ومسكر',
#   'سكرو',
#   'مغلق',
#   'سكرت',
#   'واقفه',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقه',
#   'ومغلق',
#   'وقوف',
#   'واقف',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'متوقفة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مسكرة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقه',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مسكره',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'واقف',
#   'سكرت',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'متوقف',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلقه',
#   'مغلق',
#   'واقف',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'وقوف',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'وقوف',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'سكرو',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'واقفه',
#   'واقف',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'واقفه',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'واقف',
#   'مسكرين',
#   'سكرت',
#   'وقف',
#   'مغلقة',
#   'واقف',
#   'مغلق',
#   'مغلقه',
#   'ومسكرين',
#   'وقوف',
#   'مغلق',
#   'سكرو',
#   'مسكر',
#   'مغلق',
#   'مغلق',
#   'اغلاق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'باغلاق',
#   'واقف',
#   'واقفة',
#   'واقف',
#   'واقف',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقه',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مسكره',
#   'مغلق',
#   'مغلق',
#   'واقف',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'واقف',
#   'مغلق',
#   'مسكرين',
#   'واقف',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'وقووف',
#   'واقفة',
#   'اغلق',
#   'مغلق',
#   'مغلق',
#   'اغلاق',
#   'اغلاق',
#   'اخلاق',
#   'سكر',
#   'وقوف',
#   'سكر',
#   'واقف',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'توقف',
#   'وقف',
#   'مغلق',
#   'واقف',
#   'مغلق',
#   'وواقف',
#   'مغلقة',
#   'وقوف',
#   'اغلاق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقه',
#   'وقوف',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقه',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مغلقة',
#   'مسكره',
#   'مغلق',
#   'ميسره',
#   'وقوف',
#   'مغلقة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'واقفة',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'واقف',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'اغلاق',
#   'اغلاق',
#   'واغلاق',
#   'واغلاق',
#   'مغلق',
#   'الاغلاق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'مغلق',
#   'اغلاق',
#   'مغلق',
#   'مغلق',
#   ...],
#  ['سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'تحت',
#   'سالك',
#   'تحت',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'فتح',
#   'سالك',
#   'وفاضي',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكه',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'تحت',
#   'سالك',
#   'تحت',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سألك',
#   'تحت',
#   'سألك',
#   'سألك',
#   'سألك',
#   'سألك',
#   'سالك',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'فاتحة',
#   'فاتحة',
#   'تحت',
#   'سالك',
#   'فاتح',
#   'وسالك',
#   'فاضي',
#   'سالك',
#   'سالكة',
#   'فتح',
#   'فاضي',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'تحت',
#   'سالك',
#   'تحت',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'وفاضية',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكه',
#   'سالك',
#   'سالكين',
#   'سالك',
#   'سالكين',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'فاتح',
#   'وسالك',
#   'سالك',
#   'سالكه',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكه',
#   'سالكه',
#   'سالك',
#   'فاضي',
#   'فاتح',
#   'وسالك',
#   'الكهف',
#   'لك',
#   'سالك',
#   'سلك',
#   'فاتحة',
#   'وسالكة',
#   'سالكة',
#   'سالكه',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'فاتحة',
#   'وسالكة',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'فتحت',
#   'وسالكة',
#   'سالكة',
#   'سالك',
#   'فاتحة',
#   'وسالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'فاتحة',
#   'وسالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'فتحو',
#   'سالك',
#   'فاضي',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'فتح',
#   'وسلكت',
#   'فاتحة',
#   'سالك',
#   'فاتحه',
#   'فاتحة',
#   'وسالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'فتحت',
#   'سالكة',
#   'بتمشي',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سألك',
#   'سالك',
#   'سالك',
#   'فتح',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالكين',
#   'سالك',
#   'وبمشو',
#   'سالك',
#   'سالك',
#   'فاتحة',
#   'تحت',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'فاتحة',
#   'وسالكة',
#   'سالكة',
#   'سالك',
#   'تحت',
#   'سالك',
#   'فاضي',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'فتحت',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'وسالكه',
#   'فاتح',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'بسئلوك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'يسلك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'فتح',
#   'سلكت',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'تحت',
#   'سالك',
#   'تحت',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'فاتحة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'فتح',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'تحت',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'فاتح',
#   'سالك',
#   'يسلك',
#   'فتح',
#   'يسلك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'يمشوا',
#   'سالك',
#   'سالك',
#   'سالك',
#   'تحت',
#   'سالك',
#   'فاتحين',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'بمشو',
#   'سالك',
#   'سالك',
#   'سالك',
#   'فتحت',
#   'وسالكة',
#   'سالك',
#   'فتح',
#   'سالكة',
#   'فاتح',
#   'فاضي',
#   'وسالك',
#   'سالك',
#   'سالك',
#   'سالكه',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'بفتح',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'وسالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'تحت',
#   'سالك',
#   'سالك',
#   'تحت',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكه',
#   'سالك',
#   'سالكة',
#   'سالكه',
#   'سالك',
#   'فاتحه',
#   'سالك',
#   'سالكه',
#   'سالك',
#   'سالكين',
#   'سالكه',
#   'فاتحة',
#   'سالكة',
#   'سالكه',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالكة',
#   'سالكة',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'فتح',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'تحت',
#   'سالك',
#   'تحت',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكه',
#   'فاتح',
#   'وسالك',
#   'فاتحه',
#   'وسالكه',
#   'تحت',
#   'سألكه',
#   'مفتوحة',
#   'فاتحة',
#   'وسالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'بمشي',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكين',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'وبسلك',
#   'سالك',
#   'سلك',
#   'فاتح',
#   'وسالك',
#   'بمشي',
#   'سالك',
#   'بمشي',
#   'بمشي',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'تحت',
#   'سالك',
#   'تحت',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'لك',
#   'لك',
#   'لك',
#   'سالكة',
#   'سالك',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سلك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالكه',
#   'سالكه',
#   'سالكه',
#   'سالكين',
#   'سالكه',
#   'سالكة',
#   'فتحت',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سلك',
#   'سالك',
#   'وسالكه',
#   'سالكه',
#   'فتح',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'فاتح',
#   'سالكة',
#   'سالك',
#   'فتح',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالكه',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكه',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سلكت',
#   'فاتحه',
#   'وسالكه',
#   'سالكة',
#   'سالك',
#   'سالكة',
#   'فتحت',
#   'سالك',
#   'فتحو',
#   'سالك',
#   'فتح',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'وفاضي',
#   'سالك',
#   'سالك',
#   'سالك',
#   'بمشي',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'فاضي',
#   'سالك',
#   'سالك',
#   'فاضية',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'تحت',
#   'سالك',
#   'فاتحة',
#   'سالكة',
#   'سالكة',
#   'تحت',
#   'سالك',
#   'سالكه',
#   'فاضيه',
#   'فاتحة',
#   'وسالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'فتحت',
#   'وسالكة',
#   'تحت',
#   'سالك',
#   'سالكه',
#   'سالك',
#   'وبمشي',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'فاتحة',
#   'وسالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'فاتحة',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالكة',
#   'وسالكة',
#   'سالك',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالكه',
#   'سلك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'بتمشي',
#   'سالك',
#   'تفتح',
#   'فتحت',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكه',
#   'فاتح',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'فتح',
#   'مشوا',
#   'سالكه',
#   'بمشي',
#   'سالكه',
#   'فاتحه',
#   'تحت',
#   'سالكه',
#   'سالكه',
#   'سالك',
#   'سالك',
#   'سالك',
#   'تحت',
#   'سالك',
#   'سالكة',
#   'سالكة',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'فتح',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'فاتحه',
#   'سالك',
#   'سالك',
#   'تحت',
#   'سالك',
#   'سالكة',
#   'سالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'فاتحة',
#   'وسالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'فاتحة',
#   'سالك',
#   'فاتحة',
#   'وسالكة',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكه',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكه',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالك',
#   'سالكة',
#   'وسلكت',
#   ...],
#  ['بورين',
#   'شرف',
#   'فوريك',
#   'شمرون',
#   'قانا',
#   'ليد',
#   'الله',
#   'الحرامية',
#   'ايل',
#   'حارس',
#   'استيا',
#   'شمرون',
#   'الغراب',
#   'شرف',
#   'شرف',
#   'شمرون',
#   'شرف',
#   'ليد',
#   'بورين',
#   'شرف',
#   'فوريك',
#   'شمرون',
#   'قانا',
#   'ليد',
#   'الله',
#   'الحرامية',
#   'ايل',
#   'حارس',
#   'استيا',
#   'شرف',
#   'بلوط',
#   'شرف',
#   'الجورة',
#   'الحرامية',
#   'الحرامية',
#   'شرف',
#   'عقب',
#   'بورين',
#   'شرف',
#   'فوريك',
#   'شمرون',
#   'قانا',
#   'ليد',
#   'الله',
#   'الحرامية',
#   'ايل',
#   'حارس',
#   'استيا',
#   'شرف',
#   'زيت',
#   'شمرون',
#   'شرف',
#   'صالح',
#   'زيت',
#   'الغراب',
#   'ليد',
#   'شرف',
#   'سينيا',
#   'الجورة',
#   'الجورة',
#   'الهوى',
#   'الجورة',
#   'الجورة',
#   'بيجن',
#   'النار',
#   'شرف',
#   'الغراب',
#   'جالا',
#   'الشرقية',
#   'ايل',
#   'سينيا',
#   'الهوى',
#   'الجورة',
#   'الياس',
#   'ليد',
#   'الغراب',
#   'الهوى',
#   'الجورة',
#   'شرف',
#   'النار',
#   'زيت',
#   'الحرامية',
#   'شرف',
#   'زيت',
#   'شرف',
#   'الجورة',
#   'قانا',
#   'شرف',
#   'زيت',
#   'سينيا',
#   'الجلزون',
#   'سينيا',
#   'الله',
#   'الغراب',
#   'شرف',
#   'سينيا',
#   'زيت',
#   'شمرون',
#   'الشمالية',
#   'الحرامية',
#   'شرف',
#   'جالا',
#   'عقب',
#   'زيت',
#   'الهوى',
#   'سينيا',
#   'سينيا',
#   'لحم',
#   'شرف',
#   'الياس',
#   'فوريك',
#   'الغراب',
#   'ايل',
#   'شرف',
#   'سينيا',
#   'شرف',
#   'الجورة',
#   'عور',
#   'الشرقية',
#   'ايل',
#   'الله',
#   'شرف',
#   'الغراب',
#   'الحرامية',
#   'شرف',
#   'شرف',
#   'ادوميم',
#   'ادوميم',
#   'شمرون',
#   'شرف',
#   'الجورة',
#   'الله',
#   'جالا',
#   'شرف',
#   'شمرون',
#   'ادوميم',
#   'الجورة',
#   'الجورة',
#   'شرف',
#   'سينيا',
#   'زيت',
#   'شمرون',
#   'شرف',
#   'الغراب',
#   'الله',
#   'الحرامية',
#   'قانا',
#   'استيا',
#   'سينيا',
#   'عقب',
#   'الله',
#   'شرف',
#   'بورين',
#   'شرف',
#   'فوريك',
#   'شمرون',
#   'قانا',
#   'ليد',
#   'الله',
#   'الحرامية',
#   'ايل',
#   'حارس',
#   'استيا',
#   'شمس',
#   'شرف',
#   'شرف',
#   'شمرون',
#   'الجورة',
#   'الهوى',
#   'الغراب',
#   'ادوميم',
#   'الجورة',
#   'الغراب',
#   'شرف',
#   'شرف',
#   'شمرون',
#   'حارس',
#   'زيت',
#   'سينيا',
#   'فوريك',
#   'الحرامية',
#   'ايل',
#   'زيت',
#   'شرف',
#   'شرف',
#   'جالا',
#   'ادوميم',
#   'شرف',
#   'شمرون',
#   'فوريك',
#   'بورين',
#   'الله',
#   'سينيا',
#   'الحرامية',
#   'الله',
#   'بلوط',
#   'صالح',
#   'قانا',
#   'استيا',
#   'قانا',
#   'حارس',
#   'الياس',
#   'لاقف',
#   'ليد',
#   'قانا',
#   'ليد',
#   'القدس',
#   'عقب',
#   'ادوميم',
#   'لحم',
#   'ساحور',
#   'الربيع',
#   'لحم',
#   'الهوى',
#   'شرف',
#   'الجورة',
#   'الهوى',
#   'زيت',
#   'بورين',
#   'شرف',
#   'فوريك',
#   'شمرون',
#   'قانا',
#   'ليد',
#   'الله',
#   'الحرامية',
#   'ايل',
#   'حارس',
#   'استيا',
#   'شرف',
#   'سينيا',
#   'شرف',
#   'شمس',
#   'الهوى',
#   'سينيا',
#   'شرف',
#   'ادوميم',
#   'شرف',
#   'الهوى',
#   'شرف',
#   'الغراب',
#   'ادوميم',
#   'النار',
#   'بورين',
#   'شرف',
#   'فوريك',
#   'شمرون',
#   'قانا',
#   'ليد',
#   'الله',
#   'الحرامية',
#   'ايل',
#   'حارس',
#   'استيا',
#   'الجورة',
#   'الهوى',
#   'شرف',
#   'الربيع',
#   'الجورة',
#   'شرف',
#   'شمرون',
#   'بورين',
#   'الجورة',
#   'شرف',
#   'شرف',
#   'شرف',
#   'جالا',
#   'شرف',
#   'شرف',
#   'النفق',
#   'الغراب',
#   'الجورة',
#   'الهوى',
#   'ساحور',
#   'الغراب',
#   'الغراب',
#   'شرف',
#   'الغراب',
#   'شرف',
#   'شرف',
#   'ادوميم',
#   'سينيا',
#   'عقب',
#   'الجورة',
#   'شرف',
#   'شرف',
#   'زيت',
#   'شمرون',
#   'شرف',
#   'سينيا',
#   'جالا',
#   'شرف',
#   'شرف',
#   'الجورة',
#   'سينيا',
#   'شمرون',
#   'سينيا',
#   'شرف',
#   'سينيا',
#   'بلوط',
#   'بلوط',
#   'شرف',
#   'ايل',
#   'فوريك',
#   'ايل',
#   'شرف',
#   'صالح',
#   'صالح',
#   'سينيا',
#   'شرف',
#   'ادوميم',
#   'الغراب',
#   'فوريك',
#   'فوريك',
#   'الغراب',
#   'حارس',
#   'شرف',
#   'شمرون',
#   'فوريك',
#   'الهوى',
#   'الجورة',
#   'عقب',
#   'الله',
#   'شرف',
#   'سينيا',
#   'صالح',
#   'شرف',
#   'عقب',
#   'الله',
#   'شمرون',
#   'شرف',
#   'ايل',
#   'عقب',
#   'الله',
#   'الغراب',
#   'سينيا',
#   'شرف',
#   'ايل',
#   'سينيا',
#   'الله',
#   'الهوى',
#   'الجورة',
#   'عقب',
#   'لحم',
#   'صالح',
#   'سينيا',
#   'الحرامية',
#   'شرف',
#   'الحرامية',
#   'شرف',
#   'الجورة',
#   'الحرامية',
#   'سينيا',
#   'الله',
#   'عقب',
#   'سينيا',
#   'الهوى',
#   'الجورة',
#   'ادوميم',
#   'شرف',
#   'قانا',
#   'لحم',
#   'ساحور',
#   'الغراب',
#   'ايل',
#   'الهوى',
#   'الجورة',
#   'شرف',
#   'ادوميم',
#   'عقب',
#   'شرف',
#   'الجورة',
#   'ادوميم',
#   'شرف',
#   'ايل',
#   'شرف',
#   'ايل',
#   'الجورة',
#   'ايل',
#   'عقب',
#   'شرف',
#   'عقب',
#   'شرف',
#   'شرف',
#   'شمرون',
#   'شرف',
#   'شرف',
#   'شمرون',
#   'فوريك',
#   'بورين',
#   'الله',
#   'سينيا',
#   'الحرامية',
#   'الله',
#   'بلوط',
#   'صالح',
#   'قانا',
#   'استيا',
#   'قانا',
#   'حارس',
#   'الياس',
#   'لاقف',
#   'ليد',
#   'قانا',
#   'ليد',
#   'القدس',
#   'عقب',
#   'ادوميم',
#   'لحم',
#   'ساحور',
#   'الربيع',
#   'لحم',
#   'الهوى',
#   'فوريك',
#   'الغراب',
#   'سينيا',
#   'شرف',
#   'فوريك',
#   'سينيا',
#   'الهوى',
#   'بورين',
#   'شرف',
#   'فوريك',
#   'شمرون',
#   'قانا',
#   'ليد',
#   'الله',
#   'الحرامية',
#   'ايل',
#   'حارس',
#   'استيا',
#   'شرف',
#   'ادوميم',
#   'الجورة',
#   'الهوى',
#   'شرف',
#   'الجورة',
#   'الهوى',
#   'فوريك',
#   'شرف',
#   'فوريك',
#   'شرف',
#   'زيت',
#   'سينيا',
#   'الهوى',
#   'الهوى',
#   'الجورة',
#   'جالا',
#   'شرف',
#   'شمرون',
#   'الحرامية',
#   'ادوميم',
#   'الجورة',
#   'شرف',
#   'عقب',
#   'شرف',
#   'شمرون',
#   'شرف',
#   'شمرون',
#   'الهوى',
#   'الجورة',
#   'شرف',
#   'لحم',
#   'سينيا',
#   'شرف',
#   'الحرامية',
#   'الغراب',
#   'شرف',
#   'شرف',
#   'سينيا',
#   'الهوى',
#   'شرف',
#   'شرف',
#   'الياس',
#   'عقب',
#   'الله',
#   'سينيا',
#   'ايل',
#   'شرف',
#   'شرف',
#   'شمرون',
#   'الياس',
#   'شرف',
#   'سينيا',
#   'شرف',
#   'شرف',
#   'ادوميم',
#   'زيت',
#   'شرف',
#   'سينيا',
#   'سينيا',
#   'سينيا',
#   'شرف',
#   'شرف',
#   'سينيا',
#   'سينيا',
#   'شرف',
#   'الله',
#   'سينيا',
#   'شرف',
#   'سينيا',
#   'حارس',
#   'شمرون',
#   'شرف',
#   'الجورة',
#   'صالح',
#   'سينيا',
#   'سينيا',
#   'سينيا',
#   'الجورة',
#   'شرف',
#   'ايل',
#   'شرف',
#   'شمرون',
#   'الغراب',
#   'الجورة',
#   'بلوط',
#   'الهوى',
#   'شرف',
#   'شرف',
#   'لحم',
#   'عقب',
#   'الله',
#   'ايل',
#   'ايل',
#   'الله',
#   'شرف',
#   'الجورة',
#   'لحم',
#   'لحم',
#   'شرف',
#   'سينيا',
#   'صالح',
#   'الحرامية',
#   'شرف',
#   'عقب',
#   'شرف',
#   'شرف',
#   'سينيا',
#   'شرف',
#   'الغراب',
#   'الجورة',
#   'الهوى',
#   'ايل',
#   'شرف',
#   'الهوى',
#   'الجورة',
#   'شمرون',
#   'شرف',
#   'شرف',
#   'شمرون',
#   'فوريك',
#   'بورين',
#   'الله',
#   'سينيا',
#   'الحرامية',
#   'الله',
#   'بلوط',
#   'صالح',
#   'قانا',
#   'استيا',
#   'قانا',
#   'حارس',
#   'الياس',
#   'لاقف',
#   'ليد',
#   'قانا',
#   'ليد',
#   'القدس',
#   'عقب',
#   'ادوميم',
#   'لحم',
#   'ساحور',
#   'الربيع',
#   'لحم',
#   'لحم',
#   'الهوى',
#   'سينيا',
#   'الهوى',
#   'الغراب',
#   'بلوط',
#   'بورين',
#   'شرف',
#   'فوريك',
#   'شمرون',
#   'قانا',
#   'ليد',
#   'الله',
#   'الحرامية',
#   'ايل',
#   'حارس',
#   'استيا',
#   'الغراب',
#   'الجورة',
#   'الهوى',
#   'حارس',
#   'الغراب',
#   'زيت',
#   'شمرون',
#   'شرف',
#   'شرف',
#   'الهوى',
#   'الجورة',
#   'شرف',
#   'ليد',
#   'قانا',
#   'ليد',
#   'شرف',
#   'شمرون',
#   'فوريك',
#   'بورين',
#   'شرف',
#   'بورين',
#   'شرف',
#   'فوريك',
#   'شمرون',
#   'قانا',
#   'ليد',
#   'الله',
#   'الحرامية',
#   'ايل',
#   'حارس',
#   'استيا',
#   'الجورة',
#   'فوريك',
#   'سينيا',
#   'شرف',
#   'النار',
#   'شرف',
#   'الجورة',
#   'الربيع',
#   'الجورة',
#   'جالا',
#   'شرف',
#   'الغراب',
#   'شرف',
#   'ادوميم',
#   'الهوى',
#   'شرف',
#   'شرف',
#   'الجورة',
#   'سينيا',
#   'شرف',
#   'شرف',
#   'شرف',
#   'فوريك',
#   'شرف',
#   'شرف',
#   'فوريك',
#   'الله',
#   'شمرون',
#   'الحرامية',
#   'الجورة',
#   'شرف',
#   'ادوميم',
#   'سينيا',
#   'الحرامية',
#   'سينيا',
#   'شرف',
#   'الغراب',
#   'شرف',
#   'صافوت',
#   'ايل',
#   'الله',
#   'ايل',
#   'شرف',
#   'ايل',
#   'شرف',
#   'شرف',
#   'الجورة',
#   'شرف',
#   'سينيا',
#   'صالح',
#   'بلوط',
#   'بلوط',
#   'الجورة',
#   'الهوى',
#   'سينيا',
#   'ايل',
#   'بورين',
#   'شرف',
#   'فوريك',
#   'شمرون',
#   'قانا',
#   'ليد',
#   'الله',
#   'الحرامية',
#   'ايل',
#   'حارس',
#   'استيا',
#   'شرف',
#   'شمرون',
#   'شرف',
#   'الهوى',
#   'سينيا',
#   'صالح',
#   'الحرامية',
#   'فوريك',
#   'ايل',
#   'سينيا',
#   'عقب',
#   'شرف',
#   'ايل',
#   'الغراب',
#   'الجورة',
#   'شمرون',
#   'شمرون',
#   'شرف',
#   'شرف',
#   'صالح',
#   'بورين',
#   'شرف',
#   'فوريك',
#   'شمرون',
#   'قانا',
#   'ليد',
#   'الله',
#   'الحرامية',
#   'ايل',
#   'حارس',
#   'استيا',
#   'الغراب',
#   'ايل',
#   'شمرون',
#   'سينيا',
#   'الياس',
#   'سينيا',
#   'ايل',
#   'الله',
#   'شرف',
#   'الجورة',
#   'شرف',
#   'شمرون',
#   'فوريك',
#   'بورين',
#   'الله',
#   'سينيا',
#   'الحرامية',
#   'الله',
#   'بلوط',
#   'صالح',
#   'قانا',
#   'استيا',
#   'قانا',
#   'حارس',
#   'الياس',
#   'لاقف',
#   'ليد',
#   'قانا',
#   'ليد',
#   'القدس',
#   'عقب',
#   'ادوميم',
#   'لحم',
#   'ساحور',
#   'الربيع',
#   'لحم',
#   'الهوى',
#   'الهوى',
#   'الجورة',
#   'شرف',
#   'سينيا',
#   'سينيا',
#   'الحرامية',
#   'شرف',
#   'شمرون',
#   'فوريك',
#   'بورين',
#   'ادوميم',
#   'شمرون',
#   'صالح',
#   'شرف',
#   'الغراب',
#   'ادوميم',
#   'سينيا',
#   'الهوى',
#   'الغراب',
#   'شرف',
#   'شمرون',
#   'فوريك',
#   'بورين',
#   'الحرامية',
#   'الله',
#   'الربيع',
#   'الهوى',
#   'الجورة',
#   'شرف',
#   'ليد',
#   'شمرون',
#   'شرف',
#   'صالح',
#   'جالا',
#   'الغراب',
#   'الهوى',
#   'الجورة',
#   'ايل',
#   'الحرامية',
#   'شرف',
#   'زيت',
#   'سينيا',
#   'القبلية',
#   'شرف',
#   'صالح',
#   'ادوميم',
#   'سينيا',
#   'شرف',
#   'شرف',
#   'شمرون',
#   'شرف',
#   'ادوميم',
#   'شرف',
#   'الهوى',
#   'الجورة',
#   'سينيا',
#   'سينيا',
#   'صالح',
#   'الحرامية',
#   'الله',
#   'الله',
#   'شرف',
#   'بلوط',
#   'شرف',
#   'بلوط',
#   'شرف',
#   'ايل',
#   'شرف',
#   'فوريك',
#   'فوريك',
#   'شرف',
#   'ادوميم',
#   'النار',
#   'سينيا',
#   'الله',
#   'فوريك',
#   'ايل',
#   'سينيا',
#   'سينيا',
#   'سينيا',
#   'عقب',
#   'شمرون',
#   'شرف',
#   'الله',
#   'صالح',
#   'شرف',
#   'الغراب',
#   'ايل',
#   'الجورة',
#   'شرف',
#   'ادوميم',
#   'الهوى',
#   'ادوميم',
#   'ايل',
#   'ايل',
#   'الحرامية',
#   'ايل',
#   'شرف',
#   'سينيا',
#   'الله',
#   'لاقف',
#   'صالح',
#   'الله',
#   'شرف',
#   'بلوط',
#   'الربيع',
#   'لحم',
#   'ساحور',
#   'الغراب',
#   'ايل',
#   'شرف',
#   'الهوى',
#   'سينيا',
#   'الجورة',
#   'الجورة',
#   'سينيا',
#   'الله',
#   'الهوى',
#   'شرف',
#   'شرف',
#   'الغراب',
#   'الجورة',
#   'عقب',
#   'الهوى',
#   'الهوى',
#   'شرف',
#   'ايل',
#   'زيت',
#   'شرف',
#   'شمرون',
#   'الهوى',
#   'شرف',
#   'شمرون',
#   'فوريك',
#   'بورين',
#   'الله',
#   'سينيا',
#   'الحرامية',
#   'الله',
#   'بلوط',
#   'صالح',
#   'قانا',
#   'استيا',
#   'قانا',
#   'حارس',
#   'الياس',
#   'لاقف',
#   'ليد',
#   'قانا',
#   'ليد',
#   'القدس',
#   'عقب',
#   'ادوميم',
#   'لحم',
#   'ساحور',
#   'الربيع',
#   'لحم',
#   'الجورة',
#   'الهوى',
#   'شرف',
#   'سينيا',
#   'سينيا',
#   'شرف',
#   'شرف',
#   'سينيا',
#   'الهوى',
#   'فوريك',
#   'شرف',
#   'الجورة',
#   'الهوى',
#   'شرف',
#   'شرف',
#   'شمرون',
#   'فوريك',
#   'بورين',
#   'شرف',
#   'شرف',
#   'شرف',
#   'فوريك',
#   'شمرون',
#   'جالا',
#   'الله',
#   'بورين',
#   'شرف',
#   'فوريك',
#   'شمرون',
#   'قانا',
#   'ليد',
#   'الله',
#   'زيت',
#   'الحرامية',
#   'ايل',
#   'حارس',
#   'استيا',
#   'شرف',
#   'الربيع',
#   'سينيا',
#   'شرف',
#   'شمرون',
#   'شرف',
#   'شرف',
#   'شرف',
#   'الله',
#   'لحم',
#   'لحم',
#   'الجورة',
#   'شرف',
#   'شرف',
#   'الله',
#   'سينيا',
#   'شمرون',
#   'الهوى',
#   'الهوى',
#   'شرف',
#   'شرف',
#   'ايل',
#   'بلوط',
#   'شرف',
#   'شرف',
#   'ايل',
#   'شرف',
#   'شرف',
#   'عقب',
#   'فوريك',
#   'شرف',
#   'الهوى',
#   'الجورة',
#   'ايل',
#   'شرف',
#   'الغراب',
#   'سينيا',
#   'الجورة',
#   'الله',
#   'بورين',
#   'شرف',
#   'فوريك',
#   'شمرون',
#   'قانا',
#   'ليد',
#   'الله',
#   'زيت',
#   'الحرامية',
#   ...],
#  ['شرطه',
#   'نازله',
#   'من',
#   'حادث',
#   'بعد',
#   'اشارات',
#   'باتجاه',
#   'تواجد',
#   'جيش',
#   'مع',
#   'شرطة',
#   'ومخالفات',
#   'الرجاء',
#   'من',
#   'كل',
#   'شخص',
#   'بقرا',
#   'التقرير',
#   'يكبس',
#   'أو',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'للداخل',
#   'للخارج',
#   'ونمر',
#   'صفراء',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'مع',
#   'تواجد',
#   'الجيش',
#   'ازمه',
#   'للخارج',
#   'الرئيسي',
#   'بالاتجاهين',
#   'إشارات',
#   'حارس',
#   'طريق',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'حاجز',
#   'كم',
#   'سياره',
#   'خط',
#   'عين',
#   'سينا',
#   'فوق',
#   'الجسر',
#   'والبلد',
#   'حاليا',
#   'اشارات',
#   'حاليا',
#   'راس',
#   'إلى',
#   'الحراميه',
#   'بالاتجاهين',
#   'الجسر',
#   'جسر',
#   'جباره',
#   'بوابة',
#   'بوابة',
#   'الشرقيه',
#   'مدخل',
#   'بوابة',
#   'مدخل',
#   'الغربي',
#   'طريق',
#   'السلامة',
#   'للجميع',
#   'صفحه',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'التلجرام',
#   'لاتنسونا',
#   'من',
#   'دعائكم',
#   'متواجد',
#   'معكم',
#   'عالخاص',
#   'تم',
#   'حاجز',
#   'الان',
#   'بالاتجاهين',
#   'بالاتجاهين',
#   'بداية',
#   'ازمه',
#   'ع',
#   'حاجز',
#   'لا',
#   'الداخل',
#   'الخارج',
#   'ازمه',
#   'دوار',
#   'ازمه',
#   'ماشيه',
#   'جرافه',
#   'بتفتح',
#   'الطريق',
#   'الفرعيه',
#   'بتجاه',
#   'الشمال',
#   'الجنوب',
#   'ازمه',
#   'وتفيش',
#   'بدون',
#   'تواجد',
#   'الجيش',
#   'تماما',
#   'دوار',
#   'بحري',
#   'بجميع',
#   'الاتجاهات',
#   'برضه',
#   'بجميع',
#   'الاتجاهات',
#   'مفرق',
#   'تمام',
#   'صره',
#   'لا',
#   'الخارج',
#   'فقط',
#   'نمرا',
#   'صفرا',
#   'من',
#   'كلا',
#   'الاتجاهين',
#   'دوار',
#   'سيارتين',
#   'شرطة',
#   'على',
#   'حاجز',
#   'بإتجاه',
#   'الجنوب',
#   'السير',
#   'حادث',
#   'بين',
#   'بكى',
#   'رسول',
#   'الله',
#   'ﷺ',
#   'يوما',
#   'فقالوا',
#   'الصحابة',
#   'ما',
#   'يبكيك',
#   'رسول',
#   'الله',
#   'قال',
#   'اشتقت',
#   'لأحبابي',
#   'قالوا',
#   'أولسنا',
#   'أحبابك',
#   'رسول',
#   'الله',
#   'قال',
#   'لا',
#   'أنتم',
#   'أصحابي',
#   'أما',
#   'أحبابي',
#   'فقوم',
#   'يأتون',
#   'من',
#   'بعدي',
#   'يؤمنون',
#   'بي',
#   'ولم',
#   'يروني',
#   'حبا',
#   'ل',
#   'ࢪسول',
#   'آللهہ',
#   'صـلوآ',
#   'عليهہ',
#   'الرجاء',
#   'من',
#   'كل',
#   'شخص',
#   'بقرا',
#   'التقرير',
#   'يكبس',
#   'أو',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'للداخل',
#   'للخارج',
#   'ونمر',
#   'صفراء',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'مع',
#   'تواجد',
#   'الجيش',
#   'كم',
#   'سياره',
#   'الرئيسي',
#   'بالاتجاهين',
#   'إشارات',
#   'حارس',
#   'طريق',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'حاجز',
#   'كم',
#   'سياره',
#   'خط',
#   'عين',
#   'سينا',
#   'فوق',
#   'الجسر',
#   'والبلد',
#   'حاليا',
#   'اشارات',
#   'حاليا',
#   'راس',
#   'إلى',
#   'الحراميه',
#   'بالاتجاهين',
#   'الجسر',
#   'جسر',
#   'جباره',
#   'بوابة',
#   'بوابة',
#   'الشرقيه',
#   'مدخل',
#   'بوابة',
#   'مدخل',
#   'الغربي',
#   'طريق',
#   'السلامة',
#   'للجميع',
#   'صفحه',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'التلجرام',
#   'لاتنسونا',
#   'من',
#   'دعائكم',
#   'متواجد',
#   'معكم',
#   'عالخاص',
#   'ازمه',
#   'حادث',
#   'عند',
#   'قبل',
#   'مفرق',
#   'علا',
#   'ما',
#   'يبدو',
#   'حادث',
#   'حاليا',
#   'بلشو',
#   'يمشو',
#   'منيح',
#   'شبه',
#   'حادث',
#   'بين',
#   'أريئيل',
#   'ورمزونات',
#   'مركبة',
#   'دهست',
#   'حيوان',
#   'وازمه',
#   'بالاتجاهين',
#   'بالاتجاهين',
#   'جسر',
#   'بالاتجاهين',
#   'بالاتجاهين',
#   'مفرق',
#   'بالاتجاهين',
#   'مفرق',
#   'بوابة',
#   'كفر',
#   'الديك',
#   'بوابة',
#   'فى',
#   'كلا',
#   'الاتجاهين',
#   'من',
#   'ثلث',
#   'ايام',
#   'ولا',
#   'سيارة',
#   'عليها',
#   'مرقنا',
#   'هلأ',
#   'النبي',
#   'يونس',
#   'اتجاه',
#   'النبي',
#   'يونس',
#   'اتجاه',
#   'البلد',
#   'جسر',
#   'حاليا',
#   'قبل',
#   'مفرق',
#   'مش',
#   'راضي',
#   'يمشي',
#   'ولا',
#   'سيارة',
#   '11',
#   '20',
#   'شرطة',
#   'ع',
#   'مفرق',
#   'مسواه',
#   'ع',
#   'خط',
#   '٩٠',
#   'عند',
#   'مدخل',
#   'مكب',
#   'النفايات',
#   'بالزبط',
#   'للخارج',
#   'في',
#   'شوية',
#   'ازمة',
#   'للخارج',
#   '11',
#   '13',
#   'بدون',
#   'جيش',
#   'بالاتجاهين',
#   'تمام',
#   'من',
#   'ل',
#   'مع',
#   'تواجد',
#   'سيارة',
#   'شرطة',
#   'للمتجه',
#   'للجنوب',
#   'ازمه',
#   'خانقة',
#   'باتجاه',
#   'الجنوب',
#   'بالاتجاهين',
#   'ابو',
#   'سكندر',
#   'حاجز',
#   'ولا',
#   'سياره',
#   'بالاتجاهين',
#   'سيارة',
#   'شرطة',
#   'بعد',
#   'إشارات',
#   'باتجاه',
#   'من',
#   'دوار',
#   'ل',
#   'كلو',
#   'تمام',
#   'شرطة',
#   'ع',
#   'دوار',
#   'بالاتجاهين',
#   'دوار',
#   'حاليا',
#   'ازعبم',
#   'لداخل',
#   'ازمه',
#   'للخارج',
#   'ماشيه',
#   'تفتيش',
#   'لشباب',
#   'ابو',
#   'سكندر',
#   'حاجز',
#   'شرطة',
#   'وجيش',
#   'للخارج',
#   'من',
#   'العيززبة',
#   'بالاتجاهين',
#   'بالكامل',
#   'تحديث',
#   'هلأ',
#   'للداخل',
#   'الخارج',
#   'مازال',
#   'معبر',
#   'للداخل',
#   'للخارج',
#   'ازمة',
#   'خفيفة',
#   'بالاتجاهين',
#   'بالاتجاهين',
#   'حاليا',
#   'باتجاه',
#   'الشمال',
#   'باتجاه',
#   'الجنوب',
#   'ازمة',
#   'وتفتيش',
#   'الرجاء',
#   'من',
#   'كل',
#   'شخص',
#   'بقرا',
#   'التقرير',
#   'يكبس',
#   'أو',
#   'تفاعلوا',
#   'معنا',
#   'بي',
#   'لنستمر',
#   'معكم',
#   'للداخل',
#   'للخارج',
#   'ونمر',
#   'صفراء',
#   'بكل',
#   'الاتجاهات',
#   'ال',
#   '17',
#   'مع',
#   'تواجد',
#   'الجيش',
#   'كم',
#   'سياره',
#   'الرئيسي',
#   'بالاتجاهين',
#   'إشارات',
#   'حارس',
#   'طريق',
#   'شوفه',
#   'كفر',
#   'اللبد',
#   'حاجز',
#   'كم',
#   'سياره',
#   'خط',
#   'عين',
#   'سينا',
#   'فوق',
#   'الجسر',
#   'والبلد',
#   'حاليا',
#   'اشارات',
#   'حاليا',
#   'راس',
#   'إلى',
#   'الحراميه',
#   'بالاتجاهين',
#   'الجسر',
#   'جسر',
#   'جباره',
#   'بوابة',
#   'بوابة',
#   'الشرقيه',
#   'مدخل',
#   'بوابة',
#   'مدخل',
#   'الغربي',
#   'طريق',
#   'السلامة',
#   'للجميع',
#   'صفحه',
#   'احوال',
#   'الطرق',
#   'وحواجز',
#   'الاحتلال',
#   'التلجرام',
#   'لاتنسونا',
#   'من',
#   'دعائكم',
#   'متواجد',
#   'معكم',
#   'عالخاص',
#   'بالاتجاهين',
#   'لا',
#   'تنسوا',
#   'الصلاة',
#   'على',
#   'رسولنا',
#   'الحبيب',
#   'والدعاء',
#   'لأهلنا',
#   'في',
#   'غزة',
#   'اللهم',
#   'صل',
#   'على',
#   'محمد',
#   'وعلى',
#   'آل',
#   'محمد',
#   'كما',
#   'صليت',
#   'على',
#   'إبراهيم',
#   'وعلى',
#   'آل',
#   'إبراهيم',
#   'وبارك',
#   'على',
#   'محمد',
#   'وعلى',
#   'آل',
#   'محمد',
#   'كما',
#   'باركت',
#   'على',
#   'إبراهيم',
#   'وعلى',
#   'آل',
#   'إبراهيم',
#   'إنك',
#   'حميد',
#   'مجيد',
#   'عورتافاضي',
#   'عليه',
#   'اربع',
#   'سيارات',
#   'بس',
#   'ماشي',
#   'الامور',
#   'عين',
#   'سينا',
#   'تماما',
#   'فوق',
#   'الجسر',
#   'تفتيش',
#   'عشؤائي',
#   'مفرق',
#   'دوار',
#   'سلمان',
#   'الفارسي',
#   'خط',
#   'لسا',
#   'بالاتجاهين',
#   'جباره',
#   'تماما',
#   'شوي',
#   'بصورلك',
#   'ياه',
#   'لا',
#   'تقلق',
#   'تماما',
#   'الرئسي',
#   'بالنسبة',
#   'مش',
#   'واضحة',
#   'الأمور',
#   'أو',
#   'إذا',
#   'حد',
#   'وصلو',
#   'يعطينا',
#   'خبر',
#   'ومشكور',
#   'والأغلب',
#   'انو',
#   'لحد',
#   'هاي',
#   'اللحظة',
#   'بوابة',
#   'حاجز',
#   'على',
#   'جورة',
#   'الشمعة',
#   'دوار',
#   'بوابة',
#   'دوار',
#   'اللدائن',
#   'بوابة',
#   'بوابة',
#   'عبدة',
#   'اموره',
#   'ماشيه',
#   'بالاتجاهين',
#   'خط',
#   'ونظيف',
#   'بوابات',
#   'الحواور',
#   'بوابات',
#   'جسر',
#   'ولا',
#   'سيارة',
#   'جسر',
#   'بالاتجاهين',
#   'بحري',
#   'بدون',
#   'جيش',
#   'ولا',
#   'سيارات',
#   'من',
#   'كف',
#   '٣٥',
#   'لراس',
#   'الجورة',
#   'كف',
#   '٣٥',
#   'ونظيف',
#   'بكل',
#   'الاتجاهات',
#   'من',
#   'رمزونات',
#   'النبي',
#   'يونس',
#   'لكف',
#   '٣٥',
#   'بالاتجاهين',
#   'النبي',
#   'يونس',
#   'باتجاه',
#   'باتجاه',
#   'من',
#   'بوابات',
#   'رمزونات',
#   'دوار',
#   'من',
#   'اليعازر',
#   'ونظيف',
#   'بالاتجاهين',
#   'رمزونات',
#   'اليعازر',
#   'حاجز',
#   'للخارج',
#   'وازمة',
#   'بالاتجاهين',
#   'تم',
#   'الفحص',
#   'بالاتجاهين',
#   'بالاتجاهين',
#   'حاجز',
#   'على',
#   'بوابة',
#   'اليوم',
#   'يبدأ',
#   'قانون',
#   'إضاءة',
#   'مصابيح',
#   'السيارة',
#   'بوابة',
#   'بوابة',
#   'الفحص',
#   'الساعه',
#   '07',
#   '00',
#   'بالاتجاهين',
#   'عش',
#   'غراب',
#   'لحاجز',
#   'تفتيش',
#   'باتجاه',
#   'الشمال',
#   'شارع',
#   'رقم',
#   '١',
#   'حاجز',
#   'بالاتجاهين',
#   'الي',
#   'بقدر',
#   'يساعد',
#   'في',
#   'شب',
#   'محتاج',
#   'مساعدة',
#   'شاحنتو',
#   'عملت',
#   'حادث',
#   'وبدو',
#   'ينقل',
#   'البضاعة',
#   'معلم',
#   'من',
#   'بعد',
#   'اذنك',
#   'ممكن',
#   'تعمم',
#   'على',
#   'صفحات',
#   'اذا',
#   'في',
#   'شحن',
#   'طالعة',
#   'على',
#   'قريبة',
#   'من',
#   'تماما',
#   'ابو',
#   '٢٠',
#   'سياره',
#   'للخارج',
#   'والداخل',
#   'صباح',
#   'الخير',
#   'جمعه',
#   'مباركه',
#   'بالاتجاهين',
#   'بالاتجاهين',
#   'بالاتجاهين',
#   'بالاتجاهين',
#   'صباح',
#   'الخير',
#   'جمعة',
#   'مباركة',
#   'يارب',
#   'اجعل',
#   'هذا',
#   'اليوم',
#   'يوم',
#   'عزة',
#   'وفرج',
#   'لكل',
#   'مسلم',
#   'واعط',
#   'اهل',
#   'فلسطين',
#   'راحة',
#   'البال',
#   'وطيبة',
#   'ويسر',
#   'امورنا',
#   'في',
#   'يومنا',
#   'وغدنا',
#   'ياالله',
#   'وارحم',
#   'امواتنا',
#   'واموات',
#   'المسلمين',
#   'من',
#   'قرأ',
#   'سورة',
#   'كانت',
#   'له',
#   'نورا',
#   'من',
#   'مقامه',
#   'إلى',
#   'مكة',
#   'ومن',
#   'قرأ',
#   'عشر',
#   'آيات',
#   'من',
#   'آخرها',
#   'ثم',
#   'خرج',
#   'الدجال',
#   'لم',
#   'يضره',
#   'أهل',
#   'صلاة',
#   'الفجر',
#   'هجروا',
#   'لذيذ',
#   'النوم',
#   'ولبوا',
#   'نداء',
#   'الله',
#   'إنهم',
#   'هم',
#   'الفائزون',
#   'صلاة',
#   'الفجر',
#   'راغبين',
#   'الجنة',
#   'لمتابعة',
#   'اقتحام',
#   'الأن',
#   'https',
#   't',
#   'merassd',
#   'فضل',
#   'الصلاة',
#   'على',
#   'النبي',
#   'ترفع',
#   'درجات',
#   'المصلي',
#   'في',
#   'الجنة',
#   'سبب',
#   'في',
#   'استجابة',
#   'الدعاء',
#   'سبب',
#   'لنيل',
#   'منزلة',
#   'من',
#   'الرسول',
#   'سبب',
#   'لكفاية',
#   'هموم',
#   'العبد',
#   'وإن',
#   'عظمت',
#   'أنها',
#   'سبب',
#   'لنيل',
#   'شفاعة',
#   'النبي',
#   'كانوا',
#   'قليلا',
#   'من',
#   'ما',
#   'يهجعون',
#   'أتدرون',
#   'أعظم',
#   'لذة',
#   'في',
#   'الدنيا',
#   'ماهي',
#   'هي',
#   'سجدة',
#   'في',
#   'ظلمة',
#   'لا',
#   'يعلم',
#   'بها',
#   'إلا',
#   'الله',
#   'تناجي',
#   'ربك',
#   'يسمعك',
#   'إنه',
#   'ق',
#   'ࢪيب',
#   'مجيب',
#   'ف',
#   'لعل',
#   'سجدة',
#   'في',
#   'آخر',
#   'تضيء',
#   'عمرا',
#   'بأكمله',
#   'صـلآهہ',
#   'آلوت',
#   'ࢪ',
#   'يـا',
#   'رآغبين',
#   'جنآن',
#   'آلف',
#   'ࢪدوس',
#   'ولا',
#   'تنسوا',
#   'أن',
#   'تشملوا',
#   'اهلنا',
#   'في',
#   'غزة',
#   'في',
#   'دعائڪم',
#   'Dco',
#   'إنتشار',
#   'لحواجز',
#   'شرطة',
#   'الاحتلال',
#   'وتفتيش',
#   'دقيق',
#   'جدا',
#   'للمركبات',
#   'من',
#   'دوار',
#   'عدي',
#   'التميمي',
#   'لغاية',
#   'سطح',
#   'البحر',
#   'واندماج',
#   'تفتيش',
#   'سيارة',
#   'سيارة',
#   'باتجاه',
#   'الجنوب',
#   'قال',
#   'رسول',
#   'الله',
#   'ﷺ',
#   'إن',
#   'من',
#   'أفضل',
#   'أيامكم',
#   'يوم',
#   'الجمعة',
#   'فأكثروا',
#   'من',
#   'الصلاة',
#   'فيه',
#   'فإن',
#   'صلاتكم',
#   'معروضة',
#   'حاضرا',
#   'في',
#   'قلوبنا',
#   'وفي',
#   'أفكارنا',
#   'مهما',
#   'طال',
#   'غيابك',
#   'الأسير',
#   'المشرف',
#   'منذر',
#   'حطاب',
#   'حبيب',
#   'القلب',
#   'ربي',
#   'يهونها',
#   'عليك',
#   'وع',
#   'جميع',
#   'الأسرى',
#   'قلوبنا',
#   'ونشوفكم',
#   'عن',
#   'قريب',
#   'فضيلة',
#   'إدعو',
#   'فيها',
#   'للأسرى',
#   'و',
#   'لأهلنا',
#   'في',
#   'غزة',
#   'الفحص',
#   'لحد',
#   'الان',
#   'رمزونات',
#   'حارس',
#   'سده',
#   'قراوه',
#   'من',
#   'نص',
#   'ساعة',
#   'تاام',
#   'رمزونات',
#   'حارس',
#   'التحتا',
#   'الرئيسية',
#   'كلو',
#   'ازمة',
#   'باتجاه',
#   'الجنوب',
#   'والسير',
#   'جسر',
#   'جسر',
#   'دبوان',
#   'جسر',
#   'دوار',
#   'مفرق',
#   'اشارات',
#   'اشارات',
#   'الحرميه',
#   'اشارات',
#   'اشارات',
#   'اشارات',
#   'الجامعة',
#   'بوابة',
#   'الفحص',
#   'لحد',
#   'الان',
#   'جيش',
#   'مع',
#   'ضريبه',
#   'سيارات',
#   'التجاريه',
#   'حاجز',
#   'ع',
#   'بدايه',
#   'ازمه',
#   'ولا',
#   'اشي',
#   'الهيئه',
#   'حاجز',
#   'ع',
#   'الخارج',
#   'من',
#   'حادث',
#   'ع',
#   'طريق',
#   'جيش',
#   'على',
#   'الشارع',
#   'الرئيسي',
#   'مشاه',
#   ...]]

# %%
len(sentences)
# Out:
# 5

# %%
from gensim.models import Word2Vec

model = Word2Vec(sentences = sentences, vector_size = 100, window = 5, min_count = 1, workers = 4)
model.save("word2vec.model")

# %%
model = Word2Vec.load('/Users/mac2/University/Machine Learning/new repo/ROADWATCH/Checkpoints/word2vec.model')
model.train(sentences, total_examples=303768, epochs=50)# total example = len(sentences)
# Out:
# (2229482, 15188400)

# %%
vector = model.wv['فاتح']

sims = model.wv.most_similar('مغلقة', topn= 10)

# %%
vector
# Out:
# array([ 0.09641619, -0.8532384 , -0.51998705,  1.7144744 , -1.3087382 ,
#        -1.6101961 ,  1.7697259 ,  0.9414607 , -1.4284235 ,  0.9118669 ,
#         0.9046755 , -0.66683346, -0.02841954,  0.670945  , -0.9529426 ,
#        -0.64777625,  0.660346  , -1.4590149 , -1.1786588 , -2.0606382 ,
#         0.49953854, -0.03892268,  0.4235793 , -0.6861609 , -0.512944  ,
#        -1.1498584 , -0.10724166, -0.18673094,  0.13536902, -0.48314548,
#        -0.2462334 ,  1.5298729 ,  0.918234  , -0.5951603 , -0.47480422,
#         0.644457  , -0.54783833, -1.2219504 ,  0.04287595, -1.7898796 ,
#        -0.46713504, -0.08453864, -0.31252897, -0.44335926,  0.19673504,
#        -0.7336366 , -0.60093814, -0.14845021,  1.1980057 ,  1.7614805 ,
#        -0.50775385,  0.5858582 ,  0.98286575, -0.32803226,  0.5220797 ,
#        -0.19431575,  1.0480869 , -0.5142361 , -0.7723366 ,  1.3543237 ,
#         0.62136674, -0.58610964, -0.99369526, -0.6569183 , -1.9488719 ,
#         0.11962279, -0.12092174,  1.7728466 , -0.9343597 ,  1.1233939 ,
#         0.65139073, -0.15911889,  0.60462457, -0.83112615, -0.04207532,
#        -0.3801767 ,  2.3314724 , -0.17558211, -1.2775438 , -0.8336114 ,
#        -0.44568396,  1.1692903 , -1.0057739 ,  3.0416217 , -0.81351733,
#        -0.87097514,  0.97917783,  1.7475163 , -0.40450886,  1.6972004 ,
#         1.2385358 , -0.12703598, -0.2905458 ,  0.7689107 ,  1.8534584 ,
#         1.329885  , -1.9638823 , -0.8575819 ,  1.5118443 ,  0.10758103],
#       dtype=float32)

# %%
sims
# Out:
# [('مسكره', 0.9821105599403381),
#  ('مغلق', 0.9558219313621521),
#  ('يسكرو', 0.9370615482330322),
#  ('مغلقه', 0.9370439648628235),
#  ('ومغلقه', 0.9231674671173096),
#  ('مسكرة', 0.9209417104721069),
#  ('وسكرو', 0.9123201966285706),
#  ('متوقف', 0.9093570113182068),
#  ('واقفه', 0.9088826775550842),
#  ('بسكر', 0.9079791903495789)]

# %%
from gensim.models import KeyedVectors

word_vectors = model.wv
word_vectors.save("word2vec.wordvectors")

# %%
wv = KeyedVectors.load('/Users/mac2/University/Machine Learning/new repo/ROADWATCH/Road/word2vec.wordvectors', mmap='r')

# %%
vector = wv

vector

# %%
sentences = vector
labels = tokenized_df["label_encoded"]

# %%
sentences

# %%
labels
# Out:
# 0         4
# 1         4
# 2         4
# 3         0
# 4         4
#          ..
# 303763    4
# 303764    4
# 303765    4
# 303766    0
# 303767    4
# Name: label_encoded, Length: 303768, dtype: int64

# %%
X = []
y = []

for word, label in zip(words, labels):
    if word in word_vectors:  # If word exists in the model
        X.append(word_vectors[word])  # Append the vector for the word
        y.append(label)  # Append the label
    else:
        print(f"Word '{word}' not in the vocabulary, skipping.")  # Optional warning

# Step 3: Convert to NumPy arrays
X = np.array(X)
y = np.array(y)

# Check shapes
print("Shape of X:", X.shape)  # (number_of_valid_words, vector_size)
print("Shape of y:", y.shape)  # (num
# Out:
# Word 'لࢪسول' not in the vocabulary, skipping.
# Word 'سيارة11' not in the vocabulary, skipping.
# Word 'للخارج11' not in the vocabulary, skipping.
# Word 'قࢪيب' not in the vocabulary, skipping.
# Word 'آلوتࢪ' not in the vocabulary, skipping.
# Word 'آلفࢪدوس' not in the vocabulary, skipping.
# Word 'الاࢪض' not in the vocabulary, skipping.
# Word 'السࢪاء' not in the vocabulary, skipping.
# Word 'الضࢪاء' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word '20ايلون' not in the vocabulary, skipping.
# Word '35سالك' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'بسوء' not in the vocabulary, skipping.
# Word 'صلوا_عليـﷺـه_وسلموا' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الاتجاهات5' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'النبيﷺ' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word '1بأتجاه' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'رويال_المكتبة' not in the vocabulary, skipping.
# Word 'نعمل_لأجلكم' not in the vocabulary, skipping.
# Word 'نأسف_لازعاجكم' not in the vocabulary, skipping.
# Word '3سيارات' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'عشوائي05' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word '10د' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'تحديث7' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word '2024جمعه' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word '10سيارات' not in the vocabulary, skipping.
# Word '5المغرب' not in the vocabulary, skipping.
# Word 'خط90' not in the vocabulary, skipping.
# Word 'الرقم0598263638' not in the vocabulary, skipping.
# Word 'الغرس_بزاريا' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'ب200' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'ب300' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word '10سيارات' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word '20سياره' not in the vocabulary, skipping.
# Word '17عصيره' not in the vocabulary, skipping.
# Word 'ال17' not in the vocabulary, skipping.
# Word 'ال17' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'المصير285' not in the vocabulary, skipping.
# Word 'الكافرين286' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'وال17' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'ال17' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'لل200سيارة' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'عظيماﷺ' not in the vocabulary, skipping.
# Word '100متر' not in the vocabulary, skipping.
# Word '00ص' not in the vocabulary, skipping.
# Word '00ص' not in the vocabulary, skipping.
# Word '00ص' not in the vocabulary, skipping.
# Word '00م' not in the vocabulary, skipping.
# Word '00م' not in the vocabulary, skipping.
# Word '00م' not in the vocabulary, skipping.
# Word '289من' not in the vocabulary, skipping.
# Word '5مساء' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'القدسDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word '3بفتخ' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'وﻻ' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'لdco' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'ال17' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'ال17' not in the vocabulary, skipping.
# Word '5سيارات' not in the vocabulary, skipping.
# Word 'ل4' not in the vocabulary, skipping.
# Word 'ل4' not in the vocabulary, skipping.
# Word '24ساعه' not in the vocabulary, skipping.
# Word 'العقد_مخيم' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'شويكه_دير' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word '44صباحا' not in the vocabulary, skipping.
# Word 'ائيل4' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'و10' not in the vocabulary, skipping.
# Word 'ائيل4' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'آلࢪحمـن' not in the vocabulary, skipping.
# Word 'ائيل4' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'آلࢪحمـن' not in the vocabulary, skipping.
# Word 'ائيل4' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'صلاة_الفجر' not in the vocabulary, skipping.
# Word 'ائيل4' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'جيش6' not in the vocabulary, skipping.
# Word 'المربعه18' not in the vocabulary, skipping.
# Word '40د' not in the vocabulary, skipping.
# Word 'ائيل4' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'بࢪيـد' not in the vocabulary, skipping.
# Word 'تذكيࢪ' not in the vocabulary, skipping.
# Word 'تذكيࢪ' not in the vocabulary, skipping.
# Word 'قࢪاءة' not in the vocabulary, skipping.
# Word 'سوࢪة' not in the vocabulary, skipping.
# Word 'الࢪاحلين' not in the vocabulary, skipping.
# Word 'سينيا_جفنا' not in the vocabulary, skipping.
# Word 'صلاة_الفجر' not in the vocabulary, skipping.
# Word 'سينيا_جفنا' not in the vocabulary, skipping.
# Word 'نعمل_لأجلكم' not in the vocabulary, skipping.
# Word 'نأسف_لازعاجكم' not in the vocabulary, skipping.
# Word 'ال17' not in the vocabulary, skipping.
# Word 'ائيل4' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الساعة08' not in the vocabulary, skipping.
# Word 'صلاة_الفجر' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'جيش9' not in the vocabulary, skipping.
# Word '7سيارات' not in the vocabulary, skipping.
# Word 'و10' not in the vocabulary, skipping.
# Word 'ائيل4' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'بحري7' not in the vocabulary, skipping.
# Word 'ائيل4' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'صلاة_الفجر' not in the vocabulary, skipping.
# Word 'أحبتيᥫ' not in the vocabulary, skipping.
# Word 'لحظة_ذكر' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'جندي6' not in the vocabulary, skipping.
# Word '57وسالكه' not in the vocabulary, skipping.
# Word 'وبالاتجاهين6' not in the vocabulary, skipping.
# Word 'للجيش6' not in the vocabulary, skipping.
# Word 'صلاة_الفجر' not in the vocabulary, skipping.
# Word 'آلوتࢪ' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word '45pm' not in the vocabulary, skipping.
# Word 'العماره15' not in the vocabulary, skipping.
# Word '3سالك' not in the vocabulary, skipping.
# Word 'الحاجز14' not in the vocabulary, skipping.
# Word '26طلعنا' not in the vocabulary, skipping.
# Word 'سالك14' not in the vocabulary, skipping.
# Word 'مستنفرين13' not in the vocabulary, skipping.
# Word '5دقايق' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'جيش18' not in the vocabulary, skipping.
# Word 'آلمـغࢪب' not in the vocabulary, skipping.
# Word 'لࢪسول' not in the vocabulary, skipping.
# Word 'هسا16' not in the vocabulary, skipping.
# Word 'سكندر15' not in the vocabulary, skipping.
# Word 'آلعصـࢪ' not in the vocabulary, skipping.
# Word 'آلࢪحمـن' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'طالع8' not in the vocabulary, skipping.
# Word 'الدنياᥫ' not in the vocabulary, skipping.
# Word 'الفجࢪ' not in the vocabulary, skipping.
# Word 'تࢪيح' not in the vocabulary, skipping.
# Word 'تضجࢪت' not in the vocabulary, skipping.
# Word 'الفجࢪ' not in the vocabulary, skipping.
# Word 'بالاتجاهين17' not in the vocabulary, skipping.
# Word 'لࢪسول' not in the vocabulary, skipping.
# Word 'جيش3' not in the vocabulary, skipping.
# Word 'بالاتجاهين19' not in the vocabulary, skipping.
# Word 'واقف19' not in the vocabulary, skipping.
# Word 'جيش18' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'أحوال_الطرق' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'للفجࢪ' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'ارchظووووو' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word '3ايام' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word '12ظهرآ' not in the vocabulary, skipping.
# Word 'حتى4' not in the vocabulary, skipping.
# Word '30عصرا' not in the vocabulary, skipping.
# Word 'الدنياᥫ' not in the vocabulary, skipping.
# Word 'الفجࢪ' not in the vocabulary, skipping.
# Word 'تࢪيح' not in the vocabulary, skipping.
# Word 'تضجࢪت' not in the vocabulary, skipping.
# Word 'منفࢪج' not in the vocabulary, skipping.
# Word 'أبشࢪ' not in the vocabulary, skipping.
# Word 'بخيࢪ' not in the vocabulary, skipping.
# Word 'الفاࢪج' not in the vocabulary, skipping.
# Word 'الفجࢪ' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الدنياᥫ' not in the vocabulary, skipping.
# Word 'الفجࢪ' not in the vocabulary, skipping.
# Word 'تࢪيح' not in the vocabulary, skipping.
# Word 'تضجࢪت' not in the vocabulary, skipping.
# Word 'الفجࢪ' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word '33عش' not in the vocabulary, skipping.
# Word 'الdco' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Word 'الشعائرية' not in the vocabulary, skipping.
# Word 'الشعائرية' not in the vocabulary, skipping.
# Word 'الDCO' not in the vocabulary, skipping.
# Shape of X: (303252, 100)
# Shape of y: (303252,)

# %%
import platform
print(platform.architecture())
# Out:
# ('64bit', '')

# %%
import xgboost as xgb

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# before using XGBoost i want to use DecisionTreeClassifier to compare it

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dTree_clf = DecisionTreeClassifier()

# %%
dTree_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dTree_clf.predict(X_test)

# %%
y_pred2
# Out:
# array([4, 4, 4, ..., 4, 4, 4])

# %%
from sklearn.metrics import accuracy_score, classification_report

print("Accuracy of Model::",accuracy_score(y_test,y_pred2))
# Out:
# Accuracy of Model:: 0.5819524822344232

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred2))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.21      0.02      0.03     12796
#            1       0.02      0.00      0.00      1785
#            2       0.14      0.01      0.02      7253
#            3       0.04      0.00      0.00      2747
#            4       0.59      0.97      0.74     36070
#
#     accuracy                           0.58     60651
#    macro avg       0.20      0.20      0.16     60651
# weighted avg       0.42      0.58      0.45     60651
